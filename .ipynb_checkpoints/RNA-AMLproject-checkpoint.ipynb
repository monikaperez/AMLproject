# %%
from __future__ import print_function
import os.path
import dalmatian as dm
import pandas as pd
import sys
sys.path.insert(0, '../ccle_processing/')
from CCLE_postp_function import *
sys.path.insert(0, '../JKBio/')
import datanalytics as da 
import TerraFunction as terra
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython
from taigapy import TaigaClient
tc = TaigaClient()
from wand.image import Image as WImage
import numpy as np
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from bokeh.plotting import *
from bokeh.models import HoverTool
output_notebook()
from collections import OrderedDict
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
refnamespace="broad-firecloud-ccle"
refworkspace="DepMap_hg38_RNAseq"
source="DFCI"
samplesetname="MAX_AMLproject"
gcpfolder= 'jkobject'
prefix='JK_RNA_AMLproject/'
release = samplesetname

# %%
refwm = dm.WorkspaceManager(refnamespace, refworkspace)

# %% [markdown]
# # Generate sample set from new samples

# %%
terra.UploadFromFolder(gcpfolder, prefix, refwm, samplesetname=samplesetname)
# Out:
# unrecognized file type : JK_RNA_AMLproject/._md5sum_list.txt
# unrecognized file type : JK_RNA_AMLproject/30-221016939.md5
# unrecognized file type : JK_RNA_AMLproject/md5sum_list.txt
# Successfully imported 30 participants.
# /home/jeremie/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Successfully imported 30 samples.
# Sample set "MAX_AMLproject" (30 samples) successfully updated.

# %% [markdown]
# # run the pipeline

# %% [markdown]
# ### if submitted as bams

# %%
samtofastq = refwm.get_config("samtofastq_v1-0_BETA_cfg")
samtofastq
# Out:
# {'deleted': False,
#  'inputs': {'samtofastq_workflow.samtofastq.prefix': 'this.name',
#   'samtofastq_workflow.samtofastq.disk_space': '50',
#   'samtofastq_workflow.samtofastq.num_threads': '1',
#   'samtofastq_workflow.samtofastq.memory': '3',
#   'samtofastq_workflow.samtofastq.num_preempt': '5',
#   'samtofastq_workflow.samtofastq.input_bam_cram': 'this.WES_bam'},
#  'methodConfigVersion': 2,
#  'methodRepoMethod': {'methodName': 'samtofastq_v1-0_BETA',
#   'methodVersion': 5,
#   'methodNamespace': 'broadinstitute_gtex',
#   'methodUri': 'agora://broadinstitute_gtex/samtofastq_v1-0_BETA/5',
#   'sourceRepo': 'agora'},
#  'name': 'samtofastq_v1-0_BETA_cfg',
#  'namespace': 'broadinstitute_gtex',
#  'outputs': {'samtofastq_workflow.samtofastq.fastq1': 'this.fastq1',
#   'samtofastq_workflow.samtofastq.fastq2': 'this.fastq2'},
#  'prerequisites': {},
#  'rootEntityType': 'sample'}

# %%
samtofastq['samtofastq_workflow.samtofastq.input_bam_cram']= 'this.WES_bam'
refwm.update_config(samtofastq)
submission_id = refwm.create_submission(samtofastq['name'], samplesetname,'sample_set',expression='this.samples')
# Out:
# Successfully created submission b09e54b1-4280-440a-9dd3-6926ca793056.
# 'b09e54b1-4280-440a-9dd3-6926ca793056'

# %%
wait_for_submission(refwm, submission_id1)

# %% [markdown]
# ### else as fastqs

# %%
star = refwm.get_config("star_v1-0_BETA_cfg")
star
# Out:
# {'deleted': False,
#  'inputs': {'star_workflow.star.outSAMattrRGline': '"ID:rg1 SM:sm1"',
#   'star_workflow.star.num_threads': '8',
#   'star_workflow.star.alignSoftClipAtReferenceEnds': '"Yes"',
#   'star_workflow.star.alignMatesGapMax': '1000000',
#   'star_workflow.star.outFilterType': '"BySJout"',
#   'star_workflow.star.prefix': 'this.name',
#   'star_workflow.star.num_preempt': '5',
#   'star_workflow.star.alignSJoverhangMin': '8',
#   'star_workflow.star.chimOutJunctionFormat': '1',
#   'star_workflow.star.memory': '52',
#   'star_workflow.star.fastq2': 'this.fastq2',
#   'star_workflow.star.outFilterMismatchNoverLmax': '0.1',
#   'star_workflow.star.alignIntronMax': '1000000',
#   'star_workflow.star.star_index': 'workspace.star_index',
#   'star_workflow.star.outSAMattributes': '"NH HI AS nM NM ch"',
#   'star_workflow.star.outSAMstrandField': '"intronMotif"',
#   'star_workflow.star.limitSjdbInsertNsj': '1200000',
#   'star_workflow.star.chimSegmentMin': '15',
#   'star_workflow.star.chimJunctionOverhangMin': '15',
#   'star_workflow.star.fastq1': 'this.fastq1',
#   'star_workflow.star.chimOutType': '"Junctions WithinBAM SoftClip"',
#   'star_workflow.star.quantMode': '"TranscriptomeSAM GeneCounts"',
#   'star_workflow.star.disk_space': '250',
#   'star_workflow.star.outFilterScoreMinOverLread': '0.33',
#   'star_workflow.star.chimMainSegmentMultNmax': '1',
#   'star_workflow.star.alignIntronMin': '20',
#   'star_workflow.star.outFilterMismatchNmax': '999',
#   'star_workflow.star.outFilterMultimapNmax': '20',
#   'star_workflow.star.outFilterMatchNminOverLread': '0.33',
#   'star_workflow.star.alignSJDBoverhangMin': '1',
#   'star_workflow.star.outFilterIntronMotifs': '"None"'},
#  'methodConfigVersion': 4,
#  'methodRepoMethod': {'methodName': 'star_v1-0_BETA',
#   'methodVersion': 7,
#   'methodNamespace': 'broadinstitute_gtex',
#   'methodUri': 'agora://broadinstitute_gtex/star_v1-0_BETA/7',
#   'sourceRepo': 'agora'},
#  'name': 'star_v1-0_BETA_cfg',
#  'namespace': 'broadinstitute_gtex',
#  'outputs': {'star_workflow.star.chimeric_bam_file': 'this.star_chimeric_bam_file',
#   'star_workflow.star.junctions': 'this.star_junctions',
#   'star_workflow.star.transcriptome_bam': 'this.star_transcriptome_bam',
#   'star_workflow.star.chimeric_junctions': 'this.star_chimeric_junctions',
#   'star_workflow.star.junctions_pass1': 'this.star_junctions_pass1',
#   'star_workflow.star.bam_file': 'this.star_bam_file',
#   'star_workflow.star.read_counts': 'this.star_read_counts',
#   'star_workflow.star.chimeric_bam_index': 'this.star_chimeric_bam_index',
#   'star_workflow.star.bam_index': 'this.star_bam_index',
#   'star_workflow.star.logs': 'this.star_logs'},
#  'prerequisites': {},
#  'rootEntityType': 'sample'}

# %%
refwm.update_config(star)
submission_id = refwm.create_submission(star['name'], samplesetname,'sample_set',expression='this.samples')
# Out:
# Successfully updated configuration broadinstitute_gtex/star_v1-0_BETA_cfg
# Successfully created submission b6b72f97-c1d1-44d3-9773-270e80e9eb91.

# %%
terra.wait_for_submission(refwm, submission_id)

# %%
rsem = refwm.get_config("rsem_v1-0_BETA_cfg")
rsem
# Out:
# {'deleted': False,
#  'inputs': {'rsem_workflow.rsem.transcriptome_bam': 'this.star_transcriptome_bam',
#   'rsem_workflow.rsem.max_frag_len': '1000',
#   'rsem_workflow.rsem.memory': '50',
#   'rsem_workflow.rsem.prefix': 'this.name',
#   'rsem_workflow.rsem.disk_space': '100',
#   'rsem_workflow.rsem.estimate_rspd': '"true"',
#   'rsem_workflow.rsem.is_stranded': '"false"',
#   'rsem_workflow.rsem.rsem_reference': 'workspace.rsem_reference',
#   'rsem_workflow.rsem.num_preempt': '5',
#   'rsem_workflow.rsem.num_threads': '2'},
#  'methodConfigVersion': 3,
#  'methodRepoMethod': {'methodName': 'rsem_v1-0_BETA',
#   'methodVersion': 4,
#   'methodNamespace': 'broadinstitute_gtex',
#   'methodUri': 'agora://broadinstitute_gtex/rsem_v1-0_BETA/4',
#   'sourceRepo': 'agora'},
#  'name': 'rsem_v1-0_BETA_cfg',
#  'namespace': 'broadinstitute_gtex',
#  'outputs': {'rsem_workflow.rsem.genes': 'this.rsem_genes',
#   'rsem_workflow.rsem.isoforms': 'this.rsem_isoforms'},
#  'prerequisites': {},
#  'rootEntityType': 'sample'}

# %%
refwm.update_config(rsem)
submission_id1 = refwm.create_submission(rsem['name'], samplesetname,'sample_set',expression='this.samples')
# Out:
# Successfully updated configuration broadinstitute_gtex/rsem_v1-0_BETA_cfg
# Successfully created submission c9d71d2b-1351-4923-8bbf-e7b7a758f6c8.

# %%
wait_for_submission(refwm, submission_id1)

# %%
fusion = refwm.get_config("hg38_STAR_fusion")
fusion
# Out:
# {'deleted': False,
#  'inputs': {'trinity_cleaned.StarFusion.ref_genome_fa_star_idx_files': 'workspace.hg38_star_fusion_ctat_star_index_files',
#   'trinity_cleaned.samtofastq.num_preempt': '4',
#   'trinity_cleaned.StarFusion.memory': '64',
#   'trinity_cleaned.remove_intermediate_files': 'true',
#   'trinity_cleaned.StarFusion.num_preempt': '2',
#   'trinity_cleaned.StarFusion.ctat_genome_lib_build_dir_files': 'workspace.hg38_star_fusion_ctat_files',
#   'trinity_cleaned.prefix': 'this.name',
#   'trinity_cleaned.StarFusion.num_threads': '8',
#   'trinity_cleaned.samtofastq.memory': '16',
#   'trinity_cleaned.samtofastq.num_threads': '1',
#   'trinity_cleaned.samtofastq.input_bam': 'this.WES_bam',
#   'trinity_cleaned.StarFusion.disk_space': '500',
#   'trinity_cleaned.StarFusion.docker': '"trinityctat/ctatfusion:1.6.0"',
#   'trinity_cleaned.samtofastq.disk_space': '100'},
#  'methodConfigVersion': 7,
#  'methodRepoMethod': {'methodName': 'STAR_fusion',
#   'methodVersion': 14,
#   'methodNamespace': 'gkugener',
#   'methodUri': 'agora://gkugener/STAR_fusion/14',
#   'sourceRepo': 'agora'},
#  'name': 'hg38_STAR_fusion',
#  'namespace': 'gkugener',
#  'outputs': {'trinity_cleaned.samtofastq.fastq1': 'this.fastq1',
#   'trinity_cleaned.samtofastq.fastq2': 'this.fastq2',
#   'trinity_cleaned.StarFusion.fusion_predictions': 'this.fusion_predictions',
#   'trinity_cleaned.StarFusion.fusion_predictions_abridged': 'this.fusion_predictions_abridged'},
#  'prerequisites': {},
#  'rootEntityType': 'sample'}

# %%
fusion['inputs']['trinity_cleaned.samtofastq.input_bam'] = 'this.WES_bam'
refwm.update_config(fusion)
submission_id2 = refwm.create_submission(fusion['name'], samplesetname,'sample_set',expression='this.samples')
# Out:
# Successfully updated configuration gkugener/hg38_STAR_fusion
# Successfully created submission 31bb3c99-40c0-43fa-aa80-3494166b9d22.

# %%
wait_for_submission(refwm, submission_id1)

# %%
aggregate = refwm.get_config("rsem_aggregate_results_v1-0_BETA_cfg")
aggregate
# Out:
# {'deleted': False,
#  'inputs': {'rsem_aggregate_results_workflow.rsem_aggregate_results.rsem_genes': 'this.samples.rsem_genes',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.num_preempt': '5',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.prefix': 'this.name',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.num_threads': '2',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.rsem_isoforms': 'this.samples.rsem_isoforms',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.disk_space': '50',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.memory': '13'},
#  'methodConfigVersion': 3,
#  'methodRepoMethod': {'methodName': 'rsem_aggregate_results_v1-0_BETA',
#   'methodVersion': 3,
#   'methodNamespace': 'broadinstitute_gtex',
#   'methodUri': 'agora://broadinstitute_gtex/rsem_aggregate_results_v1-0_BETA/3',
#   'sourceRepo': 'agora'},
#  'name': 'rsem_aggregate_results_v1-0_BETA_cfg',
#  'namespace': 'broadinstitute_gtex',
#  'outputs': {'rsem_aggregate_results_workflow.rsem_aggregate_results.genes_expected_count': 'this.rsem_genes_expected_count',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.transcripts_tpm': 'this.rsem_transcripts_tpm',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.transcripts_expected_count': 'this.rsem_transcripts_expected_count',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.genes_tpm': 'this.rsem_genes_tpm',
#   'rsem_aggregate_results_workflow.rsem_aggregate_results.transcripts_isopct': 'this.rsem_transcripts_isopct'},
#  'prerequisites': {},
#  'rootEntityType': 'sample_set'}

# %%
submission_id1 = refwm.create_submission(aggregate['name'], samplesetname)
# Out:
# Successfully created submission 326e42a6-1778-459e-9a95-e5dbc8c1bb67.

# %% [markdown]
# ## Expression post processing

# %%
terra.wait_for_submission(refwm, submission_id1)

# %%
# %%R
# release <- '19Q3interim'

# %%
# %%R
# source('../JKBio/gkugener/RScripts/load_libraries_and_annotations.R')
# Out:
# 2019-06-24 10:21:49::WARNING  R[write to console]:
# Attaching package: ‘dplyr’
#
#
# 2019-06-24 10:21:49::WARNING  R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# 2019-06-24 10:21:49::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# 2019-06-24 10:21:49::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: ✔ ggplot2 3.1.1     ✔ readr   1.3.1
# ✔ tibble  2.1.3     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ ggplot2 3.1.1     ✔ forcats 0.4.0
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()   masks plyr::arrange()
# ✖ purrr::compact()   masks plyr::compact()
# ✖ dplyr::count()     masks plyr::count()
# ✖ dplyr::failwith()  masks plyr::failwith()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::id()        masks plyr::id()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::mutate()    masks plyr::mutate()
# ✖ dplyr::rename()    masks plyr::rename()
# ✖ dplyr::summarise() masks plyr::summarise()
# ✖ dplyr::summarize() masks plyr::summarize()
#
# 2019-06-24 10:21:50::WARNING  R[write to console]:
# Attaching package: ‘magrittr’
#
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# 2019-06-24 10:21:50::WARNING  R[write to console]:
# Attaching package: ‘reshape2’
#
#
# 2019-06-24 10:21:50::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Loading required package: lpSolve
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘zoo’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘scales’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘rlang’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:magrittr’:
#
#     set_names
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following objects are masked from ‘package:purrr’:
#
#     %@%, as_function, flatten, flatten_chr, flatten_dbl, flatten_int,
#     flatten_lgl, flatten_raw, invoke, list_along, modify, prepend,
#     splice
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Loading required package: SnowballC
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘gridExtra’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘ggridges’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     scale_discrete_manual
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘GGally’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     nasa
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘plotly’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, mutate, rename, summarise
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Loading required package: grid
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Loading required package: futile.logger
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Registering fonts with R
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘cowplot’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:ggthemes’:
#
#     theme_map
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘data.table’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:rlang’:
#
#     :=
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following objects are masked from ‘package:reshape2’:
#
#     dcast, melt
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]:
# Attaching package: ‘DT’
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: The following object is masked from ‘package:networkD3’:
#
#     JS
#
#
# 2019-06-24 10:21:51::WARNING  R[write to console]: Loading required package: stats4
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: Loading required package: BiocGenerics
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: Loading required package: parallel
#
# 2019-06-24 10:21:52::WARNING  R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# 2019-06-24 10:21:52::WARNING  R[write to console]: Loading required package: S4Vectors
#
# 2019-06-24 10:21:53::WARNING  R[write to console]:
# Attaching package: ‘S4Vectors’
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following object is masked from ‘package:plotly’:
#
#     rename
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following object is masked from ‘package:plyr’:
#
#     rename
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# 2019-06-24 10:21:53::WARNING  R[write to console]: Loading required package: IRanges
#
# 2019-06-24 10:21:54::WARNING  R[write to console]:
# Attaching package: ‘IRanges’
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: The following object is masked from ‘package:plotly’:
#
#     slice
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: The following object is masked from ‘package:plyr’:
#
#     desc
#
#
# 2019-06-24 10:21:54::WARNING  R[write to console]: Loading required package: GenomeInfoDb
#
# 2019-06-24 10:21:55::WARNING  R[write to console]: Loading required package: Biobase
#
# 2019-06-24 10:21:55::WARNING  R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 2019-06-24 10:21:55::WARNING  R[write to console]:
# Attaching package: ‘Biobase’
#
#
# 2019-06-24 10:21:55::WARNING  R[write to console]: The following object is masked from ‘package:rlang’:
#
#     exprs
#
#
# 2019-06-24 10:21:55::WARNING  R[write to console]: Loading required package: annotate
#
# 2019-06-24 10:21:55::WARNING  R[write to console]: Loading required package: AnnotationDbi
#
# 2019-06-24 10:21:56::WARNING  R[write to console]:
# Attaching package: ‘AnnotationDbi’
#
#
# 2019-06-24 10:21:56::WARNING  R[write to console]: The following object is masked from ‘package:plotly’:
#
#     select
#
#
# 2019-06-24 10:21:56::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# 2019-06-24 10:21:56::WARNING  R[write to console]: Loading required package: XML
#
# 2019-06-24 10:21:56::WARNING  R[write to console]:
# Attaching package: ‘XML’
#
#
# 2019-06-24 10:21:56::WARNING  R[write to console]: The following object is masked from ‘package:tools’:
#
#     toHTML
#
#
# 2019-06-24 10:21:56::WARNING  R[write to console]: Loading required package: graph
#
# 2019-06-24 10:21:57::WARNING  R[write to console]:
# Attaching package: ‘graph’
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:XML’:
#
#     addNode
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:stringr’:
#
#     boundary
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:plyr’:
#
#     join
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: Loading required package: RCurl
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: Loading required package: bitops
#
# 2019-06-24 10:21:57::WARNING  R[write to console]:
# Attaching package: ‘RCurl’
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     complete
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: Loading required package: httr
#
# 2019-06-24 10:21:57::WARNING  R[write to console]:
# Attaching package: ‘httr’
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     content
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:plotly’:
#
#     config
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: Package 'mclust' version 5.4.3
# Type 'citation("mclust")' for citing this R package in publications.
#
# 2019-06-24 10:21:57::WARNING  R[write to console]:
# Attaching package: ‘mclust’
#
#
# 2019-06-24 10:21:57::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     map
# Fetching https://cds.team/taiga/api/dataset/msigdb-gene-set-collections-8453/2
# Status 200
# 2019-06-24 10:21:58::WARNING  R[write to console]: No encoding supplied: defaulting to UTF-8.
# loading cached data version from  ~/.taiga/msigdb-gene-set-collections-8453_2.toc
# Checking for cached file ~/.taiga/495ea37b8d744a428946a5628c5fe7ce_gsc-data.raw

# %%
# %%R
# source('CCLE_postp_function.R')
# release <- "MAX_AMLproject"
# Out:
# 2019-06-24 10:21:59::WARNING  R[write to console]:

# %%
res = refwm.get_sample_sets().loc[samplesetname]
rsem_genes_expected_count = res['rsem_genes_expected_count']
rsem_genes_tpm = res['rsem_genes_tpm']
rsem_transcripts_tpm = res['rsem_transcripts_tpm']
! gsutil cp $rsem_genes_expected_count "temp/expression/expectedcount.txt.gz" & gsutil cp $rsem_genes_tpm "temp/expression/genestpm.txt.gz" & gsutil cp $rsem_transcripts_tpm "temp/expression/transcripttpm.txt.gz"
# Out:
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/326e42a6-1778-459e-9a95-e5dbc8c1bb67/rsem_aggregate_results_workflow/fc5be1ee-8888-4036-8aaf-df5770b4fefa/call-rsem_aggregate_results/MAX_AMLproject.rsem_genes_expected_count.txt.gz...
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/326e42a6-1778-459e-9a95-e5dbc8c1bb67/rsem_aggregate_results_workflow/fc5be1ee-8888-4036-8aaf-df5770b4fefa/call-rsem_aggregate_results/MAX_AMLproject.rsem_genes_tpm.txt.gz...
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/326e42a6-1778-459e-9a95-e5dbc8c1bb67/rsem_aggregate_results_workflow/fc5be1ee-8888-4036-8aaf-df5770b4fefa/call-rsem_aggregate_results/MAX_AMLproject.rsem_transcripts_tpm.txt.gz...
# / [1 files][  2.4 MiB/  2.4 MiB]
# Operation completed over 1 objects/2.4 MiB.
# / [1 files][  2.2 MiB/  2.2 MiB]
# Operation completed over 1 objects/2.2 MiB.
# / [1 files][  5.8 MiB/  5.8 MiB]
# Operation completed over 1 objects/5.8 MiB.

# %%
# %%R
# # These files are downloaded from FireCloud/Terra
# download_paths <- list(
#   tpm_genes='temp/expression/genestpm.txt.gz',
#   tpm_transcripts='temp/expression/transcripttpm.txt.gz',
#   counts_genes='temp/expression/expectedcount.txt.gz')

# %%
# %%R
# tpm_transcripts = readTranscripts(download_paths$tpm_transcripts)
# counts_genes = readCounts(download_paths$counts_genes)
# tpm_genes = readTPM(download_paths$tpm_genes)
# Out:
# 2019-06-24 10:24:15::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   transcript_id = col_character(),
#   gene_id = col_character()
# )
#
# 2019-06-24 10:24:15::WARNING  R[write to console]: See spec(...) for full column specifications.
#
# 2019-06-24 10:24:17::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character()
# )
#
# 2019-06-24 10:24:17::WARNING  R[write to console]: See spec(...) for full column specifications.
#
# 2019-06-24 10:24:18::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character()
# )
#
# 2019-06-24 10:24:18::WARNING  R[write to console]: See spec(...) for full column specifications.

# %%
# %%R
# counts_genes
# Out:
# # A tibble: 58,813 x 32
#    gene_id `transcript_id(… `0h-A-RNA` `0h-B-RNA` `0h-C-RNA` `1A-24h-RNA`
#    <chr>   <chr>                 <dbl>      <dbl>      <dbl>        <dbl>
#  1 ENSG00… ENST00000373020…        0          1          1            0
#  2 ENSG00… ENST00000373031…        0          0          0            0
#  3 ENSG00… ENST00000371582…      319        257        338          261
#  4 ENSG00… ENST00000367770…       97.4       79.5       88.8         99.2
#  5 ENSG00… ENST00000286031…      192.       144.       200.         137.
#  6 ENSG00… ENST00000374003…      476        430        497          478
#  7 ENSG00… ENST00000359637…        1          3          1            6
#  8 ENSG00… ENST00000002165…      577.       504.       661.         680.
#  9 ENSG00… ENST00000229416…       61         77         94           76
# 10 ENSG00… ENST00000341376…      434        436        524          472
# # … with 58,803 more rows, and 26 more variables: `1A-8h-RNA` <dbl>,
# #   `1B-24h-RNA` <dbl>, `1B-8h-RNA` <dbl>, `1C-24h-RNA` <dbl>,
# #   `1C-8h-RNA` <dbl>, `2A-16h-RNA` <dbl>, `2A-24h-RNA` <dbl>,
# #   `2A-2h-RNA` <dbl>, `2A-4h-RNA` <dbl>, `2A-8h-RNA` <dbl>,
# #   `2B-16h-RNA` <dbl>, `2B-24h-RNA` <dbl>, `2B-2h-RNA` <dbl>,
# #   `2B-4h-RNA` <dbl>, `2B-8h-RNA` <dbl>, `2C-16h-RNA` <dbl>,
# #   `2C-24h-RNA` <dbl>, `2C-2h-RNA` <dbl>, `2C-4h-RNA` <dbl>,
# #   `2C-8h-RNA` <dbl>, `3A-8h-RNA` <dbl>, `3B-8h-RNA` <dbl>, `3C-8h-RNA` <dbl>,
# #   `4A-8h-RNA` <dbl>, `4B-8h-RNA` <dbl>, `4C-8h-RNA` <dbl>

# %% [markdown]
# ### data exploration and QC

# %%
# %%R
# # Quick QC
# # We are looking for samples with a worrying amount of zeros
# zero_threshold <- 39000
#
# number_zeros <- apply(tpm_genes[,3:ncol(tpm_genes)], 2, FUN = function(x) length(x[x == 0]))
# nzdf <- data.frame(CL=names(number_zeros), nz=number_zeros, stringsAsFactors = F)

# %%
# %%R
# # Plot of the samples that fail
# plot <- ggplot(nzdf, aes(nz)) +
#   geom_histogram(bins = 100, color='black', fill='white') +
#   geom_vline(xintercept = zero_threshold, linetype=2) +
#   geom_label_repel(data = nzdf %>% filter(nz > zero_threshold), aes(x=nz, y=0, label=CL), size=5, fill=rgb(1,1,1,0.5))
#
# ggsave(plot, filename ='temp/ggplot.pdf', width=20, height = 20)

# %%
img = WImage(filename='temp/ggplot.pdf')
img
# Out:
# <wand.image.Image: 26a46d3 'PDF' (1440x1440)>

# %%
# %%R
# pass <- number_zeros[order(-number_zeros)] %>% .[. < zero_threshold] %>% names()
#
# # These samples failed
# failed <- setdiff(colnames(tpm_genes), pass) %>% .[!(. %in% c('gene_id', 'transcript_id(s)'))]
#
# counts_genes %<>% dplyr::select(c("gene_id","transcript_id(s)", pass))
# tpm_genes %<>% dplyr::select(c("gene_id","transcript_id(s)", pass))
# tpm_transcripts %<>% dplyr::select("transcript_id", "gene_id", pass)

# %%
# %%R
# tpm_genes
# Out:
# # A tibble: 58,813 x 32
#    gene_id `transcript_id(… `0h-A-RNA` `0h-B-RNA` `0h-C-RNA` `1A-24h-RNA`
#    <chr>   <chr>                 <dbl>      <dbl>      <dbl>        <dbl>
#  1 ENSG00… ENST00000373020…       0          0.26       0.07         0
#  2 ENSG00… ENST00000373031…       0          0          0            0
#  3 ENSG00… ENST00000371582…      49.8       46.6       51.2         42.4
#  4 ENSG00… ENST00000367770…       2.94       2.76       2.89         3.46
#  5 ENSG00… ENST00000286031…      12.4       10.8       13.7          8.13
#  6 ENSG00… ENST00000374003…      28.6       34.0       31.4         34.3
#  7 ENSG00… ENST00000359637…       0.09       0.21       0.11         0.68
#  8 ENSG00… ENST00000002165…      43.3       54.3       49.6         65.8
#  9 ENSG00… ENST00000229416…       2.51       4.9        3.62         3.17
# 10 ENSG00… ENST00000341376…      19.8       27.6       24.9         24.2
# # … with 58,803 more rows, and 26 more variables: `1A-8h-RNA` <dbl>,
# #   `1B-24h-RNA` <dbl>, `1B-8h-RNA` <dbl>, `1C-24h-RNA` <dbl>,
# #   `1C-8h-RNA` <dbl>, `2A-16h-RNA` <dbl>, `2A-24h-RNA` <dbl>,
# #   `2A-2h-RNA` <dbl>, `2A-4h-RNA` <dbl>, `2A-8h-RNA` <dbl>,
# #   `2B-16h-RNA` <dbl>, `2B-24h-RNA` <dbl>, `2B-2h-RNA` <dbl>,
# #   `2B-4h-RNA` <dbl>, `2B-8h-RNA` <dbl>, `2C-16h-RNA` <dbl>,
# #   `2C-24h-RNA` <dbl>, `2C-2h-RNA` <dbl>, `2C-4h-RNA` <dbl>,
# #   `2C-8h-RNA` <dbl>, `3A-8h-RNA` <dbl>, `3B-8h-RNA` <dbl>, `3C-8h-RNA` <dbl>,
# #   `4A-8h-RNA` <dbl>, `4B-8h-RNA` <dbl>, `4C-8h-RNA` <dbl>

# %%
# %%R
# failed
# Out:
#  [1] "0h-A-RNA"   "0h-B-RNA"   "0h-C-RNA"   "1A-24h-RNA" "1A-8h-RNA"
#  [6] "1B-24h-RNA" "1B-8h-RNA"  "1C-24h-RNA" "1C-8h-RNA"  "2A-16h-RNA"
# [11] "2A-24h-RNA" "2A-2h-RNA"  "2A-4h-RNA"  "2B-16h-RNA" "2B-24h-RNA"
# [16] "2B-2h-RNA"  "2B-4h-RNA"  "2B-8h-RNA"  "2C-24h-RNA" "2C-2h-RNA"
# [21] "2C-4h-RNA"  "2C-8h-RNA"  "3A-8h-RNA"  "3B-8h-RNA"  "3C-8h-RNA"
# [26] "4A-8h-RNA"  "4B-8h-RNA"  "4C-8h-RNA"

# %% [markdown]
# ## Save files for taiga

# %%
# %%R
# write.table(
#   counts_genes,
#   file = paste0('temp/expression.', release,'.counts.tsv'),
#   sep = '\t', row.names = F, quote = F)
# write.table(
#   tpm_genes,
#   file = paste0('temp/expression.', release,'.tpm.tsv'),
#   sep = '\t', row.names = F, quote = F)
# write.table(
#   tpm_transcripts,
#   file = paste0('temp/expression.', release,'.transcripts.tsv'),
#   sep = '\t', row.names = F, quote = F)

# %% [markdown]
# # Validation

# %%
counts_genes = pd.read_csv('../AMLproject/data/expression.'+ release + '.counts.tsv', sep='\t')
tpm_genes = pd.read_csv('../AMLproject/data/expression.'+ release + '.tpm.tsv', sep='\t')
tpm_transcripts = pd.read_csv('../AMLproject/data/expression.'+ release + '.transcripts.tsv', sep='\t')

# %%
# similarity accross time:
counts_genes.shape
# Out:
# (58813, 32)

# %% [markdown]
# ## solving the problem of amount of genes set to zero

# %% [markdown]
# ### verifying the data

# %%
np.count_nonzero(tpm_genes[tpm_genes.columns[2:]].values)
# Out:
# 580710

# %%
(tpm_genes[tpm_genes.columns[2:]].shape[1]*tpm_genes[tpm_genes.columns[2:]].shape[0] - np.count_nonzero(tpm_genes[tpm_genes.columns[2:]].values))/len(tpm_genes.columns[2:])
# Out:
# 39456.0

# %%
val = counts_genes[counts_genes.columns[2:]].values

# %%
val.sum(0).mean()
# Out:
# 8966453.256333333

# %%
val.mean(0).mean()
# Out:
# 152.4569951598003

# %%
(val.sum(0)/(val!=0).sum(0)).mean()
# Out:
# 462.5116456629752

# %%
import math
math.sqrt(val.var(0).mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d4d1e6aa8faa> in <module>
#       1 import math
# ----> 2 math.sqrt(val.var(0).mean())
#
# NameError: name 'val' is not defined

# %%
new1 = set(counts_genes.columns.values.tolist())
new2 = set(tpm_genes.columns.values.tolist())
new3 = set(tpm_transcripts.columns.values.tolist())
print(len(new1), len(new1 & new2 & new3))
# Out:
# 32 31

# %%
np.count_nonzero(tpm_genes.values,0)
# Out:
# array([58813, 58813, 19084, 18871, 19260, 19091, 19154, 19287, 19604,
#        17977, 19499, 19220, 19356, 19578, 19495, 19997, 19577, 19336,
#        19377, 19450, 19420, 19849, 19521, 19209, 19628, 19537, 19166,
#        19031, 19448, 19452, 19633, 19603])

# %% [markdown]
# ## looking at previous information on cell line
#
# - compare to CCLE rna data (MV411?)
# - overlap
# - spot check a few genes (are they all weird?)
# - if not sure, do GSEA on non overlapping set for each

# %%
prev = tc.get(name='depmap-expression-87f8', version=7, file='DM19Q2.tpm')

# %%
np.count_nonzero(prev.values[2:])/1288
# Out:
# 26825.079192546586

# %%
np.count_nonzero(prev["ACH-000045"].values)
# Out:
# 26008

# %%
# genes that are expressed on MV411 ccle version
CCLEgenes = set(prev["gene_id"].values[np.where(prev["ACH-000045"].values!=0)])

# %%
overlap = set(np.where(val[:,0]!=0)[0])
for i in range(1, val.shape[1]):
    overlap = overlap & set(np.where(val[:,i]!=0)[0])

# %%
len(overlap)
# Out:
# 13883

# %%
# genes that are expressed in all version of the AML rna seq data
AMLgenes = set(counts_genes["gene_id"].values[list(overlap)])

# %%
len(AMLgenes&CCLEgenes)
# Out:
# 13874

# %%
nonoverlapping = CCLEgenes - AMLgenes

# %%
nonoverlapping
# Out:
# {'ENSG00000159712.10',
#  'ENSG00000231234.2',
#  'ENSG00000137225.12',
#  'ENSG00000223635.1',
#  'ENSG00000271743.1',
#  'ENSG00000267122.1',
#  'ENSG00000239470.3',
#  'ENSG00000215223.3',
#  'ENSG00000181045.14',
#  'ENSG00000259726.1',
#  'ENSG00000260466.1',
#  'ENSG00000237437.1',
#  'ENSG00000234043.3',
#  'ENSG00000237276.8',
#  'ENSG00000275880.1',
#  'ENSG00000285887.1',
#  'ENSG00000135898.9',
#  'ENSG00000273402.1',
#  'ENSG00000285444.1',
#  'ENSG00000261451.1',
#  'ENSG00000213467.4',
#  'ENSG00000254459.1',
#  'ENSG00000274191.1',
#  'ENSG00000272772.1',
#  'ENSG00000102243.12',
#  'ENSG00000214787.9',
#  'ENSG00000225948.2',
#  'ENSG00000277957.1',
#  'ENSG00000263164.1',
#  'ENSG00000253821.1',
#  'ENSG00000266128.2',
#  'ENSG00000274667.1',
#  'ENSG00000184293.7',
#  'ENSG00000226205.1',
#  'ENSG00000078053.16',
#  'ENSG00000187955.11',
#  'ENSG00000224839.1',
#  'ENSG00000081148.11',
#  'ENSG00000254973.1',
#  'ENSG00000251537.4',
#  'ENSG00000124159.15',
#  'ENSG00000170153.10',
#  'ENSG00000267127.7',
#  'ENSG00000269072.1',
#  'ENSG00000258967.1',
#  'ENSG00000218418.2',
#  'ENSG00000267457.1',
#  'ENSG00000229807.11',
#  'ENSG00000285253.1',
#  'ENSG00000228288.6',
#  'ENSG00000255158.1',
#  'ENSG00000242590.1',
#  'ENSG00000218896.1',
#  'ENSG00000284735.1',
#  'ENSG00000228043.5',
#  'ENSG00000253218.1',
#  'ENSG00000206075.13',
#  'ENSG00000233186.2',
#  'ENSG00000255692.1',
#  'ENSG00000188536.13',
#  'ENSG00000239617.1',
#  'ENSG00000267243.6',
#  'ENSG00000215159.3',
#  'ENSG00000086548.8',
#  'ENSG00000140835.9',
#  'ENSG00000274031.1',
#  'ENSG00000233846.2',
#  'ENSG00000228705.1',
#  'ENSG00000219487.2',
#  'ENSG00000240823.3',
#  'ENSG00000238246.1',
#  'ENSG00000186529.15',
#  'ENSG00000231203.1',
#  'ENSG00000121905.9',
#  'ENSG00000268154.2',
#  'ENSG00000273824.1',
#  'ENSG00000165457.13',
#  'ENSG00000226553.1',
#  'ENSG00000225246.1',
#  'ENSG00000180389.7',
#  'ENSG00000186912.6',
#  'ENSG00000275582.1',
#  'ENSG00000260953.1',
#  'ENSG00000268889.1',
#  'ENSG00000187123.14',
#  'ENSG00000213522.4',
#  'ENSG00000183833.16',
#  'ENSG00000264028.2',
#  'ENSG00000164949.7',
#  'ENSG00000205108.5',
#  'ENSG00000241889.1',
#  'ENSG00000234676.1',
#  'ENSG00000150760.12',
#  'ENSG00000227203.3',
#  'ENSG00000104332.11',
#  'ENSG00000278709.1',
#  'ENSG00000175170.14',
#  'ENSG00000285625.1',
#  'ENSG00000279853.1',
#  'ENSG00000255185.5',
#  'ENSG00000271788.1',
#  'ENSG00000251411.1',
#  'ENSG00000277579.1',
#  'ENSG00000175985.9',
#  'ENSG00000277999.1',
#  'ENSG00000266456.1',
#  'ENSG00000271949.1',
#  'ENSG00000259347.6',
#  'ENSG00000244381.1',
#  'ENSG00000282989.1',
#  'ENSG00000244192.1',
#  'ENSG00000248578.1',
#  'ENSG00000213252.3',
#  'ENSG00000279361.1',
#  'ENSG00000267535.1',
#  'ENSG00000285338.1',
#  'ENSG00000142621.19',
#  'ENSG00000222630.2',
#  'ENSG00000261701.7',
#  'ENSG00000271032.1',
#  'ENSG00000185483.11',
#  'ENSG00000139292.12',
#  'ENSG00000236060.2',
#  'ENSG00000224273.2',
#  'ENSG00000143318.12',
#  'ENSG00000214244.4',
#  'ENSG00000271401.1',
#  'ENSG00000273183.1',
#  'ENSG00000118596.11',
#  'ENSG00000213055.3',
#  'ENSG00000135973.2',
#  'ENSG00000241061.3',
#  'ENSG00000253651.1',
#  'ENSG00000224747.1',
#  'ENSG00000168807.16',
#  'ENSG00000276150.1',
#  'ENSG00000274215.1',
#  'ENSG00000229081.1',
#  'ENSG00000226856.6',
#  'ENSG00000259342.1',
#  'ENSG00000250107.1',
#  'ENSG00000224713.4',
#  'ENSG00000272420.1',
#  'ENSG00000249175.1',
#  'ENSG00000179111.8',
#  'ENSG00000268866.1',
#  'ENSG00000163157.14',
#  'ENSG00000183034.12',
#  'ENSG00000250254.1',
#  'ENSG00000176349.11',
#  'ENSG00000265142.8',
#  'ENSG00000261135.1',
#  'ENSG00000254676.1',
#  'ENSG00000271581.1',
#  'ENSG00000256705.3',
#  'ENSG00000213312.3',
#  'ENSG00000251655.6',
#  'ENSG00000237711.1',
#  'ENSG00000231707.4',
#  'ENSG00000174500.12',
#  'ENSG00000139679.15',
#  'ENSG00000197632.8',
#  'ENSG00000284987.1',
#  'ENSG00000249550.6',
#  'ENSG00000272512.1',
#  'ENSG00000249936.3',
#  'ENSG00000185155.11',
#  'ENSG00000021300.13',
#  'ENSG00000231799.2',
#  'ENSG00000258354.1',
#  'ENSG00000260536.1',
#  'ENSG00000272762.5',
#  'ENSG00000239945.1',
#  'ENSG00000169047.5',
#  'ENSG00000238260.1',
#  'ENSG00000234840.1',
#  'ENSG00000167767.13',
#  'ENSG00000224165.5',
#  'ENSG00000272567.1',
#  'ENSG00000248698.6',
#  'ENSG00000243988.1',
#  'ENSG00000230026.2',
#  'ENSG00000275481.1',
#  'ENSG00000267419.2',
#  'ENSG00000182048.11',
#  'ENSG00000275389.1',
#  'ENSG00000257647.1',
#  'ENSG00000265261.1',
#  'ENSG00000279887.1',
#  'ENSG00000006377.10',
#  'ENSG00000257366.1',
#  'ENSG00000261118.1',
#  'ENSG00000224363.2',
#  'ENSG00000226352.2',
#  'ENSG00000112981.4',
#  'ENSG00000248587.7',
#  'ENSG00000283251.1',
#  'ENSG00000214897.4',
#  'ENSG00000119125.16',
#  'ENSG00000268970.1',
#  'ENSG00000279809.1',
#  'ENSG00000262772.1',
#  'ENSG00000285254.1',
#  'ENSG00000254105.1',
#  'ENSG00000143869.6',
#  'ENSG00000264304.1',
#  'ENSG00000139219.18',
#  'ENSG00000226578.1',
#  'ENSG00000283125.1',
#  'ENSG00000272529.1',
#  'ENSG00000228797.2',
#  'ENSG00000236105.1',
#  'ENSG00000111319.12',
#  'ENSG00000275506.1',
#  'ENSG00000206341.7',
#  'ENSG00000153714.5',
#  'ENSG00000184350.9',
#  'ENSG00000254536.1',
#  'ENSG00000214278.4',
#  'ENSG00000254343.2',
#  'ENSG00000273091.1',
#  'ENSG00000258099.1',
#  'ENSG00000106013.14',
#  'ENSG00000101977.20',
#  'ENSG00000268836.1',
#  'ENSG00000273076.1',
#  'ENSG00000277383.1',
#  'ENSG00000196778.3',
#  'ENSG00000236829.9',
#  'ENSG00000266402.3',
#  'ENSG00000227525.4',
#  'ENSG00000260064.1',
#  'ENSG00000205277.9',
#  'ENSG00000239884.3',
#  'ENSG00000235527.6',
#  'ENSG00000187686.4',
#  'ENSG00000234350.4',
#  'ENSG00000233922.2',
#  'ENSG00000215283.3',
#  'ENSG00000173212.4',
#  'ENSG00000223427.1',
#  'ENSG00000273024.6',
#  'ENSG00000278224.6',
#  'ENSG00000147613.7',
#  'ENSG00000099139.13',
#  'ENSG00000260571.1',
#  'ENSG00000254285.3',
#  'ENSG00000177822.7',
#  'ENSG00000266651.1',
#  'ENSG00000185028.3',
#  'ENSG00000268401.1',
#  'ENSG00000205622.9',
#  'ENSG00000106278.11',
#  'ENSG00000275197.1',
#  'ENSG00000285269.2',
#  'ENSG00000163734.4',
#  'ENSG00000285857.1',
#  'ENSG00000224628.2',
#  'ENSG00000267784.1',
#  'ENSG00000243155.1',
#  'ENSG00000167880.7',
#  'ENSG00000260144.1',
#  'ENSG00000185168.5',
#  'ENSG00000232951.1',
#  'ENSG00000158859.9',
#  'ENSG00000224116.6',
#  'ENSG00000228686.2',
#  'ENSG00000135747.11',
#  'ENSG00000268379.1',
#  'ENSG00000260368.1',
#  'ENSG00000279791.1',
#  'ENSG00000234997.1',
#  'ENSG00000266473.1',
#  'ENSG00000284772.1',
#  'ENSG00000135373.12',
#  'ENSG00000252464.1',
#  'ENSG00000205861.11',
#  'ENSG00000256737.1',
#  'ENSG00000263368.1',
#  'ENSG00000266728.5',
#  'ENSG00000178412.4',
#  'ENSG00000211899.10',
#  'ENSG00000176984.6',
#  'ENSG00000141750.6',
#  'ENSG00000230397.1',
#  'ENSG00000246526.2',
#  'ENSG00000228076.2',
#  'ENSG00000267034.1',
#  'ENSG00000211683.3',
#  'ENSG00000155070.8',
#  'ENSG00000223884.6',
#  'ENSG00000233159.1',
#  'ENSG00000279344.1',
#  'ENSG00000277726.4',
#  'ENSG00000231466.2',
#  'ENSG00000180210.14',
#  'ENSG00000285850.1',
#  'ENSG00000221879.3',
#  'ENSG00000126970.15',
#  'ENSG00000273248.1',
#  'ENSG00000263394.1',
#  'ENSG00000236457.1',
#  'ENSG00000243770.3',
#  'ENSG00000273017.1',
#  'ENSG00000231274.5',
#  'ENSG00000198681.6',
#  'ENSG00000234782.3',
#  'ENSG00000105792.19',
#  'ENSG00000177447.6',
#  'ENSG00000276957.1',
#  'ENSG00000271871.1',
#  'ENSG00000275223.1',
#  'ENSG00000204099.11',
#  'ENSG00000248538.7',
#  'ENSG00000276174.1',
#  'ENSG00000140945.16',
#  'ENSG00000095397.13',
#  'ENSG00000259103.2',
#  'ENSG00000237438.7',
#  'ENSG00000233471.2',
#  'ENSG00000227963.1',
#  'ENSG00000184361.12',
#  'ENSG00000129204.16',
#  'ENSG00000204802.3',
#  'ENSG00000259581.3',
#  'ENSG00000285824.1',
#  'ENSG00000283128.1',
#  'ENSG00000196754.10',
#  'ENSG00000277991.4',
#  'ENSG00000218018.2',
#  'ENSG00000226138.4',
#  'ENSG00000260145.1',
#  'ENSG00000276136.1',
#  'ENSG00000257477.1',
#  'ENSG00000236976.1',
#  'ENSG00000273184.1',
#  'ENSG00000276071.1',
#  'ENSG00000228007.1',
#  'ENSG00000250900.6',
#  'ENSG00000124882.3',
#  'ENSG00000143502.14',
#  'ENSG00000232852.1',
#  'ENSG00000135144.7',
#  'ENSG00000257529.5',
#  'ENSG00000158825.5',
#  'ENSG00000273059.1',
#  'ENSG00000182257.7',
#  'ENSG00000112936.18',
#  'ENSG00000237161.4',
#  'ENSG00000240694.8',
#  'ENSG00000278233.1',
#  'ENSG00000131095.12',
#  'ENSG00000179776.18',
#  'ENSG00000214700.5',
#  'ENSG00000228251.1',
#  'ENSG00000249669.9',
#  'ENSG00000271607.1',
#  'ENSG00000224829.3',
#  'ENSG00000282772.1',
#  'ENSG00000120664.10',
#  'ENSG00000244682.7',
#  'ENSG00000251393.3',
#  'ENSG00000188388.10',
#  'ENSG00000279619.1',
#  'ENSG00000238109.1',
#  'ENSG00000155066.15',
#  'ENSG00000180245.4',
#  'ENSG00000282995.1',
#  'ENSG00000256745.1',
#  'ENSG00000120820.12',
#  'ENSG00000231047.1',
#  'ENSG00000241520.1',
#  'ENSG00000251497.2',
#  'ENSG00000268423.4',
#  'ENSG00000213997.3',
#  'ENSG00000256654.3',
#  'ENSG00000199293.1',
#  'ENSG00000227278.1',
#  'ENSG00000227694.1',
#  'ENSG00000136928.6',
#  'ENSG00000136931.9',
#  'ENSG00000067191.15',
#  'ENSG00000163618.17',
#  'ENSG00000180189.10',
#  'ENSG00000271662.1',
#  'ENSG00000235330.2',
#  'ENSG00000254245.2',
#  'ENSG00000144130.11',
#  'ENSG00000280047.1',
#  'ENSG00000178146.9',
#  'ENSG00000204949.8',
#  'ENSG00000229122.1',
#  'ENSG00000242411.2',
#  'ENSG00000213750.4',
#  'ENSG00000278696.1',
#  'ENSG00000229204.3',
#  'ENSG00000050628.20',
#  'ENSG00000271155.1',
#  'ENSG00000229630.1',
#  'ENSG00000271180.1',
#  'ENSG00000164251.4',
#  'ENSG00000270083.1',
#  'ENSG00000213013.4',
#  'ENSG00000234949.2',
#  'ENSG00000145103.13',
#  'ENSG00000175984.14',
#  'ENSG00000101276.15',
#  'ENSG00000283709.1',
#  'ENSG00000109956.12',
#  'ENSG00000225051.5',
#  'ENSG00000226853.2',
#  'ENSG00000233072.1',
#  'ENSG00000255248.8',
#  'ENSG00000204052.4',
#  'ENSG00000234619.1',
#  'ENSG00000230592.2',
#  'ENSG00000240589.3',
#  'ENSG00000236735.3',
#  'ENSG00000274750.2',
#  'ENSG00000224993.3',
#  'ENSG00000228923.1',
#  'ENSG00000205871.5',
#  'ENSG00000227437.1',
#  'ENSG00000218682.1',
#  'ENSG00000157890.17',
#  'ENSG00000237118.3',
#  'ENSG00000279413.1',
#  'ENSG00000229022.1',
#  'ENSG00000139915.19',
#  'ENSG00000248174.5',
#  'ENSG00000234488.1',
#  'ENSG00000258249.1',
#  'ENSG00000228606.2',
#  'ENSG00000251288.2',
#  'ENSG00000257563.1',
#  'ENSG00000253866.1',
#  'ENSG00000229598.1',
#  'ENSG00000268707.1',
#  'ENSG00000284294.1',
#  'ENSG00000104938.16',
#  'ENSG00000087085.14',
#  'ENSG00000162367.11',
#  'ENSG00000259046.1',
#  'ENSG00000276075.1',
#  'ENSG00000226284.1',
#  'ENSG00000225259.4',
#  'ENSG00000256657.1',
#  'ENSG00000232628.5',
#  'ENSG00000236723.2',
#  'ENSG00000254740.2',
#  'ENSG00000265118.5',
#  'ENSG00000174945.13',
#  'ENSG00000236397.3',
#  'ENSG00000268234.1',
#  'ENSG00000283073.1',
#  'ENSG00000266717.1',
#  'ENSG00000133116.7',
#  'ENSG00000271795.1',
#  'ENSG00000214097.4',
#  'ENSG00000015413.9',
#  'ENSG00000141449.14',
#  'ENSG00000270115.1',
#  'ENSG00000225578.1',
#  'ENSG00000225555.1',
#  'ENSG00000225822.4',
#  'ENSG00000272582.1',
#  'ENSG00000276368.1',
#  'ENSG00000279583.1',
#  'ENSG00000275850.1',
#  'ENSG00000181722.16',
#  'ENSG00000213943.3',
#  'ENSG00000172238.4',
#  'ENSG00000226332.2',
#  'ENSG00000105388.15',
#  'ENSG00000273580.1',
#  'ENSG00000127533.3',
#  'ENSG00000233994.2',
#  'ENSG00000254558.1',
#  'ENSG00000235908.1',
#  'ENSG00000179921.14',
#  'ENSG00000231369.1',
#  'ENSG00000254061.1',
#  'ENSG00000125492.9',
#  'ENSG00000224992.2',
#  'ENSG00000143450.16',
#  'ENSG00000236345.1',
#  'ENSG00000239763.2',
#  'ENSG00000276410.3',
#  'ENSG00000144278.14',
#  'ENSG00000178343.4',
#  'ENSG00000229376.3',
#  'ENSG00000270110.1',
#  'ENSG00000279022.1',
#  'ENSG00000260805.2',
#  'ENSG00000232850.3',
#  'ENSG00000073067.13',
#  'ENSG00000169668.11',
#  'ENSG00000274893.1',
#  'ENSG00000261441.1',
#  'ENSG00000214357.8',
#  'ENSG00000260836.2',
#  'ENSG00000224137.1',
#  'ENSG00000238741.1',
#  'ENSG00000132832.10',
#  'ENSG00000251441.2',
#  'ENSG00000283445.1',
#  'ENSG00000177757.2',
#  'ENSG00000172264.17',
#  'ENSG00000155367.15',
#  'ENSG00000152952.11',
#  'ENSG00000165113.12',
#  'ENSG00000214211.2',
#  'ENSG00000108018.15',
#  'ENSG00000185955.4',
#  'ENSG00000273221.1',
#  'ENSG00000186407.6',
#  'ENSG00000145192.12',
#  'ENSG00000196542.8',
#  'ENSG00000100078.3',
#  'ENSG00000226721.2',
#  'ENSG00000266373.1',
#  'ENSG00000269236.1',
#  'ENSG00000186832.8',
#  'ENSG00000235254.3',
#  'ENSG00000165092.12',
#  'ENSG00000273972.1',
#  'ENSG00000253552.7',
#  'ENSG00000244691.1',
#  'ENSG00000130988.12',
#  'ENSG00000253522.6',
#  'ENSG00000252481.1',
#  'ENSG00000238133.6',
#  'ENSG00000100218.11',
#  'ENSG00000267795.5',
#  'ENSG00000237883.1',
#  'ENSG00000230387.2',
#  'ENSG00000082512.14',
#  'ENSG00000008226.19',
#  'ENSG00000279067.1',
#  'ENSG00000214889.3',
#  'ENSG00000243188.1',
#  'ENSG00000224185.1',
#  'ENSG00000126947.12',
#  'ENSG00000219023.1',
#  'ENSG00000220749.4',
#  'ENSG00000150594.6',
#  'ENSG00000231503.4',
#  'ENSG00000261312.1',
#  'ENSG00000259298.1',
#  'ENSG00000243753.5',
#  'ENSG00000258843.1',
#  'ENSG00000225506.2',
#  'ENSG00000163564.14',
#  'ENSG00000146453.12',
#  'ENSG00000249274.1',
#  'ENSG00000258479.5',
#  'ENSG00000272918.1',
#  'ENSG00000236204.6',
#  'ENSG00000240074.1',
#  'ENSG00000237976.1',
#  'ENSG00000223442.1',
#  'ENSG00000235522.6',
#  'ENSG00000254431.1',
#  'ENSG00000225091.3',
#  'ENSG00000265136.1',
#  'ENSG00000253764.2',
#  'ENSG00000174715.7',
#  'ENSG00000222042.1',
#  'ENSG00000244515.1',
#  'ENSG00000232934.7',
#  'ENSG00000233503.1',
#  'ENSG00000281849.3',
#  'ENSG00000196565.14',
#  'ENSG00000271757.1',
#  'ENSG00000236498.1',
#  'ENSG00000179314.14',
#  'ENSG00000185634.11',
#  'ENSG00000233806.7',
#  'ENSG00000269692.1',
#  'ENSG00000255089.1',
#  'ENSG00000257596.1',
#  'ENSG00000109654.14',
#  'ENSG00000185899.1',
#  'ENSG00000271172.1',
#  'ENSG00000255353.1',
#  'ENSG00000241929.1',
#  'ENSG00000242262.1',
#  'ENSG00000259207.7',
#  'ENSG00000172935.8',
#  'ENSG00000228852.6',
#  'ENSG00000241318.3',
#  'ENSG00000158874.11',
#  'ENSG00000256950.2',
#  'ENSG00000241352.3',
#  'ENSG00000227890.1',
#  'ENSG00000224790.2',
#  'ENSG00000267697.1',
#  'ENSG00000273837.1',
#  'ENSG00000259556.2',
#  'ENSG00000169783.12',
#  'ENSG00000169676.5',
#  'ENSG00000156510.12',
#  'ENSG00000276232.1',
#  'ENSG00000254864.1',
#  'ENSG00000156413.13',
#  'ENSG00000258951.1',
#  'ENSG00000275126.1',
#  'ENSG00000205414.1',
#  'ENSG00000269019.1',
#  'ENSG00000254941.1',
#  'ENSG00000232882.1',
#  'ENSG00000188868.13',
#  'ENSG00000280607.1',
#  'ENSG00000255572.1',
#  'ENSG00000273747.1',
#  'ENSG00000249689.1',
#  'ENSG00000278983.1',
#  'ENSG00000054179.11',
#  'ENSG00000166569.8',
#  'ENSG00000253302.1',
#  'ENSG00000269903.1',
#  'ENSG00000142959.4',
#  'ENSG00000229635.1',
#  'ENSG00000115386.5',
#  'ENSG00000248641.1',
#  'ENSG00000160188.9',
#  'ENSG00000258677.2',
#  'ENSG00000253105.5',
#  'ENSG00000266821.1',
#  'ENSG00000266075.2',
#  'ENSG00000261673.1',
#  'ENSG00000253736.2',
#  'ENSG00000102539.5',
#  'ENSG00000267179.1',
#  'ENSG00000104267.9',
#  'ENSG00000272478.1',
#  'ENSG00000214263.2',
#  'ENSG00000269951.1',
#  'ENSG00000259438.1',
#  'ENSG00000037965.5',
#  'ENSG00000196711.8',
#  'ENSG00000109452.12',
#  'ENSG00000217539.2',
#  'ENSG00000255500.2',
#  'ENSG00000250144.1',
#  'ENSG00000223669.1',
#  'ENSG00000171811.13',
#  'ENSG00000262777.1',
#  'ENSG00000215199.3',
#  'ENSG00000245385.2',
#  'ENSG00000162039.15',
#  'ENSG00000283239.1',
#  'ENSG00000272695.1',
#  'ENSG00000264554.2',
#  'ENSG00000197888.2',
#  'ENSG00000223561.6',
#  'ENSG00000231995.2',
#  'ENSG00000283052.1',
#  'ENSG00000255331.1',
#  'ENSG00000274225.1',
#  'ENSG00000255301.1',
#  'ENSG00000249923.1',
#  'ENSG00000236861.6',
#  'ENSG00000213412.3',
#  'ENSG00000279917.1',
#  'ENSG00000248571.1',
#  'ENSG00000224059.1',
#  'ENSG00000272625.1',
#  'ENSG00000245080.7',
#  'ENSG00000260052.1',
#  'ENSG00000215093.3',
#  'ENSG00000237451.3',
#  'ENSG00000171714.11',
#  'ENSG00000185345.20',
#  'ENSG00000108924.13',
#  'ENSG00000255524.7',
#  'ENSG00000285653.1',
#  'ENSG00000230310.1',
#  'ENSG00000228979.4',
#  'ENSG00000265802.2',
#  'ENSG00000275485.1',
#  'ENSG00000105929.16',
#  'ENSG00000230570.1',
#  'ENSG00000227329.2',
#  'ENSG00000269271.1',
#  'ENSG00000249068.1',
#  'ENSG00000233791.5',
#  'ENSG00000276945.1',
#  'ENSG00000226539.1',
#  'ENSG00000269489.1',
#  'ENSG00000125931.10',
#  'ENSG00000226964.1',
#  'ENSG00000112394.16',
#  'ENSG00000243508.1',
#  'ENSG00000227073.1',
#  'ENSG00000259100.1',
#  'ENSG00000255562.2',
#  'ENSG00000099937.10',
#  'ENSG00000266184.1',
#  'ENSG00000112559.13',
#  'ENSG00000228838.1',
#  'ENSG00000169575.4',
#  'ENSG00000226652.3',
#  'ENSG00000173227.13',
#  'ENSG00000219435.5',
#  'ENSG00000272263.1',
#  'ENSG00000205853.10',
#  'ENSG00000197647.11',
#  'ENSG00000224413.1',
#  'ENSG00000243007.1',
#  'ENSG00000235079.1',
#  'ENSG00000229161.2',
#  'ENSG00000272983.1',
#  'ENSG00000226009.1',
#  'ENSG00000265590.9',
#  'ENSG00000227948.4',
#  'ENSG00000244268.1',
#  'ENSG00000242067.1',
#  'ENSG00000272491.1',
#  'ENSG00000259327.1',
#  'ENSG00000233217.2',
#  'ENSG00000272418.1',
#  'ENSG00000266910.2',
#  'ENSG00000165259.13',
#  'ENSG00000277327.1',
#  'ENSG00000164237.8',
#  'ENSG00000257803.2',
#  'ENSG00000281162.2',
#  'ENSG00000266648.1',
#  'ENSG00000224183.1',
#  'ENSG00000284526.1',
#  'ENSG00000269300.1',
#  'ENSG00000243960.1',
#  'ENSG00000159904.11',
#  'ENSG00000284640.1',
#  'ENSG00000229656.6',
#  'ENSG00000018408.14',
#  'ENSG00000258128.2',
#  'ENSG00000128268.11',
#  'ENSG00000058404.19',
#  'ENSG00000165568.17',
#  'ENSG00000163467.11',
#  'ENSG00000274840.4',
#  'ENSG00000259286.3',
#  'ENSG00000260740.2',
#  'ENSG00000182545.6',
#  'ENSG00000212125.2',
#  'ENSG00000184530.8',
#  'ENSG00000230149.2',
#  'ENSG00000152578.12',
#  'ENSG00000198142.4',
#  'ENSG00000232757.1',
#  'ENSG00000255330.9',
#  'ENSG00000228526.7',
#  'ENSG00000278978.1',
#  'ENSG00000270332.1',
#  'ENSG00000248734.2',
#  'ENSG00000244585.1',
#  'ENSG00000139835.13',
#  'ENSG00000170605.6',
#  'ENSG00000279785.1',
#  'ENSG00000271959.1',
#  'ENSG00000110169.10',
#  'ENSG00000114948.12',
#  'ENSG00000255641.1',
#  'ENSG00000154240.16',
#  'ENSG00000273406.1',
#  'ENSG00000083750.12',
#  'ENSG00000264943.1',
#  'ENSG00000124171.8',
#  'ENSG00000233347.1',
#  'ENSG00000002746.14',
#  'ENSG00000273765.1',
#  'ENSG00000128536.15',
#  'ENSG00000169174.10',
#  'ENSG00000173991.5',
#  'ENSG00000229525.1',
#  'ENSG00000228695.10',
#  'ENSG00000283573.1',
#  'ENSG00000263590.2',
#  'ENSG00000196604.12',
#  'ENSG00000171817.16',
#  'ENSG00000274698.1',
#  'ENSG00000258728.1',
#  'ENSG00000258539.1',
#  'ENSG00000232648.3',
#  'ENSG00000258603.3',
#  'ENSG00000183853.17',
#  'ENSG00000230581.2',
#  'ENSG00000267009.6',
#  'ENSG00000225873.4',
#  'ENSG00000228897.1',
#  'ENSG00000178401.15',
#  'ENSG00000272417.1',
#  'ENSG00000258593.2',
#  'ENSG00000281691.1',
#  'ENSG00000145626.11',
#  'ENSG00000276966.2',
#  'ENSG00000234373.1',
#  'ENSG00000198478.7',
#  'ENSG00000189051.5',
#  'ENSG00000256861.1',
#  'ENSG00000233668.1',
#  'ENSG00000243207.6',
#  'ENSG00000242439.1',
#  'ENSG00000250995.1',
#  'ENSG00000232386.9',
#  'ENSG00000251535.1',
#  'ENSG00000115221.11',
#  'ENSG00000175147.12',
#  'ENSG00000158014.14',
#  'ENSG00000153086.13',
#  'ENSG00000279897.2',
#  'ENSG00000238123.1',
#  'ENSG00000131686.14',
#  'ENSG00000136237.18',
#  'ENSG00000270878.1',
#  'ENSG00000223725.6',
#  'ENSG00000220744.1',
#  'ENSG00000269068.1',
#  'ENSG00000137033.11',
#  'ENSG00000255046.1',
#  'ENSG00000137507.11',
#  'ENSG00000274351.1',
#  'ENSG00000171951.4',
#  'ENSG00000259804.1',
#  'ENSG00000285994.1',
#  'ENSG00000203645.2',
#  'ENSG00000278847.1',
#  'ENSG00000227311.3',
#  'ENSG00000236519.1',
#  'ENSG00000227591.5',
#  'ENSG00000154227.13',
#  'ENSG00000168334.8',
#  'ENSG00000187566.5',
#  'ENSG00000218208.1',
#  'ENSG00000239830.1',
#  'ENSG00000233070.1',
#  'ENSG00000269054.1',
#  'ENSG00000254912.2',
#  'ENSG00000201772.1',
#  'ENSG00000227255.1',
#  'ENSG00000259682.1',
#  'ENSG00000233111.1',
#  'ENSG00000284882.1',
#  'ENSG00000105609.16',
#  'ENSG00000167757.13',
#  'ENSG00000229757.2',
#  'ENSG00000265078.2',
#  'ENSG00000242951.1',
#  'ENSG00000227214.2',
#  'ENSG00000236320.3',
#  'ENSG00000251215.1',
#  'ENSG00000144583.4',
#  'ENSG00000156222.11',
#  'ENSG00000259823.5',
#  'ENSG00000267470.5',
#  'ENSG00000171056.7',
#  'ENSG00000259113.1',
#  'ENSG00000276968.1',
#  'ENSG00000168955.3',
#  'ENSG00000231470.1',
#  'ENSG00000188257.11',
#  'ENSG00000272121.1',
#  'ENSG00000253661.1',
#  'ENSG00000270006.2',
#  'ENSG00000179766.19',
#  'ENSG00000224903.1',
#  'ENSG00000204956.5',
#  'ENSG00000270020.1',
#  'ENSG00000177640.15',
#  'ENSG00000167914.11',
#  'ENSG00000198134.3',
#  'ENSG00000273226.1',
#  'ENSG00000260455.1',
#  'ENSG00000214280.3',
#  'ENSG00000270165.1',
#  'ENSG00000276085.1',
#  'ENSG00000168491.9',
#  'ENSG00000196668.3',
#  'ENSG00000259456.3',
#  'ENSG00000260510.1',
#  'ENSG00000133574.9',
#  'ENSG00000230201.5',
#  'ENSG00000225982.1',
#  'ENSG00000167971.15',
#  'ENSG00000139926.15',
#  'ENSG00000214192.3',
#  'ENSG00000223711.1',
#  'ENSG00000172243.17',
#  'ENSG00000134545.13',
#  'ENSG00000233077.1',
#  'ENSG00000150281.6',
#  'ENSG00000117601.13',
#  'ENSG00000215063.3',
#  'ENSG00000112486.16',
#  'ENSG00000267432.5',
#  'ENSG00000172940.12',
#  'ENSG00000224729.5',
#  'ENSG00000270720.1',
#  'ENSG00000184224.3',
#  'ENSG00000073282.12',
#  'ENSG00000255213.1',
#  'ENSG00000234936.1',
#  'ENSG00000242375.1',
#  'ENSG00000247699.2',
#  'ENSG00000257258.1',
#  'ENSG00000278419.1',
#  'ENSG00000227118.3',
#  'ENSG00000013588.8',
#  'ENSG00000171873.7',
#  'ENSG00000277745.1',
#  'ENSG00000258645.2',
#  'ENSG00000267143.1',
#  'ENSG00000260648.3',
#  'ENSG00000272693.4',
#  'ENSG00000253537.2',
#  'ENSG00000271734.1',
#  'ENSG00000237624.1',
#  'ENSG00000277218.1',
#  'ENSG00000235958.5',
#  'ENSG00000096696.13',
#  'ENSG00000215325.4',
#  'ENSG00000275216.2',
#  'ENSG00000285549.1',
#  'ENSG00000205810.8',
#  'ENSG00000106571.13',
#  'ENSG00000272508.1',
#  'ENSG00000272989.1',
#  'ENSG00000282977.1',
#  'ENSG00000119283.15',
#  'ENSG00000240216.7',
#  'ENSG00000215915.9',
#  'ENSG00000162641.18',
#  'ENSG00000279699.1',
#  'ENSG00000151655.18',
#  'ENSG00000228543.1',
#  'ENSG00000198099.8',
#  'ENSG00000257335.8',
#  'ENSG00000266613.1',
#  'ENSG00000235078.1',
#  'ENSG00000235207.1',
#  'ENSG00000166159.10',
#  'ENSG00000226632.1',
#  'ENSG00000234492.4',
#  'ENSG00000276203.4',
#  'ENSG00000239269.1',
#  'ENSG00000261537.1',
#  'ENSG00000260100.1',
#  'ENSG00000254978.2',
#  'ENSG00000227375.5',
#  'ENSG00000258033.1',
#  'ENSG00000205457.11',
#  'ENSG00000261528.2',
#  'ENSG00000128394.16',
#  'ENSG00000156234.7',
#  'ENSG00000255397.1',
#  'ENSG00000270923.1',
#  'ENSG00000258790.1',
#  'ENSG00000236156.2',
#  'ENSG00000166173.10',
#  'ENSG00000232097.1',
#  'ENSG00000228127.2',
#  'ENSG00000174672.15',
#  'ENSG00000172382.9',
#  'ENSG00000169313.9',
#  'ENSG00000242169.2',
#  'ENSG00000154783.11',
#  'ENSG00000242697.2',
#  'ENSG00000234557.2',
#  'ENSG00000281974.1',
#  'ENSG00000229344.1',
#  'ENSG00000227076.1',
#  'ENSG00000167183.2',
#  'ENSG00000204044.6',
#  'ENSG00000248510.2',
#  'ENSG00000261717.5',
#  'ENSG00000233968.6',
#  'ENSG00000147642.16',
#  'ENSG00000268650.3',
#  'ENSG00000271803.1',
#  'ENSG00000279372.1',
#  'ENSG00000255991.2',
#  'ENSG00000273456.1',
#  'ENSG00000215467.2',
#  'ENSG00000224307.1',
#  'ENSG00000123610.4',
#  'ENSG00000226855.1',
#  'ENSG00000241219.1',
#  'ENSG00000275393.1',
#  'ENSG00000268628.2',
#  'ENSG00000224479.6',
#  'ENSG00000057468.6',
#  'ENSG00000268988.1',
#  'ENSG00000255237.1',
#  'ENSG00000223972.5',
#  'ENSG00000279019.1',
#  'ENSG00000169085.12',
#  'ENSG00000125879.4',
#  'ENSG00000167191.11',
#  ...}

# %% [markdown]
# ### we now have the feeling that they are only the protein coding ones

# %%
ProteinCoding = tc.get(name='depmap-rnaseq-expression-data-363a', file='CCLE_depMap_19Q2_TPM_ProteinCoding')
CCLEgenes = set(ProteinCoding.columns.values[np.where(ProteinCoding.loc["ACH-000045"].values!=0)])
nonoverlapping = CCLEgenes - AMLgenes

# %%
ProteinCoding.shape
# Out:
# (1283, 19144)

# %%
ProteinCoding
# Out:
#             TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# ACH-001097       0.000000      0.000000     4.667324       1.761285
# ACH-001485       0.000000      0.000000     5.755689       2.375735
# ACH-001396       2.883621      0.000000     4.471838       2.347666
# ACH-001804       4.934988      0.000000     6.635464       1.929791
# ACH-000534       0.839960      0.000000     5.376082       2.687061
# ACH-000742       3.722466      0.000000     6.029674       2.192194
# ACH-000836       4.632268      0.000000     6.704180       2.792855
# ACH-000545       4.251719      0.000000     5.651052       3.440952
# ACH-001850       4.844988      0.000000     8.068993       1.280956
# ACH-000470       3.681449      0.000000     7.294896       2.400538
# ACH-001959       3.321928      0.000000     7.357288       1.691534
# ACH-000079       3.788686      0.000000     6.626293       2.469886
# ACH-001443       3.948601      0.000000     7.472650       1.985500
# ACH-001513       4.320485      0.000000     5.411426       1.570463
# ACH-000762       4.424250      0.000000     6.567424       2.353323
# ACH-000495       4.779785      0.000000     7.201046       1.967169
# ACH-000834       6.268846      0.000000     7.088947       1.992768
# ACH-000981       0.659925      0.000000     5.790772       3.282440
# ACH-001642       0.310340      0.000000     4.102658       2.114367
# ACH-001020       5.605554      0.000000     6.862575       2.104337
# ACH-001799       5.116448      0.000000     6.960929       1.678072
# ACH-001425       3.991862      0.773996     3.601697       0.632268
# ACH-001100       0.000000      0.000000     3.607626       1.432959
# ACH-000652       4.466627      0.000000     6.972808       2.107688
# ACH-001400       2.737687      0.000000     3.758090       0.823749
# ACH-001119       0.000000      0.000000     5.216455       2.769772
# ACH-001450       0.000000      0.000000     5.972003       2.160275
# ACH-001520       0.000000      0.000000     5.017031       2.280956
# ACH-001622       4.017922      0.042644     7.200359       1.678072
# ACH-001849       3.678072      0.000000     6.089159       1.292782
# ...                   ...           ...          ...            ...
# ACH-000352       4.002703      0.000000     5.870365       3.621759
# ACH-000349       4.698218      0.000000     7.348817       3.484138
# ACH-000319       4.100978      0.000000     7.200850       2.446256
# ACH-000181       3.964399      0.000000     5.718088       2.260026
# ACH-000137       5.082788      0.000000     6.869748       2.235727
# ACH-000013       5.517591      0.056584     7.528884       1.910733
# ACH-000766       5.649041      0.014355     6.705425       2.277985
# ACH-000675       5.659639      0.286881     6.269594       1.925999
# ACH-000389       3.817623      0.000000     5.553668       2.250962
# ACH-000920       0.137504      0.000000     5.317232       3.019702
# ACH-000351       4.614121      0.000000     8.070443       2.356144
# ACH-000394       3.112700      0.056584     5.619413       3.207893
# ACH-000744       3.286881      0.000000     5.716991       2.761285
# ACH-000114       3.793896      0.028569     6.330738       2.792855
# ACH-000795       0.815575      0.000000     6.015248       3.073820
# ACH-000103       4.606442      0.000000     6.227857       2.495695
# ACH-000144       5.216843      0.097611     6.888378       3.068671
# ACH-000578       4.963936      0.000000     6.624978       2.232661
# ACH-000514       4.886550      0.000000     5.739038       3.005400
# ACH-000864       2.735522      0.000000     5.581050       2.748461
# ACH-000305       4.152183      0.000000     6.024364       2.361768
# ACH-000603       0.910733      0.000000     5.740118       2.505891
# ACH-000916       4.997744      0.000000     5.898450       3.814550
# ACH-000296       5.382321      0.150560     6.551670       2.592158
# ACH-000978       5.002252      0.042644     6.523719       2.613532
# ACH-000904       4.316870      0.028569     5.990955       3.185867
# ACH-000110       5.227279      0.070389     6.764341       3.537296
# ACH-000261       4.447579      0.028569     6.748864       2.650765
# ACH-000031       4.714795      0.028569     6.745910       2.776104
# ACH-000682       5.976364      0.124328     5.983450       2.939227
#
#             C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  \
# ACH-001097          3.554589    4.358959    0.641546      2.201634
# ACH-001485          2.634593    4.233428    0.545968      3.611172
# ACH-001396          3.392317    0.495695    0.000000      4.731726
# ACH-001804          2.503349    0.000000    4.883621      6.772546
# ACH-000534          4.440288    4.938286    0.536053      3.584963
# ACH-000742          2.533563    0.150560    5.933809      6.973382
# ACH-000836          4.079805    0.097611    1.150560      5.729553
# ACH-000545          3.275007    1.541019    6.659496      6.478648
# ACH-001850          2.757023    0.000000    1.655352      6.268472
# ACH-000470          2.849999    0.956057    0.238787      6.028569
# ACH-001959          4.328406    0.000000    0.042644      4.700440
# ACH-000079          3.094236    0.028569    5.228819      5.711770
# ACH-001443          3.337711    0.000000    3.646163      4.972693
# ACH-001513          2.443607    0.000000    0.056584      4.319762
# ACH-000762          4.536675    0.275007    4.272770      6.112075
# ACH-000495          3.563158    0.097611    5.282440      6.039796
# ACH-000834          2.531069    0.028569    2.987321      5.452200
# ACH-000981          4.945795    6.610434    5.170726      1.257011
# ACH-001642          3.084064    0.731183    5.142822      3.878725
# ACH-001020          4.055716    0.000000    0.028569      5.558268
# ACH-001799          3.564378    0.000000    6.657783      5.856488
# ACH-001425          1.659925    0.871844    3.908813      4.154616
# ACH-001100          2.319040    4.843481    3.649615      0.000000
# ACH-000652          3.702658    0.070389    0.238787      5.986638
# ACH-001400          1.000000    0.516015    3.447579      3.250962
# ACH-001119          2.893362    0.028569    0.678072      3.260026
# ACH-001450          2.965323    4.451541    0.000000      0.014355
# ACH-001520          2.173127    6.879828    0.000000      3.765535
# ACH-001622          2.389567    0.333424    0.978196      6.225545
# ACH-001849          2.232661    0.042644    0.000000      5.047451
# ...                      ...         ...         ...           ...
# ACH-000352          3.861955    0.014355    0.485427      4.614121
# ACH-000349          3.914565    0.042644    0.042644      5.933573
# ACH-000319          4.021480    0.124328    4.042644      6.272210
# ACH-000181          3.451541    0.084064    0.782409      6.039796
# ACH-000137          3.998196    0.495695    2.763412      6.300307
# ACH-000013          3.572890    0.028569    2.066950      5.419876
# ACH-000766          3.843984    0.042644    3.737687      6.535275
# ACH-000675          3.782409    0.000000    5.349082      7.541252
# ACH-000389          3.166715    0.042644    5.409391      5.865919
# ACH-000920          4.438958    0.782409    4.835419      0.485427
# ACH-000351          4.105175    1.641546    0.344828      6.004501
# ACH-000394          4.827819    0.150560    3.526069      4.401903
# ACH-000744          3.786596    0.070389    1.521051      4.852998
# ACH-000114          2.643856    0.565597    4.783980      5.748193
# ACH-000795          5.103078    3.032101    2.799087      0.622930
# ACH-000103          3.575312    0.097611    3.907852      4.234195
# ACH-000144          4.032982    0.028569    0.137504      5.263034
# ACH-000578          3.925999    0.056584    3.542258      5.386466
# ACH-000514          4.626439    0.641546    2.114367      4.303050
# ACH-000864          3.570463    0.042644    0.097611      4.812498
# ACH-000305          1.659925    0.028569    5.154616      6.506367
# ACH-000603          3.161888    0.028569    0.070389      5.328406
# ACH-000916          3.446256    0.042644    4.676944      3.574102
# ACH-000296          4.352617    0.042644    0.097611      6.420887
# ACH-000978          3.243364    0.014355    0.070389      5.372256
# ACH-000904          4.846493    0.286881    0.111031      4.799087
# ACH-000110          4.491212    0.150560    1.150560      5.537296
# ACH-000261          4.607626    0.042644    0.687061      6.400367
# ACH-000031          3.621759    0.056584    3.095924      6.936049
# ACH-000682          2.918386    0.084064    6.849374      5.742545
#
#             GCLC (2729)  NFYA (4800)  ...  SCYGR3 (112441429)  \
# ACH-001097     1.941106     2.150560  ...                 0.0
# ACH-001485     3.068671     2.693766  ...                 0.0
# ACH-001396     3.500802     2.643856  ...                 0.0
# ACH-001804     3.889474     4.139961  ...                 0.0
# ACH-000534     2.935460     3.157044  ...                 0.0
# ACH-000742     5.192194     3.258519  ...                 0.0
# ACH-000836     4.802193     4.372256  ...                 0.0
# ACH-000545     5.566206     3.927896  ...                 0.0
# ACH-001850     4.924100     4.154616  ...                 0.0
# ACH-000470     5.868390     3.866908  ...                 0.0
# ACH-001959     3.381283     4.377124  ...                 0.0
# ACH-000079     3.484138     3.346248  ...                 0.0
# ACH-001443     4.560715     4.732269  ...                 0.0
# ACH-001513     5.626731     3.831877  ...                 0.0
# ACH-000762     4.979111     3.870858  ...                 0.0
# ACH-000495     4.058316     3.619413  ...                 0.0
# ACH-000834     4.976364     3.723559  ...                 0.0
# ACH-000981     4.932628     5.783719  ...                 0.0
# ACH-001642     3.207893     2.757023  ...                 0.0
# ACH-001020     4.519164     4.143230  ...                 0.0
# ACH-001799     3.650765     4.317594  ...                 0.0
# ACH-001425     3.104337     2.238787  ...                 0.0
# ACH-001100     2.378512     2.017922  ...                 0.0
# ACH-000652     5.701272     4.482848  ...                 0.0
# ACH-001400     2.341986     1.531069  ...                 0.0
# ACH-001119     3.558268     3.235727  ...                 0.0
# ACH-001450     4.162693     5.500483  ...                 0.0
# ACH-001520     2.467279     2.918386  ...                 0.0
# ACH-001622     2.247928     3.204767  ...                 0.0
# ACH-001849     4.996841     2.655352  ...                 0.0
# ...                 ...          ...  ...                 ...
# ACH-000352     5.286881     4.429616  ...                 0.0
# ACH-000349     4.783457     4.773996  ...                 0.0
# ACH-000319     4.854494     4.014355  ...                 0.0
# ACH-000181     5.778734     4.903038  ...                 0.0
# ACH-000137     5.352617     4.172327  ...                 0.0
# ACH-000013     4.204767     3.504620  ...                 0.0
# ACH-000766     5.375387     4.456806  ...                 0.0
# ACH-000675     7.156639     5.135042  ...                 0.0
# ACH-000389     6.546740     5.150966  ...                 0.0
# ACH-000920     4.726831     5.458448  ...                 0.0
# ACH-000351     4.624686     4.126808  ...                 0.0
# ACH-000394     4.695437     4.957915  ...                 0.0
# ACH-000744     6.554589     3.986411  ...                 0.0
# ACH-000114     5.551208     4.272023  ...                 0.0
# ACH-000795     4.489928     5.514438  ...                 0.0
# ACH-000103     4.082362     3.712596  ...                 0.0
# ACH-000144     5.493455     4.470537  ...                 0.0
# ACH-000578     4.629939     4.811985  ...                 0.0
# ACH-000514     4.990047     5.031219  ...                 0.0
# ACH-000864     4.745775     4.888987  ...                 0.0
# ACH-000305     5.834408     4.206331  ...                 0.0
# ACH-000603     5.694044     3.969933  ...                 0.0
# ACH-000916     9.372647     3.727920  ...                 0.0
# ACH-000296     4.887038     4.535431  ...                 0.0
# ACH-000978     4.599318     4.402586  ...                 0.0
# ACH-000904     4.995485     4.660495  ...                 0.0
# ACH-000110     5.776894     4.766065  ...                 0.0
# ACH-000261     4.274262     4.828835  ...                 0.0
# ACH-000031     4.976822     4.451541  ...                 0.0
# ACH-000682     5.492815     3.949535  ...                 0.0
#
#             SCYGR7 (112441438)  OR8S1 (341568)  SCYGR6 (112441431)  \
# ACH-001097                 0.0        0.000000                 0.0
# ACH-001485                 0.0        0.000000                 0.0
# ACH-001396                 0.0        0.000000                 0.0
# ACH-001804                 0.0        0.000000                 0.0
# ACH-000534                 0.0        0.000000                 0.0
# ACH-000742                 0.0        0.000000                 0.0
# ACH-000836                 0.0        0.000000                 0.0
# ACH-000545                 0.0        0.000000                 0.0
# ACH-001850                 0.0        0.000000                 0.0
# ACH-000470                 0.0        0.000000                 0.0
# ACH-001959                 0.0        0.000000                 0.0
# ACH-000079                 0.0        0.000000                 0.0
# ACH-001443                 0.0        0.000000                 0.0
# ACH-001513                 0.0        0.000000                 0.0
# ACH-000762                 0.0        0.000000                 0.0
# ACH-000495                 0.0        0.000000                 0.0
# ACH-000834                 0.0        0.000000                 0.0
# ACH-000981                 0.0        0.000000                 0.0
# ACH-001642                 0.0        0.000000                 0.0
# ACH-001020                 0.0        0.000000                 0.0
# ACH-001799                 0.0        0.000000                 0.0
# ACH-001425                 0.0        0.000000                 0.0
# ACH-001100                 0.0        0.124328                 0.0
# ACH-000652                 0.0        0.000000                 0.0
# ACH-001400                 0.0        0.000000                 0.0
# ACH-001119                 0.0        0.000000                 0.0
# ACH-001450                 0.0        0.028569                 0.0
# ACH-001520                 0.0        0.310340                 0.0
# ACH-001622                 0.0        0.000000                 0.0
# ACH-001849                 0.0        0.042644                 0.0
# ...                        ...             ...                 ...
# ACH-000352                 0.0        0.000000                 0.0
# ACH-000349                 0.0        0.000000                 0.0
# ACH-000319                 0.0        0.000000                 0.0
# ACH-000181                 0.0        0.000000                 0.0
# ACH-000137                 0.0        0.070389                 0.0
# ACH-000013                 0.0        0.000000                 0.0
# ACH-000766                 0.0        0.226509                 0.0
# ACH-000675                 0.0        0.097611                 0.0
# ACH-000389                 0.0        0.124328                 0.0
# ACH-000920                 0.0        0.000000                 0.0
# ACH-000351                 0.0        0.070389                 0.0
# ACH-000394                 0.0        0.084064                 0.0
# ACH-000744                 0.0        0.028569                 0.0
# ACH-000114                 0.0        0.150560                 0.0
# ACH-000795                 0.0        0.000000                 0.0
# ACH-000103                 0.0        0.028569                 0.0
# ACH-000144                 0.0        0.443607                 0.0
# ACH-000578                 0.0        0.070389                 0.0
# ACH-000514                 0.0        0.000000                 0.0
# ACH-000864                 0.0        0.028569                 0.0
# ACH-000305                 0.0        0.275007                 0.0
# ACH-000603                 0.0        0.000000                 0.0
# ACH-000916                 0.0        0.070389                 0.0
# ACH-000296                 0.0        0.150560                 0.0
# ACH-000978                 0.0        0.042644                 0.0
# ACH-000904                 0.0        0.000000                 0.0
# ACH-000110                 0.0        0.000000                 0.0
# ACH-000261                 0.0        0.097611                 0.0
# ACH-000031                 0.0        0.263034                 0.0
# ACH-000682                 0.0        0.111031                 0.0
#
#             OR4F29 (729759)  EEF1AKMT4 (110599564)  TBCE (6905)  \
# ACH-001097         0.000000               2.980025     5.132988
# ACH-001485         0.000000               3.393691     3.646163
# ACH-001396         0.000000               4.228819     5.098032
# ACH-001804         0.000000               2.283922     4.288359
# ACH-000534         0.000000               1.333424     4.841470
# ACH-000742         0.000000               1.526069     4.494416
# ACH-000836         0.000000               2.983678     4.743623
# ACH-000545         0.000000               2.899176     5.453847
# ACH-001850         0.000000               1.521051     3.477677
# ACH-000470         0.275007               3.711495     4.500802
# ACH-001959         0.070389               3.211012     5.351911
# ACH-000079         0.000000               1.485427     5.096768
# ACH-001443         0.000000               3.207893     4.357552
# ACH-001513         0.000000               4.127633     4.868390
# ACH-000762         0.000000               2.253989     4.541639
# ACH-000495         0.000000               2.462052     5.302685
# ACH-000834         0.000000               2.970854     4.621759
# ACH-000981         0.000000               2.893362     5.384395
# ACH-001642         0.000000               2.032101     4.685380
# ACH-001020         0.014355               3.261531     4.971773
# ACH-001799         0.000000               3.617063     4.207112
# ACH-001425         0.000000               2.028569     3.314697
# ACH-001100         0.000000               2.389567     4.971314
# ACH-000652         0.000000               3.314697     5.336283
# ACH-001400         0.000000               0.659925     4.372256
# ACH-001119         0.000000               2.350497     5.016140
# ACH-001450         0.000000               3.658783     4.594549
# ACH-001520         0.000000               2.541019     4.661636
# ACH-001622         0.000000               2.482848     4.936402
# ACH-001849         0.042644               4.011675     3.158660
# ...                     ...                    ...          ...
# ACH-000352         0.042644               4.910253     5.555816
# ACH-000349         0.000000               4.554589     5.033863
# ACH-000319         0.028569               3.473787     5.363522
# ACH-000181         0.070389               3.390943     4.174726
# ACH-000137         0.042644               2.897240     4.521051
# ACH-000013         0.070389               3.554589     5.051372
# ACH-000766         0.000000               5.196922     4.311794
# ACH-000675         0.028569               3.468583     4.487358
# ACH-000389         0.056584               3.547203     4.650190
# ACH-000920         0.056584               4.209453     4.999098
# ACH-000351         0.000000               2.440952     4.818135
# ACH-000394         0.150560               4.063503     5.163499
# ACH-000744         0.014355               3.664483     4.665620
# ACH-000114         0.042644               2.446256     3.790772
# ACH-000795         0.042644               3.014355     4.677508
# ACH-000103         0.097611               3.033863     6.420044
# ACH-000144         0.028569               4.060912     4.961160
# ACH-000578         0.000000               2.358959     4.267536
# ACH-000514         0.028569               3.238787     5.713421
# ACH-000864         0.000000               2.028569     5.799605
# ACH-000305         0.014355               4.432959     4.421560
# ACH-000603         0.014355               3.229588     4.266787
# ACH-000916         0.042644               3.852998     5.120186
# ACH-000296         0.014355               4.080658     5.814038
# ACH-000978         0.000000               3.765535     5.315059
# ACH-000904         0.000000               3.831877     5.882888
# ACH-000110         0.014355               4.644433     4.605850
# ACH-000261         0.000000               2.615887     4.613532
# ACH-000031         0.070389               4.476382     4.425594
# ACH-000682         0.575312               2.871844     3.783457
#
#             OOSP4A (112577462)  ARHGAP11B (89839)  OOSP3 (112577461)
# ACH-001097            0.000000           0.443607           0.000000
# ACH-001485            0.000000           0.378512           0.000000
# ACH-001396            0.000000           0.632268           0.000000
# ACH-001804            0.000000           0.475085           0.000000
# ACH-000534            0.000000           3.904966           0.000000
# ACH-000742            0.000000           0.941106           0.000000
# ACH-000836            0.000000           2.650765           0.765535
# ACH-000545            0.000000           3.950468           0.000000
# ACH-001850            0.000000           1.959770           0.084064
# ACH-000470            0.000000           1.157044           0.000000
# ACH-001959            0.000000           1.372952           0.000000
# ACH-000079            0.000000           0.367371           0.000000
# ACH-001443            0.000000           0.189034           0.000000
# ACH-001513            0.000000           0.790772           0.000000
# ACH-000762            0.000000           1.678072           0.000000
# ACH-000495            0.000000           1.735522           0.000000
# ACH-000834            0.000000           1.042644           0.000000
# ACH-000981            0.000000           0.555816           0.000000
# ACH-001642            0.000000           1.077243           0.000000
# ACH-001020            0.000000           0.895303           0.000000
# ACH-001799            0.000000           2.895303           0.000000
# ACH-001425            0.000000           0.000000           0.000000
# ACH-001100            0.000000           0.933573           0.000000
# ACH-000652            0.000000           0.495695           0.000000
# ACH-001400            0.000000           0.687061           0.000000
# ACH-001119            0.000000           0.941106           0.000000
# ACH-001450            0.000000           1.495695           0.000000
# ACH-001520            0.000000           0.594549           0.000000
# ACH-001622            0.000000           0.815575           0.000000
# ACH-001849            0.000000           0.378512           0.000000
# ...                        ...                ...                ...
# ACH-000352            0.000000           2.182692           0.000000
# ACH-000349            0.000000           1.739848           0.070389
# ACH-000319            0.000000           2.266037           0.028569
# ACH-000181            0.000000           1.925999           0.028569
# ACH-000137            0.070389           1.967169           0.000000
# ACH-000013            0.000000           1.627607           0.000000
# ACH-000766            0.000000           2.336283           0.097611
# ACH-000675            0.000000           2.111031           0.111031
# ACH-000389            0.000000           1.521051           0.000000
# ACH-000920            0.000000           2.495695           0.042644
# ACH-000351            0.000000           1.137504           0.042644
# ACH-000394            0.000000           2.364572           0.000000
# ACH-000744            0.000000           1.925999           0.000000
# ACH-000114            0.000000           1.356144           0.000000
# ACH-000795            0.000000           3.747387           0.000000
# ACH-000103            0.000000           1.589763           0.000000
# ACH-000144            0.070389           2.207893           0.042644
# ACH-000578            0.000000           2.454176           0.000000
# ACH-000514            0.000000           2.904966           0.000000
# ACH-000864            0.000000           1.713696           0.000000
# ACH-000305            0.000000           1.350497           0.000000
# ACH-000603            0.056584           1.176323           0.000000
# ACH-000916            0.000000           2.720278           0.000000
# ACH-000296            0.000000           1.137504           0.189034
# ACH-000978            0.111031           2.384050           0.042644
# ACH-000904            0.000000           3.063503           0.000000
# ACH-000110            0.000000           1.906891           0.000000
# ACH-000261            0.000000           2.411426           0.042644
# ACH-000031            0.422233           2.014355           0.084064
# ACH-000682            0.000000           1.526069           0.000000
#
# [1283 rows x 19144 columns]

# %%
gene_mapping = tc.get(name='hgnc-87ab', file='hgnc_complete_set-2018q3')

# %%
gene_mapping
# Out:
#           hgnc_id       symbol  \
# 0          HGNC:5         A1BG
# 1      HGNC:37133     A1BG-AS1
# 2      HGNC:24086         A1CF
# 3          HGNC:7          A2M
# 4      HGNC:27057      A2M-AS1
# 5      HGNC:23336        A2ML1
# 6      HGNC:41022    A2ML1-AS1
# 7      HGNC:41523    A2ML1-AS2
# 8          HGNC:8        A2MP1
# 9      HGNC:30005      A3GALT2
# 10     HGNC:18149       A4GALT
# 11     HGNC:17968        A4GNT
# 12         HGNC:1        A12M1
# 13         HGNC:2        A12M2
# 14         HGNC:3        A12M3
# 15         HGNC:4        A12M4
# 16     HGNC:13666         AAAS
# 17        HGNC:12         AABT
# 18     HGNC:21298         AACS
# 19     HGNC:18226       AACSP1
# 20        HGNC:17        AADAC
# 21     HGNC:24427      AADACL2
# 22     HGNC:50301  AADACL2-AS1
# 23     HGNC:32037      AADACL3
# 24     HGNC:32038      AADACL4
# 25     HGNC:50305      AADACP1
# 26     HGNC:17929        AADAT
# 27     HGNC:25662        AAGAB
# 28     HGNC:19679         AAK1
# 29     HGNC:30205        AAMDC
# ...           ...          ...
# 42568  HGNC:14097      ZSCAN31
# 42569  HGNC:20812      ZSCAN32
# 42570  HGNC:16155       ZSWIM1
# 42571  HGNC:30990       ZSWIM2
# 42572  HGNC:16157       ZSWIM3
# 42573  HGNC:25704       ZSWIM4
# 42574  HGNC:29299       ZSWIM5
# 42575  HGNC:43768     ZSWIM5P1
# 42576  HGNC:43769     ZSWIM5P2
# 42577  HGNC:43770     ZSWIM5P3
# 42578  HGNC:29316       ZSWIM6
# 42579  HGNC:26993       ZSWIM7
# 42580  HGNC:23528       ZSWIM8
# 42581  HGNC:45103   ZSWIM8-AS1
# 42582  HGNC:34495       ZSWIM9
# 42583  HGNC:21224         ZUP1
# 42584  HGNC:13194         ZW10
# 42585  HGNC:25468       ZWILCH
# 42586  HGNC:13195        ZWINT
# 42587  HGNC:13196      ZWINTAS
# 42588  HGNC:13198         ZXDA
# 42589  HGNC:13199         ZXDB
# 42590  HGNC:28160         ZXDC
# 42591  HGNC:32058       ZYG11A
# 42592  HGNC:38032     ZYG11AP1
# 42593  HGNC:25820       ZYG11B
# 42594  HGNC:13200          ZYX
# 42595  HGNC:51695        ZYXP1
# 42596  HGNC:29027        ZZEF1
# 42597  HGNC:24523         ZZZ3
#
#                                                     name          locus_group  \
# 0                                 alpha-1-B glycoprotein  protein-coding gene
# 1                                   A1BG antisense RNA 1       non-coding RNA
# 2                         APOBEC1 complementation factor  protein-coding gene
# 3                                  alpha-2-macroglobulin  protein-coding gene
# 4                                    A2M antisense RNA 1       non-coding RNA
# 5                           alpha-2-macroglobulin like 1  protein-coding gene
# 6                                  A2ML1 antisense RNA 1       non-coding RNA
# 7                                  A2ML1 antisense RNA 2       non-coding RNA
# 8                     alpha-2-macroglobulin pseudogene 1           pseudogene
# 9                      alpha 1,3-galactosyltransferase 2  protein-coding gene
# 10       alpha 1,4-galactosyltransferase (P blood group)  protein-coding gene
# 11             alpha-1,4-N-acetylglucosaminyltransferase  protein-coding gene
# 12                                       entry withdrawn            withdrawn
# 13                                       entry withdrawn            withdrawn
# 14                                       entry withdrawn            withdrawn
# 15                                       entry withdrawn            withdrawn
# 16                          aladin WD repeat nucleoporin  protein-coding gene
# 17                                       entry withdrawn            withdrawn
# 18                            acetoacetyl-CoA synthetase  protein-coding gene
# 19               acetoacetyl-CoA synthetase pseudogene 1           pseudogene
# 20                             arylacetamide deacetylase  protein-coding gene
# 21                      arylacetamide deacetylase like 2  protein-coding gene
# 22                               AADACL2 antisense RNA 1       non-coding RNA
# 23                      arylacetamide deacetylase like 3  protein-coding gene
# 24                      arylacetamide deacetylase like 4  protein-coding gene
# 25                arylacetamide deacetylase pseudogene 1           pseudogene
# 26                         aminoadipate aminotransferase  protein-coding gene
# 27               alpha and gamma adaptin binding protein  protein-coding gene
# 28                               AP2 associated kinase 1  protein-coding gene
# 29      adipogenesis associated Mth938 domain containing  protein-coding gene
# ...                                                  ...                  ...
# 42568          zinc finger and SCAN domain containing 31  protein-coding gene
# 42569          zinc finger and SCAN domain containing 32  protein-coding gene
# 42570                 zinc finger SWIM-type containing 1  protein-coding gene
# 42571                 zinc finger SWIM-type containing 2  protein-coding gene
# 42572                 zinc finger SWIM-type containing 3  protein-coding gene
# 42573                 zinc finger SWIM-type containing 4  protein-coding gene
# 42574                 zinc finger SWIM-type containing 5  protein-coding gene
# 42575    zinc finger SWIM-type containing 5 pseudogene 1           pseudogene
# 42576    zinc finger SWIM-type containing 5 pseudogene 2           pseudogene
# 42577    zinc finger SWIM-type containing 5 pseudogene 3           pseudogene
# 42578                 zinc finger SWIM-type containing 6  protein-coding gene
# 42579                 zinc finger SWIM-type containing 7  protein-coding gene
# 42580                 zinc finger SWIM-type containing 8  protein-coding gene
# 42581                             ZSWIM8 antisense RNA 1       non-coding RNA
# 42582                 zinc finger SWIM-type containing 9  protein-coding gene
# 42583       zinc finger containing ubiquitin peptidase 1  protein-coding gene
# 42584                           zw10 kinetochore protein  protein-coding gene
# 42585                         zwilch kinetochore protein  protein-coding gene
# 42586               ZW10 interacting kinetochore protein  protein-coding gene
# 42587                                    entry withdrawn            withdrawn
# 42588                  zinc finger X-linked duplicated A  protein-coding gene
# 42589                  zinc finger X-linked duplicated B  protein-coding gene
# 42590                           ZXD family zinc finger C  protein-coding gene
# 42591       zyg-11 family member A, cell cycle regulator  protein-coding gene
# 42592  zyg-11 family member A, cell cycle regulator p...           pseudogene
# 42593       zyg-11 family member B, cell cycle regulator  protein-coding gene
# 42594                                              zyxin  protein-coding gene
# 42595                                 zyxin pseudogene 1           pseudogene
# 42596  zinc finger ZZ-type and EF-hand domain contain...  protein-coding gene
# 42597                   zinc finger ZZ-type containing 3  protein-coding gene
#
#                       locus_type           status  location location_sortable  \
# 0      gene with protein product         Approved  19q13.43          19q13.43
# 1           RNA, long non-coding         Approved  19q13.43          19q13.43
# 2      gene with protein product         Approved  10q11.23          10q11.23
# 3      gene with protein product         Approved  12p13.31          12p13.31
# 4           RNA, long non-coding         Approved  12p13.31          12p13.31
# 5      gene with protein product         Approved  12p13.31          12p13.31
# 6           RNA, long non-coding         Approved  12p13.31          12p13.31
# 7           RNA, long non-coding         Approved  12p13.31          12p13.31
# 8                     pseudogene         Approved  12p13.31          12p13.31
# 9      gene with protein product         Approved    1p35.1           01p35.1
# 10     gene with protein product         Approved   22q13.2           22q13.2
# 11     gene with protein product         Approved    3q22.3           03q22.3
# 12                     withdrawn  Entry Withdrawn       NaN               NaN
# 13                     withdrawn  Entry Withdrawn       NaN               NaN
# 14                     withdrawn  Entry Withdrawn       NaN               NaN
# 15                     withdrawn  Entry Withdrawn       NaN               NaN
# 16     gene with protein product         Approved  12q13.13          12q13.13
# 17                     withdrawn  Entry Withdrawn       NaN               NaN
# 18     gene with protein product         Approved  12q24.31          12q24.31
# 19                    pseudogene         Approved    5q35.3           05q35.3
# 20     gene with protein product         Approved    3q25.1           03q25.1
# 21     gene with protein product         Approved    3q25.1           03q25.1
# 22          RNA, long non-coding         Approved    3q25.1           03q25.1
# 23     gene with protein product         Approved   1p36.21          01p36.21
# 24     gene with protein product         Approved   1p36.21          01p36.21
# 25                    pseudogene         Approved    3q25.1           03q25.1
# 26     gene with protein product         Approved      4q33             04q33
# 27     gene with protein product         Approved     15q23             15q23
# 28     gene with protein product         Approved    2p13.3           02p13.3
# 29     gene with protein product         Approved   11q14.1           11q14.1
# ...                          ...              ...       ...               ...
# 42568  gene with protein product         Approved    6p22.1           06p22.1
# 42569  gene with protein product         Approved   16p13.3           16p13.3
# 42570  gene with protein product         Approved  20q13.12          20q13.12
# 42571  gene with protein product         Approved    2q32.1           02q32.1
# 42572  gene with protein product         Approved  20q13.12          20q13.12
# 42573  gene with protein product         Approved  19p13.13          19p13.13
# 42574  gene with protein product         Approved    1p34.1           01p34.1
# 42575                 pseudogene         Approved     17p12             17p12
# 42576                 pseudogene         Approved   17p11.2           17p11.2
# 42577                 pseudogene         Approved    4q28.2           04q28.2
# 42578  gene with protein product         Approved    5q12.1           05q12.1
# 42579  gene with protein product         Approved     17p12             17p12
# 42580  gene with protein product         Approved   10q22.2           10q22.2
# 42581       RNA, long non-coding         Approved   10q22.2           10q22.2
# 42582  gene with protein product         Approved  19q13.33          19q13.33
# 42583  gene with protein product         Approved    6q22.1           06q22.1
# 42584  gene with protein product         Approved   11q23.2           11q23.2
# 42585  gene with protein product         Approved  15q22.31          15q22.31
# 42586  gene with protein product         Approved   10q21.1           10q21.1
# 42587                  withdrawn  Entry Withdrawn       NaN               NaN
# 42588  gene with protein product         Approved   Xp11.21           Xp11.21
# 42589  gene with protein product         Approved   Xp11.21           Xp11.21
# 42590  gene with protein product         Approved    3q21.3           03q21.3
# 42591  gene with protein product         Approved    1p32.3           01p32.3
# 42592                 pseudogene         Approved    9q31.1           09q31.1
# 42593  gene with protein product         Approved    1p32.3           01p32.3
# 42594  gene with protein product         Approved      7q34             07q34
# 42595                 pseudogene         Approved   8q24.23          08q24.23
# 42596  gene with protein product         Approved   17p13.2           17p13.2
# 42597  gene with protein product         Approved    1p31.1           01p31.1
#
#                         alias_symbol  \
# 0                                NaN
# 1                           FLJ23569
# 2      ACF|ASP|ACF64|ACF65|APOBEC1CF
# 3               FWP007|S863-7|CPAMD5
# 4                                NaN
# 5                      FLJ25179|p170
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                       IGBS3S|IGB3S
# 10                 A14GALT|Gb3S|P(k)
# 11                         alpha4GnT
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18              FLJ12389|SUR-5|ACSF1
# 19                               NaN
# 20                        DAC|CES5A1
# 21                          MGC72001
# 22                               NaN
# 23                OTTHUMG00000001887
# 24                OTTHUMG00000001889
# 25                               NaN
# 26                  KATII|KAT2|KYAT2
# 27                      FLJ11506|p34
# 28           KIAA1048|DKFZp686K16132
# 29             PTD015|FLJ21035|CK067
# ...                              ...
# 42568                            NaN
# 42569                       FLJ20417
# 42570                     dJ337O18.5
# 42571              MGC33890|ZZZ2|MEX
# 42572            dJ337O18.7|PPP1R174
# 42573                       FLJ12221
# 42574                       KIAA1511
# 42575                            NaN
# 42576                            NaN
# 42577                            NaN
# 42578                       KIAA1577
# 42579                           SWS1
# 42580                  4832404P21Rik
# 42581                            NaN
# 42582                      LOC374920
# 42583                      dJ412I7.3
# 42584                        KNTC1AP
# 42585               FLJ10036|KNTC1AP
# 42586           KNTC2AP|SIP30|Zwint1
# 42587                            NaN
# 42588                         ZNF896
# 42589                         ZNF905
# 42590              MGC11349|FLJ13861
# 42591                          ZYG11
# 42592                            NaN
# 42593                       FLJ13456
# 42594                            NaN
# 42595                            NaN
# 42596         KIAA0399|ZZZ4|FLJ10821
# 42597             DKFZP564I052|ATAC1
#
#                                               alias_name  ...   merops imgt  \
# 0                                                    NaN  ...  I43.950  NaN
# 1                                                    NaN  ...      NaN  NaN
# 2                                                    NaN  ...      NaN  NaN
# 3                                                    NaN  ...  I39.001  NaN
# 4                                                    NaN  ...      NaN  NaN
# 5                                                    NaN  ...  I39.007  NaN
# 6                                                    NaN  ...      NaN  NaN
# 7                                                    NaN  ...      NaN  NaN
# 8                                                    NaN  ...      NaN  NaN
# 9        iGb3 synthase|isoglobotriaosylceramide synthase  ...      NaN  NaN
# 10     Gb3 synthase|CD77 synthase|globotriaosylcerami...  ...      NaN  NaN
# 11                                                   NaN  ...      NaN  NaN
# 12                                                   NaN  ...      NaN  NaN
# 13                                                   NaN  ...      NaN  NaN
# 14                                                   NaN  ...      NaN  NaN
# 15                                                   NaN  ...      NaN  NaN
# 16                   aladin|Allgrove, triple-A|adracalin  ...      NaN  NaN
# 17                                                   NaN  ...      NaN  NaN
# 18                   acyl-CoA synthetase family member 1  ...      NaN  NaN
# 19                                                   NaN  ...      NaN  NaN
# 20                                                   NaN  ...  S09.991  NaN
# 21                                                   NaN  ...      NaN  NaN
# 22                                                   NaN  ...      NaN  NaN
# 23                                                   NaN  ...      NaN  NaN
# 24                                                   NaN  ...      NaN  NaN
# 25                                                   NaN  ...      NaN  NaN
# 26     kynurenine aminotransferase II|L kynurenine/al...  ...      NaN  NaN
# 27                                                   NaN  ...      NaN  NaN
# 28                                                   NaN  ...      NaN  NaN
# 29                                                   NaN  ...      NaN  NaN
# ...                                                  ...  ...      ...  ...
# 42568                                                NaN  ...      NaN  NaN
# 42569                                                NaN  ...      NaN  NaN
# 42570                                                NaN  ...      NaN  NaN
# 42571                                                NaN  ...      NaN  NaN
# 42572      protein phosphatase 1, regulatory subunit 174  ...      NaN  NaN
# 42573                                                NaN  ...      NaN  NaN
# 42574                                                NaN  ...      NaN  NaN
# 42575                                                NaN  ...      NaN  NaN
# 42576                                                NaN  ...      NaN  NaN
# 42577                                                NaN  ...      NaN  NaN
# 42578                                                NaN  ...      NaN  NaN
# 42579  SWIM domain containing Srs2 interacting protein 1  ...      NaN  NaN
# 42580                                                NaN  ...      NaN  NaN
# 42581                                                NaN  ...      NaN  NaN
# 42582                                                NaN  ...      NaN  NaN
# 42583                                                NaN  ...      NaN  NaN
# 42584                                                NaN  ...      NaN  NaN
# 42585                                                NaN  ...      NaN  NaN
# 42586               SNAP25 interacting protein of 30 kDa  ...      NaN  NaN
# 42587                                                NaN  ...      NaN  NaN
# 42588                            zinc finger protein 896  ...      NaN  NaN
# 42589                                                NaN  ...      NaN  NaN
# 42590                                                NaN  ...      NaN  NaN
# 42591                                                NaN  ...      NaN  NaN
# 42592                                                NaN  ...      NaN  NaN
# 42593                                                NaN  ...      NaN  NaN
# 42594                                                NaN  ...      NaN  NaN
# 42595                                                NaN  ...      NaN  NaN
# 42596                                                NaN  ...      NaN  NaN
# 42597              ATAC component 1 homolog (Drosophila)  ...      NaN  NaN
#
#       iuphar kznf_gene_catalog mamit-trnadb   cd lncrnadb         enzyme_id  \
# 0        NaN               NaN          NaN  NaN      NaN               NaN
# 1        NaN               NaN          NaN  NaN      NaN               NaN
# 2        NaN               NaN          NaN  NaN      NaN               NaN
# 3        NaN               NaN          NaN  NaN      NaN               NaN
# 4        NaN               NaN          NaN  NaN      NaN               NaN
# 5        NaN               NaN          NaN  NaN      NaN               NaN
# 6        NaN               NaN          NaN  NaN      NaN               NaN
# 7        NaN               NaN          NaN  NaN      NaN               NaN
# 8        NaN               NaN          NaN  NaN      NaN               NaN
# 9        NaN               NaN          NaN  NaN      NaN               NaN
# 10       NaN               NaN          NaN  NaN      NaN         2.4.1.228
# 11       NaN               NaN          NaN  NaN      NaN               NaN
# 12       NaN               NaN          NaN  NaN      NaN               NaN
# 13       NaN               NaN          NaN  NaN      NaN               NaN
# 14       NaN               NaN          NaN  NaN      NaN               NaN
# 15       NaN               NaN          NaN  NaN      NaN               NaN
# 16       NaN               NaN          NaN  NaN      NaN               NaN
# 17       NaN               NaN          NaN  NaN      NaN               NaN
# 18       NaN               NaN          NaN  NaN      NaN          6.2.1.16
# 19       NaN               NaN          NaN  NaN      NaN               NaN
# 20       NaN               NaN          NaN  NaN      NaN           3.1.1.3
# 21       NaN               NaN          NaN  NaN      NaN               NaN
# 22       NaN               NaN          NaN  NaN      NaN               NaN
# 23       NaN               NaN          NaN  NaN      NaN               NaN
# 24       NaN               NaN          NaN  NaN      NaN               NaN
# 25       NaN               NaN          NaN  NaN      NaN               NaN
# 26       NaN               NaN          NaN  NaN      NaN  2.6.1.39|2.6.1.7
# 27       NaN               NaN          NaN  NaN      NaN               NaN
# 28       NaN               NaN          NaN  NaN      NaN               NaN
# 29       NaN               NaN          NaN  NaN      NaN               NaN
# ...      ...               ...          ...  ...      ...               ...
# 42568    NaN             432.0          NaN  NaN      NaN               NaN
# 42569    NaN             104.0          NaN  NaN      NaN               NaN
# 42570    NaN               NaN          NaN  NaN      NaN               NaN
# 42571    NaN               NaN          NaN  NaN      NaN               NaN
# 42572    NaN               NaN          NaN  NaN      NaN               NaN
# 42573    NaN               NaN          NaN  NaN      NaN               NaN
# 42574    NaN               NaN          NaN  NaN      NaN               NaN
# 42575    NaN               NaN          NaN  NaN      NaN               NaN
# 42576    NaN               NaN          NaN  NaN      NaN               NaN
# 42577    NaN               NaN          NaN  NaN      NaN               NaN
# 42578    NaN               NaN          NaN  NaN      NaN               NaN
# 42579    NaN               NaN          NaN  NaN      NaN               NaN
# 42580    NaN               NaN          NaN  NaN      NaN               NaN
# 42581    NaN               NaN          NaN  NaN      NaN               NaN
# 42582    NaN               NaN          NaN  NaN      NaN               NaN
# 42583    NaN               NaN          NaN  NaN      NaN               NaN
# 42584    NaN               NaN          NaN  NaN      NaN               NaN
# 42585    NaN               NaN          NaN  NaN      NaN               NaN
# 42586    NaN               NaN          NaN  NaN      NaN               NaN
# 42587    NaN               NaN          NaN  NaN      NaN               NaN
# 42588    NaN             573.0          NaN  NaN      NaN               NaN
# 42589    NaN             572.0          NaN  NaN      NaN               NaN
# 42590    NaN               NaN          NaN  NaN      NaN               NaN
# 42591    NaN               NaN          NaN  NaN      NaN               NaN
# 42592    NaN               NaN          NaN  NaN      NaN               NaN
# 42593    NaN               NaN          NaN  NaN      NaN               NaN
# 42594    NaN               NaN          NaN  NaN      NaN               NaN
# 42595    NaN               NaN          NaN  NaN      NaN               NaN
# 42596    NaN               NaN          NaN  NaN      NaN               NaN
# 42597    NaN               NaN          NaN  NaN      NaN               NaN
#
#        intermediate_filament_db rna_central_ids
# 0                           NaN             NaN
# 1                           NaN   URS00007E4F6E
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN   URS00001F234A
# 5                           NaN             NaN
# 6                           NaN   URS00005F9A07
# 7                           NaN   URS00001BFF15
# 8                           NaN             NaN
# 9                           NaN             NaN
# 10                          NaN             NaN
# 11                          NaN             NaN
# 12                          NaN             NaN
# 13                          NaN             NaN
# 14                          NaN             NaN
# 15                          NaN             NaN
# 16                          NaN             NaN
# 17                          NaN             NaN
# 18                          NaN             NaN
# 19                          NaN             NaN
# 20                          NaN             NaN
# 21                          NaN             NaN
# 22                          NaN   URS000075D0ED
# 23                          NaN             NaN
# 24                          NaN             NaN
# 25                          NaN             NaN
# 26                          NaN             NaN
# 27                          NaN             NaN
# 28                          NaN             NaN
# 29                          NaN             NaN
# ...                         ...             ...
# 42568                       NaN             NaN
# 42569                       NaN             NaN
# 42570                       NaN             NaN
# 42571                       NaN             NaN
# 42572                       NaN             NaN
# 42573                       NaN             NaN
# 42574                       NaN             NaN
# 42575                       NaN             NaN
# 42576                       NaN             NaN
# 42577                       NaN             NaN
# 42578                       NaN             NaN
# 42579                       NaN             NaN
# 42580                       NaN             NaN
# 42581                       NaN   URS000075C76D
# 42582                       NaN             NaN
# 42583                       NaN             NaN
# 42584                       NaN             NaN
# 42585                       NaN             NaN
# 42586                       NaN             NaN
# 42587                       NaN             NaN
# 42588                       NaN             NaN
# 42589                       NaN             NaN
# 42590                       NaN             NaN
# 42591                       NaN             NaN
# 42592                       NaN             NaN
# 42593                       NaN             NaN
# 42594                       NaN             NaN
# 42595                       NaN             NaN
# 42596                       NaN             NaN
# 42597                       NaN             NaN
#
# [42598 rows x 49 columns]

# %%
gene_mapping[gene_mapping["ensembl_gene_id"]=='ENSG00000271743']
# Out:
# Empty DataFrame
# Columns: [hgnc_id, symbol, name, locus_group, locus_type, status, location, location_sortable, alias_symbol, alias_name, prev_symbol, prev_name, gene_family, gene_family_id, date_approved_reserved, date_symbol_changed, date_name_changed, date_modified, entrez_id, ensembl_gene_id, vega_id, ucsc_id, ena, refseq_accession, ccds_id, uniprot_ids, pubmed_id, mgd_id, rgd_id, lsdb, cosmic, omim_id, mirbase, homeodb, snornabase, bioparadigms_slc, orphanet, pseudogene.org, horde_id, merops, imgt, iuphar, kznf_gene_catalog, mamit-trnadb, cd, lncrnadb, enzyme_id, intermediate_filament_db, rna_central_ids]
# Index: []
#
# [0 rows x 49 columns]

# %%
gene_mapping.shape
# Out:
# (42598, 49)

# %%
i = 0
b=0
for val in nonoverlapping:
    val = val.split(".")[0]
    a = gene_mapping["locus_group"][gene_mapping["ensembl_gene_id"]==val].values
    if len(a) > 0:
        if a[0] == "protein-coding gene":
            i+=1
    else:
        b+=1

# %%
i
# Out:
# 0

# %%
b
# Out:
# 15506

# %%
len(nonoverlapping)
# Out:
# 15506

# %%
! mv temp/expression/* AMLproject/data

# %% [markdown]
# ## Fusion post processing

# %%
terra.wait_for_submission(submission_id2)

# %%
aggregate = refwm.get_config('Aggregate_Fusion_Calls')
aggregate
# Out:
# {'deleted': False,
#  'inputs': {'aggregate_set_files_workflow.aggregate_set_files.disk_space': '250',
#   'aggregate_set_files_workflow.aggregate_set_files.output_file_name': '"Fusions.aggregated.tsv"',
#   'aggregate_set_files_workflow.aggregate_set_files.aggregate_files_script': 'workspace.aggregate_fusions_script',
#   'aggregate_set_files_workflow.aggregate_set_files.num_preempt': '5',
#   'aggregate_set_files_workflow.aggregate_set_files.sample_files': 'this.samples.fusion_predictions_abridged',
#   'aggregate_set_files_workflow.aggregate_set_files.memory': '3'},
#  'methodConfigVersion': 7,
#  'methodRepoMethod': {'methodName': 'Aggregate_files_set',
#   'methodVersion': 2,
#   'methodNamespace': 'gkugener',
#   'methodUri': 'agora://gkugener/Aggregate_files_set/2',
#   'sourceRepo': 'agora'},
#  'name': 'Aggregate_Fusion_Calls',
#  'namespace': 'gkugener',
#  'outputs': {'aggregate_set_files_workflow.aggregate_set_files.output_merged_file': 'this.fusions_star'},
#  'prerequisites': {},
#  'rootEntityType': 'sample_set'}

# %%
refwm.update_config(aggregate)
submission_id2 = refwm.create_submission(aggregate['name'], 'All_samples')
# Out:
# Successfully updated configuration gkugener/Aggregate_Fusion_Calls
# Successfully created submission c853b79b-c226-4b29-a718-5875b7f74e10.

# %%
terra.wait_for_submission(submission_id2)

# %%
refwm.get_sample_sets().loc['All_samples']['fusions_star']
# Out:
# fusions_star                                                                     NaN
# mergedExonUsageRObj_hg38                                                         NaN
# rsem_genes_expected_count                                                        NaN
# rsem_genes_tpm                                                                   NaN
# rsem_transcripts_expected_count                                                  NaN
# rsem_transcripts_isopct                                                          NaN
# rsem_transcripts_tpm                                                             NaN
# samples                            [dm_ACH-000001, dm_ACH-000002, dm_ACH-000003, ...
# Name: all_samples, dtype: object

# %%
! gsutil cp $aggregated "temp/fusion.Fusions.aggregated.tsv"
# Out:
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/15ab70c1-73af-44bc-9aeb-750ef6d70bc8/aggregate_set_files_workflow/7d6bdfe1-27fb-478b-ade1-fcda622c4960/call-aggregate_set_files/Fusions.aggregated.tsv...
# / [1 files][ 30.2 KiB/ 30.2 KiB]
# Operation completed over 1 objects/30.2 KiB.

# %% [markdown]
# ### Overview
#
# This document contains the code used to generate the unfiltered and filtered versions of the fusion datasets for the release. The bottom of the document also contains some comparisons between the release fusion dataset, CCLE2 fusion calls, and the translocation data from CCLE2.

# %%
# %%R
# source("CCLE_postp_function.R")
# filepath <- 'temp/fusion.Fusions.aggregated.tsv'

# %% [markdown]
# ## Generate filtered fusion table
#
# Release: `r release`
#
# We want to apply filters to the fusion table to reduce the number of artifacts in the dataset. Specifically, we filter the following:
#
# * Remove fusions involving mitochondrial chromosomes, or HLA genes, or immunoglobulin genes
# * Remove red herring fusions (from STAR-Fusion annotations column)
# * Remove recurrent in CCLE (>= 25 samples)
# * Remove fusion with (SpliceType=" INCL_NON_REF_SPLICE" and LargeAnchorSupport="No" and FFPM < 0.1)
# * Remove fusions with FFPM < 0.05 (STAR-Fusion suggests using 0.1, but looking at the translocation data, this looks like it might be too aggressive)

# %%
# %%R
# unfiltered_fusions <- read_fusions(filepath)
# filtered_fusions <- filter_fusions(unfiltered_fusions)

# %%
# %%R
# # Save the files (to be uploaded to taiga)
# write.table(
#   unfiltered_fusions,
#   file = paste0('temp/fusions.',release, '.unfiltered.tsv'),
#   sep = '\t', quote = F, row.names = F
# )
# write.table(
#   filtered_fusions,
#   file = paste0('temp/fusions.', release, '.filtered.tsv'),
#   sep = '\t', quote = F, row.names = F
# )

# %% [markdown]
# # IF want to merge here instead of on Terra:

# %%
res = refwm.get_samples().loc['ibm_ACH-001616']
genes_fusion = res['fusion_predictions_abridged']
rsem_genes_transcripts = res['rsem_isoforms']
rsem_genes_expected_count = res['rsem_genes']

! gsutil cp $rsem_genes_expected_count "temp/expression.genes.results" && gsutil cp $rsem_genes_transcripts "temp/expression.transcripts.results" && gsutil cp $genes_fusion "temp/expression.fusion.tsv"
# Out:
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/25b86d44-d5d3-481a-9c29-5438c9905f44/rsem_workflow/7b23b231-27f3-47c4-b3bb-8df48393b187/call-rsem/ibm_ACH-001616.rsem.genes.results...
# / [1 files][  6.3 MiB/  6.3 MiB]
# Operation completed over 1 objects/6.3 MiB.
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/25b86d44-d5d3-481a-9c29-5438c9905f44/rsem_workflow/7b23b231-27f3-47c4-b3bb-8df48393b187/call-rsem/ibm_ACH-001616.rsem.isoforms.results...
# Resuming download for temp/expression.transcripts.results
# / [1 files][ 13.6 MiB/ 13.6 MiB]
# Operation completed over 1 objects/13.6 MiB.
# Copying gs://fc-secure-639c94ba-2b0d-4960-92fc-9cd50046a968/988fb43c-f90d-4327-ba52-be47db7d5f46/trinity_cleaned/9570c783-9757-4a32-a569-b98d02b8a7d6/call-StarFusion/attempt-2/ibm_ACH-001616.star-fusion.fusion_predictions.abridged.tsv...
# / [1 files][ 23.3 KiB/ 23.3 KiB]
# Operation completed over 1 objects/23.3 KiB.

# %%
# %%R
# library("taigr")
# source('CCLE_postp_function.R')
# source('../JKBio/gkugener/RScripts/load_libraries_and_annotations.R')
# Out:
# 2019-06-18 09:16:41::WARNING  R[write to console]: Loading required package: RCurl
#
# 2019-06-18 09:16:41::WARNING  R[write to console]: Loading required package: bitops
#
# 2019-06-18 09:16:41::WARNING  R[write to console]: Loading required package: httr
#
# 2019-06-18 09:16:41::WARNING  R[write to console]: Loading required package: AnnotationDbi
#
# 2019-06-18 09:16:41::WARNING  R[write to console]: Loading required package: stats4
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Loading required package: BiocGenerics
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Loading required package: parallel
#
# 2019-06-18 09:16:42::WARNING  R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Loading required package: Biobase
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]:
# Attaching package: ‘Biobase’
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: The following object is masked from ‘package:httr’:
#
#     content
#
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Loading required package: IRanges
#
# 2019-06-18 09:16:42::WARNING  R[write to console]: Loading required package: S4Vectors
#
# 2019-06-18 09:16:43::WARNING  R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# 2019-06-18 09:16:43::WARNING  R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# 2019-06-18 09:16:44::WARNING  R[write to console]:
#
# 2019-06-18 09:16:44::WARNING  R[write to console]:
# Attaching package: ‘plyr’
#
#
# 2019-06-18 09:16:44::WARNING  R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     desc
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]:
# Attaching package: ‘dplyr’
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# 2019-06-18 09:16:45::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: ✔ ggplot2 3.1.1     ✔ tidyr   0.8.3
# ✔ tibble  2.1.3     ✔ purrr   0.3.2
# ✔ ggplot2 3.1.1     ✔ forcats 0.4.0
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()    masks plyr::arrange()
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ purrr::compact()    masks plyr::compact()
# ✖ tidyr::complete()   masks RCurl::complete()
# ✖ Biobase::content()  masks httr::content()
# ✖ dplyr::count()      masks plyr::count()
# ✖ dplyr::desc()       masks plyr::desc(), IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::failwith()   masks plyr::failwith()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::id()         masks plyr::id()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ dplyr::mutate()     masks plyr::mutate()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks IRanges::reduce()
# ✖ dplyr::rename()     masks plyr::rename(), S4Vectors::rename()
# ✖ dplyr::select()     masks AnnotationDbi::select()
# ✖ dplyr::slice()      masks IRanges::slice()
# ✖ dplyr::summarise()  masks plyr::summarise()
# ✖ dplyr::summarize()  masks plyr::summarize()
#
# 2019-06-18 09:16:46::WARNING  R[write to console]:
# Attaching package: ‘magrittr’
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]:
# Attaching package: ‘reshape2’
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# 2019-06-18 09:16:46::WARNING  R[write to console]: Error in library(sva) : there is no package called ‘sva’
# Calls: <Anonymous> ... withVisible -> source -> withVisible -> eval -> eval -> library
# Error in library(sva) : there is no package called ‘sva’
# Calls: <Anonymous> ... withVisible -> source -> withVisible -> eval -> eval -> library

# %%
# %%R
# dataset <- list(genes_count= load.from.taiga(data.name='depmap-rnaseq-expression-data-363a', data.file='CCLE_depMap_19Q2_RNAseq_reads'),trancripts =load.from.taiga(data.name='depmap-rnaseq-expression-data-363a', data.file='CCLE_depMap_19Q2_TPM_transcripts'),genes_tpm = load.from.taiga(data.name='depmap-rnaseq-expression-data-363a', data.file='CCLE_depMap_19Q2_TPM'))
#
# download.raw.from.taiga(data.name='gene-fusions-8b7a', data.file='temp/fusions.prevunfiltered.tsv')
#
# listOfSamples<- list( genes_count= c("temp/expression.genes.results"), trancripts= c("temp/expression.transcripts.results"), fusions= c("temp/expression.fusion.tsv"))
# Out:
# Fetching https://cds.team/taiga/api/datafile?format=metadata&dataset_permaname=depmap-rnaseq-expression-data-363a&datafile_name=CCLE_depMap_19Q2_RNAseq_reads
# Status 200
# 2019-06-18 09:19:15::WARNING  R[write to console]: No encoding supplied: defaulting to UTF-8.
#
# 2019-06-18 09:19:15::WARNING  R[write to console]: Loading from cached file /home/jeremie/.taiga/7c31f9e4f7554078af3e0726a8afaf44_ccle-depmap-19q2-rnaseq-reads.rds
# Fetching https://cds.team/taiga/api/datafile?format=metadata&dataset_permaname=depmap-rnaseq-expression-data-363a&datafile_name=CCLE_depMap_19Q2_TPM_transcripts
# Status 200
# 2019-06-18 09:19:25::WARNING  R[write to console]: No encoding supplied: defaulting to UTF-8.
#
# 2019-06-18 09:19:25::WARNING  R[write to console]: Loading from cached file /home/jeremie/.taiga/7c31f9e4f7554078af3e0726a8afaf44_ccle-depmap-19q2-tpm-transcripts.rds
# Fetching https://cds.team/taiga/api/datafile?format=metadata&dataset_permaname=depmap-rnaseq-expression-data-363a&datafile_name=CCLE_depMap_19Q2_TPM
# Status 200
# 2019-06-18 09:20:09::WARNING  R[write to console]: No encoding supplied: defaulting to UTF-8.
#
# 2019-06-18 09:20:09::WARNING  R[write to console]: Loading from cached file /home/jeremie/.taiga/7c31f9e4f7554078af3e0726a8afaf44_ccle-depmap-19q2-tpm.rds
# Fetching https://cds.team/taiga/api/datafile?format=metadata&dataset_permaname=gene-fusions-8b7a&datafile_name=temp%2Ffusions.prevunfiltered.tsv
# Status 404

# %%
# %%R
# head(dataset$genes_count)
# Out:
#            TSPAN6 (ENSG00000000003) TNMD (ENSG00000000005)
# ACH-001097                        0                      0
#            DPM1 (ENSG00000000419) SCYL3 (ENSG00000000457)
# ACH-001097                   3104                 1920.90
#            C1orf112 (ENSG00000000460) FGR (ENSG00000000938)
# ACH-001097                    4826.10                  6464
#            CFH (ENSG00000000971) FUCA2 (ENSG00000001036) GCLC (ENSG00000001084)
# ACH-001097                328.99                  1098.0                   1396
#            NFYA (ENSG00000001167) STPG1 (ENSG00000001460)
# ACH-001097                   1819                     234
#            NIPAL3 (ENSG00000001461) LAS1L (ENSG00000001497)
# ACH-001097                     1591                    9774
#            ENPP4 (ENSG00000001561) SEMA3F (ENSG00000001617)
# ACH-001097                     629                        0
#            CFTR (ENSG00000001626) ANKIB1 (ENSG00000001629)
# ACH-001097                      1                     2696
#            CYP51A1 (ENSG00000001630) KRIT1 (ENSG00000001631)
# ACH-001097                    7824.9                  2871.0
#            RAD52 (ENSG00000002016) MYH16 (ENSG00000002079)
# ACH-001097                     704                      71
#            BAD (ENSG00000002330) LAP3 (ENSG00000002549) CD99 (ENSG00000002586)
# ACH-001097                4881.6                   6128                  18210
#            HS3ST1 (ENSG00000002587) AOC1 (ENSG00000002726)
# ACH-001097                        0                      0
#            WNT16 (ENSG00000002745) HECW1 (ENSG00000002746)
# ACH-001097                       1                      17
#            MAD1L1 (ENSG00000002822) LASP1 (ENSG00000002834)
# ACH-001097                     9000                 12456.0
#            SNX11 (ENSG00000002919) TMEM176A (ENSG00000002933)
# ACH-001097                    1556                          5
#            M6PR (ENSG00000003056) KLHL13 (ENSG00000003096)
# ACH-001097                10307.0                        0
#            CYP26B1 (ENSG00000003137) ICA1 (ENSG00000003147)
# ACH-001097                         0                    240
#            DBNDD1 (ENSG00000003249) ALS2 (ENSG00000003393)
# ACH-001097                        1                    616
#            CASP10 (ENSG00000003400) CFLAR (ENSG00000003402)
# ACH-001097                       60                 21797.0
#            TFPI (ENSG00000003436) NDUFAF7 (ENSG00000003509)
# ACH-001097                      1                   1175.30
#            RBM5 (ENSG00000003756) MTMR7 (ENSG00000003987)
# ACH-001097                14449.0                   34.74
#            SLC7A2 (ENSG00000003989) ARF5 (ENSG00000004059)
# ACH-001097                        0                13136.0
#            SARM1 (ENSG00000004139) POLDIP2 (ENSG00000004142)
# ACH-001097                 1961.10                     11432
#            PLXND1 (ENSG00000004399) AK2 (ENSG00000004455)
# ACH-001097                        0               16336.0
#            CD38 (ENSG00000004468) FKBP4 (ENSG00000004478)
# ACH-001097                   4403                 15942.0
#            KDM1A (ENSG00000004487) RBM6 (ENSG00000004534)
# ACH-001097                    7840                  10504
#            CAMKK1 (ENSG00000004660) RECQL (ENSG00000004700)
# ACH-001097                       49                 7710.50
#            VPS50 (ENSG00000004766) HSPB6 (ENSG00000004776)
# ACH-001097                    2016                   51.52
#            ARHGAP33 (ENSG00000004777) NDUFAB1 (ENSG00000004779)
# ACH-001097                     1295.9                      9736
#            PDK4 (ENSG00000004799) SLC22A16 (ENSG00000004809)
# ACH-001097                      1                          0
#            ZMYND10 (ENSG00000004838) ABCB5 (ENSG00000004846)
# ACH-001097                       384                       1
#            ARX (ENSG00000004848) SLC25A13 (ENSG00000004864)
# ACH-001097                     1                          0
#            ST7 (ENSG00000004866) CDC27 (ENSG00000004897)
# ACH-001097               1976.80                    6124
#            SLC4A1 (ENSG00000004939) CALCR (ENSG00000004948)
# ACH-001097                        0                       0
#            HCCS (ENSG00000004961) DVL2 (ENSG00000004975)
# ACH-001097                   1854                   4496
#            PRSS22 (ENSG00000005001) UPF1 (ENSG00000005007)
# ACH-001097                        0                   7233
#            SKAP2 (ENSG00000005020) SLC25A5 (ENSG00000005022)
# ACH-001097                       0                   37463.0
#            MCUB (ENSG00000005059) HOXA11 (ENSG00000005073)
# ACH-001097                   6075                     0.00
#            POLR2J (ENSG00000005075) DHX33 (ENSG00000005100)
# ACH-001097                  15053.0                    3232
#            MEOX1 (ENSG00000005102) THSD7A (ENSG00000005108)
# ACH-001097                      48                        0
#            LIG3 (ENSG00000005156) RPAP3 (ENSG00000005175)
# ACH-001097                3619.20                    1788
#            ACSM3 (ENSG00000005187) REXO5 (ENSG00000005189)
# ACH-001097                  475.69                    2733
#            CIAPIN1 (ENSG00000005194) SPPL2B (ENSG00000005206)
# ACH-001097                      3475                    11124
#            FAM214B (ENSG00000005238) COPZ2 (ENSG00000005243)
# ACH-001097                       990                      16
#            PRKAR2B (ENSG00000005249) MSL3 (ENSG00000005302)
# ACH-001097                         0                   1421
#            CREBBP (ENSG00000005339) TSPOAP1 (ENSG00000005379)
# ACH-001097                     2490                     31378
#            MPO (ENSG00000005381) PON1 (ENSG00000005421) GCFC2 (ENSG00000005436)
# ACH-001097                     0                      2                 1415.80
#            WDR54 (ENSG00000005448) CROT (ENSG00000005469)
# ACH-001097                    3135                    695
#            ABCB4 (ENSG00000005471) KMT2E (ENSG00000005483)
# ACH-001097                       7                  3295.0
#            RHBDD2 (ENSG00000005486) SOX8 (ENSG00000005513)
# ACH-001097                    12204                      4
#            IBTK (ENSG00000005700) ZNF195 (ENSG00000005801)
# ACH-001097                   3744                     2332
#            MYCBP2 (ENSG00000005810) FBXL3 (ENSG00000005812)
# ACH-001097                  6295.80                 3641.80
#            ITGAL (ENSG00000005844) PDK2 (ENSG00000005882)
# ACH-001097                  136900                   0.00
#            ITGA3 (ENSG00000005884) ZFX (ENSG00000005889)
# ACH-001097                    2784                  1070
#            LAMP2 (ENSG00000005893) ITGA2B (ENSG00000005961)
# ACH-001097                    6317                       20
#            ASB4 (ENSG00000005981) GDE1 (ENSG00000006007)
# ACH-001097                      0                5127.90
#            REX1BD (ENSG00000006015) CRLF1 (ENSG00000006016)
# ACH-001097                     7059                  228.88
#            OSBPL7 (ENSG00000006025) TMEM98 (ENSG00000006042)
# ACH-001097                     1143                        2
#            YBX2 (ENSG00000006047) KRT33A (ENSG00000006059)
# ACH-001097                      7                        0
#            MAP3K14 (ENSG00000006062) ABCC8 (ENSG00000006071)
# ACH-001097                   3784.30                       0
#            CACNG3 (ENSG00000006116) TMEM132A (ENSG00000006118)
# ACH-001097                        0                          8
#            AP2B1 (ENSG00000006125) TAC1 (ENSG00000006128)
# ACH-001097                   13815                      0
#            ZNF263 (ENSG00000006194) CX3CL1 (ENSG00000006210)
# ACH-001097                  4787.40                        1
#            SPATA20 (ENSG00000006282) CACNA1G (ENSG00000006283)
# ACH-001097                    9416.0                         2
#            TNFRSF12A (ENSG00000006327) DLX6 (ENSG00000006377)
# ACH-001097                         491                      0
#            MAP3K9 (ENSG00000006432) RALA (ENSG00000006451)
# ACH-001097                      177                   2823
#            BAIAP2L1 (ENSG00000006453) KDM7A (ENSG00000006459)
# ACH-001097                      66.00                     204
#            ETV1 (ENSG00000006468) AGK (ENSG00000006530)
# ACH-001097                   1413                1602.2
#            ALDH3B1 (ENSG00000006534) TTC22 (ENSG00000006555)
# ACH-001097                     14.00                     521
#            PHTF2 (ENSG00000006576) CCL26 (ENSG00000006606)
# ACH-001097                    2943                       0
#            FARP2 (ENSG00000006607) USH1C (ENSG00000006611)
# ACH-001097                    0.00                       0
#            GGCT (ENSG00000006625) DBF4 (ENSG00000006634)
# ACH-001097                   7170                 6448.9
#            TBXA2R (ENSG00000006638) IFRD1 (ENSG00000006652)
# ACH-001097                        0                    5286
#            LGALS14 (ENSG00000006659) COX10 (ENSG00000006695)
# ACH-001097                         0                 2470.00
#            GTF2IRD1 (ENSG00000006704) PAF1 (ENSG00000006712)
# ACH-001097                          0                   6599
#            VPS41 (ENSG00000006715) ARHGAP44 (ENSG00000006740)
# ACH-001097                    2429                       43.0
#            ELAC2 (ENSG00000006744) SCIN (ENSG00000006747)
# ACH-001097                   10669                      0
#            ARSD (ENSG00000006756) PNPLA4 (ENSG00000006757)
# ACH-001097                   0.00                        0
#            MYH13 (ENSG00000006788) ADIPOR2 (ENSG00000006831)
# ACH-001097                       1                      4802
#            CDKL3 (ENSG00000006837) UPP2 (ENSG00000007001)
# ACH-001097                    8.21                      0
#            PRSS21 (ENSG00000007038) MARK4 (ENSG00000007047)
# ACH-001097                        1                    1284
#            PROM1 (ENSG00000007062) CCDC124 (ENSG00000007080)
# ACH-001097                       0                     15465
#            CEACAM21 (ENSG00000007129) PAFAH1B1 (ENSG00000007168)
# ACH-001097                          1                       6646
#            NOS2 (ENSG00000007171) DNAH9 (ENSG00000007174)
# ACH-001097                      0                       1
#            KIAA0100 (ENSG00000007202) SLC13A2 (ENSG00000007216)
# ACH-001097                    21353.0                         0
#            GAS7 (ENSG00000007237) TRAPPC6A (ENSG00000007255)
# ACH-001097                    186                       3820
#            MATK (ENSG00000007264) CEACAM7 (ENSG00000007306)
# ACH-001097                  18353                         0
#            CD79B (ENSG00000007312) SCN4A (ENSG00000007314)
# ACH-001097                     4.0                      82
#            ST7L (ENSG00000007341) TKTL1 (ENSG00000007350)
# ACH-001097                 564.00                      74
#            PAX6 (ENSG00000007372) RPUSD1 (ENSG00000007376)
# ACH-001097                   5.00                     4579
#            RHBDF1 (ENSG00000007384) LUC7L (ENSG00000007392)
# ACH-001097                      197                    4556
#            CACNA2D2 (ENSG00000007402) BAIAP3 (ENSG00000007516)
# ACH-001097                          5                    77.13
#            TSR3 (ENSG00000007520) PIGQ (ENSG00000007541)
# ACH-001097                7373.90                 5579.0
#            CRAMP1 (ENSG00000007545) TEAD3 (ENSG00000007866)
# ACH-001097                  1292.40                       9
#            SELE (ENSG00000007908) DNAJC11 (ENSG00000007923)
# ACH-001097                      0                    4090.9
#            FMO3 (ENSG00000007933) MYLIP (ENSG00000007944)
# ACH-001097                     23                     527
#            NOX1 (ENSG00000007952) E2F2 (ENSG00000007968)
# ACH-001097                      7                   7396
#            PSMB1 (ENSG00000008018) SYN1 (ENSG00000008056)
# ACH-001097                   21427                   0.00
#            JARID2 (ENSG00000008083) CDKL5 (ENSG00000008086)
# ACH-001097                     4731                       0
#            CAMK1G (ENSG00000008118) CDK11A (ENSG00000008128)
# ACH-001097                        0                  5483.70
#            NADK (ENSG00000008130) TFAP2B (ENSG00000008196)
# ACH-001097                   7196                       92
#            TFAP2D (ENSG00000008197) DLEC1 (ENSG00000008226)
# ACH-001097                        0                   12.03
#            CYTH3 (ENSG00000008256) ADAM22 (ENSG00000008277)
# ACH-001097                     753                      978
#            SYPL1 (ENSG00000008282) CYB561 (ENSG00000008283)
# ACH-001097                    8590                        1
#            SPAG9 (ENSG00000008294) CELSR3 (ENSG00000008300)
# ACH-001097                    2606                     7560
#            AASS (ENSG00000008311) PLEKHG6 (ENSG00000008323)
# ACH-001097                      0                         6
#            SS18L2 (ENSG00000008324) MPND (ENSG00000008382)
# ACH-001097                     4450                   4522
#            MGST1 (ENSG00000008394) CRY1 (ENSG00000008405)
# ACH-001097                       2                    853
#            PGLYRP1 (ENSG00000008438) NFIX (ENSG00000008441)
# ACH-001097                         2                     38
#            ST3GAL1 (ENSG00000008513) MMP25 (ENSG00000008516)
# ACH-001097                     11728                  117.12
#            IL32 (ENSG00000008517) PKD1 (ENSG00000008710)
# ACH-001097                 105430                4734.60
#            MAPK8IP2 (ENSG00000008735) MED24 (ENSG00000008838)
# ACH-001097                       1538                    5145
#            RHOBTB2 (ENSG00000008853) HEATR5B (ENSG00000008869)
# ACH-001097                     80.55                      1204
#            SEC62 (ENSG00000008952) RPS20 (ENSG00000008988)
# ACH-001097                    9786                  213980
#            CSDE1 (ENSG00000009307) UBE3C (ENSG00000009335)
# ACH-001097                   13467                    5277
#            REV3L (ENSG00000009413) TENM1 (ENSG00000009694)
# ACH-001097                  1157.9                      42
#            PAX7 (ENSG00000009709) MASP2 (ENSG00000009724) IYD (ENSG00000009765)
# ACH-001097                      0                      16                     0
#            FAM76A (ENSG00000009780) TRAF3IP3 (ENSG00000009790)
# ACH-001097                      707                   14100.00
#            POMT2 (ENSG00000009830) VTA1 (ENSG00000009844)
# ACH-001097                    2255                   2776
#            MLXIPL (ENSG00000009950) BAZ1B (ENSG00000009954)
# ACH-001097                        2                    9716
#            RANBP9 (ENSG00000010017) ETV7 (ENSG00000010030)
# ACH-001097                   3586.4                      0
#            SPRTN (ENSG00000010072) METTL13 (ENSG00000010165)
# ACH-001097                 1457.30                      7310
#            DYRK4 (ENSG00000010219) ZNF207 (ENSG00000010244)
# ACH-001097                   772.0                  12211.0
#            UQCRC1 (ENSG00000010256) STARD3NL (ENSG00000010270)
# ACH-001097                    35529                       4319
#            CD9 (ENSG00000010278) HHATL (ENSG00000010282)
# ACH-001097                    34                       0
#            NCAPD2 (ENSG00000010292) IFFO1 (ENSG00000010295)
# ACH-001097                  15556.0                    3240
#            GIPR (ENSG00000010310) PHF7 (ENSG00000010318)
# ACH-001097                    179                    736
#            SEMA3G (ENSG00000010319) NISCH (ENSG00000010322)
# ACH-001097                        4                   10748
#            STAB1 (ENSG00000010327) FUZ (ENSG00000010361)
# ACH-001097                   12.00                128.89
#            SLC6A13 (ENSG00000010379) IDS (ENSG00000010404)
# ACH-001097                      1291               12275.0
#            PRSS3 (ENSG00000010438) ZNF200 (ENSG00000010539)
# ACH-001097                       0                     1094
#            CD4 (ENSG00000010610) LRRC23 (ENSG00000010626) BTK (ENSG00000010671)
# ACH-001097                     1                   799.39                     4
#            HFE (ENSG00000010704) SCMH1 (ENSG00000010803) FYN (ENSG00000010810)
# ACH-001097                     0                    3023                  4095
#            HIVEP2 (ENSG00000010818) FMO1 (ENSG00000010932)
# ACH-001097                   1399.0                      0
#            ELOA (ENSG00000011007) LYPLA2 (ENSG00000011009)
# ACH-001097                4612.40                     7478
#            CLCN6 (ENSG00000011021) MRC2 (ENSG00000011028)
# ACH-001097                  805.24                      0
#            NME1-NME2 (ENSG00000011052) SLC6A7 (ENSG00000011083)
# ACH-001097                     1550.80                        0
#            TSPAN9 (ENSG00000011105) BTBD7 (ENSG00000011114)
# ACH-001097                        0                     549
#            APBA3 (ENSG00000011132) MKS1 (ENSG00000011143)
# ACH-001097                  3164.5                    840
#            ABHD5 (ENSG00000011198) ANOS1 (ENSG00000011201)
# ACH-001097                    2347                       0
#            AKAP8L (ENSG00000011243) MBTD1 (ENSG00000011258)
# ACH-001097                  14098.0                     592
#            UTP18 (ENSG00000011260) RNF216 (ENSG00000011275)
# ACH-001097                    3202                     5032
#            TTC19 (ENSG00000011295) PTBP1 (ENSG00000011304)
# ACH-001097                 7520.10                   19102
#            DPF1 (ENSG00000011332) SYT7 (ENSG00000011347)
# ACH-001097                      9                      0
#            LARS2 (ENSG00000011376) PIK3C2A (ENSG00000011405)
# ACH-001097                    2416                       884
#            PLAUR (ENSG00000011422) ANLN (ENSG00000011426) WIZ (ENSG00000011451)
# ACH-001097                      14                   1311                  8751
#            RABGAP1 (ENSG00000011454) DCN (ENSG00000011465)
# ACH-001097                      1249                    10
#            QPCTL (ENSG00000011478) PPP5C (ENSG00000011485)
# ACH-001097                    1628                  9198.0
#            CEP68 (ENSG00000011523) MAP4K3 (ENSG00000011566)
# ACH-001097                  698.90                        1
#            ZBTB32 (ENSG00000011590) TYROBP (ENSG00000011600)
# ACH-001097                     7582                        5
#            TMEM159 (ENSG00000011638) GABRA3 (ENSG00000011677)
# ACH-001097                       271                        0
#            BRCA1 (ENSG00000012048) ERCC1 (ENSG00000012061)
# ACH-001097                    4074                  9443.5
#            CD22 (ENSG00000012124) SEMA3B (ENSG00000012171)
# ACH-001097                      0                      700
#            MBTPS2 (ENSG00000012174) PRICKLE3 (ENSG00000012211)
# ACH-001097                    686.0                        191
#            LTF (ENSG00000012223) EXTL3 (ENSG00000012232)
# ACH-001097                    30                    3280
#            NR1H4 (ENSG00000012504) ELOVL5 (ENSG00000012660)
# ACH-001097                       0                    10970
#            ALOX5 (ENSG00000012779) KDM5D (ENSG00000012817)
# ACH-001097                       0                    2541
#            CALCOCO1 (ENSG00000012822) UBR7 (ENSG00000012963)
# ACH-001097                        498                   4189
#            MAP4K5 (ENSG00000012983) EHD3 (ENSG00000013016)
# ACH-001097                     2145                      0
#            PSMC4 (ENSG00000013275) MAN2B2 (ENSG00000013288)
# ACH-001097                   13228                     8189
#            SLC7A14 (ENSG00000013293) CLDN11 (ENSG00000013297)
# ACH-001097                         2                     0.00
#            SLC25A39 (ENSG00000013306) MVP (ENSG00000013364)
# ACH-001097                      11688                  3780
#            NUB1 (ENSG00000013374) PGM3 (ENSG00000013375)
# ACH-001097                 3310.0                1468.10
#            RWDD2A (ENSG00000013392) CLK1 (ENSG00000013441)
# ACH-001097                      295                   7644
#            POLR3B (ENSG00000013503) ANGEL1 (ENSG00000013523)
# ACH-001097                      721                  1737.30
#            RNF14 (ENSG00000013561) DNASE1L1 (ENSG00000013563)
# ACH-001097                    1991                    3572.90
#            DDX11 (ENSG00000013573) HEBP1 (ENSG00000013583)
# ACH-001097                10200.00                     9.0
#            GPRC5A (ENSG00000013588) MAMLD1 (ENSG00000013619)
# ACH-001097                        0                     1739
#            CD6 (ENSG00000013725) TACC3 (ENSG00000013810) UFL1 (ENSG00000014123)
# ACH-001097                  9282                   20988                   2143
#            POLA2 (ENSG00000014138) ZC3H3 (ENSG00000014164)
# ACH-001097                 6354.00                    1868
#            CAPN1 (ENSG00000014216) ACPP (ENSG00000014257)
# ACH-001097                    5304                      0
#            MDH1 (ENSG00000014641) SLC30A9 (ENSG00000014824)
# ACH-001097                  10592                      3150
#            MTMR11 (ENSG00000014914) COX15 (ENSG00000014919)
# ACH-001097                      761                  4266.5
#            CCDC88C (ENSG00000015133) YAF2 (ENSG00000015153)
# ACH-001097                      7629                   1332
#            ZMYND11 (ENSG00000015171) WAS (ENSG00000015285)
# ACH-001097                      2916                 11471
#            DPEP1 (ENSG00000015413) BID (ENSG00000015475)
# ACH-001097                       0                  3581
#            MATR3 (ENSG00000015479) NPC1L1 (ENSG00000015520)
# ACH-001097                 19603.0                       17
#            XYLT2 (ENSG00000015532) RGPD5 (ENSG00000015568)
# ACH-001097                  5951.0                  433.62
#            STMN4 (ENSG00000015592) NUDCD3 (ENSG00000015676)
# ACH-001097                       1                    11226
#            ISL1 (ENSG00000016082) CHDH (ENSG00000016391)
# ACH-001097                      0                   5.00
#            IL20RA (ENSG00000016402) CLCA1 (ENSG00000016490)
# ACH-001097                        0                       0
#            CLCA4 (ENSG00000016602) GLT8D1 (ENSG00000016864)
# ACH-001097                       0                   3291.0
#            ATP2C1 (ENSG00000017260) IGF1 (ENSG00000017427)
# ACH-001097                   3434.5                 183.79
#            SLC38A5 (ENSG00000017483) RALBP1 (ENSG00000017797)
# ACH-001097                      5481                     3361
#            RUFY3 (ENSG00000018189) CNTN1 (ENSG00000018236)
# ACH-001097                     308                       0
#            SLC11A1 (ENSG00000018280) WWTR1 (ENSG00000018408)
# ACH-001097                        39                   35.95
#            AGPS (ENSG00000018510) ZNF806 (ENSG00000018607)
# ACH-001097                   5841                        0
#            CXorf56 (ENSG00000018610) ATP1A2 (ENSG00000018625)
# ACH-001097                      1352                        0
#            TTC27 (ENSG00000018699) ZNF582 (ENSG00000018869)
# ACH-001097                    2608                       26
#            VSIG2 (ENSG00000019102) PHLDB1 (ENSG00000019144)
# ACH-001097                       0                    16.48
#            MARCO (ENSG00000019169) CYP24A1 (ENSG00000019186)
# ACH-001097                       5                         0
#            PRDM11 (ENSG00000019485) SYT13 (ENSG00000019505)
# ACH-001097                      157                       0
#            SNAI2 (ENSG00000019549) CD74 (ENSG00000019582) HGF (ENSG00000019991)
# ACH-001097                       0                 384640                    11
#            ZRANB1 (ENSG00000019995) NCDN (ENSG00000020129)
# ACH-001097                  1411.70                 1327.0
#            ADGRA2 (ENSG00000020181) CCT8L1P (ENSG00000020219)
# ACH-001097                   546.64                         2
#            ZFP64 (ENSG00000020256) MNAT1 (ENSG00000020426)
# ACH-001097                     955                    2730
#            SAMD4A (ENSG00000020577) RUNX3 (ENSG00000020633)
# ACH-001097                        0                   13090
#            MRE11 (ENSG00000020922) PLEKHB1 (ENSG00000021300)
# ACH-001097                    2686                         1
#            SERPINB1 (ENSG00000021355) CYP3A43 (ENSG00000021461)
# ACH-001097                       3638                         0
#            SLC7A9 (ENSG00000021488) SPAST (ENSG00000021574)
# ACH-001097                        0                     670
#            NRXN3 (ENSG00000021645) OSBPL5 (ENSG00000021762)
# ACH-001097                       0                        0
#            AQR (ENSG00000021776) CPS1 (ENSG00000021826) C8B (ENSG00000021852)
# ACH-001097                  3370                      7                     1
#            FHL1 (ENSG00000022267) RTF2 (ENSG00000022277)
# ACH-001097                      8                  14452
#            GABRA1 (ENSG00000022355) NLRP2 (ENSG00000022556)
# ACH-001097                        0                      30
#            SLC45A4 (ENSG00000022567) RNF10 (ENSG00000022840)
# ACH-001097                      1499                   16252
#            ZNF839 (ENSG00000022976) ZDHHC6 (ENSG00000023041)
# ACH-001097                  3065.60                     1650
#            GRAMD1B (ENSG00000023171) RNH1 (ENSG00000023191)
# ACH-001097                      2369                  13846
#            NDUFS1 (ENSG00000023228) RB1CC1 (ENSG00000023287)
# ACH-001097                   4184.0                     1287
#            ERP44 (ENSG00000023318) ALAS1 (ENSG00000023330)
# ACH-001097                    6578                    6464
#            BIRC3 (ENSG00000023445) AKAP11 (ENSG00000023516)
# ACH-001097                    5449                     1680
#            GLRX2 (ENSG00000023572) SNAPC1 (ENSG00000023608)
# ACH-001097                 6730.80                      798
#            DERA (ENSG00000023697) STRAP (ENSG00000023734)
# ACH-001097                   3583                    7639
#            ABCC2 (ENSG00000023839) DEF6 (ENSG00000023892)
# ACH-001097                       1                  16574
#            PLEKHO1 (ENSG00000023902) GCLM (ENSG00000023909)
# ACH-001097                     16885                   2897
#            UBR2 (ENSG00000024048) EHD2 (ENSG00000024422)
# ACH-001097                   2092                      0
#            DEPDC1 (ENSG00000024526) CCDC28A (ENSG00000024862)
# ACH-001097                  1042.00                      1753
#            RRAGD (ENSG00000025039) HSF2 (ENSG00000025156)
# ACH-001097                       0                   3132
#            PHF20 (ENSG00000025293) HSD17B6 (ENSG00000025423)
# ACH-001097                    4795                    297.02
#            NR1H3 (ENSG00000025434) TYMP (ENSG00000025708)
# ACH-001097                    1011                2977.80
#            NCAPH2 (ENSG00000025770) TOMM34 (ENSG00000025772)
# ACH-001097                    14672                     8295
#            SEC63 (ENSG00000025796) KPNA6 (ENSG00000025800)
# ACH-001097                  4862.3                  5678.4
#            VIM (ENSG00000026025) RTEL1-TNFRSF6B (ENSG00000026036)
# ACH-001097                257440                          3437.30
#            FAS (ENSG00000026103) RNASET2 (ENSG00000026297)
# ACH-001097                   3.0                     983.0
#            CD44 (ENSG00000026508) KCNG1 (ENSG00000026559)
# ACH-001097                  21135                       0
#            AGPAT4 (ENSG00000026652) SLAMF7 (ENSG00000026751)
# ACH-001097                      620                    75433
#            BTN3A1 (ENSG00000026950) MIPEP (ENSG00000027001)
# ACH-001097                  4664.40                     994
#            PRKCH (ENSG00000027075) INSRR (ENSG00000027644)
# ACH-001097                    7295                       0
#            IFNGR1 (ENSG00000027697) B4GALT7 (ENSG00000027847)
# ACH-001097                     1333                      3394
#            SH2D2A (ENSG00000027869) VRK2 (ENSG00000028116)
# ACH-001097                     7928                 859.19
#            TNFRSF1B (ENSG00000028137) VEZT (ENSG00000028203)
# ACH-001097                      24350                   1570
#            POU2F2 (ENSG00000028277) BRD9 (ENSG00000028310)
# ACH-001097                      111                 9072.0
#            SNX1 (ENSG00000028528) TBPL1 (ENSG00000028839)
# ACH-001097                   5473                 1867.00
#            ARNTL2 (ENSG00000029153) BCLAF1 (ENSG00000029363)
# ACH-001097                     4091                  10898.0
#            SLC39A9 (ENSG00000029364) ANK1 (ENSG00000029534)
# ACH-001097                      4332                     10
#            IBSP (ENSG00000029559) TFB1M (ENSG00000029639)
# ACH-001097                      0                    1158
#            RABEP1 (ENSG00000029725) HMGB3 (ENSG00000029993)
# ACH-001097                   5383.0                       0
#            NUP160 (ENSG00000030066) BAK1 (ENSG00000030110)
# ACH-001097                     3616                  13876
#            MUSK (ENSG00000030304) IKZF2 (ENSG00000030419) GRN (ENSG00000030582)
# ACH-001097                      0                      79                  7055
#            FAM13B (ENSG00000031003) ARHGAP31 (ENSG00000031081)
# ACH-001097                   2334.0                        448
#            CENPQ (ENSG00000031691) SARS (ENSG00000031698)
# ACH-001097                     770                   7315
#            RANBP3 (ENSG00000031823) ARID4A (ENSG00000032219)
# ACH-001097                    15579                     1085
#            EIPR1 (ENSG00000032389) PNPLA6 (ENSG00000032444)
# ACH-001097                    2971                  17917.0
#            IFT88 (ENSG00000032742) ALG1 (ENSG00000033011)
# ACH-001097                     928                1760.20
#            ZCCHC8 (ENSG00000033030) ABCF2 (ENSG00000033050)
# ACH-001097                     2026                 10782.0
#            CHPF2 (ENSG00000033100) LRRC7 (ENSG00000033122)
# ACH-001097                 7521.80                       3
#            FUT8 (ENSG00000033170) UBA6 (ENSG00000033178) GAB2 (ENSG00000033327)
# ACH-001097                1808.00                   3948                      3
#            ATP6V0A1 (ENSG00000033627) PIAS1 (ENSG00000033800)
# ACH-001097                        767                  2369.5
#            SLC4A7 (ENSG00000033867) APBA2 (ENSG00000034053)
# ACH-001097                     1748                       0
#            MAP2K3 (ENSG00000034152) EFCAB1 (ENSG00000034239)
# ACH-001097                     9915                        0
#            TMSB10 (ENSG00000034510) ASTE1 (ENSG00000034533)
# ACH-001097                   279420                  353.46
#            RNF19A (ENSG00000034677) PEX3 (ENSG00000034693)
# ACH-001097                     1130                   1416
#            GABARAPL2 (ENSG00000034713) MYOC (ENSG00000034971)
# ACH-001097                        3923                      0
#            SH3YL1 (ENSG00000035115) FAM136A (ENSG00000035141)
# ACH-001097                      623                      6731
#            VCL (ENSG00000035403) DEPDC1B (ENSG00000035499)
# ACH-001097                1986.3                      2507
#            DAPK2 (ENSG00000035664) NSMAF (ENSG00000035681)
# ACH-001097                      16                    7073
#            ADSS (ENSG00000035687) STAP1 (ENSG00000035720)
# ACH-001097                   5418                       9
#            TIMP2 (ENSG00000035862) RFC1 (ENSG00000035928)
# ACH-001097                    0.00                   3754
#            TBC1D23 (ENSG00000036054) CUL3 (ENSG00000036257)
# ACH-001097                      1295                 2520.0
#            MYOM2 (ENSG00000036448) OTC (ENSG00000036473)
# ACH-001097                       0                     1
#            CYP46A1 (ENSG00000036530) ZZZ3 (ENSG00000036549)
# ACH-001097                         8                    917
#            SLC18A1 (ENSG00000036565) USP2 (ENSG00000036672)
# ACH-001097                         0                    131
#            CASR (ENSG00000036828) TUBG2 (ENSG00000037042)
# ACH-001097                      0                  200.84
#            RPL26L1 (ENSG00000037241) FLT4 (ENSG00000037280)
# ACH-001097                   2463.20                      0
#            NSUN2 (ENSG00000037474) FBXO42 (ENSG00000037637)
# ACH-001097                    8579                     3500
#            MFAP3 (ENSG00000037749) MRI1 (ENSG00000037757)
# ACH-001097                     470                1273.10
#            METTL1 (ENSG00000037897) HOXC8 (ENSG00000037965)
# ACH-001097                  2746.00                       0
#            AGA (ENSG00000038002) PI4K2B (ENSG00000038210)
# ACH-001097                  1958                   5112.0
#            BOD1L1 (ENSG00000038219) MAT2B (ENSG00000038274)
# ACH-001097                     1309                    2804
#            TLL1 (ENSG00000038295) EDC4 (ENSG00000038358) TRIO (ENSG00000038382)
# ACH-001097                     93                10125.0                   3497
#            VCAN (ENSG00000038427) CLEC16A (ENSG00000038532)
# ACH-001097                      3                      2421
#            MSR1 (ENSG00000038945) CDH1 (ENSG00000039068)
# ACH-001097                      0                     39
#            MTREX (ENSG00000039123) DNAH5 (ENSG00000039139)
# ACH-001097                  7022.0                       0
#            ZFYVE16 (ENSG00000039319) RIPOR1 (ENSG00000039523)
# ACH-001097                       969                       88
#            C6 (ENSG00000039537) RAI14 (ENSG00000039560) SOX30 (ENSG00000039600)
# ACH-001097                    0                       0                       0
#            PNKP (ENSG00000039650) BEST2 (ENSG00000039987)
# ACH-001097                4106.40                       3
#            PHLPP2 (ENSG00000040199) SPDL1 (ENSG00000040275)
# ACH-001097                    923.0                    2741
#            STAU2 (ENSG00000040341) PQLC2 (ENSG00000040487)
# ACH-001097                  1783.0                    1304
#            CTNS (ENSG00000040531) RTN4R (ENSG00000040608)
# ACH-001097                    770                      45
#            PHF23 (ENSG00000040633) CDH10 (ENSG00000040731)
# ACH-001097                    5219                       1
#            INPP4A (ENSG00000040933) RAB27B (ENSG00000041353)
# ACH-001097                     8378                      468
#            PSMA4 (ENSG00000041357) MYO16 (ENSG00000041515)
# ACH-001097                   12975                     865
#            LSG1 (ENSG00000041802) PARP3 (ENSG00000041880) TNC (ENSG00000041982)
# ACH-001097                   4230                    1806                     1
#            THAP3 (ENSG00000041988) RIPOR3 (ENSG00000042062)
# ACH-001097                 5614.10                        0
#            TDP1 (ENSG00000042088) AIFM2 (ENSG00000042286)
# ACH-001097                   2873                    8224
#            C2orf83 (ENSG00000042304) SPATA7 (ENSG00000042317)
# ACH-001097                         0                      462
#            MED17 (ENSG00000042429) RETSAT (ENSG00000042445)
# ACH-001097                 1125.00                     3431
#            CAPG (ENSG00000042493) AP2S1 (ENSG00000042753)
# ACH-001097                    317                   11872
#            USH2A (ENSG00000042781) ZPBP (ENSG00000042813) TG (ENSG00000042832)
# ACH-001097                      23                      0                   24
#            ADAM28 (ENSG00000042980) BARX2 (ENSG00000043039)
# ACH-001097                        3                       0
#            DCUN1D1 (ENSG00000043093) JADE2 (ENSG00000043143)
# ACH-001097                      2456                    5683
#            ZIC2 (ENSG00000043355) LCP2 (ENSG00000043462)
# ACH-001097                      0                   6585
#            TRIT1 (ENSG00000043514) ADRB1 (ENSG00000043591)
# ACH-001097                    1527                       0
#            GUCA2B (ENSG00000044012) CUL7 (ENSG00000044090)
# ACH-001097                        0                 5136.0
#            CTNNA1 (ENSG00000044115) PHKA2 (ENSG00000044446)
# ACH-001097                        5                    2348
#            CNTLN (ENSG00000044459) EPHA3 (ENSG00000044524)
# ACH-001097                       2                       0
#            HSPA5 (ENSG00000044574) DSG2 (ENSG00000046604)
# ACH-001097                   89445                      0
#            GEMIN8 (ENSG00000046647) OFD1 (ENSG00000046651)
# ACH-001097                      711                   2960
#            GPM6B (ENSG00000046653) MAGEC2 (ENSG00000046774)
# ACH-001097                       0                        0
#            PREX2 (ENSG00000046889) WDR37 (ENSG00000047056)
# ACH-001097                       0                    1074
#            YTHDC2 (ENSG00000047188) CTPS2 (ENSG00000047230)
# ACH-001097                     1226                       0
#            ATP6V1H (ENSG00000047249) POLR2B (ENSG00000047315)
# ACH-001097                      1607                   7654.6
#            FAM214A (ENSG00000047346) ARAP2 (ENSG00000047365)
# ACH-001097                       514                    1655
#            TPR (ENSG00000047410) CP (ENSG00000047457)
# ACH-001097                 21786                10.29
#            KIAA0556 (ENSG00000047578) DTNBP1 (ENSG00000047579)
# ACH-001097                     787.86                     1645
#            XK (ENSG00000047597) ANO2 (ENSG00000047617)
# ACH-001097                    0                      0
#            C12orf4 (ENSG00000047621) SCML1 (ENSG00000047634)
# ACH-001097                      1232                       0
#            WWC3 (ENSG00000047644) ARHGAP6 (ENSG00000047648)
# ACH-001097                   5017                         0
#            FAM184B (ENSG00000047662) MAP4 (ENSG00000047849)
# ACH-001097                      0.00                   6809
#            GOPC (ENSG00000047932) ROS1 (ENSG00000047936)
# ACH-001097                   2793                      0
#            USP28 (ENSG00000048028) HDAC9 (ENSG00000048052)
# ACH-001097                    1697                     232
#            TSPAN17 (ENSG00000048140) NOP16 (ENSG00000048162)
# ACH-001097                      7597                 8307.70
#            CC2D2A (ENSG00000048342) RRM2B (ENSG00000048392)
# ACH-001097                        0                    2652
#            ZNF800 (ENSG00000048405) TNFRSF17 (ENSG00000048462)
# ACH-001097                     1249                          0
#            SNX29 (ENSG00000048471) LMO3 (ENSG00000048540)
# ACH-001097                     628                      0
#            MRPS10 (ENSG00000048544) GUCA1A (ENSG00000048545)
# ACH-001097                     5132                        0
#            RSF1 (ENSG00000048649) VPS13D (ENSG00000048707)
# ACH-001097                 1809.5                     2040
#            CELF2 (ENSG00000048740) FAM120A (ENSG00000048828)
# ACH-001097                    8368                    7067.5
#            R3HDM1 (ENSG00000048991) COL9A2 (ENSG00000049089)
# ACH-001097                     2258                      693
#            KITLG (ENSG00000049130) ERCC8 (ENSG00000049167)
# ACH-001097                       0                  385.00
#            ADAMTS6 (ENSG00000049192) H6PD (ENSG00000049239)
# ACH-001097                        96                  13331
#            VAMP3 (ENSG00000049245) PER3 (ENSG00000049246)
# ACH-001097                    1628                     36
#            UTS2 (ENSG00000049247) TNFRSF9 (ENSG00000049249)
# ACH-001097                      1                       836
#            EPN3 (ENSG00000049283) LTBP1 (ENSG00000049323)
# ACH-001097                    9.0                     119
#            RCN1 (ENSG00000049449) ELN (ENSG00000049540) RFC2 (ENSG00000049541)
# ACH-001097                9403.40                  63.0                  17377
#            ARID1B (ENSG00000049618) CLPTM1L (ENSG00000049656)
# ACH-001097                   3260.9                     26410
#            NEDD4L (ENSG00000049759) FOXP3 (ENSG00000049768)
# ACH-001097                      807                      37
#            PPP1R3F (ENSG00000049769) HEXB (ENSG00000049860)
# ACH-001097                       559                 8222.8
#            PTCD2 (ENSG00000049883) NEXMIF (ENSG00000050030)
# ACH-001097                     715                        0
#            JKAMP (ENSG00000050130) DKK3 (ENSG00000050165)
# ACH-001097                    2471                      0
#            ARHGEF5 (ENSG00000050327) NFE2L3 (ENSG00000050344)
# ACH-001097                      0.00                      404
#            MCUR1 (ENSG00000050393) LIMA1 (ENSG00000050405)
# ACH-001097                    3495                    2830
#            LETMD1 (ENSG00000050426) SLC4A8 (ENSG00000050438)
# ACH-001097                     4944                      807
#            LAMC3 (ENSG00000050555) PTGER3 (ENSG00000050628)
# ACH-001097                     185                        1
#            TNIP3 (ENSG00000050730) MAPK9 (ENSG00000050748)
# ACH-001097                       1                    4378
#            COL23A1 (ENSG00000050767) BCAR1 (ENSG00000050820)
# ACH-001097                        26                       0
#            FAM160A2 (ENSG00000051009) HERPUD1 (ENSG00000051108)
# ACH-001097                       1200                      3687
#            HOMER3 (ENSG00000051128) RAD51 (ENSG00000051180)
# ACH-001097                      0.0                    4104
#            POLQ (ENSG00000051341) PIK3CB (ENSG00000051382)
# ACH-001097                   4533                     1492
#            CYBA (ENSG00000051523) THOC3 (ENSG00000051596)
# ACH-001097                  26634                 4056.10
#            HEBP2 (ENSG00000051620) MPHOSPH9 (ENSG00000051825)
# ACH-001097                    3935                    1707.60
#            PLEKHA5 (ENSG00000052126) PRSS8 (ENSG00000052344)
# ACH-001097                       523                     0.0
#            SIKE1 (ENSG00000052723) RRP12 (ENSG00000052749)
# ACH-001097                    2745                    6446
#            FNIP2 (ENSG00000052795) MSMO1 (ENSG00000052802)
# ACH-001097                       1                   11157
#            TTC17 (ENSG00000052841) ALX4 (ENSG00000052850)
# ACH-001097                    3203                      0
#            FSTL4 (ENSG00000053108) FOXN3 (ENSG00000053254)
# ACH-001097                      16                  5460.7
#            METTL24 (ENSG00000053328) AKR7A2 (ENSG00000053371)
# ACH-001097                         0                     6420
#            MRTO4 (ENSG00000053372) NNAT (ENSG00000053438)
# ACH-001097                   10303                      3
#            USE1 (ENSG00000053501) MCF2L2 (ENSG00000053524)
# ACH-001097                   3551                   219.32
#            NRIP2 (ENSG00000053702) LAMA3 (ENSG00000053747)
# ACH-001097                      24                       3
#            AP5M1 (ENSG00000053770) ANAPC4 (ENSG00000053900)
# ACH-001097                    2255                     4959
#            KCNQ1 (ENSG00000053918) TRAPPC3 (ENSG00000054116)
# ACH-001097                       0                      5747
#            THRAP3 (ENSG00000054118) PHPT1 (ENSG00000054148)
# ACH-001097                   6359.0                   10408
#            ENTPD2 (ENSG00000054179) LY75 (ENSG00000054219)
# ACH-001097                        4                 2694.2
#            ARID4B (ENSG00000054267) OPN3 (ENSG00000054277)
# ACH-001097                   2345.0                 132.00
#            SDCCAG8 (ENSG00000054282) PTPRN (ENSG00000054356)
# ACH-001097                    917.52                      11
#            HHAT (ENSG00000054392) KIF1B (ENSG00000054523)
# ACH-001097                    538                 2332.40
#            FOXC1 (ENSG00000054598) TBC1D22A (ENSG00000054611)
# ACH-001097                       0                       2216
#            SYNE2 (ENSG00000054654) PLEKHH1 (ENSG00000054690)
# ACH-001097                    1470                     22.05
#            ATP9A (ENSG00000054793) SPO11 (ENSG00000054796)
# ACH-001097                      20                       0
#            CBLN4 (ENSG00000054803) CHRDL2 (ENSG00000054938)
# ACH-001097                       0                        0
#            FAM168A (ENSG00000054965) RELT (ENSG00000054967)
# ACH-001097                      2913                2321.00
#            GALC (ENSG00000054983) NOP58 (ENSG00000055044)
# ACH-001097                   2642                    6264
#            SZRD1 (ENSG00000055070) KCNH2 (ENSG00000055118)
# ACH-001097                 12085.0                       0
#            CUL1 (ENSG00000055130) FAM114A2 (ENSG00000055147)
# ACH-001097                21397.0                       1157
#            CYFIP2 (ENSG00000055163) TAB2 (ENSG00000055208)
# ACH-001097                    24337                   2474
#            GINM1 (ENSG00000055211) EIF2AK2 (ENSG00000055332)
# ACH-001097                    1502                      2469
#            USP36 (ENSG00000055483) KMT2C (ENSG00000055609)
# ACH-001097                    4420                  2078.9
#            MCOLN3 (ENSG00000055732) CCDC85A (ENSG00000055813)
# ACH-001097                        0                      0.00
#            PUM2 (ENSG00000055917) MRPL43 (ENSG00000055950)
# ACH-001097                   7009                   4115.0
#            ITIH4 (ENSG00000055955) ITIH1 (ENSG00000055957)
# ACH-001097                  269.94                       3
#            HPF1 (ENSG00000056050) ZFR (ENSG00000056097)
# ACH-001097                   1528                  5977
#            ZNF280C (ENSG00000056277) NPFFR2 (ENSG00000056291)
# ACH-001097                       678                        0
#            PHF21B (ENSG00000056487) TRAF1 (ENSG00000056558)
# ACH-001097                        0                    6272
#            RC3H2 (ENSG00000056586) IL17RB (ENSG00000056736)
# ACH-001097                    2379                       16
#            TRAF3IP2 (ENSG00000056972) GYG2 (ENSG00000056998)
# ACH-001097                          5                      0
#            DCBLD2 (ENSG00000057019) SERPINB3 (ENSG00000057149)
# ACH-001097                        0                          0
#            SOAT1 (ENSG00000057252) PKP2 (ENSG00000057294)
# ACH-001097                    8608                      0
#            MSH4 (ENSG00000057468) F7 (ENSG00000057593) GDI2 (ENSG00000057608)
# ACH-001097                      2                    2                  15894
#            PRDM1 (ENSG00000057657) ATG5 (ENSG00000057663)
# ACH-001097                    4806                   2600
#            TMCC3 (ENSG00000057704) PITHD1 (ENSG00000057757)
# ACH-001097                       0                     4483
#            MTA3 (ENSG00000057935) USP13 (ENSG00000058056)
# ACH-001097                      1                    2904
#            ATP11B (ENSG00000058063) LAMC2 (ENSG00000058085)
# ACH-001097                   5796.8                       2
#            CDK14 (ENSG00000058091) SEC61A1 (ENSG00000058262)
# ACH-001097                       5                   36050.0
#            PPP1R12A (ENSG00000058272) RASGRF1 (ENSG00000058335)
# ACH-001097                     2313.2                         0
#            CAMK2B (ENSG00000058404) CROCC (ENSG00000058453)
# ACH-001097                      448                     104
#            POLR3E (ENSG00000058600) ATP2B4 (ENSG00000058668)
# ACH-001097                     3731                     8215
#            ZC3H11A (ENSG00000058673) RIOK2 (ENSG00000058729)
# ACH-001097                   14437.0                    1640
#            YIPF1 (ENSG00000058799) NDC1 (ENSG00000058804)
# ACH-001097                    1059                   5157
#            DGKG (ENSG00000058866) FLYWCH1 (ENSG00000059122)
# ACH-001097                      0                      5339
#            UNKL (ENSG00000059145) TBXAS1 (ENSG00000059377)
# ACH-001097                 176.56                      149
#            PARP12 (ENSG00000059378) ALDH18A1 (ENSG00000059573)
# ACH-001097                     6932                       7276
#            TARBP1 (ENSG00000059588) GATB (ENSG00000059691)
# ACH-001097                     3124                 733.00
#            MXD1 (ENSG00000059728) CDK17 (ENSG00000059758)
# ACH-001097                 160.00                     816
#            DNAJC25 (ENSG00000059769) SLC2A3 (ENSG00000059804)
# ACH-001097                   1043.00                     6420
#            PSD (ENSG00000059915) CTDP1 (ENSG00000060069) YBX3 (ENSG00000060138)
# ACH-001097                439.68                    2315                   4097
# ...
#            AC017104.4 (ENSG00000283312) RF00026 (ENSG00000283313)
# ACH-001097                           12                         0
#            LINC02357 (ENSG00000283314) AL831711.1 (ENSG00000283317)
# ACH-001097                           0                            2
#            MIR103B2 (ENSG00000283320) AC019117.2 (ENSG00000283321)
# ACH-001097                          0                            0
#            CTXND2 (ENSG00000283324) MIR6860 (ENSG00000283326)
# ACH-001097                        4                         0
#            MIR6841 (ENSG00000283327) FAM240B (ENSG00000283329)
# ACH-001097                         0                         0
#            MIR518D (ENSG00000283330) MIR7977 (ENSG00000283333)
# ACH-001097                         0                         0
#            MIR4536-1 (ENSG00000283334) MIR219B (ENSG00000283335)
# ACH-001097                           0                         0
#            RF00026 (ENSG00000283337) AC090582.1 (ENSG00000283338)
# ACH-001097                         0                            0
#            AC093726.3 (ENSG00000283339) MIR3119-1 (ENSG00000283340)
# ACH-001097
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#            MIR614 (ENSG00000283759) AC118553.2 (ENSG00000283761)
# ACH-001097                        0                         2.99
#            MIR20A (ENSG00000283762) MIR6850 (ENSG00000283764)
# ACH-001097                        0                         0
#            AC131160.1 (ENSG00000283765) AC141930.2 (ENSG00000283766)
# ACH-001097                         0.00                            0
#            MIR1178 (ENSG00000283768) CR392000.2 (ENSG00000283769)
# ACH-001097                         0                            0
#            MIR6849 (ENSG00000283770) MIR6778 (ENSG00000283772)
# ACH-001097                         0                         0
#            AL137798.3 (ENSG00000283773) MIR632 (ENSG00000283774)
# ACH-001097                         4.55                        0
#            MIR4329 (ENSG00000283775) TAF11L13 (ENSG00000283776)
# ACH-001097                         0                          0
#            AC116366.3 (ENSG00000283782) MIR622 (ENSG00000283783)
# ACH-001097                       990.50                        0
#            MIR15A (ENSG00000283785) PRR33 (ENSG00000283787)
# ACH-001097                        0                  664.26
#            MIR936 (ENSG00000283788) MIR7846 (ENSG00000283789)
# ACH-001097                        0                         0
#            MIR612 (ENSG00000283791) MIR4453 (ENSG00000283792)
# ACH-001097                        0                         0
#            MIR6861 (ENSG00000283793) MIR4426 (ENSG00000283795)
# ACH-001097                         0                         0
#            MIR6510 (ENSG00000283796) MIR29B1 (ENSG00000283797)
# ACH-001097                         0                         0
#            MIR630 (ENSG00000283798) MIR1182 (ENSG00000283799)
# ACH-001097                        0                         0
#            MIR1302-11 (ENSG00000283801) MIR3198-2 (ENSG00000283803)
# ACH-001097                            0                           0
#            MIR636 (ENSG00000283805) AC007326.4 (ENSG00000283809)
# ACH-001097                        0                        13.90
#            MIR4485 (ENSG00000283813) MIR18A (ENSG00000283815)
# ACH-001097                         0                        0
#            MIR7844 (ENSG00000283818) MIR144 (ENSG00000283819)
# ACH-001097                         0                        0
#            MIR6875 (ENSG00000283821) MIR639 (ENSG00000283822)
# ACH-001097                         0                        0
#            MIR22 (ENSG00000283824) AL137002.2 (ENSG00000283828)
# ACH-001097                       0                            0
#            MIR378I (ENSG00000283829) MIR6734 (ENSG00000283836)
# ACH-001097                         0                         0
#            AC096667.1 (ENSG00000283839) MIR6764 (ENSG00000283840)
# ACH-001097                            0                         0
#            MIR4751 (ENSG00000283842) MIR214 (ENSG00000283844)
# ACH-001097                         0                        0
#            MIR4721 (ENSG00000283845) MIR6872 (ENSG00000283848)
# ACH-001097                         0                         0
#            AC092053.2 (ENSG00000283849) MIR4738 (ENSG00000283853)
# ACH-001097                            8                         0
#            MIR7703 (ENSG00000283856) MIR1247 (ENSG00000283857)
# ACH-001097                         0                         0
#            MIR3674 (ENSG00000283858) MIR3960 (ENSG00000283863)
# ACH-001097                         0                         0
#            MTND3P18 (ENSG00000283865) MIR1307 (ENSG00000283867)
# ACH-001097                          0                      0.00
#            MIR130B (ENSG00000283871) SSU72P4 (ENSG00000283873)
# ACH-001097                         0                         4
#            MIR3911 (ENSG00000283874) MIR4260 (ENSG00000283876)
# ACH-001097                         0                         0
#            AC104304.1 (ENSG00000283877) AC132825.5 (ENSG00000283879)
# ACH-001097                            0                            0
#            MIR7704 (ENSG00000283880) MIR3916 (ENSG00000283881)
# ACH-001097                         0                         0
#            MIR3714 (ENSG00000283885) BX664615.2 (ENSG00000283886)
# ACH-001097                         0                         0.00
#            MIR1469 (ENSG00000283888) MIR628 (ENSG00000283891)
# ACH-001097                         0                        0
#            MIR1324 (ENSG00000283894) AC011416.3 (ENSG00000283897)
# ACH-001097                         0                            0
#            MIR761 (ENSG00000283899) TPTEP2-CSNK1E (ENSG00000283900)
# ACH-001097                        0                            0.00
#            MIR155 (ENSG00000283904) IGHV4-80 (ENSG00000283906)
# ACH-001097                        0                          0
#            AD000090.1 (ENSG00000283907) BMS1P21 (ENSG00000283913)
# ACH-001097                            0                         0
#            AC087645.4 (ENSG00000283914) MIR6743 (ENSG00000283920)
# ACH-001097                            0                         0
#            MIR1302-9 (ENSG00000283921) MIR6132 (ENSG00000283923)
# ACH-001097                           0                         0
#            MIR192 (ENSG00000283926) MIR133A1 (ENSG00000283927)
# ACH-001097                        0                          0
#            MIR637 (ENSG00000283928) MIR5010 (ENSG00000283929)
# ACH-001097                        0                         0
#            AL117339.5 (ENSG00000283930) MIR18B (ENSG00000283931)
# ACH-001097                        34.09                        0
#            AL121722.1 (ENSG00000283932) MIR6878 (ENSG00000283933)
# ACH-001097                         0.00                         0
#            MIR423 (ENSG00000283935) MIR3658 (ENSG00000283936)
# ACH-001097                        0                         0
#            MIR3917 (ENSG00000283938) AC068137.3 (ENSG00000283940)
# ACH-001097                         0                            0
#            MIR600 (ENSG00000283941) MIR4709 (ENSG00000283944)
# ACH-001097                        0                         0
#            LINC00032 (ENSG00000283945) IGHVIII-16-1 (ENSG00000283948)
# ACH-001097                           0                              0
#            MIR6791 (ENSG00000283950) AC092017.3 (ENSG00000283952)
# ACH-001097                         0                            0
#            MIR3610 (ENSG00000283956) MIR1248 (ENSG00000283958)
# ACH-001097                         0                         0
#            AP002851.1 (ENSG00000283959) TAF11L8 (ENSG00000283967)
# ACH-001097                           52                         0
#            MIR6838 (ENSG00000283969) MIR4442 (ENSG00000283971)
# ACH-001097                         0                         0
#            AP000550.4 (ENSG00000283972) AC099795.1 (ENSG00000283973)
# ACH-001097                            0                            0
#            AC084337.2 (ENSG00000283977) MIR365B (ENSG00000283978)
# ACH-001097                        17.17                         0
#            GNG14 (ENSG00000283980) AL445623.2 (ENSG00000283982)
# ACH-001097                       0                            8
#            TAF11L9 (ENSG00000283988) MIRLET7A3 (ENSG00000283990)
# ACH-001097                         0                           0
#            AC017000.1 (ENSG00000283991) SLURP2 (ENSG00000283992)
# ACH-001097                            0                     0.00
#            AC092652.3 (ENSG00000283994) MIR492 (ENSG00000283998)
# ACH-001097                           20                        0
#            AL358215.3 (ENSG00000283999) MIR4458 (ENSG00000284000)
# ACH-001097                            0                         0
#            AC073869.6 (ENSG00000284003) MIR6084 (ENSG00000284005)
# ACH-001097                            0                         0
#            MIR6511B1 (ENSG00000284008) MIR675 (ENSG00000284010)
# ACH-001097                           0                        0
#            MIR6502 (ENSG00000284011) MIR6840 (ENSG00000284012)
# ACH-001097                         0                         0
#            MIR1281 (ENSG00000284015) SSU72P5 (ENSG00000284018)
# ACH-001097                         0                         0
#            MIR4697 (ENSG00000284020) HSPA14 (ENSG00000284024)
# ACH-001097                         0                  2479.70
#            MIR497 (ENSG00000284027) MIR4468 (ENSG00000284028)
# ACH-001097                        0                         0
#            MIR6805 (ENSG00000284029) MIR4761 (ENSG00000284031)
# ACH-001097                         0                         0
#            MIR29A (ENSG00000284032) MIR5196 (ENSG00000284034)
# ACH-001097                        0                         0
#            MIR5187 (ENSG00000284035) MIR10A (ENSG00000284038)
# ACH-001097                         0                        0
#            MIR296 (ENSG00000284040) AC073111.3 (ENSG00000284041)
# ACH-001097                        0                         0.00
#            TAF11L6 (ENSG00000284042) MIR20B (ENSG00000284043)
# ACH-001097                         0                        0
#            MIR6836 (ENSG00000284047) AC073111.4 (ENSG00000284048)
# ACH-001097                         0                        60.48
#            MIR650 (ENSG00000284049) AC006460.2 (ENSG00000284052)
# ACH-001097                        0                            9
#            MIR7112 (ENSG00000284054) MIR4315-1 (ENSG00000284055)
# ACH-001097                         0                           0
#            AP001273.2 (ENSG00000284057) MIR5572 (ENSG00000284059)
# ACH-001097                         0.00                         0
#            AC002472.2 (ENSG00000284060) MIR4469 (ENSG00000284062)
# ACH-001097                         0.00                         0
#            MIR6834 (ENSG00000284064) MIR6887 (ENSG00000284065)
# ACH-001097                         0                         0
#            MIR6837 (ENSG00000284067) AP000356.2 (ENSG00000284070)
# ACH-001097                         0                        10.38
#            AC012005.2 (ENSG00000284071) MIR4758 (ENSG00000284074)
# ACH-001097                            0                         0
#            AC108110.1 (ENSG00000284078) MIR4775 (ENSG00000284079)
# ACH-001097                            0                         0
#            MIR1199 (ENSG00000284081) MIR7109 (ENSG00000284082)
# ACH-001097                         0                         0
#            AOX3P-AOX2P (ENSG00000284084) MIR4732 (ENSG00000284085)
# ACH-001097                             0                         0
#            MIR6844 (ENSG00000284087) MIR5703 (ENSG00000284092)
# ACH-001097                         0                         0
#            MIR6073 (ENSG00000284094) AC055733.4 (ENSG00000284095)
# ACH-001097                         0                            0
#            AC099654.9 (ENSG00000284098) MIR19B2 (ENSG00000284107)
# ACH-001097                            0                         0
#            MIR611 (ENSG00000284108) MIR195 (ENSG00000284112)
# ACH-001097                        0                        0
#            MIR6800 (ENSG00000284114) AL772307.1 (ENSG00000284116)
# ACH-001097                         0                        47.77
#            MIR6883 (ENSG00000284117) MIR4707 (ENSG00000284118)
# ACH-001097                         0                         0
#            MIR198 (ENSG00000284121) MIR6717 (ENSG00000284122)
# ACH-001097                        0                         0
#            MIR1825 (ENSG00000284125) AP000356.3 (ENSG00000284128)
# ACH-001097                         0                        56.39
#            MIR6789 (ENSG00000284129) AC002472.3 (ENSG00000284130)
# ACH-001097                         0                            0
#            MIR568 (ENSG00000284134) MIR3654 (ENSG00000284135)
# ACH-001097                        0                         0
#            ATP6V0CP4 (ENSG00000284138) MIR1234 (ENSG00000284139)
# ACH-001097                           0                         0
#            MIR3618 (ENSG00000284140) MIR6845 (ENSG00000284142)
# ACH-001097                         0                         0
#            MIR4700 (ENSG00000284143) MIR6866 (ENSG00000284144)
# ACH-001097                         0                         0
#            MIR922 (ENSG00000284146) MIR3150B (ENSG00000284147)
# ACH-001097                        0                          0
#            MIR6756 (ENSG00000284148) MIR4784 (ENSG00000284149)
# ACH-001097                         0                         0
#            MIR6758 (ENSG00000284152) MIR3605 (ENSG00000284154)
# ACH-001097                         0                         0
#            MIR194-2 (ENSG00000284155) MIR106A (ENSG00000284157)
# ACH-001097                          0                         0
#            MIR6822 (ENSG00000284158) MIR3940 (ENSG00000284159)
# ACH-001097                         0                         0
#            MIR7706 (ENSG00000284160) MIR4523 (ENSG00000284162)
# ACH-001097                         0                         0
#                          1.00
#            AC023095.1 (ENSG00000285971) CERNA2 (ENSG00000285972)
# ACH-001097                            0                        0
#            AC063960.2 (ENSG00000285973) AC026624.1 (ENSG00000285974)
# ACH-001097                            0                            0
#            AC134684.11 (ENSG00000285975) AL135905.2 (ENSG00000285976)
# ACH-001097                             0                       5880.3
#            AC022068.1 (ENSG00000285977) AC113348.2 (ENSG00000285978)
# ACH-001097                            0                         3.43
#            AC009090.6 (ENSG00000285979) AP003025.2 (ENSG00000285980)
# ACH-001097                        61.43                            0
#            AL591888.1 (ENSG00000285981) AC012213.5 (ENSG00000285982)
# ACH-001097                            0                         0.00
#            AC009301.1 (ENSG00000285984) AC136297.1 (ENSG00000285985)
# ACH-001097                            0                            0
#            BX248415.1 (ENSG00000285986) AL157886.1 (ENSG00000285987)
# ACH-001097                            0                           19
#            AL392086.3 (ENSG00000285988) AL357123.1 (ENSG00000285989)
# ACH-001097                         0.00                            0
#            AL589743.7 (ENSG00000285990) AL355312.5 (ENSG00000285991)
# ACH-001097                         0.00                         0.00
#            AC120036.5 (ENSG00000285992) AC018931.1 (ENSG00000285993)
# ACH-001097                            0                            0
#            AL731559.1 (ENSG00000285994)
# ACH-001097                            0
#  [ reached getOption("max.print") -- omitted 5 rows ]

# %%
# %%R
# read_tsv(f)
# Out:
# 2019-06-18 09:27:15::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double()
# )
# # A tibble: 58,813 x 7
#    gene_id  `transcript_id(s… length effective_length expected_count   TPM  FPKM
#    <chr>    <chr>              <dbl>            <dbl>          <dbl> <dbl> <dbl>
#  1 ENSG000… ENST00000373020.…  1749.            1424.             0   0     0
#  2 ENSG000… ENST00000373031.…   940.             619.             0   0     0
#  3 ENSG000… ENST00000371582.…  1063.             737.          2598  41.2  53.4
#  4 ENSG000… ENST00000367770.…  4956.            4631.           884.  2.23  2.89
#  5 ENSG000… ENST00000286031.…  2382.            2057.           281.  1.6   2.07
#  6 ENSG000… ENST00000374003.…  2350             2025.            37   0.21  0.28
#  7 ENSG000… ENST00000359637.…  2588.            2264.             0   0     0
#  8 ENSG000… ENST00000002165.…  2271.            1946.           180   1.08  1.4
#  9 ENSG000… ENST00000229416.…  3155.            2832.          5720  23.6  30.6
# 10 ENSG000… ENST00000341376.…  3638.            3312.          1986   7.01  9.09
# # … with 58,803 more rows

# %%
# %%R
# dataset <- AddSamplesTo(dataset, listOfSamples)
# Out:
# 2019-06-18 09:22:55::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   gene_id = col_character(),
#   `transcript_id(s)` = col_character(),
#   length = col_double(),
#   effective_length = col_double(),
#   expected_count = col_double(),
#   TPM = col_double(),
#   FPKM = col_double()
# )
#
# 2019-06-18 09:22:55::WARNING  R[write to console]: Error in UseMethod("left_join") :
#   no applicable method for 'left_join' applied to an object of class "c('matrix', 'double', 'numeric')"
# Calls: <Anonymous> ... _fseq -> freduce -> withVisible -> <Anonymous> -> left_join
#
# 2019-06-18 09:22:55::WARNING  R[write to console]: In addition:
# 2019-06-18 09:22:55::WARNING  R[write to console]: Warning message:
#
# 2019-06-18 09:22:55::WARNING  R[write to console]: In taiga2.resolve.id(data.id, data.name, data.version, data.dir,  :
# 2019-06-18 09:22:55::WARNING  R[write to console]:
#
# 2019-06-18 09:22:55::WARNING  R[write to console]:  No such datafile, load.from.taiga returning NULL
# Error in UseMethod("left_join") :
#   no applicable method for 'left_join' applied to an object of class "c('matrix', 'double', 'numeric')"
# Calls: <Anonymous> ... _fseq -> freduce -> withVisible -> <Anonymous> -> left_join

# %%
# %%R
# source('CCLE_postp_function.R')
#
# fusionFusions(c('temp/expression.fusion.tsv'),'temp/fusions.unfiltered.tsv')
# Out:
# [1] "ha"
# [1] "ha"
# [1] "ha"
# 2019-06-14 07:42:46::WARNING  R[write to console]: Error: 'NA' does not exist in current working directory ('/home/jeremie/ccle_processing').
# Error: 'NA' does not exist in current working directory ('/home/jeremie/ccle_processing').

# %%
# %%R
# Out:
# No traceback available

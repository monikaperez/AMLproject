# %%
from __future__ import print_function
import os.path
import pandas as pd
import sys
sys.path.insert(0, '../JKBio/')
# %load_ext autoreload
from Helper import *
# %autoreload 2
# %load_ext rpy2.ipython
import numpy as np
from bokeh.plotting import *
from bokeh.models import HoverTool
output_notebook()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from helper import pyDESeq2
from sklearn.neighbors import KNeighborsClassifier
from sklearn.manifold import MDS, TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
#from umap import UMAP
import kipoi
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
model = kipoi.get_model('DeepBind/Homo_sapiens/TF/D00345.002_SELEX_E2F2')
# Out:
# Collecting kipoi
#   Downloading https://files.pythonhosted.org/packages/3a/38/694abc9e867e1570fcb8e52e30483dde894cbd12f6d846e43eecd48d55e7/kipoi-0.6.24-py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 2.7MB/s ta 0:00:011
# Requirement already satisfied: urllib3>=1.21.1 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (1.24.2)
# Requirement already satisfied: jinja2 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (2.10.3)
# Collecting related>=0.6.0 (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/23/6e/5419d1364d9c408cb4943d1301800bf88b8d91e034c355448b00440ca202/related-0.7.2-py2.py3-none-any.whl
# Collecting kipoi-utils>=0.3.8 (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/87/d0/794ec069369a4d29c689c3d8e86354c3fc549ac78e559353e0a986c65bbf/kipoi_utils-0.3.8.tar.gz
# Requirement already satisfied: attrs>=17.4.0 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (19.3.0)
# Requirement already satisfied: future in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (0.17.1)
# Collecting cookiecutter>=1.6.0 (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/16/99/1ca3a75978270288354f419e9166666801cf7e7d8df984de44a7d5d8b8d0/cookiecutter-1.6.0-py2.py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 21.3MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (4.32.1)
# Requirement already satisfied: h5py in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (2.10.0)
# Collecting kipoi-conda>=0.1.6 (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/f9/9a/0ca89ce13ede55f6ce9a7ebc2e405659eab106252ce148dc37afb84fc1c4/kipoi_conda-0.2.2-py3-none-any.whl
# Collecting deprecation>=2.0.6 (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/b9/2a/d5084a8781398cea745c01237b95d9762c382697c63760a95cc6a814ad3a/deprecation-2.0.7-py2.py3-none-any.whl
# Requirement already satisfied: colorlog in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (4.0.2)
# Requirement already satisfied: numpy in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (1.17.2)
# Requirement already satisfied: pyyaml in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (5.1.2)
# Requirement already satisfied: pandas>=0.21.0 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi) (0.25.1)
# Collecting tinydb (from kipoi)
#   Downloading https://files.pythonhosted.org/packages/9b/83/2d46115b89640e9b85b94df47216547396e94125245dd3ade186036ce976/tinydb-3.15.1-py2.py3-none-any.whl
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from jinja2->kipoi) (1.1.1)
# Requirement already satisfied: python-dateutil in /home/jeremie/miniconda3/lib/python3.7/site-packages (from related>=0.6.0->kipoi) (2.8.0)
# Requirement already satisfied: six in /home/jeremie/miniconda3/lib/python3.7/site-packages (from kipoi-utils>=0.3.8->kipoi) (1.12.0)
# Collecting poyo>=0.1.0 (from cookiecutter>=1.6.0->kipoi)
#   Downloading https://files.pythonhosted.org/packages/42/50/0b0820601bde2eda403f47b9a4a1f270098ed0dd4c00c443d883164bdccc/poyo-0.5.0-py2.py3-none-any.whl
# Collecting whichcraft>=0.4.0 (from cookiecutter>=1.6.0->kipoi)
#   Downloading https://files.pythonhosted.org/packages/b5/a2/81887a0dae2e4d2adc70d9a3557fdda969f863ced51cd3c47b587d25bce5/whichcraft-0.6.1-py2.py3-none-any.whl
# Collecting binaryornot>=0.2.0 (from cookiecutter>=1.6.0->kipoi)
#   Downloading https://files.pythonhosted.org/packages/24/7e/f7b6f453e6481d1e233540262ccbfcf89adcd43606f44a028d7f5fae5eb2/binaryornot-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: click>=5.0 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from cookiecutter>=1.6.0->kipoi) (7.0)
# Requirement already satisfied: requests>=2.18.0 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from cookiecutter>=1.6.0->kipoi) (2.22.0)
# Collecting jinja2-time>=0.1.0 (from cookiecutter>=1.6.0->kipoi)
#   Downloading https://files.pythonhosted.org/packages/6a/a1/d44fa38306ffa34a7e1af09632b158e13ec89670ce491f8a15af3ebcb4e4/jinja2_time-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: packaging in /home/jeremie/miniconda3/lib/python3.7/site-packages (from deprecation>=2.0.6->kipoi) (19.2)
# Requirement already satisfied: pytz>=2017.2 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from pandas>=0.21.0->kipoi) (2019.2)
# Requirement already satisfied: chardet>=3.0.2 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from binaryornot>=0.2.0->cookiecutter>=1.6.0->kipoi) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from requests>=2.18.0->cookiecutter>=1.6.0->kipoi) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from requests>=2.18.0->cookiecutter>=1.6.0->kipoi) (2019.9.11)
# Collecting arrow (from jinja2-time>=0.1.0->cookiecutter>=1.6.0->kipoi)
#   Downloading https://files.pythonhosted.org/packages/a1/39/a8e116084cf4160f0821ca9bb84ec312ccca84caa2b2bffb70d95d47f91f/arrow-0.15.4-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 23.3MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /home/jeremie/miniconda3/lib/python3.7/site-packages (from packaging->deprecation>=2.0.6->kipoi) (2.4.2)
# Building wheels for collected packages: kipoi-utils
#   Building wheel for kipoi-utils (setup.py) ... done
#   Stored in directory: /home/jeremie/.cache/pip/wheels/25/46/ed/6cb515dafb601c6f5c2d074750472e8bf6ea447aa3dc9b605b
# Successfully built kipoi-utils
# Installing collected packages: related, kipoi-utils, poyo, whichcraft, binaryornot, arrow, jinja2-time, cookiecutter, kipoi-conda, deprecation, tinydb, kipoi
# Successfully installed arrow-0.15.4 binaryornot-0.4.4 cookiecutter-1.6.0 deprecation-2.0.7 jinja2-time-0.2.0 kipoi-0.6.24 kipoi-conda-0.2.2 kipoi-utils-0.3.8 poyo-0.5.0 related-0.7.2 tinydb-3.15.1 whichcraft-0.6.1

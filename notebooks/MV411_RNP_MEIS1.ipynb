# %%
from __future__ import print_function
import pandas as pd
import sys
sys.path.insert(0, '../../')
import numpy as np
import itertools

from genepy import terra
from genepy.utils import helper as h
from genepy.google import gcp
from genepy import rna
from genepy.utils import plot
from genepy.rna import pyDESeq2

from taigapy import TaigaClient
import dalmatian as dm

from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import AgglomerativeClustering, DBSCAN
from sklearn.manifold import MDS, TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import networkx as nx

import gseapy

import matplotlib.pyplot as plt
from bokeh.plotting import *
from bokeh.models import HoverTool
import seaborn as sns

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython
tc = TaigaClient()
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
#Experiment outline: MONOMAC1 cell line, simultaneous RNP knockout of MEF2D and MEF2C  followed by RNAseq at 48 and 72 hours. 
project = "RNP_MEIS1"
version = "v1"

# %% [markdown]
# ## getting data

# %%
folder = "MP8652"

# %%
! gsutil mv gs://transfer-amlproject/*$folder*/*.fastq.gz gs://transfer-amlproject/$project/
# Out:
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP1_MP8652_S1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP1_MP8652_S1_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP1_MP8652_S1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP1_MP8652_S1_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP2_MP8652_S2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP2_MP8652_S2_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP2_MP8652_S2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP2_MP8652_S2_R2_001.fastq.gz...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP3_MP8652_S3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP3_MP8652_S3_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP3_MP8652_S3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP3_MP8652_S3_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP4_MP8652_S4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP4_MP8652_S4_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP4_MP8652_S4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP4_MP8652_S4_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP5_MP8652_S5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP5_MP8652_S5_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP5_MP8652_S5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP5_MP8652_S5_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP6_MP8652_S6_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP6_MP8652_S6_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP6_MP8652_S6_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP6_MP8652_S6_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP7_MP8652_S7_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP7_MP8652_S7_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP7_MP8652_S7_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP7_MP8652_S7_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP8_MP8652_S8_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP8_MP8652_S8_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP8_MP8652_S8_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Removing gs://transfer-amlproject/210210_MP8652_fastq/20210210_MP8_MP8652_S8_R2_001.fastq.gz...
# /
# Operation completed over 16 objects/25.3 GiB.

# %%
! gsutil -m cp gs://transfer-amlproject/$project/* gs://amlproject/RNA/$project/
# Out:
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP1_MP8652_S1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP1_MP8652_S1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP2_MP8652_S2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP2_MP8652_S2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP3_MP8652_S3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP3_MP8652_S3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP4_MP8652_S4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP4_MP8652_S4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP5_MP8652_S5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP5_MP8652_S5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP6_MP8652_S6_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP6_MP8652_S6_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP7_MP8652_S7_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP7_MP8652_S7_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP8_MP8652_S8_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying gs://transfer-amlproject/RNP_MEIS1/20210210_MP8_MP8652_S8_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# - [16/16 files][ 25.3 GiB/ 25.3 GiB] 100% Done
# Operation completed over 16 objects/25.3 GiB.

# %% [markdown]
# ### Rename

# %%
rename={"20210210_MP1_MP8652_S1": "mr351-MV411-DMSO-r1",
"20210210_MP2_MP8652_S2": "mr352-MV411-DMSO-r2",
"20210210_MP3_MP8652_S3": "mr353-MV411-DMSO-r3",
"20210210_MP4_MP8652_S4": "mr354-MV411-DMSO-r4",
"20210210_MP5_MP8652_S5": "mr355-MV411-72h_MEIS1-r1",
"20210210_MP6_MP8652_S6": "mr356-MV411-72h_MEIS1-r2",
"20210210_MP7_MP8652_S7": "mr357-MV411-72h_MEIS1-r3",
"20210210_MP8_MP8652_S8": "mr358-MV411-72h_MEIS1-r4"}

# %%
gcp.patternRN(rename,'gs://amlproject/RNA/'+project+'/',['.*'], dryrun=False)
# Out:
# found 0 files to rename
# found 1 files to rename
# found 1 files to rename
# found 2 files to rename
# found 2 files to rename
# found 2 files to rename
# found 2 files to rename
# found 2 files to rename

# %% [markdown]
# ## Running on Terra

# %%
terra.uploadFromFolder('amlproject','RNA/'+project+"/",
                       'broad-firecloud-ccle/hg38_RNAseq',samplesetname=project,
                      fformat="fastqR1R2", sep='_R1|_R2', test=False)
# Out:
# please be sure you gave access to your terra email account access to this bucket
# /home/jeremie/.local/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/jeremie/.local/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ['RNA/RNP_MEIS1/mr351-MV411-DMSO-r1_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr351-MV411-DMSO-r1_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr352-MV411-DMSO-r2_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr352-MV411-DMSO-r2_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr353-MV411-DMSO-r3_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr353-MV411-DMSO-r3_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr354-MV411-DMSO-r4_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr354-MV411-DMSO-r4_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr355-MV411-72h_MEIS1-r1_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr355-MV411-72h_MEIS1-r1_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr356-MV411-72h_MEIS1-r2_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr356-MV411-72h_MEIS1-r2_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr357-MV411-72h_MEIS1-r3_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr357-MV411-72h_MEIS1-r3_R2_001.fastq.gz', 'RNA/RNP_MEIS1/mr358-MV411-72h_MEIS1-r4_R1_001.fastq.gz', 'RNA/RNP_MEIS1/mr358-MV411-72h_MEIS1-r4_R2_001.fastq.gz']
# /home/jeremie/.local/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Successfully imported 8 participants.
# /home/jeremie/.local/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/jeremie/.local/lib/python3.8/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Successfully imported 8 samples.
# Successfully imported 1 sample sets:
#   * RNP_MEIS1 (8 samples)
#                                                                      fastq1  \
# sample_id
# mr351-MV411-DMSO-r1       gs://amlproject/RNA/RNP_MEIS1/mr351-MV411-DMSO...
# mr352-MV411-DMSO-r2       gs://amlproject/RNA/RNP_MEIS1/mr352-MV411-DMSO...
# mr353-MV411-DMSO-r3       gs://amlproject/RNA/RNP_MEIS1/mr353-MV411-DMSO...
# mr354-MV411-DMSO-r4       gs://amlproject/RNA/RNP_MEIS1/mr354-MV411-DMSO...
# mr355-MV411-72h_MEIS1-r1  gs://amlproject/RNA/RNP_MEIS1/mr355-MV411-72h_...
# mr356-MV411-72h_MEIS1-r2  gs://amlproject/RNA/RNP_MEIS1/mr356-MV411-72h_...
# mr357-MV411-72h_MEIS1-r3  gs://amlproject/RNA/RNP_MEIS1/mr357-MV411-72h_...
# mr358-MV411-72h_MEIS1-r4  gs://amlproject/RNA/RNP_MEIS1/mr358-MV411-72h_...
#
#                                                                      fastq2  \
# sample_id
# mr351-MV411-DMSO-r1       gs://amlproject/RNA/RNP_MEIS1/mr351-MV411-DMSO...
# mr352-MV411-DMSO-r2       gs://amlproject/RNA/RNP_MEIS1/mr352-MV411-DMSO...
# mr353-MV411-DMSO-r3       gs://amlproject/RNA/RNP_MEIS1/mr353-MV411-DMSO...
# mr354-MV411-DMSO-r4       gs://amlproject/RNA/RNP_MEIS1/mr354-MV411-DMSO...
# mr355-MV411-72h_MEIS1-r1  gs://amlproject/RNA/RNP_MEIS1/mr355-MV411-72h_...
# mr356-MV411-72h_MEIS1-r2  gs://amlproject/RNA/RNP_MEIS1/mr356-MV411-72h_...
# mr357-MV411-72h_MEIS1-r3  gs://amlproject/RNA/RNP_MEIS1/mr357-MV411-72h_...
# mr358-MV411-72h_MEIS1-r4  gs://amlproject/RNA/RNP_MEIS1/mr358-MV411-72h_...
#
#                          Source               participant
# sample_id
# mr351-MV411-DMSO-r1           U       mr351-MV411-DMSO-r1
# mr352-MV411-DMSO-r2           U       mr352-MV411-DMSO-r2
# mr353-MV411-DMSO-r3           U       mr353-MV411-DMSO-r3
# mr354-MV411-DMSO-r4           U       mr354-MV411-DMSO-r4
# mr355-MV411-72h_MEIS1-r1      U  mr355-MV411-72h_MEIS1-r1
# mr356-MV411-72h_MEIS1-r2      U  mr356-MV411-72h_MEIS1-r2
# mr357-MV411-72h_MEIS1-r3      U  mr357-MV411-72h_MEIS1-r3
# mr358-MV411-72h_MEIS1-r4      U  mr358-MV411-72h_MEIS1-r4

# %%
wm = dm.WorkspaceManager('broad-firecloud-ccle/hg38_RNAseq')

# %%
submission_id = wm.create_submission("star_v1-0_BETA_cfg", project, 'sample_set',expression='this.samples')
terra.waitForSubmission('broad-firecloud-ccle/hg38_RNAseq', submission_id)
# Out:
# Successfully created submission 667936e7-6708-493e-a81e-d4f8436a4cb5.
# status is: Failed for 0 jobs in submission 0. 55 mn elapsed.

# %%
submission_id = wm.create_submission("rsem_v1-0_BETA_cfg", project, 'sample_set', expression = 'this.samples')
terra.waitForSubmission('broad-firecloud-ccle/hg38_RNAseq', submission_id)

# %%
submission_id = wm.create_submission("rsem_aggregate_results_v1-0_BETA_cfg", project)
terra.waitForSubmission('broad-firecloud-ccle/hg38_RNAseq', submission_id)

# %%
results = wm.get_sample_sets().loc[project]
rsem_genes_expected_count = results['rsem_genes_expected_count']

# %% [markdown]
# ## Loading

# %%
mkdir ../data/$project

# %%
! gsutil cp $rsem_genes_expected_count ../data/$project/

# %%
file = '../data/'+project+'/'+rsem_genes_expected_count.split('/')[-1]

# %%
! gunzip $file

# %%
rsem_genes_expected_count = pd.read_csv(file[:-3], sep='\t')

# %%
data = rsem_genes_expected_count.drop("transcript_id(s)", 1).set_index('gene_id')

# %%
data.index = rna.convertGenes(data.index)[0]

# %% [markdown]
# ## post processing and filtering

# %% [markdown]
# filter some more

# %%
minvar = 0
minmean = 0

# %%
toremove = np.argwhere(data.values.var(1)<=minvar)
data = data.drop(data.iloc[toremove.ravel()].index,0)
toremove.ravel()
# Out:
# array([    0,    15,    24, ..., 58715, 58716, 58719])

# %%
toremove = np.argwhere(data.values.mean(1)<=minmean)
data = data.drop(data.iloc[toremove.ravel()].index,0)
toremove.ravel()

# %%
data.shape
# Out:
# (30010, 16)

# %%
ERCC = data[~data.index.str.contains('ENSG00')]

# %%
data = data[~data.index.str.contains('ENSG00')]

# %% [markdown]
# renormalize the data

# %%
len(ERCC)
# Out:
# 21801

# %% [markdown]
# ## Loading the CRC members

# %%
ctf=h.fileToList('../data/CRCs.txt',header=None)[0].values.tolist()
ctf
# Out:
# ['CEBPA',
#  'E2F3',
#  'FLI1',
#  'FOSL2',
#  'GFI1',
#  'HEX',
#  'IRF8',
#  'LYL1',
#  'MEF2C',
#  'MEF2D',
#  'MEIS1',
#  'MYB',
#  'PLAGL2',
#  'RUNX1',
#  'RUNX2',
#  'RXRA',
#  'SP1',
#  'SPI1',
#  'SREBF1',
#  'STAT5B',
#  'TFAP4',
#  'ZEB2',
#  'ZFPM1',
#  'ZNF281',
#  'LMO2',
#  'ZMYND8',
#  'GATA2',
#  'MAX',
#  'MYC',
#  'ETV6',
#  'HOXA9']

# %% [markdown]
# ## Correlation analysis across replicates

# %%
a = data.columns.tolist()
a.sort()
data =data[a]

# %% [markdown]
# I would like to spend a bit of time looking at this matrix, we can see that it contains a lot of weird things and adding the additionals did not help decipher it to me.
#
# We have a set of samples IRF2BP2 r4, MYCs r4,5,6, RUNX1s r7,8,9, SPI1 R4,r7 are all very different from their replicates or the rest of the experiment but ccan be closer to some unrelated experiments.
#
# We can not as well the difference in the AAVS1s and a strange pattern showing likely misslabeling in AAVS1 r7.

# %%
# !mkdir ../results/$project/
# !mkdir ../results/$project/plots_$version/
# Out:
# mkdir: cannot create directory ‘../results/MONOMAC_synMEF2CD/’: File exists

# %%
# %matplotlib inline
ig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), 
            xticklabels=data.columns,
            yticklabels=data.columns, ax=ax)
plt.savefig('../results/'+project+'/plots_'+version+'/correlation.pdf')

# %%
sns.clustermap(data.corr(), 
            xticklabels=data.columns,
            yticklabels=data.columns)

# %%
ig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), 
            xticklabels=data.columns,
            yticklabels=data.columns, ax=ax)
plt.savefig('../results/'+project+'/plots_'+version+'/correlation.pdf')

# %%
data.to_csv('../results/'+project+'/'+version+'_counts.csv')

# %%
version = 'v1'

# %%
data = pd.read_csv('../results/'+project+'/'+version+'_counts.csv',index_col=0)

# %% [markdown]
# ## We are looking for bias in the data and the replicates

# %%
col = {v:i for i, v in enumerate(set([i.split('-')[2] for i in data.columns[:-1]]))}

# %%
col
# Out:
# {'72h_MEF2C_MEF2D': 0, '48h_AAVS1': 1, '48h_MEF2C_MEF2D': 2, '72h_AAVS1': 3}

# %%
sdata = data.copy()

# %%
data = data[[i for i in data.columns if i.split('-')[0] not in  ["mr334", "mr342", "mr338", "mr329","mr337"]]]

# %%
red = PCA(2).fit_transform(data[data.columns[:-1]].T)
plot.scatter(red, labels=data.columns[:-1], title="PCA plot across replicates", radi=60000, colors=[col[i.split('-')[2]] for i in data.columns[:-1]], folder= "../results/"+project+"/plots_"+version+"/", showlabels=True)
# Out:
#   <div class="bk-root" id="73b2bcf2-06d3-4f1c-995b-2a96bf0846ac" data-root-id="5320"></div>
# Figure(id='5320', ...)

# %% [markdown]
# mr129-MYC-r4 seems weird

# %% [markdown]
# ## Making and running the dashboard

# %%
ERCC = ERCC.astype(int)

# %%
ERCC['Feature'] = ERCC.index

# %%
ERCC.columns = [i.replace('_','') for i in ERCC.columns]

# %%
experiments = list(set([i.split('-')[2].replace('_','') for i in ERCC.columns[:-1]]))
experiments
# Out:
# ['72hAAVS1', '48hMEF2CMEF2D', '72hMEF2CMEF2D', '48hAAVS1']

# %%
ERCC
# Out:
#             mr327-MONOMAC1-48hMEF2CMEF2D-r1  mr328-MONOMAC1-48hMEF2CMEF2D-r2  \
# TNMD                                      0                                0
# DPM1                                    670                              888
# SCYL3                                   121                              144
# C1orf112                                280                              329
# FGR                                    1203                             1487
# ...                                     ...                              ...
# ERCC-00164                                9                               19
# ERCC-00165                             1132                             1351
# ERCC-00168                               14                               29
# ERCC-00170                               85                               94
# ERCC-00171                            36959                            42413
#
#             mr329-MONOMAC1-48hMEF2CMEF2D-r3  mr330-MONOMAC1-48hMEF2CMEF2D-r4  \
# TNMD                                      0                                0
# DPM1                                   1321                             1014
# SCYL3                                   209                              186
# C1orf112                                462                              397
# FGR                                    2106                             1931
# ...                                     ...                              ...
# ERCC-00164                               27                               19
# ERCC-00165                             2182                             1430
# ERCC-00168                               50                               42
# ERCC-00170                              174                              114
# ERCC-00171                            65927                            52026
#
#             mr331-MONOMAC1-48hAAVS1-r1  mr332-MONOMAC1-48hAAVS1-r2  \
# TNMD                                 0                           0
# DPM1                              1105                        1084
# SCYL3                              209                         213
# C1orf112                           493                         450
# FGR                               1448                        1383
# ...                                ...                         ...
# ERCC-00164                          15                          12
# ERCC-00165                        1587                        1151
# ERCC-00168                          30                          25
# ERCC-00170                          98                          94
# ERCC-00171                       51177                       40847
#
#             mr333-MONOMAC1-48hAAVS1-r3  mr334-MONOMAC1-48hAAVS1-r4  \
# TNMD                                 2                           0
# DPM1                              1332                        1037
# SCYL3                              191                         171
# C1orf112                           534                         430
# FGR                               1704                        1051
# ...                                ...                         ...
# ERCC-00164                          19                          13
# ERCC-00165                        1980                        1498
# ERCC-00168                          28                          35
# ERCC-00170                         114                         117
# ERCC-00171                       67788                       49381
#
#             mr335-MONOMAC1-72hMEF2CMEF2D-r1  mr336-MONOMAC1-72hMEF2CMEF2D-r2  \
# TNMD                                      0                                0
# DPM1                                    792                              902
# SCYL3                                   153                              219
# C1orf112                                294                              335
# FGR                                    2172                             2280
# ...                                     ...                              ...
# ERCC-00164                               10                               10
# ERCC-00165                             1035                             1169
# ERCC-00168                               17                               18
# ERCC-00170                               66                               82
# ERCC-00171                            35155                            38455
#
#             mr337-MONOMAC1-72hMEF2CMEF2D-r3  mr338-MONOMAC1-72hMEF2CMEF2D-r4  \
# TNMD                                      0                                0
# DPM1                                    600                             1664
# SCYL3                                   131                              315
# C1orf112                                190                              556
# FGR                                    1983                             3839
# ...                                     ...                              ...
# ERCC-00164                               14                               34
# ERCC-00165                             1428                             4313
# ERCC-00168                               33                               73
# ERCC-00170                               97                              290
# ERCC-00171                            47022                           144230
#
#             mr339-MONOMAC1-72hAAVS1-r1  mr340-MONOMAC1-72hAAVS1-r2  \
# TNMD                                 0                           0
# DPM1                               999                         960
# SCYL3                              193                         201
# C1orf112                           434                         416
# FGR                               1377                        1366
# ...                                ...                         ...
# ERCC-00164                          26                          13
# ERCC-00165                        1574                        1442
# ERCC-00168                          32                          16
# ERCC-00170                         113                         120
# ERCC-00171                       51543                       46992
#
#             mr341-MONOMAC1-72hAAVS1-r3  mr342-MONOMAC1-72hAAVS1-r4     Feature
# TNMD                                 0                           0        TNMD
# DPM1                              1022                        1543        DPM1
# SCYL3                              208                         245       SCYL3
# C1orf112                           446                         638    C1orf112
# FGR                               1323                        1631         FGR
# ...                                ...                         ...         ...
# ERCC-00164                          14                          16  ERCC-00164
# ERCC-00165                        1749                        2302  ERCC-00165
# ERCC-00168                          33                          44  ERCC-00168
# ERCC-00170                         109                         152  ERCC-00170
# ERCC-00171                       58056                       78112  ERCC-00171
#
# [21801 rows x 17 columns]

# %%
res = rna.runERCC(ERCC, ['48hMEF2CMEF2D'], featurename="Feature", issingle=False, dilution=1/100,
name="RNPv2", spikevol=1, control="48hAAVS1", fdr=0.1, totalrnamass=0.5)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# [1] "48hMEF2CMEF2D"
# [1] "48hAAVS1"
#    Feature X48hMEF2CMEF2D_1 X48hMEF2CMEF2D_2 X48hMEF2CMEF2D_3 X48hMEF2CMEF2D_4
# 1     TNMD                0                0                0                0
# 2     DPM1              670              888             1321             1014
# 3    SCYL3              121              144              209              186
# 4 C1orf112              280              329              462              397
# 5      FGR             1203             1487             2106             1931
# 6      CFH               16               16               48               32
#   X48hAAVS1_1 X48hAAVS1_2 X48hAAVS1_3 X48hAAVS1_4
# 1           0           0           2           0
# 2        1105        1084        1332        1037
# 3         209         213         191         171
# 4         493         450         534         430
# 5        1448        1383        1704        1051
# 6          22          10          20          16
#
# Initializing the exDat list structure...
# choseFDR = 0.1
# repNormFactor is NULL
# Filename root is: RNPv2.48hMEF2CMEF2D.48hAAVS1
#
# Transcripts were removed with a mean count < 1 or more than 2
# replicates with 0 counts.
# Original data contained  21801 transcripts.
# After filtering  15968 transcripts remain for  analysis.
# A total of 6 out of 92
# ERCC controls were filtered from the data set
# The excluded ERCCs are:
# ERCC-00017 ERCC-00048 ERCC-00057 ERCC-00083 ERCC-00117
# ERCC-00156
#
# repNormFactor is NULL,
#  Using Default Upper Quartile Normalization Method  - 75th percentile
#
# normVec:
# 617 831 1084 976 1157.25 1127 1358 925
# Check for sample mRNA fraction differences(r_m)...
#
# Number of ERCC Controls Used in r_m estimate
# 86
#
# Outlier ERCCs for GLM r_m Estimate:
# ERCC-00061 ERCC-00123 ERCC-00097 ERCC-00086 ERCC-00041
# ERCC-00164 ERCC-00120 ERCC-00147 ERCC-00168 ERCC-00137
# ERCC-00040 ERCC-00013 ERCC-00077 ERCC-00058 ERCC-00033
# ERCC-00154 ERCC-00028 ERCC-00069 ERCC-00039 ERCC-00085
# ERCC-00054 ERCC-00160 ERCC-00157 ERCC-00014 ERCC-00170
# ERCC-00144 ERCC-00059 ERCC-00163 ERCC-00019 ERCC-00051
# ERCC-00099 ERCC-00084 ERCC-00162 ERCC-00062 ERCC-00078
# ERCC-00095 ERCC-00071 ERCC-00079 ERCC-00131 ERCC-00165
# ERCC-00044 ERCC-00092 ERCC-00076 ERCC-00112 ERCC-00022
# ERCC-00111 ERCC-00116 ERCC-00108 ERCC-00043 ERCC-00145
# ERCC-00136 ERCC-00003 ERCC-00004 ERCC-00046 ERCC-00113
# ERCC-00074 ERCC-00130 ERCC-00002
#
# GLM log(r_m) estimate:
# -0.3097004
#
# GLM log(r_m) estimate weighted s.e.:
# 0.7431711
#
# Number of ERCCs in Mix 1 dyn range:  86
#
# Number of ERCCs in Mix 2 dyn range:  86
#
# Error in simpleLoess(y, x, w, span, degree = degree, parametric = parametric,  :
#   invalid 'x'
#               Length Class      Mode
# sampleInfo    11     -none-     list
# plotInfo       9     -none-     list
# erccInfo       4     -none-     list
# Transcripts    9     data.frame list
# designMat      3     data.frame list
# sampleNames    2     -none-     character
# idCols         6     data.frame list
# normERCCDat    9     data.frame list
# normFactor     8     -none-     numeric
# mnLibeFactor   1     -none-     numeric
# spikeFraction  1     -none-     numeric
# idColsAdj      6     data.frame list
# Results        2     -none-     list
# Figures        1     -none-     list
#
# Error in gList(list(wrapvp = list(x = 0.5, y = 0.5, width = 1, height = 1,  :
#   only 'grobs' allowed in "gList"
# Error in gList(list(wrapvp = list(x = 0.5, y = 0.5, width = 1, height = 1,  :
#   only 'grobs' allowed in "gList"
# [1] 1

# %%
a = rna.runERCC(ERCC, ['72hMEF2CMEF2D'], featurename="Feature", issingle=False, dilution=1/100,
name="RNPv2", spikevol=1, control="72hAAVS1", fdr=0.1, totalrnamass=0.5)
res.update(a)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# [1] "72hMEF2CMEF2D"
# [1] "72hAAVS1"
#    Feature X72hMEF2CMEF2D_1 X72hMEF2CMEF2D_2 X72hMEF2CMEF2D_3 X72hMEF2CMEF2D_4
# 1     TNMD                0                0                0                0
# 2     DPM1              792              902              600             1664
# 3    SCYL3              153              219              131              315
# 4 C1orf112              294              335              190              556
# 5      FGR             2172             2280             1983             3839
# 6      CFH               21               17               19               42
#   X72hAAVS1_1 X72hAAVS1_2 X72hAAVS1_3 X72hAAVS1_4
# 1           0           0           0           0
# 2         999         960        1022        1543
# 3         193         201         208         245
# 4         434         416         446         638
# 5        1377        1366        1323        1631
# 6          15          18          15          24
#
# Initializing the exDat list structure...
# choseFDR = 0.1
# repNormFactor is NULL
# Filename root is: RNPv2.72hMEF2CMEF2D.72hAAVS1
#
# Transcripts were removed with a mean count < 1 or more than 2
# replicates with 0 counts.
# Original data contained  21801 transcripts.
# After filtering  16195 transcripts remain for  analysis.
# A total of 5 out of 92
# ERCC controls were filtered from the data set
# The excluded ERCCs are:
# ERCC-00048 ERCC-00057 ERCC-00083 ERCC-00134 ERCC-00156
#
# repNormFactor is NULL,
#  Using Default Upper Quartile Normalization Method  - 75th percentile
#
# normVec:
# 866 932 665 1509 1054 1058 1068 1301
# Check for sample mRNA fraction differences(r_m)...
#
# Number of ERCC Controls Used in r_m estimate
# 87
#
# Outlier ERCCs for GLM r_m Estimate:
# ERCC-00097 ERCC-00041 ERCC-00168 ERCC-00137 ERCC-00013
# ERCC-00077 ERCC-00033 ERCC-00154 ERCC-00028 ERCC-00069
# ERCC-00143 ERCC-00085 ERCC-00160 ERCC-00170 ERCC-00144
# ERCC-00014 ERCC-00059 ERCC-00163 ERCC-00019 ERCC-00099
# ERCC-00162 ERCC-00062 ERCC-00095 ERCC-00078 ERCC-00079
# ERCC-00131 ERCC-00165 ERCC-00092 ERCC-00112 ERCC-00022
# ERCC-00111 ERCC-00116 ERCC-00108 ERCC-00043 ERCC-00136
# ERCC-00003 ERCC-00004 ERCC-00046 ERCC-00074 ERCC-00130
# ERCC-00002
#
# GLM log(r_m) estimate:
# -0.15951
#
# GLM log(r_m) estimate weighted s.e.:
# 0.8014858
#
# Number of ERCCs in Mix 1 dyn range:  87
#
# Number of ERCCs in Mix 2 dyn range:  87
#
# Error in simpleLoess(y, x, w, span, degree = degree, parametric = parametric,  :
#   invalid 'x'
#               Length Class      Mode
# sampleInfo    11     -none-     list
# plotInfo       9     -none-     list
# erccInfo       4     -none-     list
# Transcripts    9     data.frame list
# designMat      3     data.frame list
# sampleNames    2     -none-     character
# idCols         6     data.frame list
# normERCCDat    9     data.frame list
# normFactor     8     -none-     numeric
# mnLibeFactor   1     -none-     numeric
# spikeFraction  1     -none-     numeric
# idColsAdj      6     data.frame list
# Results        2     -none-     list
# Figures        1     -none-     list
#
# Error in gList(list(wrapvp = list(x = 0.5, y = 0.5, width = 1, height = 1,  :
#   only 'grobs' allowed in "gList"
# Error in gList(list(wrapvp = list(x = 0.5, y = 0.5, width = 1, height = 1,  :
#   only 'grobs' allowed in "gList"
# [1] 1

# %%
df= pd.DataFrame(data=res.values(),index=res.keys(), columns=['scaling','var'])
df['RNPs']=df.index
sns.barplot("RNPs","scaling",data=df,ci=None,)
plt.errorbar(x=range(0,len(df)),y=df['scaling'],
            yerr=df['var'], fmt='none', c= 'r')
plt.xticks(rotation=60,ha='right')
plt.savefig('../results/'+project+"/plots/"+version+"_scaling_fact_with_conf.pdf")

# %%
scaling = res
scaling
# Out:
# {'48hMEF2CMEF2D': (-0.309700394158224, 0.743171102607337),
#  '72hMEF2CMEF2D': (-0.15950996757923, 0.801485838199572)}

# %%
for i, v in scaling.items():
    if abs(v[0]) > 2*v[1]:
        print(i, v[0])

# %%
version="v1" #scaling_2, additionals, v4

# %%
ls ../results/$project/*_scaling.json
# Out:
# ../results/MONOMAC_synMEF2CD/v1_scaling.json

# %%
h.dictToFile(scaling,"../results/"+project+"/"+version+"_scaling.json")

# %%
scaling = h.fileToDict("../results/"+project+"/"+version+"_scaling.json")

# %% [markdown]
# ## Differential expression analysis

# %%
data['gene_id'] = data.index

# %%
housekeeping = ["C1orf43", "CHMP2A", "EMC7", "GPI", "PSMB2", "PSMB4", "RAB7A", "REEP5", "SNRPD3", "VCP", "VPS29"]
# from https://www.cell.com/trends/genetics/pdf/S0168-9525(13)00089-9.pdf

#https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4760967/ FOR CANCER CELL LINES
housekeeping2 = ['18S rRNA',
'ACTB',
'B2M',
'G6PD',
'GAPDH',
'GUSB',
'HMBS',
'HPRT1',
'PGK1',
'PPIA',
'RPL13a',
'SDHA',
'TBP',
'TUBB',
'YWHAZ']

# %%
results = {}

# %%
experiments = list(set([i.split('-')[2] for i in data.columns[:-1]]))
experiments
# Out:
# ['72h_MEF2C_MEF2D', '48h_AAVS1', '48h_MEF2C_MEF2D', '72h_AAVS1']

# %%
for k in list(scaling.keys()):
    scaling["RNP_"+k] = scaling.pop(k)

# %%
results = rna.DESeqSamples(data, ['72h_MEF2C_MEF2D','48h_MEF2C_MEF2D'], controlcontain=['72h_AAVS1', '48h_AAVS1'], scaling=False, keep=True, results={})
# Out:
# 72h_MEF2C_MEF2D
# 3.3.2
# scaling using a gene set
# ____________________________________________
# 48h_MEF2C_MEF2D
# 3.3.2
# scaling using a gene set
# ____________________________________________

# %% [markdown]
# ### volcano plot with CRC members highlighted

# %%
experiments
# Out:
# ['72h_MEF2C_MEF2D', '48h_AAVS1', '48h_MEF2C_MEF2D', '72h_AAVS1']

# %%
results['48h_MEF2C_MEF2D'].loc['MYC']
# Out:
# baseMean              4549.47
# log2FoldChange      -0.379261
# lfcSE               0.0923218
# stat                 -4.10804
# pvalue            3.99033e-05
# padj               0.00104716
# gene_id                   MYC
# Name: MYC, dtype: object

# %%
for val in ['72h_MEF2C_MEF2D', '48h_MEF2C_MEF2D']:
    plot.volcano(results[val],tohighlight=ctf,title=val, maxvalue= 60, searchbox=True, showlabels=True,folder="../results/"+project+"/plots/"+version+'_')
# Out:
#   <div class="bk-root" id="79c9dc1e-62a0-409c-b6cc-a47d0bb8b156" data-root-id="5766"></div>
#   <div class="bk-root" id="8e8430d4-b020-40a1-bd60-dc0bd21d5f97" data-root-id="6154"></div>

# %%
# !mkdir ../results/$project/deseq_$version
for k, val in results.items(): 
    if k!='48h_MEF2C_MEF2D':
        continue
    scale = str("geneset2")
    #scale = str(scaling[k][0] if abs(scaling[k][0]) > 1*scaling[k][1] else 0)
    val.to_csv('../results/'+project+'/deseq_'+version+'/'+ k + '_scalingof' + scale + ".csv")
# Out:
# mkdir: cannot create directory ‘../results/MONOMAC_synMEF2CD/deseq_v1’: File exists

# %%
results.keys()

# %%
results.keys()
# Out:
# dict_keys(['72h_MEF2C_MEF2D', '48h_MEF2C_MEF2D'])

# %%
#results = {}
des = ! ls ../results/$project/deseq_$version/*.csv
for val in des:
    results["RNP_"+val.split('RNP_')[-1].split('.')[0].split('_scalingof')[0]] = pd.read_csv(val,index_col=0)

# %%
res = {}

# %%
experiments
# Out:
# ['72h_MEF2C_MEF2D', '48h_AAVS1', '48h_MEF2C_MEF2D', '72h_AAVS1']

# %%
scaling
# Out:
# {'RNP_48hMEF2CMEF2D': (-0.309700394158224, 0.743171102607337),
#  'RNP_72hMEF2CMEF2D': (-0.15950996757923, 0.801485838199572)}

# %%
totest = data[[v for v in data.columns[:-1] if "48h_MEF2C_MEF2D" in v or '48h_AAVS1' in v]]
cls = ['Condition' if "48h_MEF2C_MEF2D" in v else 'DMSO' for v in totest.columns]
#if abs(scaling[val.split('_')[1]][0]) > 3*scaling[val.split('_')[1]][1]:
    #print("rescaling this one")
    #cols = [i for i in totest.columns if val+'-' in i]
    #totest[cols] = totest[cols]*(2**scaling[val.split('_')[1]][0])
res["48h_MEF2C_MEF2D"] = gseapy.gsea(data=totest, gene_sets='WikiPathways_2013', 
            cls= cls, no_plot=False, processes=8)
res["48h_MEF2C_MEF2D"].res2d['Term'] = [i for i in res["48h_MEF2C_MEF2D"].res2d.index]
sns.barplot(data=res["48h_MEF2C_MEF2D"].res2d.iloc[:25], x="es", y="Term",
            hue_order="geneset_size").set_title(val)
# Out:
# Text(0.5, 1.0, '72h_AAVS1')

# %%
totest = data[[v for v in data.columns[:-1] if "72h_MEF2C_MEF2D" in v or '72h_AAVS1' in v]]
cls = ['Condition' if "72h_MEF2C_MEF2D" in v else 'DMSO' for v in totest.columns]
#if abs(scaling[val.split('_')[1]][0]) > 3*scaling[val.split('_')[1]][1]:
    #print("rescaling this one")
    #cols = [i for i in totest.columns if val+'-' in i]
    #totest[cols] = totest[cols]*(2**scaling[val.split('_')[1]][0])
res["72h_MEF2C_MEF2D"] = gseapy.gsea(data=totest, gene_sets='WikiPathways_2013', 
            cls= cls, no_plot=False, processes=8)
res["72h_MEF2C_MEF2D"].res2d['Term'] = [i for i in res["72h_MEF2C_MEF2D"].res2d.index]
sns.barplot(data=res["72h_MEF2C_MEF2D"].res2d.iloc[:25], x="es", y="Term",
            hue_order="geneset_size").set_title(val)
# Out:
# Text(0.5, 1.0, '72h_AAVS1')

# %%
with open('../data/'+project+'/'+version+'_wikipathway', 'wb') as f:
    pickle.dump(res,f)

# %%
with open('../data/'+project+'/'+version+'_wikipathway','rb') as f:
    res = pickle.load(f)

# %% [markdown]
# ### Analysis on the wiki pathways geneset

# %%
res
# Out:
#                  Retinol metabolism (BiGCaT, NuGO)   EPO Receptor Signaling   \
# 72h_MEF2C_MEF2D                            0.369090                 0.462958
# 48h_AAVS1                                 -0.421677                -0.382350
# 48h_MEF2C_MEF2D                            0.361865                 0.261335
#
#                  Selenium metabolism-Selenoproteins   \
# 72h_MEF2C_MEF2D                            -0.242670
# 48h_AAVS1                                   0.540026
# 48h_MEF2C_MEF2D                            -0.415694
#
#                  Regulation of Actin Cytoskeleton   Senescence and Autophagy   \
# 72h_MEF2C_MEF2D                           0.251568                   0.514852
# 48h_AAVS1                                 0.224756                   0.293079
# 48h_MEF2C_MEF2D                          -0.106095                   0.322645
#
#                  Glycogen Metabolism   \
# 72h_MEF2C_MEF2D             -0.266838
# 48h_AAVS1                   -0.282053
# 48h_MEF2C_MEF2D             -0.224609
#
#                  Complement and Coagulation Cascades KEGG   mRNA processing   \
# 72h_MEF2C_MEF2D                                   0.793589         -0.502639
# 48h_AAVS1                                         0.527548         -0.208968
# 48h_MEF2C_MEF2D                                   0.426877         -0.375845
#
#                  Oxidative phosphorylation   Senescence and Autophagy   ...  \
# 72h_MEF2C_MEF2D                   -0.406634                   0.514852  ...
# 48h_AAVS1                         -0.344178                   0.293079  ...
# 48h_MEF2C_MEF2D                   -0.401471                   0.322645  ...
#
#                  Retinol metabolism (BiGCaT, NuGO)   \
# 72h_MEF2C_MEF2D                            0.369090
# 48h_AAVS1                                 -0.421677
# 48h_MEF2C_MEF2D                            0.361865
#
#                  TGF-beta Receptor Signaling Pathway   \
# 72h_MEF2C_MEF2D                              0.220005
# 48h_AAVS1                                   -0.202131
# 48h_MEF2C_MEF2D                             -0.123913
#
#                  Statin Pathway PharmGKB   G1 to S cell cycle control   \
# 72h_MEF2C_MEF2D                  0.490717                     0.210126
# 48h_AAVS1                        0.643610                     0.153956
# 48h_MEF2C_MEF2D                  0.320637                    -0.170987
#
#                  G Protein Signaling Pathways   Endochondral Ossification   \
# 72h_MEF2C_MEF2D                      -0.278570                    0.598274
# 48h_AAVS1                            -0.304111                    0.478568
# 48h_MEF2C_MEF2D                      -0.243110                    0.407892
#
#                  Peptide GPCRs   MAPK signaling pathway   \
# 72h_MEF2C_MEF2D        0.485068                 0.330785
# 48h_AAVS1              0.393554                 0.186341
# 48h_MEF2C_MEF2D        0.583770                 0.162772
#
#                  EGFR1 Signaling Pathway   Senescence and Autophagy
# 72h_MEF2C_MEF2D                 -0.146194                   0.514852
# 48h_AAVS1                        0.183029                   0.293079
# 48h_MEF2C_MEF2D                 -0.157124                   0.322645
#
# [3 rows x 108 columns]

# %%
a = set()
for k, val in res.items():
    a.update(set(val.res2d.index))
a = {i:[0]*len(res) for i in a}
for n,(k, val) in enumerate(res.items()):
    for i,v in val.res2d.iterrows():
        a[i][n] = v.es
res = pd.DataFrame(a, index=res.keys())
res.columns = [i[3:].split('WP')[0] for i in res.columns]

# %%
fig = sns.clustermap(figsize=(25,20), data=res,vmin=-1,vmax=1,xticklabels=res.columns, yticklabels=res.index)
fig.savefig("../results/"+project+"/"+version+"enriched_terms_scaled_gsea.pdf")

# %%
res.to_csv('../results/'+project+'/'+version+'_wikipathway_gsea_matrix.csv')

# %%
res = {}

# %%
res.keys()

# %% [markdown]
# ### Analysis on the entire set of pathways (biopathways)

# %%
for i, val in enumerate(experiments):
    print(val)
    totest = data[[v for v in data.columns[:-1] if val+'-' in v or 'AAVS1' in v]]
    cls = ['Condition' if val+'-' in v else 'DMSO' for v in totest.columns]
    if abs(scaling[val.split('_')[1]][0]) > 3*scaling[val.split('_')[1]][1]:
        print("rescaling this one")
        cols = [i for i in totest.columns if val+'-' in i]
        totest[cols] = totest[cols]*(2**scaling[val.split('_')[1]][0])
    elif val in res:
        continue
    res[val] = gseapy.gsea(data=totest, gene_sets='GO_Biological_Process_2015', 
                cls= cls, no_plot=False, processes=8)
    res[val].res2d['Term'] = [i for i in res[val].res2d.index]
    plt.figure(i)
    a = sns.barplot(data=res[val].res2d.iloc[:25], x="es", y="Term",
                hue_order="geneset_size")
    a.set_title(val)
    a.figure.savefig('../results/'+ project+ '/plots/'+version + '_gobioproc2015_mainTerms_'+val+'.pdf')

# %%
with open('../results/'+project+'/'+version+'_GO_Biological_Process_2015_RNPv2', 'wb') as f:
    pickle.dump(res,f)

# %%
with open('../results/'+project+'/'+version+'_GO_Biological_Process_2015_RNPv2', 'wb') as f:
    res = pickle.load(f)

# %%
for i, v in res.items():
    res[i].res2d['Term'] = [i.split('(GO')[0] for i in v.res2d['Term']]

# %% [markdown]
# creating matrices

# %%
a = set()
for k, val in res.items():
    a.update(set(val.res2d.Term))
a = {i:[0]*len(res) for i in a}
for n,(k, val) in enumerate(res.items()):
    for i,v in val.res2d.iterrows():
        a[v.Term][n] = v.es
res = pd.DataFrame(a, index=res.keys())

# %%
fig = sns.clustermap(figsize=(25,20), data=res,vmin=-1,vmax=1, yticklabels=res.index ,cmap=plt.cm.RdYlBu)
fig.savefig("../results/"+project+"/"+version+"enriched_terms_scaled_gsea_bioproc2015.pdf")

# %%
model = DBSCAN(eps=0.5, min_samples=3, metric='euclidean')
labels = model.fit_predict(res)

# %%
sort = labels.argsort()

# %% [markdown]
# ### Correlation matrix across experiment on at the gene set level

# %%
a = sns.clustermap(-res.T.corr(),cmap=plt.cm.RdYlBu,vmin=-1,vmax=1)
a.savefig("../results/"+project+"/plots/"+version+"_clustermap_over_bioproc2015_geneset.pdf")

# %%
a = h.plotCorrelationMatrix(res.values[sort], res.index[sort].tolist(), interactive=True, title="correlation matrix over bioproc2015 gene sets", folder="../results/"+project+"/plots/"+version+"_")#,colors=[labels[i] for i in sort])

# %% [markdown]
# ### similarity distance plot over the genesets

# %%
red = PCA(2).fit_transform(res)
h.scatter(red, labels=res.index, radi=1, colors=labels, title="PCA distance in geneset space", showlabels=True,folder="../results/"+project+"/plots/"+version+"_")

# %%
red = TSNE(2,2).fit_transform(res)
h.scatter(red, labels=res.index, radi=9, colors=labels, title="TSNE distance in geneset space",showlabels=True,folder="../results/"+project+"/plots/"+version+"_")

# %%
res.to_csv('../results/'+project+'/'+version+'_biopathway_gsea.csv')

# %%
res = pd.read_csv('../results/'+project+'/'+version+'_biopathway_gsea.csv',index_col=0)

# %% [markdown]
# ## Getting the correlation at the transcriptome level

# %%
data = pd.DataFrame(index=results['RNP_SP1'].index.tolist())
for i, v in results.items():
    data[i]=v.log2FoldChange

# %%
model = AgglomerativeClustering(n_clusters=8,linkage="average", 
                                affinity="cosine", compute_full_tree=True)
labels = model.fit_predict(data.values.T)
ii = itertools.count(data.values.shape[1])
tree = [{'node_id': next(ii), 'left': x[0], 'right':x[1]} for x in model.children_]
sort = labels.argsort()

# %%
model = DBSCAN(eps=0.5, min_samples=3, metric='euclidean')
labels = model.fit_predict(data.values)

# %%
a = sns.clustermap(data.corr())
a.savefig("../results/"+project+"/plots/"+version+"_clustermap_correlation_transcriptome.pdf")

# %%
a = h.plotCorrelationMatrix(data.values.T[sort], data.columns[sort].tolist(), interactive=True, title="transcriptome correlation",folder= "../results/"+project+"/plots/"+version+"_")#,colors=[labels[i] for i in sort])

# %%
## Filtered version (set to 0 genes with low p_value)

# %%
data = pd.DataFrame(index=results['RNP_SP1'].index.tolist())
for i, v in results.items():
    v.loc[v[v.pvalue>0.01].index,"log2FoldChange"]==0
    data[i]=v.log2FoldChange

# %%
a = h.plotCorrelationMatrix(data.values.T[sort], data.columns[sort].tolist(), interactive=True, title="transcriptome correlation matrix over high pvalue genes",folder="../results/"+project+"/plots/"+version+"_")

# %%
mostvar = data[(~data.index.str.contains('ERCC-')) & (data.var(1)>4)]

# %%
a = sns.clustermap(-mostvar.corr(), cmap=plt.cm.RdYlBu, vmin=-1, vmax=1)
a.savefig("../results/"+project+"/plots/"+version+"_clustermap_mostvariable_genes.pdf")

# %% [markdown]
# ### Doing it at the CRC members' expression only

# %%
results_ctf = data.loc[set(['MYC',
 'MYB',
 'SPI1',
 'RUNX1',
 'IRF2BP2',
 'FLI1',
 'ELF2',
 'ZEB2',
 'GFI1',
 'LMO2',
 'CEBPa',
 'MEF2D',
 'MEF2C',
 'IRF8',
 'MEIS1',
 'RUNX2',
 'ZMYND8']) & set(data.index)].T
model = AgglomerativeClustering(n_clusters=7,linkage="average", 
                                affinity="cosine", compute_full_tree=True)
labels = model.fit_predict(results_ctf)
ii = itertools.count(results_ctf.shape[0])
tree = [{'node_id': next(ii), 'left': x[0], 'right':x[1]} for x in model.children_]
sort = labels.argsort()
h.plotCorrelationMatrix(results_ctf.values[sort], title="correlation matrix over similarity over CRC members aggregated with agglomerative clustering", folder="../results/"+project+'/plots/'+version+'_',names=results_ctf.index[sort].tolist(),interactive=True)

# %%
a = sns.clustermap(results_ctf.corr())
a.set_title("clustermap of correlation matrix over similarity over CRC members")
a.figure.savefig('../results/'+project+'/plots/'+version+"_clustermap_correlation_CRConly.pdf")

# %%
a.fig.savefig('../results/'+project+'/plots/'+version+"_pairplot_deseq_crconly.pdf")

# %%
a = sns.pairplot(results_ctf.T)
a.fig.suptitle("pairplot of differential expression of CRC members under RNP of these members", y=1.08)

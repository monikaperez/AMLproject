# %%
import os
import pandas as pd
import sys
sys.path.insert(0, '../..')
import numpy as np
import itertools

from JKBio import Helper as h

from bokeh.plotting import *
from IPython.display import IFrame
import igv

from sklearn.manifold import MDS, TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.cluster import AgglomerativeClustering
from sklearn.mixture import GaussianMixture

output_notebook()
# %load_ext autoreload
# %autoreload 2
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Processing ChipSeq for Cobinding

# %%
version="v2"
project="cobinding"

# %% [markdown]
# ## finding all the relevant files for chipseq processing

# %%
a = !gsutil ls gs://amlproject/Chip/fastqs

# %%
a
# Out:
# ['gs://amlproject/Chip/fastqs/mp100-U937-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp101-NOMO1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp102-UT7-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp106-MV411-MYB-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp109-M6-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp112-MV411-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp115-MV411-PU1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp116-MV411-MYB-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp117-MV411-POLII-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp118-MV411-SP1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp120-HL60-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp121-UCSDAML1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp122-M6-CEBPA-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp123-M6-RUNX1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp124-M6-MYB-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp125-M6-ETV6-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp127-M6-SP1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp128-M6-MED1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp129-MV411-RUNX1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp134-MV411-IGG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp136-MV411-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp137-MV411-H3K4me1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp138-MV411-H3K4me3-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp14-D9-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp14-D9-INPUT-r13.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp153-D9-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp154-D9-PU1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp155-D9-MYB-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp156-D9-SP1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp157-D9-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp160-D9-MED1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp168-OCIAML2-PU1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp171-M6-PU1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp18.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp183-MV411_DMSO-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp186-NOMO1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp187-UT7-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp188-UCSDAML1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp193-NB4-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp194-TF1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp195-OCIAML3-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp196-MONOMAC6-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp197-SKNO1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp2-D9-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp203-NB4-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp204-TF1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp205-OCIAML3-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp206-MONOMAC6-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp207-KG1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp213-U937-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp214-UT7-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp216-SKNO1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp217-HEL-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp218-HEL-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp230-SKNO1-MYB-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp231-SKNO1-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp232-SKNO1-ETV6-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp233-SKNO1-RUNX1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp24-OCIAML2-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp27-D9-CEBPA-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp293-MV411-H3K79me2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp299-MV411-CEBPA-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp301-MV411-PU1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp302-M6-MYB-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp304-D9-PU1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp305-SKNO1-PU1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp308-SKNO1-RUNX1_RUNX1T1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp309-KG1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp310-Kasumi1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp311-MOLM13-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp312-NB4-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp313-TF1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp314-OCIAML3-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp315-MONOMAC6-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp316-SKNO1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp319-MV411-FLI1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp320-MV411-ZEB2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp321-MV411-GFI1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp324-MV411-MEF2D-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp325-MV411-SP1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp326-DFAM71927V3-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp33-OCIAML2-INPUT-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp35-D9-INPUT-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp351-D0-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp352-D0-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp353-D9-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp354-D9-H3K27ac-r4.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp355-M6-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp356-M6-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp357-MV411-ZMYND8-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp358-MV411-ZMYND8-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp359-MV411-LMO2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp4-D9-IGG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp41-OCIAML2-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp424-MV411-RUNX1-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp425-MV411-ETV6-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp426-MV411-SP1-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp427-MV411-LMO2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp428-MV411-PU1-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp429-MV411-IRF8-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp430-MV411-IRF2BP2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp431-MV411-IRF2BP2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp433-MV411-GSE1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp435-MV411-MED1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp45-OCIAML2-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp48-MOLM13-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp5-D9-INPUT-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp50-OCIAML2-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp53-HL60-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp56-Kasumi1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp565-MV411-CDK13-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp568-MV411-ZEB2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp569-MV411-ETV6-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp570-MV411-CTCF-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp575-MV411-IRF2BP2-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp577-MV411-SMC1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp58-KG1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp581-MV411-MEF2C-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp582-MV411-MEIS1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp583-MV411-ELF2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp584-MV411-MYC-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp585-MV411-MYC-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp587-MV411-IKZF1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp589-MV411-ETV6-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp590-MV411-GATA2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp591-MONOMAC1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp592-MONOMAC1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp593-HEL9217-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp594-HEL9217-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp597-PLB985-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp598-PLB985-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp6-D0-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp601-MV411-RUNX2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp604-MV411-IKZF1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp607-MV411-ELF2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp609-MONOMAC1-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp610-HEL9217-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp611-P31FUJ-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp612-PLB985-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp614-MV411-MEF2C-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp623-MV411-MEF2D-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp627-MV411-MEF2C-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp631-SKNO1-PU1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp633-SKNO1-FLI1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp635-SKNO1-ERG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp636-SKNO1-MYC-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp637-SKNO1-ERG-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp638-SKNO1-MAX-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp639-MV411-MAX-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp640-MV411-LYL1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp643-DFAM71927V3-INPUT-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp650-MV411-LDB1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp67-OCIAML2-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp690-MV411_DMSO-MAX-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp7-D0-EZH2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp70-MV411-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp702-MV411_DMSO-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp71-MV411-H3K27me3-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp714-MV411-ZEB2-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp715-MV411-ZEB2-r4.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp716-MV411-GSE1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp717-MV411-GATA2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp718-MV411-IRF2BP2-r4.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp72-MV411-CEBPA-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp724-MV411_DMSO-MYC-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp728-MV411_DMSO-CEBPA-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp73-U937-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp734-MV411_DMSO-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp739-DFAM71927V3-RUNX1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp741-DFAM71927V3-MYB-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp742-DFAM71927V3-MYC-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp743-DFAM71927V3-SP1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp745-DFAM71927V3-GFI1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp748-DFAM71927V3-ELF2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp750-DFAM71927V3-GATA2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp751-DFAM71927V3-FLI1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp752-SHI1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp754-EOL1-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp755-EOL1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp756-F36P-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp757-F36P-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp758-SHI1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp759-SHI1-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp760-MV411_MEF2D_NT_SC_63-FLAG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp761-MV411_PU1_NT_SC_1-FLAG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp762-MV411_IRF2BP2_CT_GFP_8-FLAG-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp763-MV411-RUNX2-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp764-MV411-RUNX2-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp765-MV411-RUNX2-r4.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp767-MV411-FOXP1-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp768-MV411-FOXP1-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp77-HL60-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp770-MV411-MYBL2-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp771-MV411-JUND-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp772-MV411-JUND-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp773-MV411-HOXA9-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp774-MV411-HOXA9-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp776-P31FUJ-H3K27ac-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp777-MONOMAC1-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp778-MONOMAC1-H3K27ac-r4.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp8-D0-INPUT-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp864-MV411_RNP_RUNX1_RUNX2-H3K27AC-r1_R1_001.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp874-MV411_MEF2D_NT_SC_63-FLAG_MEF2D-r2_R1_001.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp874-MV411_MEF2D_NT_SC_63-FLAG_MEF2D-r2_R2_001.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp875-MV411_MEF2C_NT-FLAG_MEF2C-r1_R1_001.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp875-MV411_MEF2C_NT-FLAG_MEF2C-r1_R2_001.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp88-MV411-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp89-MV411-H3K36me3-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp90-U937-H3K27ac-r3.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp92-NOMO1-H3K27ac-r2.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp98-M6-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/mp99-MV411-INPUT-r1.fastq.gz',
#  'gs://amlproject/Chip/fastqs/paired_end/']

# %% [markdown]
# ## looking for duplicates

# %%
import re
mps=[]
for i in a:
    res = re.search('mp(\d+)', i)
    if res is not None:
        mps.append(res.group(0))

# %%
mps.sort()

# %%
mps

# %%
duplicates=[ 'gs://amlproject/Chip/fastqs/Sample_mp582-MV411-MEIS1-r1.fastq.gz',
'gs://amlproject/Chip/fastqs/Sample_mp587-MV411-IKZF1-r1.fastq.gz',
,
'gs://amlproject/Chip/fastqs/mp88-MV411-H3K27ac-r2.fastq.gz']

# %%
for val in duplicates:
    os.system('gsutil rm '+val)

# %%
paired_end_tomove= ['gs://amlproject/Chip/fastqs/mp304-D9-PU1-r2_S1_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp305-SKNO1-PU1-r1_S2_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp320-MV411-ZEB2-r1_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp319-MV411-FLI1-r1_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp308-SKNO1-RUNX1-RUNX1T1-r1_S5_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r3_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp321-MV411-GFI1-r4_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp324-MV411-MEF2D-r1_R2.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp299-MV411-CEBPA-r3_S7_R2.fastq.gz'
 'gs://amlproject/Chip/fastqs/mp325-MV411-SP1-r2_R2.fastq.gz']

# %%
for val in paired_end_tomove:
    os.system('gsutil mv '+val+' gs://amlproject/Chip/fastqs/paired_end/')

# %% [markdown]
# ## renamings

# %%
# renaming files
rename1 = {
'gs://amlproject/Chip/fastqs/20180709_1_MP5773_S1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp631.fastq.gz',
 'gs://amlproject/Chip/fastqs/20180709_3_MP5773_S3.fastq.gz': 'gs://amlproject/Chip/fastqs/mp633.fastq.gz',
 'gs://amlproject/Chip/fastqs/20180709_5_MP5773_S5.fastq.gz': 'gs://amlproject/Chip/fastqs/mp635.fastq.gz',
 'gs://amlproject/Chip/fastqs/20180709_6_MP5773_S6.fastq.gz': 'gs://amlproject/Chip/fastqs/mp636.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-11_MP7213-2of2_S4_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp748.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-13_MP7213-2of2_S5_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp750.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-14_MP7213-2of2_S6_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp751.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-2_MP7213-1of2_S2_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp739.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-4_MP7213-1of2_S4_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp741.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-5_MP7213-1of2_S5_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp742.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-6_MP7213-1of2_S6_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp743.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190718_MP-8_MP7213-2of2_S1_R1_001.fastq.gz': 'gs://amlproject/Chip/fastqs/mp745.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190826_10_MB7326-2of2_S5.fastq.gz': 'gs://amlproject/Chip/fastqs/mp761.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190826_11_MB7326-2of2_S6.fastq.gz': 'gs://amlproject/Chip/fastqs/mp762.fastq.gz',
 'gs://amlproject/Chip/fastqs/20190826_9_MB7326-2of2_S4.fastq.gz': 'gs://amlproject/Chip/fastqs/mp760.fastq.gz',
 'gs://amlproject/Chip/fastqs/D0-INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp8.fastq.gz',
 'gs://amlproject/Chip/fastqs/D9-INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp14.fastq.gz',
 'gs://amlproject/Chip/fastqs/D9_CEBPA_m.fastq.gz': 'gs://amlproject/Chip/fastqs/mp27.fastq.gz',
 'gs://amlproject/Chip/fastqs/D9_INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp35.fastq.gz',
 'gs://amlproject/Chip/fastqs/MP29.fastq.gz': 'gs://amlproject/Chip/fastqs/mp4.fastq.gz',
 'gs://amlproject/Chip/fastqs/MP30.fastq.gz': 'gs://amlproject/Chip/fastqs/mp5.fastq.gz',
 'gs://amlproject/Chip/fastqs/MP31.fastq.gz': 'gs://amlproject/Chip/fastqs/mp6.fastq.gz',
 'gs://amlproject/Chip/fastqs/OCI_AML2-INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp24.fastq.gz',
 'gs://amlproject/Chip/fastqs/OCI_AML2_CEBPA_m.fastq.gz': 'gs://amlproject/Chip/fastqs/mp41.fastq.gz',
 'gs://amlproject/Chip/fastqs/OCI_AML2_INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp33.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_10-D8-SP1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp156.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_12-MV411-SPI1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp115.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_15-MV411-SP1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp118.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_18-D8-MED1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp160.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_19-M6-CEBPA.fastq.gz': 'gs://amlproject/Chip/fastqs/mp122.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_20-M6-RUNX1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp123.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_21-M6-MYB.fastq.gz': 'gs://amlproject/Chip/fastqs/mp124.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_22-M6-ETV6.fastq.gz': 'gs://amlproject/Chip/fastqs/mp125.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_24-M6-SPI1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp171.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_25-M6-SP1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp127.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_26-M6-MED1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp128.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_27-MV411-RUNX1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp129.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_27-OCIAML2-SPI1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp168.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_31.M6.INPUT.fastq.gz': 'gs://amlproject/Chip/fastqs/mp98.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_41-M6-IGG.fastq.gz': 'gs://amlproject/Chip/fastqs/mp143.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_6-M6-CEBPA.fastq.gz': 'gs://amlproject/Chip/fastqs/mp109.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_7-D8-CEBPA.fastq.gz': 'gs://amlproject/Chip/fastqs/mp153.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_8-D8-SPI1.fastq.gz': 'gs://amlproject/Chip/fastqs/mp154.fastq.gz',
 'gs://amlproject/Chip/fastqs/Sample_9-D8-MYB.fastq.gz': 'gs://amlproject/Chip/fastqs/mp155.fastq.gz'
}

# %%
for k, val in rename1.items():
    os.system('gsutil mv '+k+' '+val)

# %%
## IT SHOULD NOT CAUSE ANY PROBLEM TO CP R2 SINCE IT DOES NOT EXIST 
#(will throw an error and skip)
import re
import time
mps=[]
for i in a:
    res = re.search('mp(\d+)', i)
    if res is not None:
        print('gsutil mv '+i+' gs://amlproject/Chip/fastqs/'+res.group(0)+'.fastq.gz')
        time.sleep(2)
        os.system('gsutil mv '+i+' gs://amlproject/Chip/fastqs/'+res.group(0)+'.fastq.gz')

# %%
# !gsutil ls gs://amlproject/Chip/fastqs/

# %%
# EXCEPT these two... TO RETRIEVE
gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r3_R2.fastq.gz
gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r3_R1.fastq.gz

# %%
stored = !gsutil ls -a gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r3_R2.fastq.gz
stored=stored[0]
! gsutil cp $stored gs://amlproject/Chip/fastqs/mp300-MV411-RUNX1-r3_R2.fastq.gz

# %%
a

# %%
#continuing
a[85]

# %%
import re
import time
mps=[]
for i in a[86:]:
    res = re.search('mp(\d+)', i)
    if res is not None:
        print('gsutil mv '+i+' gs://amlproject/Chip/fastqs/'+res.group(0)+'.fastq.gz')
        time.sleep(2)
        os.system('gsutil mv '+i+' gs://amlproject/Chip/fastqs/'+res.group(0)+'.fastq.gz')

# %% [markdown]
# ## adding metadata and creating the design file

# %%
from gsheets import Sheets
sheets = Sheets.from_files('~/.client_secret.json', '~/.storage.json')

# %%
url="https://docs.google.com/spreadsheets/d/14onj_lD6WrjSEsE5dWJid6lGdJ81O6qpcetP5_Z0FxQ"
gsheets = sheets.get(url).sheets[1].to_frame()

# %%
gsheets

# %%
gsheets = gsheets.set_index('Unique sample ID')

# %%
a = !gsutil -m ls gs://amlproject/Chip/fastqs/
a

# %%
data = pd.DataFrame({'fastq_1':a[:-1]}, index=[i.split('/')[-1].split('.')[0] for i in a[:-1]])

# %%
data[['quality','Protein','Replicate No','Cell line ID']] = gsheets[
    ['quality','Protein','Replicate No','Cell line ID']]

# %%
data['fastq_2']= np.NaN

# %%
data = data.rename(columns={'Protein': 'antibody','Cell line ID': 'group','Replicate No': 'replicate'})

# %%
data.loc[data[data.antibody.isin(['INPUT','IGG'])].index,'group'] = \
data[data.antibody.isin(['INPUT','IGG'])].antibody +'_'+\
data[data.antibody.isin(['INPUT','IGG'])].group

# %%
data.loc[data[~data.antibody.isin(['INPUT','IGG'])].index,'control'] = \
'INPUT_'+\
data[~data.antibody.isin(['INPUT','IGG'])].group

# %%
data

# %%
set(data.control)-set(data.group)

# %%
withoutinput = ["HEL",
                "SHI1",
                "EOL1",
                "F36P"]

# %%
# requesting them and downloading them...

# %%
rename = {'gs://amlproject/Chip/fastqs/1_MP5835-1of4_S1_R1_001.fastq.gz':"gs://amlproject/Chip/fastqs/mp643.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_17-HL60-INPUT.fastq.gz':"gs://amlproject/Chip/fastqs/mp120.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_33.U937.INPUT.fastq.gz':"gs://amlproject/Chip/fastqs/mp100.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_34.NOMO1.INPUT.fastq.gz':"gs://amlproject/Chip/fastqs/mp101.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_35.UT7.INPUT.fastq.gz':"gs://amlproject/Chip/fastqs/mp102.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp309-KG1-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp309.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp310-Kasumi1-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp310.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp311-MOLM13-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp311.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp312-NB4-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp312.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp313-TF1-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp313.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp314-OCIAML3-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp314.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp315-MONOMAC3-INPUT-r1.fastq.gz':"gs://amlproject/Chip/fastqs/mp315.fastq.gz",
 'gs://amlproject/Chip/fastqs/Sample_mp326-DFAM71927V3-INPUT-r1_R1.fastq.gz':"gs://amlproject/Chip/fastqs/mp326.fastq.gz",
 'gs://amlproject/Chip/fastqs/mp609-MONOMAC1-INPUT-r1_S4.fastq.gz': 'gs://amlproject/Chip/fastqs/mp609.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp610-HEL9217-INPUT-r1_S5.fastq.gz': 'gs://amlproject/Chip/fastqs/mp610.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp611-P31FUJ-INPUT-r1_S6.fastq.gz': 'gs://amlproject/Chip/fastqs/mp611.fastq.gz',
 'gs://amlproject/Chip/fastqs/mp612-PLB985-INPUT-r1_S7.fastq.gz': 'gs://amlproject/Chip/fastqs/mp612.fastq.gz',
          
 'gs://amlproject/Chip/fastqs/1_MP5835-1of4_S1_R2_001.fastq.gz':"gs://amlproject/Chip/fastqs/paired_end/mp643-1_MP5835-1of4_S1_R2_001.fastq.gz",          
'gs://amlproject/Chip/fastqs/Sample_mp326-DFAM71927V3-INPUT-r1_R2.fastq.gz':"gs://amlproject/Chip/fastqs/paired_end/mp326-DFAM71927V3-INPUT-r1_R2.fastq.gz"}

# %%
for k,v in rename.items():
    ! gsutil mv $k $v

# %%
data = data.drop(data[data.group.isin(withoutinput)].index)

# %%
data.loc[data[~data.antibody.isin(['INPUT','IGG'])].index,'group'] = \
data[~data.antibody.isin(['INPUT','IGG'])].group + '_' + \
data[~data.antibody.isin(['INPUT','IGG'])].replicate.astype(str)

# %%
data[data.antibody.isin(['INPUT','IGG'])].antibody = np.nan

# %%
data['replicate']=1

# %%
data #things will be mergfed

# %%
data[data.columns[[4,3,0,5,2,6]]].to_csv('../nextflow/design_cobinding_'+version+'.csv', index=False)

# %%
! sudo ../nextflow run nf-core/chipseq --paired_end --seq_center 'DFCI' --email 'jkobject@gmail.com' \
--input ../AMLproject/nextflow/additional_degraded_v1_design.csv \
--genome GRCh38 --skip_preseq \ 
--max_cpus 16 -profile docker \
-w work \ #where you want your cached files to be stored
-resume exotic_bartik #when the job failed or was stopped. you can launch it back from a previous version

# %%
gsheets[gsheets['Cell line ID'].isin([
    "MOLM13",
"MONOMAC1",
"MONOMAC6",
"NB4",
"UT7",
"KG1",
"U937",
"P31FUJ",
"HL60",
"PLB985",
"OCIAML3",
"HEL9217",
"Kasumi1",
"NOMO1",
"TF1",
"SHI1",
"DFAM71927V3",
"EOL1",
"F36P"
])][gsheets.Protein=='INPUT'].index

# %% [markdown]
# ## Additional samples

# %%
! gsutil mv gs://transfer-amlproject/200827_MP8178_fastq/* gs://transfer-amlproject/Cobinding_additional/

# %%
! mkdir ../../data/fastqs/

# %%
! gsutil -m cp gs://transfer-amlproject/Cobinding_additional/*.fastq.gz ../../data/fastqs/
# Out:
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_FRA2_MP8178_S55_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_HEX_MP8178_S54_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_PLAGL2_MP8178_S53_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_FRA2_MP8178_S55_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_RARA_MP8178_S56_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_PLAGL2_MP8178_S53_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_HEX_MP8178_S54_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_RARA_MP8178_S56_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_ZFP281_MP8178_S52_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/Cobinding_additional/20200827_ZFP281_MP8178_S52_R2_001.fastq.gz...
# - [10/10 files][ 22.5 GiB/ 22.5 GiB] 100% Done  57.7 MiB/s ETA 00:00:00
# Operation completed over 10 objects/22.5 GiB.

# %%
f = ! ls ../../data/fastqs/*
f
# Out:
# ['../../data/fastqs/20200827_FRA2_MP8178_S55_R1_001.fastq.gz',
#  '../../data/fastqs/20200827_FRA2_MP8178_S55_R2_001.fastq.gz',
#  '../../data/fastqs/20200827_HEX_MP8178_S54_R1_001.fastq.gz',
#  '../../data/fastqs/20200827_HEX_MP8178_S54_R2_001.fastq.gz',
#  '../../data/fastqs/20200827_PLAGL2_MP8178_S53_R1_001.fastq.gz',
#  '../../data/fastqs/20200827_PLAGL2_MP8178_S53_R2_001.fastq.gz',
#  '../../data/fastqs/20200827_RARA_MP8178_S56_R1_001.fastq.gz',
#  '../../data/fastqs/20200827_RARA_MP8178_S56_R2_001.fastq.gz',
#  '../../data/fastqs/20200827_ZFP281_MP8178_S52_R1_001.fastq.gz',
#  '../../data/fastqs/20200827_ZFP281_MP8178_S52_R2_001.fastq.gz']

# %%
rename2 = {
"20200827_ZFP281_MP8178_S52": "mp876-MV411-ZFP281-r1",
"20200827_PLAGL2_MP8178_S53": "mp877-MV411-PLAGL2-r1",
"20200827_HEX_MP8178_S54": "mp878-MV411-HEX-r1",
"20200827_FRA2_MP8178_S55": "mp879-MV411-FOSL2-r1",
"20200827_RARA_MP8178_S56": "mp880-MV411-RARA-r1",
}

# %%
for val in f:
    ren = val
    for k, v in rename2.items():
        ren = ren.replace(k,v)
    ! mv $val $ren

# %%
from gsheets import Sheets
sheets = Sheets.from_files('~/.client_secret.json', '~/.storage.json')
url="https://docs.google.com/spreadsheets/d/1yFLjYB1McU530JnLgL0QIMAKIkVl3kl0_LCHje2gk8U"
gsheet = sheets.get(url).sheets[2].to_frame()

# %%
gsheet
# Out:
#         id cell line  replicate protein quality paired_end  \
# 0    mp100      U937          1   INPUT     NaN          n
# 1    mp101     NOMO1          1   INPUT     NaN          n
# 2    mp102       UT7          1   INPUT     NaN          n
# 3    mp106     MV411          1     MYB       x          n
# 4    mp109        M6          1   CEBPA       x          n
# ..     ...       ...        ...     ...     ...        ...
# 304  mp876     MV411          1  ZFP281     NaN        NaN
# 305  mp877     MV411          1  PLAGL2     NaN        NaN
# 306  mp878     MV411          1     HEX     NaN        NaN
# 307  mp879     MV411          1   FOSL2     NaN        NaN
# 308  mp880     MV411          1    RARA     NaN        NaN
#
#     matching input name processed                   name  \
# 0                   NaN         Y    mp100-U937-INPUT-r1
# 1                   NaN         Y   mp101-NOMO1-INPUT-r1
# 2                   NaN         Y     mp102-UT7-INPUT-r1
# 3           INPUT_MV411         Y     mp106-MV411-MYB-r1
# 4              INPUT_M6         Y      mp109-M6-CEBPA-r1
# ..                  ...       ...                    ...
# 304         INPUT_MV412       NaN  mp876-MV411-ZFP281-r1
# 305         INPUT_MV413       NaN  mp877-MV411-PLAGL2-r1
# 306         INPUT_MV414       NaN     mp878-MV411-HEX-r1
# 307         INPUT_MV415       NaN   mp879-MV411-FOSL2-r1
# 308         INPUT_MV416       NaN    mp880-MV411-RARA-r1
#
#                   previous name  ... ratio to droso  \
# 0                           NaN  ...            NaN
# 1                           NaN  ...            NaN
# 2                           NaN  ...            NaN
# 3                           NaN  ...            NaN
# 4                           NaN  ...            NaN
# ..                          ...  ...            ...
# 304  20200827_ZFP281_MP8178_S52  ...            NaN
# 305  20200827_PLAGL2_MP8178_S53  ...            NaN
# 306     20200827_HEX_MP8178_S54  ...            NaN
# 307    20200827_FRA2_MP8178_S55  ...            NaN
# 308    20200827_RARA_MP8178_S56  ...            NaN
#
#     unique mapped reads(droso) scaling factor  \
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ..                         ...            ...
# 304                        NaN            NaN
# 305                        NaN            NaN
# 306                        NaN            NaN
# 307                        NaN            NaN
# 308                        NaN            NaN
#
#                                               Total QC  \
# 0    https://storage.cloud.google.com/amlproject/Ch...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
#
#                                           folderNarrow folderCompensated  \
# 0    https://console.cloud.google.com/storage/brows...               NaN
# 1                                                  NaN               NaN
# 2                                                  NaN               NaN
# 3                                                  NaN               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 304                                                NaN               NaN
# 305                                                NaN               NaN
# 306                                                NaN               NaN
# 307                                                NaN               NaN
# 308                                                NaN               NaN
#
#                                               folderQC  \
# 0    https://console.cloud.google.com/storage/brows...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
#
#                                            folderBroad  \
# 0    https://console.cloud.google.com/storage/brows...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
#
#                                          folder Bigwig  folder diffPeaks
# 0    https://console.cloud.google.com/storage/brows...               NaN
# 1                                                  NaN               NaN
# 2                                                  NaN               NaN
# 3                                                  NaN               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 304                                                NaN               NaN
# 305                                                NaN               NaN
# 306                                                NaN               NaN
# 307                                                NaN               NaN
# 308                                                NaN               NaN
#
# [309 rows x 30 columns]

# %%
a = ! ls ../../data/fastqs/*

# %%
a
# Out:
# ['../../data/fastqs/mp876-MV411-ZFP281-r1_R1_001.fastq.gz',
#  '../../data/fastqs/mp876-MV411-ZFP281-r1_R2_001.fastq.gz',
#  '../../data/fastqs/mp877-MV411-PLAGL2-r1_R1_001.fastq.gz',
#  '../../data/fastqs/mp877-MV411-PLAGL2-r1_R2_001.fastq.gz',
#  '../../data/fastqs/mp878-MV411-HEX-r1_R1_001.fastq.gz',
#  '../../data/fastqs/mp878-MV411-HEX-r1_R2_001.fastq.gz',
#  '../../data/fastqs/mp879-MV411-FOSL2-r1_R1_001.fastq.gz',
#  '../../data/fastqs/mp879-MV411-FOSL2-r1_R2_001.fastq.gz',
#  '../../data/fastqs/mp880-MV411-RARA-r1_R1_001.fastq.gz',
#  '../../data/fastqs/mp880-MV411-RARA-r1_R2_001.fastq.gz']

# %%
df = {
"fastq_1": [],
"fastq_2": [],
"antibody": [],
"group": [],
"replicate": [],
"control": []
}
for val in h.grouped(a,2):
    row = gsheet[gsheet.id==val[0].split('/')[-1].split('-')[0]]
    df['group'].append("MV4"+row['name'].values[0].split('-r')[0].split('-MV4')[1])
    df['replicate'].append(row['name'].values[0].split('-r')[1])
    df['fastq_1'].append("fastqs/"+val[0])
    df['fastq_2'].append("fastqs/"+val[1])
    df['antibody'].append(row['protein'].values[0])
    df['control'].append("INPUT")
df['group'].append('INPUT')
df['replicate'].append(1)
df['fastq_1'].append('ref/mp845-MV411-INPUT-r2_R1.fastq.gz')
df['fastq_2'].append('ref/mp845-MV411-INPUT-r2_R2.fastq.gz')
df['antibody'].append("")
df['control'].append("")
df = pd.DataFrame(df)

# %%
df
# Out:
#                                              fastq_1  \
# 0  fastqs/../../data/fastqs/mp876-MV411-ZFP281-r1...
# 1  fastqs/../../data/fastqs/mp877-MV411-PLAGL2-r1...
# 2  fastqs/../../data/fastqs/mp878-MV411-HEX-r1_R1...
# 3  fastqs/../../data/fastqs/mp879-MV411-FOSL2-r1_...
# 4  fastqs/../../data/fastqs/mp880-MV411-RARA-r1_R...
# 5               ref/mp845-MV411-INPUT-r2_R1.fastq.gz
#
#                                              fastq_2 antibody         group  \
# 0  fastqs/../../data/fastqs/mp876-MV411-ZFP281-r1...   ZFP281  MV411-ZFP281
# 1  fastqs/../../data/fastqs/mp877-MV411-PLAGL2-r1...   PLAGL2  MV411-PLAGL2
# 2  fastqs/../../data/fastqs/mp878-MV411-HEX-r1_R2...      HEX     MV411-HEX
# 3  fastqs/../../data/fastqs/mp879-MV411-FOSL2-r1_...    FOSL2   MV411-FOSL2
# 4  fastqs/../../data/fastqs/mp880-MV411-RARA-r1_R...     RARA    MV411-RARA
# 5               ref/mp845-MV411-INPUT-r2_R2.fastq.gz                  INPUT
#
#   replicate control
# 0         1   INPUT
# 1         1   INPUT
# 2         1   INPUT
# 3         1   INPUT
# 4         1   INPUT
# 5         1

# %%
df[df.columns[[3,4,0,1,2,5]]].to_csv('../nextflow/additional_cobinding_v1_design.csv',index=False)

# %%
! cd ../../data/ && sudo ../nextflow log ## to get access to the previous runs
# Out:
# TIMESTAMP          	DURATION      	RUN NAME              	STATUS	REVISION ID	SESSION ID                          	COMMAND
# 2020-02-10 22:39:18	8m 25s        	stupefied_crick       	ERR   	21be314954 	76ea5df0-153c-4e71-a59d-52c6112fda84	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work
# 2020-02-10 22:40:37	1m 6s         	ridiculous_hilbert    	ERR   	21be314954 	75004903-035d-4504-ab80-cab74b5acac4	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work
# 2020-02-10 22:41:52	1m 18s        	intergalactic_mercator	ERR   	21be314954 	bf13ed87-be57-46c0-8a99-3939bba1a794	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work
# 2020-02-10 22:52:31	1d 15h 39m 50s	grave_baekeland       	OK    	21be314954 	b554f82a-f7d1-42fd-8421-543518d2aa84	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work
# 2020-03-10 17:24:20	4h 47m 8s     	festering_lovelace    	ERR   	21be314954 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design_rep4.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work
# 2020-03-11 15:16:55	16s           	compassionate_raman   	ERR   	21be314954 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design_rep4.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work -resume festering_lovelace
# 2020-03-11 15:17:44	19h 57m 30s   	silly_thompson        	OK    	21be314954 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --narrow_peak --input design_rep4.csv --genome GRCh38 --skip_preseq --max_cpus 24 -profile docker -w work -resume festering_lovelace
# 2020-05-27 15:08:20	-             	ridiculous_bardeen    	-     	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh37 -resume
# 2020-05-27 15:09:40	-             	magical_mirzakhani    	-     	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh37 -resume
# 2020-05-27 16:54:22	6m 55s        	nice_tesla            	ERR   	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh37 -resume
# 2020-05-27 17:01:54	1m 32s        	agitated_bose         	ERR   	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh37 -resume
# 2020-05-27 17:03:49	-             	confident_pauling     	-     	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --genome --max_cpus 16
# 2020-05-27 17:04:17	-             	hopeful_watson        	-     	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --max_cpus 16
# 2020-05-27 17:42:01	-             	elegant_liskov        	-     	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --max_cpus 12
# 2020-05-27 18:23:13	3h 1m 56s     	curious_engelbart     	ERR   	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --max_cpus 12
# 2020-05-27 21:25:55	4m 43s        	mad_bell              	ERR   	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --max_cpus 6
# 2020-05-28 13:08:34	11h 21m 20s   	special_heyrovsky     	OK    	fa1e3f8993 	384099a2-df0f-4a41-b5b0-667436ee09de	nextflow run nf-core/atacseq -profile docker --input MV4_ATAC.csv --genome GRCh38 -resume --max_cpus 6
# 2020-08-04 17:36:59	1m 59s        	backstabbing_hilbert  	ERR   	21be314954 	360ae07b-fb63-4b50-b834-7ba2af75b988	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 8 -profile docker -w work
# 2020-08-04 17:40:57	1m 14s        	furious_liskov        	ERR   	21be314954 	b16ce591-36eb-4bc2-901b-840bbe4c73bd	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 8 -profile docker -w work
# 2020-08-04 17:42:40	17.5s         	ridiculous_kilby      	ERR   	21be314954 	c3ff2f08-8186-4048-b643-1d615eb7dcc1	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 6 -profile docker -w work
# 2020-08-04 18:23:46	6.1s          	lethal_celsius        	ERR   	21be314954 	58d0cab0-e38f-4cd7-97a9-d897c5d2b66d	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 6 -profile docker -w work
# 2020-08-04 18:23:57	4h 44m 38s    	infallible_woese      	ERR   	21be314954 	9d191f62-68e0-4e0b-8c13-2e7c1b32ca2f	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work
# 2020-08-04 23:21:36	16h 4m 40s    	exotic_bartik         	ERR   	21be314954 	9d191f62-68e0-4e0b-8c13-2e7c1b32ca2f	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work -resume infallible_woese
# 2020-08-05 15:27:56	1d 3h 52m 45s 	wise_legentil         	OK    	21be314954 	9d191f62-68e0-4e0b-8c13-2e7c1b32ca2f	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --broad_peak --input ../AMLproject/nextflow/additional_degraded_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work -resume exotic_bartik
# 2020-08-07 17:37:32	-             	cranky_gutenberg      	-     	21be314954 	d1305363-9abe-43b2-9334-e0fd0f02e3f0	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --input ../AMLproject/nextflow/cobinding_more.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work
# 2020-08-07 17:38:56	5m 26s        	ecstatic_descartes    	ERR   	21be314954 	ee247a6d-b9c8-47e6-9860-70664157a6b1	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --input ../AMLproject/nextflow/cobinding_more.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work
# 2020-08-07 17:44:55	14h 48m 35s   	desperate_euler       	OK    	21be314954 	5ee36b13-c778-4ae9-af64-8d00cacdc782	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --input ../AMLproject/nextflow/cobinding_more.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work
# 2020-09-09 14:39:55	1h 42s        	curious_northcutt     	ERR   	21be314954 	b40d43bc-27b9-4201-bcfc-b5eeda3f8933	nextflow run nf-core/chipseq --paired_end --seq_center DFCI --email jkobject@gmail.com --input ../AMLproject/nextflow/additional_cobinding_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work

# %%
#process chips
! cd ../../data/ && sudo ../nextflow run nf-core/chipseq --paired_end --seq_center 'DFCI' --email 'jkobject@gmail.com' --input ../AMLproject/nextflow/additional_cobinding_v1_design.csv --genome GRCh38 --skip_preseq --max_cpus 16 -profile docker -w work #-resume exotic_bartik

# %%
# !cp -r ../../data/results/* ../../data/$project/ && sudo rm -r ../data/results && sudo rm -r ..data/work

# %% [markdown]
# # HiCseq Preprocessing

# %% [markdown]
# ### need to use juicer
# https://github.com/aidenlab/juicer/wiki/Data-Extraction
#
# https://github.com/aidenlab/straw/wiki/Python
#
# https://github.com/aidenlab/juicer/wiki/Data
#
# https://github.com/aidenlab/juicer

# %%
! pip install hic-straw

# %%
import straw

# %%
result = straw.straw('KR', 
                     '../../data/'+project+'/MV411_H3K27ac_all_rep_duplicate_removed_allValidPairs.hic',
                     'X', 'X', 'BP', 5000)

# %%
len(result[1])

# %%
! ls ../../data/$project

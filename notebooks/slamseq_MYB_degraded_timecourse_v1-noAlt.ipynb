# %% [markdown]
# # SLAMseq

# %% [markdown]
# ## Installing slamdunk (only do once)

# %%
# install slamdunk
#! pip3 install git+https://github.com/jkobject/slamdunk.git --upgrade

# %%
# please also install cutadapt, fastqc, and trimgalore
#! conda install -c bioconda cutadapt
#! conda install -c bioconda fastqc
#! conda install -c bioconda trim-galore

# %%
from __future__ import print_function
import os.path
import pandas as pd
import sys
sys.path.insert(0, '../../')
import seaborn as sns
import numpy as np

from genepy.utils import helper as h
from genepy.utils import plot as genepyPlot
from genepy.rna import pyDESeq2
import genepy.rna as rna

from bokeh.plotting import *
from bokeh.models import HoverTool
from bokeh.io import output_notebook

import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.manifold import MDS, TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
#from umap import UMAP

output_notebook()
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
# %load_ext rpy2.ipython
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
def createDir(directory):
    if not os.path.exists(directory):
        print("Creating output directory: " + directory)
        os.makedirs(directory)

# %% [markdown]
# # MYB degron time course (no alt loci)

# %%
project = "MYB_degraded_timecourse_v1"

# %% [markdown]
# ### download the data

# %%
project = "MYB_degraded_timecourse_v1"
location = "../data/slamseq_"+project+"/" # new data location
loc = "211108_MP9454_fastq" # transfer AML folder

# %%
! mkdir ../$location
! mkdir ../results/slamseq_$project
! mkdir $location && mkdir $location/qc # make data dir in AMLproject
! mkdir ../$location/fastqs/ # make dir in /home/monika/data/project/fastqs
# Out:
# mkdir: cannot create directory ‘../../data/slamseq_MYB_degraded_timecourse_v1/’: File exists
# mkdir: cannot create directory ‘../results/slamseq_MYB_degraded_timecourse_v1’: File exists
# mkdir: cannot create directory ‘../data/slamseq_MYB_degraded_timecourse_v1/’: File exists
# mkdir: cannot create directory ‘../data/slamseq_MYB_degraded_timecourse_v1//qc’: File exists
# mkdir: cannot create directory ‘../../data/slamseq_MYB_degraded_timecourse_v1//fastqs/’: File exists

# %%
! gsutil ls gs://transfer-amlproject/$loc/
# Out:
# gs://transfer-amlproject/211108_MP9454_fastq/._multiqc_report.html
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R1_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R2_001.fastq.gz
# gs://transfer-amlproject/211108_MP9454_fastq/multiqc_report.html
# gs://transfer-amlproject/211108_MP9454_fastq/Reports/
# gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/

# %%
location
# Out:
# '../data/slamseq_MYB_degraded_timecourse_v1/'

# %%
! gsutil -m cp gs://transfer-amlproject/$loc/multiqc_report.html $location/qc/ # transfer qc files
! gsutil -m cp -r gs://transfer-amlproject/$loc/Reports/ $location/qc/
! gsutil -m cp -r gs://transfer-amlproject/$loc/multiqc_data/ $location/qc/
# Out:
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_report.html...
# / [1/1 files][  5.9 MiB/  5.9 MiB] 100% Done
# Operation completed over 1 objects/5.9 MiB.
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R2_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R1_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R1_001_fastqc.zip...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R2_001_fastqc.html...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/Reports/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R2_001_fastqc.zip...
# \ [280/280 files][130.8 MiB/130.8 MiB] 100% Done
# Operation completed over 280 objects/130.8 MiB.
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_adapter_content_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_overrepresented_sequencesi_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_per_base_n_content_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_per_base_sequence_quality_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_per_sequence_gc_content_plot_Counts.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_per_sequence_gc_content_plot_Percentages.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_per_sequence_quality_scores_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_sequence_counts_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/mqc_fastqc_sequence_duplication_levels_plot_1.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc_data.json...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc.log...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc_fastqc.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc_general_stats.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc_sources.txt...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/multiqc_data/multiqc_qualimap_bamqc_genome_results.txt...
# / [15/15 files][  1.7 MiB/  1.7 MiB] 100% Done
# Operation completed over 15 objects/1.7 MiB.

# %%
! cp $location/qc/multiqc_report.html ../results/slamseq_$project

# %%
fastqs = ! gsutil ls gs://transfer-amlproject/$loc/*.gz

# %%
from natsort import os_sorted

# %%
fastqs = [fastq.split("/")[-1] for fastq in os_sorted(fastqs)]

# %%
for val1, val2 in h.grouped(fastqs, 2):
    print(val1.split("_R")[0])
# Out:
# 20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75
# 20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76
# 20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77
# 20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78
# 20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79
# 20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80
# 20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81
# 20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82
# 20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83
# 20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84
# 20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85
# 20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86
# 20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87
# 20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88
# 20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89
# 20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90
# 20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91
# 20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92
# 20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93
# 20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94
# 20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95
# 20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96
# 20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97
# 20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98
# 20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111
# 20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112
# 20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113
# 20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114
# 20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115
# 20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116
# 20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117
# 20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118
# 20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119
# 20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120
# 20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121
# 20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122
# 20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123
# 20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124
# 20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125
# 20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126
# 20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127
# 20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128
# 20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129
# 20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130
# 20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131
# 20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132
# 20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133
# 20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134
# 20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21
# 20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22
# 20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23
# 20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24
# 20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25
# 20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26
# 20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27
# 20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28
# 20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29
# 20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30
# 20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31
# 20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32
# 20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33
# 20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34
# 20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35
# 20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36
# 20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37
# 20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38
# 20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39
# 20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40
# 20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41
# 20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42

# %%
! gsutil -m cp gs://transfer-amlproject/$loc/*.fastq.gz ../$location/fastqs/ # transfer fastqs
# Out:
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R2_001.fastq.gz...
# ==> NOTE: You are downloading one or more large file(s), which would
# run significantly faster if you enabled sliced object downloads. This
# feature is enabled by default but requires that compiled crcmod be
# installed (see "gsutil help crcmod").
#
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R2_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R1_001.fastq.gz...
# Copying gs://transfer-amlproject/211108_MP9454_fastq/20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R2_001.fastq.gz...
# - [140/140 files][693.7 GiB/693.7 GiB] 100% Done     0.0 B/s
# Operation completed over 140 objects/693.7 GiB.

# %% [markdown]
# ### rename local fastqs

# %%
fastq_folder = "../"+location+"fastqs"
print(fastq_folder)
fastqs = ! ls $fastq_folder
fastqs
# Out:
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs
# ['20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R1_001.fastq.gz',
#  '20211108_10_MYB-dTAG_VHL_1h_E_MP9454_S84_R2_001.fastq.gz',
#  '20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R1_001.fastq.gz',
#  '20211108_11_MYB-dTAG_DMSO_2h_A_MP9454_S85_R2_001.fastq.gz',
#  '20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R1_001.fastq.gz',
#  '20211108_12_MYB-dTAG_DMSO_2h_B_MP9454_S86_R2_001.fastq.gz',
#  '20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R1_001.fastq.gz',
#  '20211108_13_MYB-dTAG_DMSO_2h_C_MP9454_S87_R2_001.fastq.gz',
#  '20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R1_001.fastq.gz',
#  '20211108_14_MYB-dTAG_DMSO_2h_D_MP9454_S88_R2_001.fastq.gz',
#  '20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R1_001.fastq.gz',
#  '20211108_15_MYB-dTAG_DMSO_2h_E_MP9454_S89_R2_001.fastq.gz',
#  '20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R1_001.fastq.gz',
#  '20211108_16_MYB-dTAG_VHL_2h_A_MP9454_S90_R2_001.fastq.gz',
#  '20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R1_001.fastq.gz',
#  '20211108_17_MYB-dTAG_VHL_2h_B_MP9454_S91_R2_001.fastq.gz',
#  '20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R1_001.fastq.gz',
#  '20211108_18_MYB-dTAG_VHL_2h_C_MP9454_S92_R2_001.fastq.gz',
#  '20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R1_001.fastq.gz',
#  '20211108_19_MYB-dTAG_VHL_2h_D_MP9454_S93_R2_001.fastq.gz',
#  '20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R1_001.fastq.gz',
#  '20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75_R2_001.fastq.gz',
#  '20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R1_001.fastq.gz',
#  '20211108_20_MYB-dTAG_VHL_2h_E_MP9454_S94_R2_001.fastq.gz',
#  '20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R1_001.fastq.gz',
#  '20211108_21_MYB-dTAG_DMSO_4h_A_MP9454_S95_R2_001.fastq.gz',
#  '20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R1_001.fastq.gz',
#  '20211108_22_MYB-dTAG_DMSO_4h_B_MP9454_S96_R2_001.fastq.gz',
#  '20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R1_001.fastq.gz',
#  '20211108_23_MYB-dTAG_DMSO_4h_C_MP9454_S97_R2_001.fastq.gz',
#  '20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R1_001.fastq.gz',
#  '20211108_24_MYB-dTAG_DMSO_4h_D_MP9454_S98_R2_001.fastq.gz',
#  '20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R1_001.fastq.gz',
#  '20211108_25_MYB-dTAG_DMSO_4h_E_MP9454_S111_R2_001.fastq.gz',
#  '20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R1_001.fastq.gz',
#  '20211108_26_MYB-dTAG_VHL_4h_A_MP9454_S112_R2_001.fastq.gz',
#  '20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R1_001.fastq.gz',
#  '20211108_27_MYB-dTAG_VHL_4h_B_MP9454_S113_R2_001.fastq.gz',
#  '20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R1_001.fastq.gz',
#  '20211108_28_MYB-dTAG_VHL_4h_C_MP9454_S114_R2_001.fastq.gz',
#  '20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R1_001.fastq.gz',
#  '20211108_29_MYB-dTAG_VHL_4h_D_MP9454_S115_R2_001.fastq.gz',
#  '20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R1_001.fastq.gz',
#  '20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76_R2_001.fastq.gz',
#  '20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R1_001.fastq.gz',
#  '20211108_30_MYB-dTAG_VHL_4h_E_MP9454_S116_R2_001.fastq.gz',
#  '20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R1_001.fastq.gz',
#  '20211108_31_MYB-dTAG_DMSO_8h_A_MP9454_S117_R2_001.fastq.gz',
#  '20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R1_001.fastq.gz',
#  '20211108_32_MYB-dTAG_DMSO_8h_B_MP9454_S118_R2_001.fastq.gz',
#  '20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R1_001.fastq.gz',
#  '20211108_33_MYB-dTAG_DMSO_8h_C_MP9454_S119_R2_001.fastq.gz',
#  '20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R1_001.fastq.gz',
#  '20211108_34_MYB-dTAG_DMSO_8h_D_MP9454_S120_R2_001.fastq.gz',
#  '20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R1_001.fastq.gz',
#  '20211108_35_MYB-dTAG_DMSO_8h_E_MP9454_S121_R2_001.fastq.gz',
#  '20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R1_001.fastq.gz',
#  '20211108_36_MYB-dTAG_VHL_8h_A_MP9454_S122_R2_001.fastq.gz',
#  '20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R1_001.fastq.gz',
#  '20211108_37_MYB-dTAG_VHL_8h_B_MP9454_S123_R2_001.fastq.gz',
#  '20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R1_001.fastq.gz',
#  '20211108_38_MYB-dTAG_VHL_8h_C_MP9454_S124_R2_001.fastq.gz',
#  '20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R1_001.fastq.gz',
#  '20211108_39_MYB-dTAG_VHL_8h_D_MP9454_S125_R2_001.fastq.gz',
#  '20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R1_001.fastq.gz',
#  '20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77_R2_001.fastq.gz',
#  '20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R1_001.fastq.gz',
#  '20211108_40_MYB-dTAG_VHL_8h_E_MP9454_S126_R2_001.fastq.gz',
#  '20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R1_001.fastq.gz',
#  '20211108_41_MYB-dTAG_DMSO_12h_A_MP9454_S127_R2_001.fastq.gz',
#  '20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R1_001.fastq.gz',
#  '20211108_42_MYB-dTAG_DMSO_12h_B_MP9454_S128_R2_001.fastq.gz',
#  '20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R1_001.fastq.gz',
#  '20211108_43_MYB-dTAG_DMSO_12h_C_MP9454_S129_R2_001.fastq.gz',
#  '20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R1_001.fastq.gz',
#  '20211108_44_MYB-dTAG_DMSO_12h_D_MP9454_S130_R2_001.fastq.gz',
#  '20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R1_001.fastq.gz',
#  '20211108_45_MYB-dTAG_DMSO_12h_E_MP9454_S131_R2_001.fastq.gz',
#  '20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R1_001.fastq.gz',
#  '20211108_46_MYB-dTAG_VHL_12h_A_MP9454_S132_R2_001.fastq.gz',
#  '20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R1_001.fastq.gz',
#  '20211108_47_MYB-dTAG_VHL_12h_B_MP9454_S133_R2_001.fastq.gz',
#  '20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R1_001.fastq.gz',
#  '20211108_48_MYB-dTAG_VHL_12h_C_MP9454_S134_R2_001.fastq.gz',
#  '20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R1_001.fastq.gz',
#  '20211108_49_MYB-dTAG_VHL_12h_D_MP9454_S21_R2_001.fastq.gz',
#  '20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R1_001.fastq.gz',
#  '20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78_R2_001.fastq.gz',
#  '20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R1_001.fastq.gz',
#  '20211108_50_MYB-dTAG_VHL_12h_E_MP9454_S22_R2_001.fastq.gz',
#  '20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R1_001.fastq.gz',
#  '20211108_51_MYB-dTAG_DMSO_24h_A_MP9454_S23_R2_001.fastq.gz',
#  '20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R1_001.fastq.gz',
#  '20211108_52_MYB-dTAG_DMSO_24h_B_MP9454_S24_R2_001.fastq.gz',
#  '20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R1_001.fastq.gz',
#  '20211108_53_MYB-dTAG_DMSO_24h_C_MP9454_S25_R2_001.fastq.gz',
#  '20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R1_001.fastq.gz',
#  '20211108_54_MYB-dTAG_DMSO_24h_D_MP9454_S26_R2_001.fastq.gz',
#  '20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R1_001.fastq.gz',
#  '20211108_55_MYB-dTAG_DMSO_24h_E_MP9454_S27_R2_001.fastq.gz',
#  '20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R1_001.fastq.gz',
#  '20211108_56_MYB-dTAG_VHL_24h_A_MP9454_S28_R2_001.fastq.gz',
#  '20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R1_001.fastq.gz',
#  '20211108_57_MYB-dTAG_VHL_24h_B_MP9454_S29_R2_001.fastq.gz',
#  '20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R1_001.fastq.gz',
#  '20211108_58_MYB-dTAG_VHL_24h_C_MP9454_S30_R2_001.fastq.gz',
#  '20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R1_001.fastq.gz',
#  '20211108_59_MYB-dTAG_VHL_24h_D_MP9454_S31_R2_001.fastq.gz',
#  '20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R1_001.fastq.gz',
#  '20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79_R2_001.fastq.gz',
#  '20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R1_001.fastq.gz',
#  '20211108_60_MYB-dTAG_VHL_24h_E_MP9454_S32_R2_001.fastq.gz',
#  '20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R1_001.fastq.gz',
#  '20211108_61_MYB-dTAG_DMSO_48h_A_MP9454_S33_R2_001.fastq.gz',
#  '20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R1_001.fastq.gz',
#  '20211108_62_MYB-dTAG_DMSO_48h_B_MP9454_S34_R2_001.fastq.gz',
#  '20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R1_001.fastq.gz',
#  '20211108_63_MYB-dTAG_DMSO_48h_C_MP9454_S35_R2_001.fastq.gz',
#  '20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R1_001.fastq.gz',
#  '20211108_64_MYB-dTAG_DMSO_48h_D_MP9454_S36_R2_001.fastq.gz',
#  '20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R1_001.fastq.gz',
#  '20211108_65_MYB-dTAG_DMSO_48h_E_MP9454_S37_R2_001.fastq.gz',
#  '20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R1_001.fastq.gz',
#  '20211108_66_MYB-dTAG_VHL_48h_A_MP9454_S38_R2_001.fastq.gz',
#  '20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R1_001.fastq.gz',
#  '20211108_67_MYB-dTAG_VHL_48h_B_MP9454_S39_R2_001.fastq.gz',
#  '20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R1_001.fastq.gz',
#  '20211108_68_MYB-dTAG_VHL_48h_C_MP9454_S40_R2_001.fastq.gz',
#  '20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R1_001.fastq.gz',
#  '20211108_69_MYB-dTAG_VHL_48h_D_MP9454_S41_R2_001.fastq.gz',
#  '20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R1_001.fastq.gz',
#  '20211108_6_MYB-dTAG_VHL_1h_A_MP9454_S80_R2_001.fastq.gz',
#  '20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R1_001.fastq.gz',
#  '20211108_70_MYB-dTAG_VHL_48h_E_MP9454_S42_R2_001.fastq.gz',
#  '20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R1_001.fastq.gz',
#  '20211108_7_MYB-dTAG_VHL_1h_B_MP9454_S81_R2_001.fastq.gz',
#  '20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R1_001.fastq.gz',
#  '20211108_8_MYB-dTAG_VHL_1h_C_MP9454_S82_R2_001.fastq.gz',
#  '20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R1_001.fastq.gz',
#  '20211108_9_MYB-dTAG_VHL_1h_D_MP9454_S83_R2_001.fastq.gz']

# %%
from natsort import os_sorted
os_sorted(fastqs[::2])
# Out:
# ['20211012_GFI1_DMSO_A_MP9377_S76_R1_001.fastq.gz',
#  '20211012_GFI1_DMSO_B_MP9377_S77_R1_001.fastq.gz',
#  '20211012_GFI1_DMSO_C_MP9377_S78_R1_001.fastq.gz',
#  '20211012_GFI1_DMSO_D_MP9377_S79_R1_001.fastq.gz',
#  '20211012_GFI1_DMSO_E_MP9377_S80_R1_001.fastq.gz',
#  '20211012_GFI1_VHL_A_MP9377_S81_R1_001.fastq.gz',
#  '20211012_GFI1_VHL_B_MP9377_S82_R1_001.fastq.gz',
#  '20211012_GFI1_VHL_D_MP9377_S83_R1_001.fastq.gz',
#  '20211012_GFI1_VHL_E_MP9377_S84_R1_001.fastq.gz',
#  '20211012_RUNX1_DMSO_A_MP9377_S50_R1_001.fastq.gz',
#  '20211012_RUNX1_DMSO_B_MP9377_S51_R1_001.fastq.gz',
#  '20211012_RUNX1_DMSO_C_MP9377_S52_R1_001.fastq.gz',
#  '20211012_RUNX1_DMSO_D_MP9377_S53_R1_001.fastq.gz',
#  '20211012_RUNX1_VHL_A_MP9377_S54_R1_001.fastq.gz',
#  '20211012_RUNX1_VHL_B_MP9377_S55_R1_001.fastq.gz',
#  '20211012_RUNX1_VHL_C_MP9377_S56_R1_001.fastq.gz',
#  '20211012_RUNX1_VHL_D_MP9377_S57_R1_001.fastq.gz',
#  '20211012_RUNX2_DMSO_A_MP9377_S58_R1_001.fastq.gz',
#  '20211012_RUNX2_DMSO_B_MP9377_S59_R1_001.fastq.gz',
#  '20211012_RUNX2_DMSO_C_MP9377_S60_R1_001.fastq.gz',
#  '20211012_RUNX2_DMSO_D_MP9377_S61_R1_001.fastq.gz',
#  '20211012_RUNX2_VHL_A_MP9377_S62_R1_001.fastq.gz',
#  '20211012_RUNX2_VHL_B_MP9377_S63_R1_001.fastq.gz',
#  '20211012_RUNX2_VHL_C_MP9377_S64_R1_001.fastq.gz',
#  '20211012_RUNX2_VHL_D_MP9377_S65_R1_001.fastq.gz',
#  '20211012_SPI1_DMSO_A_MP9377_S66_R1_001.fastq.gz',
#  '20211012_SPI1_DMSO_B_MP9377_S67_R1_001.fastq.gz',
#  '20211012_SPI1_DMSO_C_MP9377_S68_R1_001.fastq.gz',
#  '20211012_SPI1_DMSO_D_MP9377_S69_R1_001.fastq.gz',
#  '20211012_SPI1_DMSO_E_MP9377_S70_R1_001.fastq.gz',
#  '20211012_SPI1_VHL_A_MP9377_S71_R1_001.fastq.gz',
#  '20211012_SPI1_VHL_B_MP9377_S72_R1_001.fastq.gz',
#  '20211012_SPI1_VHL_C_MP9377_S73_R1_001.fastq.gz',
#  '20211012_SPI1_VHL_D_MP9377_S74_R1_001.fastq.gz',
#  '20211012_SPI1_VHL_E_MP9377_S75_R1_001.fastq.gz']

# %%
from gsheets import Sheets
sheets = Sheets.from_files('~/.client_secret_web.json', '~/.storage.json')
url = "https://docs.google.com/spreadsheets/d/1yFLjYB1McU530JnLgL0QIMAKIkVl3kl0_LCHje2gk8U/edit?ts=5fab1071#gid=738732237"
gsheet = sheets.get(url).sheets[12].to_frame()

# %%
# get new sample names from AML sample tracker - RNA_tracker_JK
idx = gsheet.index[gsheet['batch'] == project] # get first row with project number
sample_info = gsheet.loc[idx[0]:, ["prev_name", "name"]]
sample_info.head()
# Out:
#                                     prev_name                             name
# 421  20211108_1_MYB-dTAG_DMSO_1h_A_MP9454_S75  mr422-MV411-MYB-dTAG-DMSO_1h-r1
# 422  20211108_2_MYB-dTAG_DMSO_1h_B_MP9454_S76  mr423-MV411-MYB-dTAG-DMSO_1h-r2
# 423  20211108_3_MYB-dTAG_DMSO_1h_C_MP9454_S77  mr424-MV411-MYB-dTAG-DMSO_1h-r3
# 424  20211108_4_MYB-dTAG_DMSO_1h_D_MP9454_S78  mr425-MV411-MYB-dTAG-DMSO_1h-r4
# 425  20211108_5_MYB-dTAG_DMSO_1h_E_MP9454_S79  mr426-MV411-MYB-dTAG-DMSO_1h-r5

# %%
rename = dict(zip(sample_info.prev_name, sample_info.name)) # make dict with names

# %%
any(prev_name in fastq for fastq in fastqs for prev_name in list(rename.keys()))
# Out:
# True

# %%
# copy from AML sample tracker - RNA_tracker_JK
rename
#rename = {
#    "20210514_1R_MP8847_S154": "mr371-MV411-IRF2BP2-dTAG-DMSO_3h-r1",
#}

# %%
# rename fastqs locally
for val in fastqs:
    rep  = val
    for old, new in rename.items():
        rep = rep.replace(old, new)
    if rep != val:
        ! mv $fastq_folder/$val $fastq_folder/$rep

# %% [markdown]
# # SLAMDUNK

# %%
project = "MYB_degraded_timecourse_v1"

# %%
fastq_folder = "../../data/"+"slamseq_"+project+"/fastqs"
fastqs = ! ls $fastq_folder/*fastq.gz
fastqs[:5]
# Out:
# ['../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R1_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R2_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R1_001.fastq.gz']

# %% [markdown]
# ## run trim galore

# %% [markdown]
# running in batches of 10

# %%
for val1, val2 in h.grouped(fastqs[128:], 2):
    print(val1)
    print(val2)
    print("\n")
# Out:
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001.fastq.gz
#
#
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr489-MV411-MYB-dTAG-VHL_48h-r3_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr489-MV411-MYB-dTAG-VHL_48h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr490-MV411-MYB-dTAG-VHL_48h-r4_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr490-MV411-MYB-dTAG-VHL_48h-r4_R2_001.fastq.gz
#
#
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr491-MV411-MYB-dTAG-VHL_48h-r5_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr491-MV411-MYB-dTAG-VHL_48h-r5_R2_001.fastq.gz

# %%
# %%time
h.parrun(['trim_galore --paired --cores 8 --retain_unpaired -stringency 3\
 --illumina '+val1+' '+val2+' -o '+fastq_folder for val1, val2 in h.grouped(fastqs[128:], 2)], 2)
# Out:
# CPU times: user 300 ms, sys: 156 ms, total: 456 ms
# Wall time: 2h 54min 39s
# ['pigz 2.6\npigz 2.6\n', 'pigz 2.6\npigz 2.6\n', 'pigz 2.6\npigz 2.6\n']

# %%
# %%time

for val1, val2 in h.grouped(fastqs[40:42], 2):
    print(val1)
    print(val2)
    h.parrun(['trim_galore --paired --cores 16 --retain_unpaired -stringency 3 --illumina '+val1+' '+val2+' -o '+fastq_folder], 1)
# Out:
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R2_001.fastq.gz
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/genepy/genepy/utils/helper.py in parrun(cmds, cores, add)
#     298       res = subprocess.run(exe, capture_output=True, shell=True)
#     299       if res.returncode != 0:
# --> 300         raise ValueError('issue with the command: ' + str(res.stderr))
#     301       exe = ''
#     302       if len(add) != 0:
#
# ValueError: issue with the command: b'Using an excessive number of cores has a diminishing return! It is recommended not to exceed 8 cores per trimming process (you asked for 16 cores). Please consider re-specifying\nPath to Cutadapt set as: \'cutadapt\' (default)\nCutadapt seems to be working fine (tested command \'cutadapt --version\')\nCutadapt version: 3.4\nCould not detect version of Python used by Cutadapt from the first line of Cutadapt (but found this: >>>#!/bin/sh<<<)\nLetting the (modified) Cutadapt deal with the Python version instead\nParallel gzip (pigz) detected. Proceeding with multicore (de)compression using 16 cores\n\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/monika/data/slamseq_MYB_degraded_timecourse_v1/fastqs/\nWriting report to \'/home/monika/data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz_trimming_report.txt\'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.7\nCutadapt version: 3.4\nPython version: could not detect\nNumber of cores used for trimming: 16\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: \'AGATCGGAAGAGC\' (Illumina TruSeq, Sanger iPCR; user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 3 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nLength cut-off for read 1: 35 bp (default)\nLength cut-off for read 2: 35 bb (default)\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be fairly up-to-date (version 3.4). Setting -j 16\nWriting final adapter and quality trimmed output to mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff \'-q 20\') and adapter trimming in a single pass for the adapter sequence: \'AGATCGGAAGAGC\' from file ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz <<< \n10000000 sequences processed\n20000000 sequences processed\n30000000 sequences processed\n40000000 sequences processed\nThis is cutadapt 3.4 with Python 3.8.11\nCommand line parameters: -j 16 -e 0.1 -q 20 -O 3 -a AGATCGGAAGAGC ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz\nProcessing reads on 16 cores in single-end mode ...\nTraceback (most recent call last):\n  File "/home/monika/anaconda3/envs/slamseq/bin/cutadapt", line 10, in <module>\n    sys.exit(main_cli())\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/site-packages/cutadapt/__main__.py", line 848, in main_cli\n    main(sys.argv[1:])\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/site-packages/cutadapt/__main__.py", line 913, in main\n    stats = r.run()\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/site-packages/cutadapt/pipeline.py", line 836, in run\n    data = connection.recv_bytes()\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes\n    buf = self._recv_bytes(maxlength)\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/multiprocessing/connection.py", line 421, in _recv_bytes\n    return self._recv(size)\n  File "/home/monika/anaconda3/envs/slamseq/lib/python3.8/multiprocessing/connection.py", line 386, in _recv\n    buf.write(chunk)\nMemoryError\n\n\nCutadapt terminated with exit signal: \'256\'.\nTerminating Trim Galore run, please check error message(s) to get an idea what went wrong...\n\n'

# %%
len(fastqs)/2
# Out:
# 35.0

# %%
for val1, val2 in h.grouped(fastqs[24:], 2):
    print(val1)
    print(val2)
    print("\n")
# Out:
# ../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr407-MV411-SPI1-dTAG-DMSO_1h-r5_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr407-MV411-SPI1-dTAG-DMSO_1h-r5_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr408-MV411-SPI1-dTAG-VHL_1h-r1_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr408-MV411-SPI1-dTAG-VHL_1h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr409-MV411-SPI1-dTAG-VHL_1h-r2_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr409-MV411-SPI1-dTAG-VHL_1h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr410-MV411-SPI1-dTAG-VHL_1h-r3_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr410-MV411-SPI1-dTAG-VHL_1h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr411-MV411-SPI1-dTAG-VHL_1h-r4_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr411-MV411-SPI1-dTAG-VHL_1h-r4_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr412-MV411-SPI1-dTAG-VHL_1h-r5_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr412-MV411-SPI1-dTAG-VHL_1h-r5_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr413-MV411-GFI1-dTAG-DMSO_2h-r1_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr413-MV411-GFI1-dTAG-DMSO_2h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr414-MV411-GFI1-dTAG-DMSO_2h-r2_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr414-MV411-GFI1-dTAG-DMSO_2h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr415-MV411-GFI1-dTAG-DMSO_2h-r3_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr415-MV411-GFI1-dTAG-DMSO_2h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr416-MV411-GFI1-dTAG-DMSO_2h-r4_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr416-MV411-GFI1-dTAG-DMSO_2h-r4_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr417-MV411-GFI1-dTAG-DMSO_2h-r5_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr417-MV411-GFI1-dTAG-DMSO_2h-r5_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr418-MV411-GFI1-dTAG-VHL_2h-r1_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr418-MV411-GFI1-dTAG-VHL_2h-r1_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr419-MV411-GFI1-dTAG-VHL_2h-r2_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr419-MV411-GFI1-dTAG-VHL_2h-r2_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr420-MV411-GFI1-dTAG-VHL_2h-r3_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr420-MV411-GFI1-dTAG-VHL_2h-r3_R2_001.fastq.gz
#
#
# ../../data/slamseq_4_degrons_v1/fastqs/mr421-MV411-GFI1-dTAG-VHL_2h-r4_R1_001.fastq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr421-MV411-GFI1-dTAG-VHL_2h-r4_R2_001.fastq.gz

# %% [markdown]
# install slamdunk & dependencies if needed (see above)

# %%
# install slamdunk
#! pip3 install git+https://github.com/jkobject/slamdunk.git --upgrade

# %%
# please also install cutadapt, fastqc, and trimgalore
#! conda install -c bioconda cutadapt
#! conda install -c bioconda fastqc
#! conda install -c bioconda trim-galore

# %% [markdown]
# download reference genome files

# %%
# google storage bucket with reference files
#! gsutil ls gs://ccle_default_params

# copy reference genome files
#! gsutil -m cp gs://ccle_default_params/Homo_sapiens_assembly38* ../../ref/

# copy reference genome files
#! cp ../data/Muhar_Slamseq/{ERCC92.fa,ERCC92.gtf,GSE100708_hg38_refseq_062016_ensemblv84_3UTR.bed} ../../ref
# Out:
# gs://ccle_default_params/3UTRs.bed
# gs://ccle_default_params/Axiom_Exome_Plus.genotypes.all_populations.poly.vcf
# gs://ccle_default_params/Axiom_Exome_Plus.genotypes.all_populations.poly.vcf.idx
# gs://ccle_default_params/CGA_WES_Characterization_v0.1_cga_pipeline_config_optional_parameters.json
# gs://ccle_default_params/CGA_WES_Characterization_v0.1_cga_pipeline_config_optional_parameters_light.json
# gs://ccle_default_params/CNV_and_centromere_blacklist.hg38liftover.list
# gs://ccle_default_params/GTEX-111FC-0001-SM-6WBTJ.wgs_ccle.bai
# gs://ccle_default_params/GTEX-111FC-0001-SM-6WBTJ.wgs_ccle.bam
# gs://ccle_default_params/Homo_sapiens_assembly38_ERCC92.fasta
# gs://ccle_default_params/Homo_sapiens_assembly38_ERCC92.fasta-enc.2.ngm
# gs://ccle_default_params/Homo_sapiens_assembly38_ERCC92.fasta-ht-13-2.3.ngm
# gs://ccle_default_params/Homo_sapiens_assembly38_ERCC92.fasta.fai
# gs://ccle_default_params/STAR_genome_GRCh38_noALT_noHLA_noDecoy_ERCC_v29_oh100.tar.gz
# gs://ccle_default_params/allknown_mutations.txt
# gs://ccle_default_params/allknown_mutations_hg19.txt
# gs://ccle_default_params/allknown_mutations_hg19_idx.txt
# gs://ccle_default_params/allknown_mutations_idx.txt
# gs://ccle_default_params/generate_single_seg_file.R
# gs://ccle_default_params/hg38ToHg19.over.chain
# gs://ccle_default_params/hg38_ERCC92.gtf
# gs://ccle_default_params/ice_hg38_lifted_chrXY.no_header.list
# gs://ccle_default_params/jointGenotyping_intervals_correctFormat.list
# gs://ccle_default_params/jointGenotyping_intervals_header.interval_list
# gs://ccle_default_params/mastermind_cited_variants_reference-2021.04.02-grch38-vcf.zip
# gs://ccle_default_params/references_gtex_gencode.v29.GRCh38.ERCC.genes.collapsed_only.gtf
# gs://ccle_default_params/rsem_reference_GRCh38_gencode29_ercc.tar.gz
# gs://ccle_default_params/scatter_wes_ice_hg19_baits.interval_list
# gs://ccle_default_params/wes_agilent_hg19_baits.interval_list
# gs://ccle_default_params/wes_agilent_hg19_refseq3.baits.jointdiscovery.list
# gs://ccle_default_params/baits_scatter_agilent_hg19/
# gs://ccle_default_params/fingerprinting_snps/
# gs://ccle_default_params/liftover/
# gs://ccle_default_params/pons/
# gs://ccle_default_params/pseudonormals/
# gs://ccle_default_params/reference/
# gs://ccle_default_params/references/
# gs://ccle_default_params/scatter_wes_ice_hg19_baits/
# gs://ccle_default_params/scripts/
# gs://ccle_default_params/slamseq/

# %% [markdown]
# ## run slamdunk

# %%
# using an ERCC ref genome (you can just append ERCC fasta to the hg38 fasta)
refgenome_noAlt="../../ref/Homo_sapiens_assembly38_ERCC92_noAlt.fasta"

# %%
# gene intervals bed (use for all projects)
gene_intervals = "../../ref/GSE100708_hg38_refseq_062016_ensemblv84_3UTR.bed"

# %% [markdown]
# res = slamdunk all w/ (-fb, -m, -n 1, -rl 152, -r Homo_sapiens_assembly38_ERCC92_noAlt.fasta)

# %% [markdown]
# Read length note!
# <br>Difference between min and max read length is > 100bp
# <br>Average read length 127 (min: 8, max: 152)

# %%
fastq_folder = "../../data/"+"slamseq_"+project+"/fastqs"
fastqs = ! ls $fastq_folder
fastqs = [fastq for fastq in fastqs if "val" in fastq]
fastq_full = [fastq_folder+"/"+f for f in fastqs]

# %%
res_dir = "../../data/"+"slamseq_"+project+"/res"
res_dir
# Out:
# '../../data/slamseq_MYB_degraded_timecourse_v1/res'

# %%
len(fastq_full)/2
# Out:
# 4.0

# %%
# %%time

print(['slamdunk all'+
       ' -o '+res_dir+
       ' -r '+refgenome_noAlt+
       ' -b '+gene_intervals+
       ' -t 14'+
       ' -c 2'+
       ' -rl 152'+ # max-read-length = 152
       # new parameters
       ' -5 12'+
       ' -n 1'+ # reads map to multiple locations at once
       ' -m'+ # multimapping
       ' -N '+val1.split('/')[-1].split('_R')[0]+
       ' '+val1+" "+val2
       for val1, val2 in h.grouped(fastq_full[:2], 2)])
# Out:
# ['slamdunk all -o ../../data/slamseq_MYB_degraded_timecourse_v1/res -r ../../ref/Homo_sapiens_assembly38_ERCC92_noAlt.fasta -b ../../ref/GSE100708_hg38_refseq_062016_ensemblv84_3UTR.bed -t 14 -c 2 -rl 152 -5 12 -n 1 -m -N mr488-MV411-MYB-dTAG-VHL_48h-r2 ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001_val_1.fq.gz ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001_val_2.fq.gz']
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 6.92 ms

# %%
for idx, vals in enumerate(h.grouped(fastq_full[:2], 2)):
    print(idx)
    print(vals[0])
    print(vals[1])
# Out:
# 0
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001_val_1.fq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001_val_2.fq.gz

# %%
# %%time

# we are doing it paired end
h.parrun(['slamdunk all'+
          ' -o '+res_dir+
          ' -r '+refgenome_noAlt+
          ' -b '+gene_intervals+
          ' -t 14'+
          ' -c 2'+
          ' -rl 152'+ # max-read-length = 152
          # new parameters
          ' -5 12'+
          ' -n 1'+ # reads map to multiple locations at once
          ' -m True'+ # multimapping
          ' -N '+val1.split('/')[-1].split('_R')[0]+
          ' '+val1+" "+val2
          for val1, val2 in h.grouped(fastq_full[:2], 2)], 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/genepy/genepy/utils/helper.py in parrun(cmds, cores, add)
#     298       res = subprocess.run(exe, capture_output=True, shell=True)
#     299       if res.returncode != 0:
# --> 300         raise ValueError('issue with the command: ' + str(res.stderr))
#     301       exe = ''
#     302       if len(add) != 0:
#
# ValueError: issue with the command: b'[MAIN] NextGenMap 0.5.5\n[MAIN] Startup : x64 (build Jul  3 2020 02:47:43)\n[MAIN] Starting time: 2022-01-04.00:21:10\n[CONFIG] Parameter:  --affine 0 --argos_min_score 0 --bin_size 2 --block_multiplier 2 --broken_pairs 0 --bs_cutoff 6 --bs_mapping 0 --cpu_threads 14 --dualstrand 1 --fast 0 --fast_pairing 0 --force_rlength_check 0 --format 1 --gap_extend_penalty 5 --gap_read_penalty 20 --gap_ref_penalty 20 --hard_clip 0 --keep_tags 0 --kmer 13 --kmer_min 0 --kmer_skip 2 --local 1 --match_bonus 10 --match_bonus_tc 2 --match_bonus_tt 10 --max_cmrs 2147483647 --max_equal 1 --max_insert_size 1000 --max_polya 4 --max_read_length 0 --min_identity 0.650000 --min_insert_size 0 --min_mq 0 --min_residues 0.500000 --min_score 0.000000 --mismatch_penalty 15 --mode 0 --no_progress 1 --no_unal 0 --ocl_threads 1 --output ../../data/slamseq_MYB_degraded_timecourse_v1/res/map/mr488-MV411-MYB-dTAG-VHL_48h-r2_slamdunk_mapped.sam --overwrite 1 --pair_score_cutoff 0.900000 --paired 1 --parse_all 1 --pe_delimiter / --qry1 ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001_val_1.fq.gz --qry2 ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001_val_2.fq.gz --qry_count -1 --qry_start 0 --ref ../../ref/Homo_sapiens_assembly38_ERCC92_noAlt.fasta --ref_mode -1 --rg_id 0 --rg_sm sample_0:NA:-1 --sensitive 0 --silent_clip 0 --skip_mate_check 0 --skip_save 0 --slam_seq 2 --step_count 4 --strata 0 --topn 1 --trim5 12 --update_check 0 --very_fast 0 --very_sensitive 0\n[NGM] Opening for output (SAM): ../../data/slamseq_MYB_degraded_timecourse_v1/res/map/mr488-MV411-MYB-dTAG-VHL_48h-r2_slamdunk_mapped.sam\n[SEQPROV] Reading encoded reference from ../../ref/Homo_sapiens_assembly38_ERCC92_noAlt.fasta-enc.2.ngm\n[SEQPROV] Reading 3111 Mbp from disk took 14.96s\n[PREPROCESS] Reading RefTable from ../../ref/Homo_sapiens_assembly38_ERCC92_noAlt.fasta-ht-13-2.3.ngm\n[PREPROCESS] Reading from disk took 39.86s\n[PREPROCESS] Max. k-mer frequency set so 887!\n[INPUT] Input is paired end data.\n[INPUT] Opening file ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001_val_1.fq.gz for reading\n[INPUT] Opening file ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001_val_2.fq.gz for reading\n[INPUT] Input is Fastq\n[INPUT] Estimating parameter from data\n[INPUT] Input reads don\'t have the same length!\n[INPUT] Maximum read length found in the first 10000000 reads is 138. For longer reads only the first 151 bp will be mapped.\n[INPUT] The maximum read length can be overwritten with the \'--max-read-length\' parameter. With \'--force-rlength-check\', NextGenMap will run through all reads to find the max. read length. This might take some time.\n[INPUT] Average read length: 127 (min: 8, max: 152)\n[INPUT] Corridor width: 24\n[INPUT] Average kmer hits pro read: 27.155787\n[INPUT] Max possible kmer hit: 38\n[INPUT] Estimated sensitivity: 0.714626\n[INPUT] Estimating parameter took 252.398s\n[INPUT] Input is Fastq\n[INPUT] Input is Fastq\n[OPENCL] Available platforms: 1\n[OPENCL] AMD Accelerated Parallel Processing\n[OPENCL] Selecting OpenCl platform: AMD Accelerated Parallel Processing\n[OPENCL] Platform: OpenCL 1.2 AMD-APP (1214.3)\n[OPENCL] 1 CPU device found.\n[OPENCL] Device 0: Intel(R) Xeon(R) CPU @ 3.10GHz (Driver: 1214.3 (sse2,avx))\n[OPENCL] 8 CPU cores available.\nException bad_alloc occured in thread 4. This usually means you ran out of physical or virtual memory (try ulimit -v)\nSegmentation fault\nslamdunk all\nRunning slamDunk map for 2 files (14 threads)\nTraceback (most recent call last):\n  File "/home/monika/anaconda3/envs/slamseq/bin/slamdunk", line 33, in <module>\n    sys.exit(load_entry_point(\'slamdunk\', \'console_scripts\', \'slamdunk\')())\n  File "/home/monika/slamdunk/slamdunk/slamdunk.py", line 541, in run\n    runAll(args)\n  File "/home/monika/slamdunk/slamd ...

# %%
for idx, vals in enumerate(h.grouped(fastq_full[14:18], 2)):
    print(idx)
    print(vals[0])
    print(vals[1])
# Out:
# 0
# ../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R1_001_val_1.fq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R2_001_val_2.fq.gz
# 1
# ../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz
# ../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz

# %% [markdown]
# ## Saving the data in our bucket

# %%
print(project)
# Out:
# MYB_degraded_timecourse_v1

# %%
! ls ../../data/slamseq_$project
# Out:
# fastqs	res

# %% [markdown]
# * save fastqs to bucket
# * save processed res to bucket
# * remove processed fastqs from local

# %%
! gsutil -m cp ../../data/slamseq_$project/fastqs/* gs://amlproject/RNA/slamseq/$project/fastqs/ 
! gsutil -m cp ../../data/slamseq_$project/res/map/* gs://amlproject/RNA/slamseq/$project/res/map/ 
! gsutil -m cp ../../data/slamseq_$project/res/filter/* gs://amlproject/RNA/slamseq/$project/res/filter/ 
! gsutil -m cp ../../data/slamseq_$project/res/snp/* gs://amlproject/RNA/slamseq/$project/res/snp/ 
! gsutil -m cp ../../data/slamseq_$project/res/count/* gs://amlproject/RNA/slamseq/$project/res/count/
# Out:
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr422-MV411-MYB-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr423-MV411-MYB-dTAG-DMSO_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr424-MV411-MYB-dTAG-DMSO_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr425-MV411-MYB-dTAG-DMSO_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr426-MV411-MYB-dTAG-DMSO_1h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr427-MV411-MYB-dTAG-VHL_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr428-MV411-MYB-dTAG-VHL_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr429-MV411-MYB-dTAG-VHL_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr430-MV411-MYB-dTAG-VHL_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr431-MV411-MYB-dTAG-VHL_1h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr432-MV411-MYB-dTAG-DMSO_2h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr433-MV411-MYB-dTAG-DMSO_2h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr434-MV411-MYB-dTAG-DMSO_2h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr435-MV411-MYB-dTAG-DMSO_2h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr436-MV411-MYB-dTAG-DMSO_2h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr437-MV411-MYB-dTAG-VHL_2h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr438-MV411-MYB-dTAG-VHL_2h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr439-MV411-MYB-dTAG-VHL_2h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr440-MV411-MYB-dTAG-VHL_2h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr441-MV411-MYB-dTAG-VHL_2h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr442-MV411-MYB-dTAG-DMSO_4h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr443-MV411-MYB-dTAG-DMSO_4h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr444-MV411-MYB-dTAG-DMSO_4h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr445-MV411-MYB-dTAG-DMSO_4h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr446-MV411-MYB-dTAG-DMSO_4h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr447-MV411-MYB-dTAG-VHL_4h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr448-MV411-MYB-dTAG-VHL_4h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr449-MV411-MYB-dTAG-VHL_4h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr450-MV411-MYB-dTAG-VHL_4h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr451-MV411-MYB-dTAG-VHL_4h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr452-MV411-MYB-dTAG-DMSO_8h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr453-MV411-MYB-dTAG-DMSO_8h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr454-MV411-MYB-dTAG-DMSO_8h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr455-MV411-MYB-dTAG-DMSO_8h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr456-MV411-MYB-dTAG-DMSO_8h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr457-MV411-MYB-dTAG-VHL_8h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr458-MV411-MYB-dTAG-VHL_8h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr459-MV411-MYB-dTAG-VHL_8h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr460-MV411-MYB-dTAG-VHL_8h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr461-MV411-MYB-dTAG-VHL_8h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr463-MV411-MYB-dTAG-DMSO_12h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr464-MV411-MYB-dTAG-DMSO_12h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr465-MV411-MYB-dTAG-DMSO_12h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr466-MV411-MYB-dTAG-DMSO_12h-r5_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr467-MV411-MYB-dTAG-VHL_12h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr467-MV411-MYB-dTAG-VHL_12h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr467-MV411-MYB-dTAG-VHL_12h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr467-MV411-MYB-dTAG-VHL_12h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# - [324/560 files][755.7 GiB/  1.2 TiB]  59% Done 192.3 MiB/s ETA 00:46:27

# %% [markdown]
# ### remove processed fastq files

# %%
res_folder = "../../data/"+"slamseq_"+project+"/res"
count_files = ! ls $res_folder/count/*tsv
#count_files

# %%
processed_samples = [f.split("/")[-1].split("-")[0] for f in count_files]
#processed_samples

# %%
fastq_files = ! ls $fastq_folder
fastq_files = [fastq_folder+"/"+f for f in fastq_files]
fastqs_rm = [fastq for fastq in fastq_files if any(sample in fastq for sample in processed_samples)]
print(len(fastqs_rm)/8)
fastqs_rm
# Out:
# 2.0
# ['../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001.fastq.gz_trimming_report.txt',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001_unpaired_1.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001_val_1.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001.fastq.gz_trimming_report.txt',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001_unpaired_2.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001_val_2.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001.fastq.gz_trimming_report.txt',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001_unpaired_1.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001_val_1.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001.fastq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001.fastq.gz_trimming_report.txt',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001_unpaired_2.fq.gz',
#  '../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001_val_2.fq.gz']

# %%
for f in fastqs_rm:
    os.remove(f)

# %%
! ls $fastq_folder/*fastq.gz
# Out:
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr462-MV411-MYB-dTAG-DMSO_12h-r1_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr473-MV411-MYB-dTAG-DMSO_24h-r2_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr473-MV411-MYB-dTAG-DMSO_24h-r2_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr477-MV411-MYB-dTAG-VHL_24h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr477-MV411-MYB-dTAG-VHL_24h-r1_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr478-MV411-MYB-dTAG-VHL_24h-r2_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr478-MV411-MYB-dTAG-VHL_24h-r2_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr479-MV411-MYB-dTAG-VHL_24h-r3_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr479-MV411-MYB-dTAG-VHL_24h-r3_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr480-MV411-MYB-dTAG-VHL_24h-r4_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr480-MV411-MYB-dTAG-VHL_24h-r4_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr481-MV411-MYB-dTAG-VHL_24h-r5_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr481-MV411-MYB-dTAG-VHL_24h-r5_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr482-MV411-MYB-dTAG-DMSO_48h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr482-MV411-MYB-dTAG-DMSO_48h-r1_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr483-MV411-MYB-dTAG-DMSO_48h-r2_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr483-MV411-MYB-dTAG-DMSO_48h-r2_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr484-MV411-MYB-dTAG-DMSO_48h-r3_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr484-MV411-MYB-dTAG-DMSO_48h-r3_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr485-MV411-MYB-dTAG-DMSO_48h-r4_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr485-MV411-MYB-dTAG-DMSO_48h-r4_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr486-MV411-MYB-dTAG-DMSO_48h-r5_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr487-MV411-MYB-dTAG-VHL_48h-r1_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr488-MV411-MYB-dTAG-VHL_48h-r2_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr489-MV411-MYB-dTAG-VHL_48h-r3_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr489-MV411-MYB-dTAG-VHL_48h-r3_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr490-MV411-MYB-dTAG-VHL_48h-r4_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr490-MV411-MYB-dTAG-VHL_48h-r4_R2_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr491-MV411-MYB-dTAG-VHL_48h-r5_R1_001.fastq.gz
# ../../data/slamseq_MYB_degraded_timecourse_v1/fastqs/mr491-MV411-MYB-dTAG-VHL_48h-r5_R2_001.fastq.gz

# %% [markdown]
# ## Recreate RNA matrix from slamdunk's tcount files

# %% [markdown]
# #### Getting counts over ERCC genome

# %%
processed_samples
# Out:
# ['mr422',
#  'mr423',
#  'mr424',
#  'mr425',
#  'mr426',
#  'mr427',
#  'mr428',
#  'mr429',
#  'mr430',
#  'mr431',
#  'mr432',
#  'mr433',
#  'mr434',
#  'mr435',
#  'mr436',
#  'mr437',
#  'mr438',
#  'mr439',
#  'mr440',
#  'mr441',
#  'mr442',
#  'mr443',
#  'mr444',
#  'mr445',
#  'mr446',
#  'mr447',
#  'mr448',
#  'mr449',
#  'mr450',
#  'mr451',
#  'mr452',
#  'mr453',
#  'mr454',
#  'mr455',
#  'mr456',
#  'mr457',
#  'mr458',
#  'mr459',
#  'mr460',
#  'mr461',
#  'mr462',
#  'mr463',
#  'mr464',
#  'mr465',
#  'mr466',
#  'mr467',
#  'mr468',
#  'mr469',
#  'mr470',
#  'mr471',
#  'mr472',
#  'mr473',
#  'mr474',
#  'mr475',
#  'mr476',
#  'mr477',
#  'mr478',
#  'mr479',
#  'mr480',
#  'mr481',
#  'mr482',
#  'mr483',
#  'mr484',
#  'mr485',
#  'mr486',
#  'mr487']

# %%
counts = {}
folder = "../../data/slamseq_"+project+"/res/filter"
files = ! ls $folder/mr*.bam
files = [os.path.basename(f) for f in files]

# %%
print(len(files))
files
# Out:
# 70
# ['mr422-MV411-MYB-dTAG-DMSO_1h-r1_filtered.bam',
#  'mr423-MV411-MYB-dTAG-DMSO_1h-r2_filtered.bam',
#  'mr424-MV411-MYB-dTAG-DMSO_1h-r3_filtered.bam',
#  'mr425-MV411-MYB-dTAG-DMSO_1h-r4_filtered.bam',
#  'mr426-MV411-MYB-dTAG-DMSO_1h-r5_filtered.bam',
#  'mr427-MV411-MYB-dTAG-VHL_1h-r1_filtered.bam',
#  'mr428-MV411-MYB-dTAG-VHL_1h-r2_filtered.bam',
#  'mr429-MV411-MYB-dTAG-VHL_1h-r3_filtered.bam',
#  'mr430-MV411-MYB-dTAG-VHL_1h-r4_filtered.bam',
#  'mr431-MV411-MYB-dTAG-VHL_1h-r5_filtered.bam',
#  'mr432-MV411-MYB-dTAG-DMSO_2h-r1_filtered.bam',
#  'mr433-MV411-MYB-dTAG-DMSO_2h-r2_filtered.bam',
#  'mr434-MV411-MYB-dTAG-DMSO_2h-r3_filtered.bam',
#  'mr435-MV411-MYB-dTAG-DMSO_2h-r4_filtered.bam',
#  'mr436-MV411-MYB-dTAG-DMSO_2h-r5_filtered.bam',
#  'mr437-MV411-MYB-dTAG-VHL_2h-r1_filtered.bam',
#  'mr438-MV411-MYB-dTAG-VHL_2h-r2_filtered.bam',
#  'mr439-MV411-MYB-dTAG-VHL_2h-r3_filtered.bam',
#  'mr440-MV411-MYB-dTAG-VHL_2h-r4_filtered.bam',
#  'mr441-MV411-MYB-dTAG-VHL_2h-r5_filtered.bam',
#  'mr442-MV411-MYB-dTAG-DMSO_4h-r1_filtered.bam',
#  'mr443-MV411-MYB-dTAG-DMSO_4h-r2_filtered.bam',
#  'mr444-MV411-MYB-dTAG-DMSO_4h-r3_filtered.bam',
#  'mr445-MV411-MYB-dTAG-DMSO_4h-r4_filtered.bam',
#  'mr446-MV411-MYB-dTAG-DMSO_4h-r5_filtered.bam',
#  'mr447-MV411-MYB-dTAG-VHL_4h-r1_filtered.bam',
#  'mr448-MV411-MYB-dTAG-VHL_4h-r2_filtered.bam',
#  'mr449-MV411-MYB-dTAG-VHL_4h-r3_filtered.bam',
#  'mr450-MV411-MYB-dTAG-VHL_4h-r4_filtered.bam',
#  'mr451-MV411-MYB-dTAG-VHL_4h-r5_filtered.bam',
#  'mr452-MV411-MYB-dTAG-DMSO_8h-r1_filtered.bam',
#  'mr453-MV411-MYB-dTAG-DMSO_8h-r2_filtered.bam',
#  'mr454-MV411-MYB-dTAG-DMSO_8h-r3_filtered.bam',
#  'mr455-MV411-MYB-dTAG-DMSO_8h-r4_filtered.bam',
#  'mr456-MV411-MYB-dTAG-DMSO_8h-r5_filtered.bam',
#  'mr457-MV411-MYB-dTAG-VHL_8h-r1_filtered.bam',
#  'mr458-MV411-MYB-dTAG-VHL_8h-r2_filtered.bam',
#  'mr459-MV411-MYB-dTAG-VHL_8h-r3_filtered.bam',
#  'mr460-MV411-MYB-dTAG-VHL_8h-r4_filtered.bam',
#  'mr461-MV411-MYB-dTAG-VHL_8h-r5_filtered.bam',
#  'mr462-MV411-MYB-dTAG-DMSO_12h-r1_filtered.bam',
#  'mr463-MV411-MYB-dTAG-DMSO_12h-r2_filtered.bam',
#  'mr464-MV411-MYB-dTAG-DMSO_12h-r3_filtered.bam',
#  'mr465-MV411-MYB-dTAG-DMSO_12h-r4_filtered.bam',
#  'mr466-MV411-MYB-dTAG-DMSO_12h-r5_filtered.bam',
#  'mr467-MV411-MYB-dTAG-VHL_12h-r1_filtered.bam',
#  'mr468-MV411-MYB-dTAG-VHL_12h-r2_filtered.bam',
#  'mr469-MV411-MYB-dTAG-VHL_12h-r3_filtered.bam',
#  'mr470-MV411-MYB-dTAG-VHL_12h-r4_filtered.bam',
#  'mr471-MV411-MYB-dTAG-VHL_12h-r5_filtered.bam',
#  'mr472-MV411-MYB-dTAG-DMSO_24h-r1_filtered.bam',
#  'mr473-MV411-MYB-dTAG-DMSO_24h-r2_filtered.bam',
#  'mr474-MV411-MYB-dTAG-DMSO_24h-r3_filtered.bam',
#  'mr475-MV411-MYB-dTAG-DMSO_24h-r4_filtered.bam',
#  'mr476-MV411-MYB-dTAG-DMSO_24h-r5_filtered.bam',
#  'mr477-MV411-MYB-dTAG-VHL_24h-r1_filtered.bam',
#  'mr478-MV411-MYB-dTAG-VHL_24h-r2_filtered.bam',
#  'mr479-MV411-MYB-dTAG-VHL_24h-r3_filtered.bam',
#  'mr480-MV411-MYB-dTAG-VHL_24h-r4_filtered.bam',
#  'mr481-MV411-MYB-dTAG-VHL_24h-r5_filtered.bam',
#  'mr482-MV411-MYB-dTAG-DMSO_48h-r1_filtered.bam',
#  'mr483-MV411-MYB-dTAG-DMSO_48h-r2_filtered.bam',
#  'mr484-MV411-MYB-dTAG-DMSO_48h-r3_filtered.bam',
#  'mr485-MV411-MYB-dTAG-DMSO_48h-r4_filtered.bam',
#  'mr486-MV411-MYB-dTAG-DMSO_48h-r5_filtered.bam',
#  'mr487-MV411-MYB-dTAG-VHL_48h-r1_filtered.bam',
#  'mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam',
#  'mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam',
#  'mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam',
#  'mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam']

# %%
specified_regions = " ERCC-00002 ERCC-00003 ERCC-00004 ERCC-00009 ERCC-00012 ERCC-00013 ERCC-00014 ERCC-00016 ERCC-00017 ERCC-00019 ERCC-00022 ERCC-00024 ERCC-00025 ERCC-00028 ERCC-00031 ERCC-00033 ERCC-00034 ERCC-00035 ERCC-00039 ERCC-00040 ERCC-00041 ERCC-00042 ERCC-00043 ERCC-00044 ERCC-00046 ERCC-00048 ERCC-00051 ERCC-00053 ERCC-00054 ERCC-00057 ERCC-00058 ERCC-00059 ERCC-00060 ERCC-00061 ERCC-00062 ERCC-00067 ERCC-00069 ERCC-00071 ERCC-00073 ERCC-00074 ERCC-00075 ERCC-00076 ERCC-00077 ERCC-00078 ERCC-00079 ERCC-00081 ERCC-00083 ERCC-00084 ERCC-00085 ERCC-00086 ERCC-00092 ERCC-00095 ERCC-00096 ERCC-00097 ERCC-00098 ERCC-00099 ERCC-00104 ERCC-00108 ERCC-00109 ERCC-00111 ERCC-00112 ERCC-00113 ERCC-00116 ERCC-00117 ERCC-00120 ERCC-00123 ERCC-00126 ERCC-00130 ERCC-00131 ERCC-00134 ERCC-00136 ERCC-00137 ERCC-00138 ERCC-00142 ERCC-00143 ERCC-00144 ERCC-00145 ERCC-00147 ERCC-00148 ERCC-00150 ERCC-00154 ERCC-00156 ERCC-00157 ERCC-00158 ERCC-00160 ERCC-00162 ERCC-00163 ERCC-00164 ERCC-00165 ERCC-00168 ERCC-00170 ERCC-00171 > "

# %%
print(["samtools view -hb "+folder+"/"+f+specified_regions+folder+"/ERCC_"+f for f in files][0])
# Out:
# samtools view -hb ../../data/slamseq_MYB_degraded_timecourse_v1/res/filter/mr422-MV411-MYB-dTAG-DMSO_1h-r1_filtered.bam ERCC-00002 ERCC-00003 ERCC-00004 ERCC-00009 ERCC-00012 ERCC-00013 ERCC-00014 ERCC-00016 ERCC-00017 ERCC-00019 ERCC-00022 ERCC-00024 ERCC-00025 ERCC-00028 ERCC-00031 ERCC-00033 ERCC-00034 ERCC-00035 ERCC-00039 ERCC-00040 ERCC-00041 ERCC-00042 ERCC-00043 ERCC-00044 ERCC-00046 ERCC-00048 ERCC-00051 ERCC-00053 ERCC-00054 ERCC-00057 ERCC-00058 ERCC-00059 ERCC-00060 ERCC-00061 ERCC-00062 ERCC-00067 ERCC-00069 ERCC-00071 ERCC-00073 ERCC-00074 ERCC-00075 ERCC-00076 ERCC-00077 ERCC-00078 ERCC-00079 ERCC-00081 ERCC-00083 ERCC-00084 ERCC-00085 ERCC-00086 ERCC-00092 ERCC-00095 ERCC-00096 ERCC-00097 ERCC-00098 ERCC-00099 ERCC-00104 ERCC-00108 ERCC-00109 ERCC-00111 ERCC-00112 ERCC-00113 ERCC-00116 ERCC-00117 ERCC-00120 ERCC-00123 ERCC-00126 ERCC-00130 ERCC-00131 ERCC-00134 ERCC-00136 ERCC-00137 ERCC-00138 ERCC-00142 ERCC-00143 ERCC-00144 ERCC-00145 ERCC-00147 ERCC-00148 ERCC-00150 ERCC-00154 ERCC-00156 ERCC-00157 ERCC-00158 ERCC-00160 ERCC-00162 ERCC-00163 ERCC-00164 ERCC-00165 ERCC-00168 ERCC-00170 ERCC-00171 > ../../data/slamseq_MYB_degraded_timecourse_v1/res/filter/ERCC_mr422-MV411-MYB-dTAG-DMSO_1h-r1_filtered.bam

# %%
# bam with alignments overlpping over ERCC regions
h.parrun(["samtools view -hb "+folder+"/"+f+specified_regions+folder+"/ERCC_"+f for f in files], cores=10)
# Out:
# ['']

# %%
# compute histogram , per-base reports, & bedgraph summaries of feature coverage
# computes coverage over ERCC genes --> # of transcripts mapped to each gene as bed
h.parrun(["bedtools genomecov -ibam "+folder+"/ERCC_"+f+" > "+folder+"/ERCC_"+f+".bed" for f in files], cores=10)
# Out:
# ['']

# %%
# ERCC files
files = ! ls $folder/ERCC*.bam
files = [file.split('/')[-1] for file in files if "ERCC" in file if file.endswith(".bam")]
print(len(files))
# Out:
# 70

# %%
ERCC = ["ERCC-00002", "ERCC-00003", "ERCC-00004", "ERCC-00009", "ERCC-00012", "ERCC-00013", 
        "ERCC-00014", "ERCC-00016", "ERCC-00017", "ERCC-00019", "ERCC-00022", "ERCC-00024", 
        "ERCC-00025", "ERCC-00028", "ERCC-00031", "ERCC-00033", "ERCC-00034", "ERCC-00035", 
        "ERCC-00039", "ERCC-00040", "ERCC-00041", "ERCC-00042", "ERCC-00043", "ERCC-00044", 
        "ERCC-00046", "ERCC-00048", "ERCC-00051", "ERCC-00053", "ERCC-00054", "ERCC-00057", 
        "ERCC-00058", "ERCC-00059", "ERCC-00060", "ERCC-00061", "ERCC-00062", "ERCC-00067", 
        "ERCC-00069", "ERCC-00071", "ERCC-00073", "ERCC-00074", "ERCC-00075", "ERCC-00076", 
        "ERCC-00077", "ERCC-00078", "ERCC-00079", "ERCC-00081", "ERCC-00083", "ERCC-00084", 
        "ERCC-00085", "ERCC-00086", "ERCC-00092", "ERCC-00095", "ERCC-00096", "ERCC-00097", 
        "ERCC-00098", "ERCC-00099", "ERCC-00104", "ERCC-00108", "ERCC-00109", "ERCC-00111", 
        "ERCC-00112", "ERCC-00113", "ERCC-00116", "ERCC-00117", "ERCC-00120", "ERCC-00123", 
        "ERCC-00126", "ERCC-00130", "ERCC-00131", "ERCC-00134", "ERCC-00136", "ERCC-00137", 
        "ERCC-00138", "ERCC-00142", "ERCC-00143", "ERCC-00144", "ERCC-00145", "ERCC-00147", 
        "ERCC-00148", "ERCC-00150", "ERCC-00154", "ERCC-00156", "ERCC-00157", "ERCC-00158", 
        "ERCC-00160", "ERCC-00162", "ERCC-00163", "ERCC-00164", "ERCC-00165", "ERCC-00168", 
        "ERCC-00170", "ERCC-00171"]

# parse ERCC bed files
res  = {i:[] for i in files}
for val in files:
    cov = pd.read_csv(folder+"/"+val+'.bed',sep="\t",header=None)
    for i in ERCC:
        res[val].append(cov[cov[0]==i][1].mean())
df = pd.DataFrame(data=res,index=ERCC)

# %%
print(df.shape)
df.iloc[:2]
# Out:
# (92, 70)
#             ERCC_mr422-MV411-MYB-dTAG-DMSO_1h-r1_filtered.bam  \
# ERCC-00002                                      122572.803588
# ERCC-00003                                        6559.649269
#
#             ERCC_mr423-MV411-MYB-dTAG-DMSO_1h-r2_filtered.bam  \
# ERCC-00002                                       67656.573055
# ERCC-00003                                        7918.157556
#
#             ERCC_mr424-MV411-MYB-dTAG-DMSO_1h-r3_filtered.bam  \
# ERCC-00002                                       41558.030651
# ERCC-00003                                        6193.680355
#
#             ERCC_mr425-MV411-MYB-dTAG-DMSO_1h-r4_filtered.bam  \
# ERCC-00002                                       65857.432665
# ERCC-00003                                        8698.617137
#
#             ERCC_mr426-MV411-MYB-dTAG-DMSO_1h-r5_filtered.bam  \
# ERCC-00002                                       69843.702006
# ERCC-00003                                        3101.840462
#
#             ERCC_mr427-MV411-MYB-dTAG-VHL_1h-r1_filtered.bam  \
# ERCC-00002                                      69844.390935
# ERCC-00003                                       8623.391396
#
#             ERCC_mr428-MV411-MYB-dTAG-VHL_1h-r2_filtered.bam  \
# ERCC-00002                                      53019.687081
# ERCC-00003                                       6366.311351
#
#             ERCC_mr429-MV411-MYB-dTAG-VHL_1h-r3_filtered.bam  \
# ERCC-00002                                      50770.557765
# ERCC-00003                                       6466.630482
#
#             ERCC_mr430-MV411-MYB-dTAG-VHL_1h-r4_filtered.bam  \
# ERCC-00002                                      49085.677512
# ERCC-00003                                      10283.150104
#
#             ERCC_mr431-MV411-MYB-dTAG-VHL_1h-r5_filtered.bam  ...  \
# ERCC-00002                                      63219.761321  ...
# ERCC-00003                                       9181.832305  ...
#
#             ERCC_mr482-MV411-MYB-dTAG-DMSO_48h-r1_filtered.bam  \
# ERCC-00002                                       37527.046980
# ERCC-00003                                        4867.179596
#
#             ERCC_mr483-MV411-MYB-dTAG-DMSO_48h-r2_filtered.bam  \
# ERCC-00002                                       53694.797336
# ERCC-00003                                        6072.724249
#
#             ERCC_mr484-MV411-MYB-dTAG-DMSO_48h-r3_filtered.bam  \
# ERCC-00002                                       70201.029328
# ERCC-00003                                        9376.305846
#
#             ERCC_mr485-MV411-MYB-dTAG-DMSO_48h-r4_filtered.bam  \
# ERCC-00002                                       75287.464962
# ERCC-00003                                       11020.295908
#
#             ERCC_mr486-MV411-MYB-dTAG-DMSO_48h-r5_filtered.bam  \
# ERCC-00002                                       69775.222222
# ERCC-00003                                        7490.901814
#
#             ERCC_mr487-MV411-MYB-dTAG-VHL_48h-r1_filtered.bam  \
# ERCC-00002                                       84137.574163
# ERCC-00003                                        4754.146214
#
#             ERCC_mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam  \
# ERCC-00002                                       66356.807436
# ERCC-00003                                        7505.032874
#
#             ERCC_mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam  \
# ERCC-00002                                       68948.090562
# ERCC-00003                                        8658.450311
#
#             ERCC_mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam  \
# ERCC-00002                                      122103.651515
# ERCC-00003                                        7056.246604
#
#             ERCC_mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam
# ERCC-00002                                       79835.806851
# ERCC-00003                                       11663.359053
#
# [2 rows x 70 columns]

# %% [markdown]
# __fill in project manually__

# %%
project
# Out:
# 'MYB_degraded_timecourse_v1'

# %%
print(df.shape)
print(len(totalcounts))
# Out:
# (92, 70)
# 66

# %%
# (fill in project manually) same as previous run w/o -rl
totalcounts = ! for unkn in $(ls ../../data/slamseq_MYB_degraded_timecourse_v1/res/filter/mr*.bam); do samtools view -c -F 260 $unkn; done
totalcounts = [int(i) for i in totalcounts]
totalcounts
# Out:
# [137152109,
#  93261178,
#  97444672,
#  122572181,
#  105215946,
#  104909946,
#  89075359,
#  93219900,
#  150028335,
#  149801690,
#  159666958,
#  132429330,
#  144385166,
#  108186184,
#  148852250,
#  120314500,
#  110258002,
#  133151015,
#  172235750,
#  105623322,
#  121341764,
#  135340703,
#  156259711,
#  125868381,
#  78537220,
#  68757766,
#  84965233,
#  68456370,
#  86390206,
#  93792109,
#  83129777,
#  76553088,
#  88980497,
#  73228189,
#  77153151,
#  87748263,
#  91648022,
#  78412313,
#  95487125,
#  91473587,
#  67302716,
#  53182104,
#  70395994,
#  46132697,
#  68017882,
#  61631172,
#  89518128,
#  83892306,
#  123508211,
#  128955573,
#  63403714,
#  114520397,
#  83115572,
#  108012427,
#  97382899,
#  118508860,
#  101496873,
#  92873451,
#  125678618,
#  125981361,
#  59935828,
#  97551198,
#  130139413,
#  162867831,
#  124432831,
#  65186460]

# %%
samples = ! ls ../../data/slamseq_MYB_degraded_timecourse_v1/res/filter/mr*.bam
samples = [os.path.basename(sample) for sample in samples]
samples = [sample.split("_filtered.bam")[0] for sample in samples]
print(len(samples))
samples
# Out:
# 70
# ['mr422-MV411-MYB-dTAG-DMSO_1h-r1',
#  'mr423-MV411-MYB-dTAG-DMSO_1h-r2',
#  'mr424-MV411-MYB-dTAG-DMSO_1h-r3',
#  'mr425-MV411-MYB-dTAG-DMSO_1h-r4',
#  'mr426-MV411-MYB-dTAG-DMSO_1h-r5',
#  'mr427-MV411-MYB-dTAG-VHL_1h-r1',
#  'mr428-MV411-MYB-dTAG-VHL_1h-r2',
#  'mr429-MV411-MYB-dTAG-VHL_1h-r3',
#  'mr430-MV411-MYB-dTAG-VHL_1h-r4',
#  'mr431-MV411-MYB-dTAG-VHL_1h-r5',
#  'mr432-MV411-MYB-dTAG-DMSO_2h-r1',
#  'mr433-MV411-MYB-dTAG-DMSO_2h-r2',
#  'mr434-MV411-MYB-dTAG-DMSO_2h-r3',
#  'mr435-MV411-MYB-dTAG-DMSO_2h-r4',
#  'mr436-MV411-MYB-dTAG-DMSO_2h-r5',
#  'mr437-MV411-MYB-dTAG-VHL_2h-r1',
#  'mr438-MV411-MYB-dTAG-VHL_2h-r2',
#  'mr439-MV411-MYB-dTAG-VHL_2h-r3',
#  'mr440-MV411-MYB-dTAG-VHL_2h-r4',
#  'mr441-MV411-MYB-dTAG-VHL_2h-r5',
#  'mr442-MV411-MYB-dTAG-DMSO_4h-r1',
#  'mr443-MV411-MYB-dTAG-DMSO_4h-r2',
#  'mr444-MV411-MYB-dTAG-DMSO_4h-r3',
#  'mr445-MV411-MYB-dTAG-DMSO_4h-r4',
#  'mr446-MV411-MYB-dTAG-DMSO_4h-r5',
#  'mr447-MV411-MYB-dTAG-VHL_4h-r1',
#  'mr448-MV411-MYB-dTAG-VHL_4h-r2',
#  'mr449-MV411-MYB-dTAG-VHL_4h-r3',
#  'mr450-MV411-MYB-dTAG-VHL_4h-r4',
#  'mr451-MV411-MYB-dTAG-VHL_4h-r5',
#  'mr452-MV411-MYB-dTAG-DMSO_8h-r1',
#  'mr453-MV411-MYB-dTAG-DMSO_8h-r2',
#  'mr454-MV411-MYB-dTAG-DMSO_8h-r3',
#  'mr455-MV411-MYB-dTAG-DMSO_8h-r4',
#  'mr456-MV411-MYB-dTAG-DMSO_8h-r5',
#  'mr457-MV411-MYB-dTAG-VHL_8h-r1',
#  'mr458-MV411-MYB-dTAG-VHL_8h-r2',
#  'mr459-MV411-MYB-dTAG-VHL_8h-r3',
#  'mr460-MV411-MYB-dTAG-VHL_8h-r4',
#  'mr461-MV411-MYB-dTAG-VHL_8h-r5',
#  'mr462-MV411-MYB-dTAG-DMSO_12h-r1',
#  'mr463-MV411-MYB-dTAG-DMSO_12h-r2',
#  'mr464-MV411-MYB-dTAG-DMSO_12h-r3',
#  'mr465-MV411-MYB-dTAG-DMSO_12h-r4',
#  'mr466-MV411-MYB-dTAG-DMSO_12h-r5',
#  'mr467-MV411-MYB-dTAG-VHL_12h-r1',
#  'mr468-MV411-MYB-dTAG-VHL_12h-r2',
#  'mr469-MV411-MYB-dTAG-VHL_12h-r3',
#  'mr470-MV411-MYB-dTAG-VHL_12h-r4',
#  'mr471-MV411-MYB-dTAG-VHL_12h-r5',
#  'mr472-MV411-MYB-dTAG-DMSO_24h-r1',
#  'mr473-MV411-MYB-dTAG-DMSO_24h-r2',
#  'mr474-MV411-MYB-dTAG-DMSO_24h-r3',
#  'mr475-MV411-MYB-dTAG-DMSO_24h-r4',
#  'mr476-MV411-MYB-dTAG-DMSO_24h-r5',
#  'mr477-MV411-MYB-dTAG-VHL_24h-r1',
#  'mr478-MV411-MYB-dTAG-VHL_24h-r2',
#  'mr479-MV411-MYB-dTAG-VHL_24h-r3',
#  'mr480-MV411-MYB-dTAG-VHL_24h-r4',
#  'mr481-MV411-MYB-dTAG-VHL_24h-r5',
#  'mr482-MV411-MYB-dTAG-DMSO_48h-r1',
#  'mr483-MV411-MYB-dTAG-DMSO_48h-r2',
#  'mr484-MV411-MYB-dTAG-DMSO_48h-r3',
#  'mr485-MV411-MYB-dTAG-DMSO_48h-r4',
#  'mr486-MV411-MYB-dTAG-DMSO_48h-r5',
#  'mr487-MV411-MYB-dTAG-VHL_48h-r1',
#  'mr488-MV411-MYB-dTAG-VHL_48h-r2',
#  'mr489-MV411-MYB-dTAG-VHL_48h-r3',
#  'mr490-MV411-MYB-dTAG-VHL_48h-r4',
#  'mr491-MV411-MYB-dTAG-VHL_48h-r5']

# %% [markdown]
# __add newly processed samples__

# %%
folder = "../../data/slamseq_"+project+"/res/filter"
filt_files = ! ls $folder/mr*.bam
filt_files = [os.path.basename(f) for f in filt_files]
filt_files = [f for f in filt_files if not any(sample in f for sample in totalcounts_csv.index.tolist())]
filt_files
# Out:
# ['mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam',
#  'mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam',
#  'mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam',
#  'mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam']

# %%
totalcounts_new = []
for f in filt_files:
    print(f)
    counts = ! samtools view -c -F 260 ../../data/slamseq_MYB_degraded_timecourse_v1/res/filter/{f}
    print(counts)
    totalcounts_new.append(counts)
# Out:
# mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam
# ['93657330']
# mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam
# ['66727322']
# mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam
# ['97487052']
# mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam
# ['101781948']

# %%
#totalcounts_new = [int(i[0]) for i in totalcounts_new]
print(totalcounts_new)
pd.Series(totalcounts_new, index=[i.split("_f")[0] for i in filt_files])
# Out:
# [93657330, 66727322, 97487052, 101781948]
# mr488-MV411-MYB-dTAG-VHL_48h-r2     93657330
# mr489-MV411-MYB-dTAG-VHL_48h-r3     66727322
# mr490-MV411-MYB-dTAG-VHL_48h-r4     97487052
# mr491-MV411-MYB-dTAG-VHL_48h-r5    101781948
# dtype: int64

# %%
# add new counts to totalcounts_csv series
totalcounts_csv = totalcounts_csv.append(pd.Series(totalcounts_new, index=[i.split("_f")[0] for i in filt_files]))

# %%
totalcounts_csv
# Out:
# mr422-MV411-MYB-dTAG-DMSO_1h-r1    137152109
# mr423-MV411-MYB-dTAG-DMSO_1h-r2     93261178
# mr424-MV411-MYB-dTAG-DMSO_1h-r3     97444672
# mr425-MV411-MYB-dTAG-DMSO_1h-r4    122572181
# mr426-MV411-MYB-dTAG-DMSO_1h-r5    105215946
#                                      ...
# mr487-MV411-MYB-dTAG-VHL_48h-r1     65186460
# mr488-MV411-MYB-dTAG-VHL_48h-r2     93657330
# mr489-MV411-MYB-dTAG-VHL_48h-r3     66727322
# mr490-MV411-MYB-dTAG-VHL_48h-r4     97487052
# mr491-MV411-MYB-dTAG-VHL_48h-r5    101781948
# Length: 70, dtype: int64

# %%
# save total counts
totalcounts_csv.to_csv("../results/slamseq_"+project+"/"+project+"_totalcounts.csv", header=False)

# %%
print(len(totalcounts))
totalcounts.extend(totalcounts_new)
print(len(totalcounts))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4049/61102743.py in <module>
#       1 len(totalcounts)
# ----> 2 len(totalcounts.extend(totalcounts_new))
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# calc pseudocounts / scaling factors

# %%
# column avg * 10,000 / total column counts
res = 10000*df.mean()/totalcounts

# %%
res
# Out:
# ERCC_mr422-MV411-MYB-dTAG-DMSO_1h-r1_filtered.bam    0.420881
# ERCC_mr423-MV411-MYB-dTAG-DMSO_1h-r2_filtered.bam    0.411434
# ERCC_mr424-MV411-MYB-dTAG-DMSO_1h-r3_filtered.bam    0.242111
# ERCC_mr425-MV411-MYB-dTAG-DMSO_1h-r4_filtered.bam    0.289384
# ERCC_mr426-MV411-MYB-dTAG-DMSO_1h-r5_filtered.bam    0.264057
#                                                        ...
# ERCC_mr487-MV411-MYB-dTAG-VHL_48h-r1_filtered.bam    0.719177
# ERCC_mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam    0.351553
# ERCC_mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam    0.581743
# ERCC_mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam    0.540469
# ERCC_mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam    0.445321
# Length: 70, dtype: float64

# %%
# save ERCC pseudocounts
res_dir = "../results/slamseq_"+project+"/"
createDir(res_dir+"/plots/")
res.to_csv(res_dir+project+"_scaling_factors.csv", header=False)

# %% [markdown]
# #### Calc ERCC scaling factors

# %%
from natsort import natsorted, ns
from collections import Counter

# %%
# replicates per condition
reps = [r.split("MV411-")[1].split("-r")[0] for r in res.keys()]

#print(list(Counter(reps).keys()))
#print(list(Counter(reps).values()))
#print("\n")

prev=0
r={}
# get mean and variance of replicates per condition
for val in list(Counter(reps).values()):
    print(res.keys()[prev].split("MV411-")[1].split("-r")[0]+": "+
          str([np.mean(res[prev:prev+val]), np.var(res[prev:prev+val])**(1/2)]))
    r[res.keys()[prev].split("MV411-")[1].split("-r")[0]]=\
    [np.mean(res[prev:prev+val]), np.var(res[prev:prev+val])**(1/2)]
    prev+=val
# Out:
# MYB-dTAG-DMSO_1h: [0.325573436198936, 0.07551892553370528]
# MYB-dTAG-VHL_1h: [0.28893708112717464, 0.05935233259050325]
# MYB-dTAG-DMSO_2h: [0.2645460906464753, 0.04340368938038078]
# MYB-dTAG-VHL_2h: [0.2677970005646301, 0.02502444305005462]
# MYB-dTAG-DMSO_4h: [0.26710523388320373, 0.038351839271311645]
# MYB-dTAG-VHL_4h: [0.25765281155205527, 0.016196726952362777]
# MYB-dTAG-DMSO_8h: [0.22924003265719434, 0.023660321359132336]
# MYB-dTAG-VHL_8h: [0.24133586577528116, 0.01050472376480384]
# MYB-dTAG-DMSO_12h: [0.2488113927895422, 0.052244377738582454]
# MYB-dTAG-VHL_12h: [0.25372589661784994, 0.04426070431981371]
# MYB-dTAG-DMSO_24h: [0.15661760782261827, 0.01597283882166509]
# MYB-dTAG-VHL_24h: [0.19612878973855677, 0.020195036231909904]
# MYB-dTAG-DMSO_48h: [0.29591411206266854, 0.03483194062727635]
# MYB-dTAG-VHL_48h: [0.5276524774668248, 0.12454802195044304]

# %%
print(np.quantile(res.tolist(), [0,0.25,0.5,0.75,1]))
plt.plot(range(1, len(res)+1), sorted(res.tolist()), '-ok')
# Out:
# [0.13247655 0.21925637 0.25331272 0.28729426 0.71917666]

# %%
# df of DMSO vs VHL for each condition
d=pd.DataFrame(data=r.values(), index=r.keys(), columns=['ERCC pseudo-counts','var'])
d['Experiments']=d.index
d
# Out:
#                    ERCC pseudo-counts       var        Experiments
# MYB-dTAG-DMSO_1h             0.325573  0.075519   MYB-dTAG-DMSO_1h
# MYB-dTAG-VHL_1h              0.288937  0.059352    MYB-dTAG-VHL_1h
# MYB-dTAG-DMSO_2h             0.264546  0.043404   MYB-dTAG-DMSO_2h
# MYB-dTAG-VHL_2h              0.267797  0.025024    MYB-dTAG-VHL_2h
# MYB-dTAG-DMSO_4h             0.267105  0.038352   MYB-dTAG-DMSO_4h
# MYB-dTAG-VHL_4h              0.257653  0.016197    MYB-dTAG-VHL_4h
# MYB-dTAG-DMSO_8h             0.229240  0.023660   MYB-dTAG-DMSO_8h
# MYB-dTAG-VHL_8h              0.241336  0.010505    MYB-dTAG-VHL_8h
# MYB-dTAG-DMSO_12h            0.248811  0.052244  MYB-dTAG-DMSO_12h
# MYB-dTAG-VHL_12h             0.253726  0.044261   MYB-dTAG-VHL_12h
# MYB-dTAG-DMSO_24h            0.156618  0.015973  MYB-dTAG-DMSO_24h
# MYB-dTAG-VHL_24h             0.196129  0.020195   MYB-dTAG-VHL_24h
# MYB-dTAG-DMSO_48h            0.295914  0.034832  MYB-dTAG-DMSO_48h
# MYB-dTAG-VHL_48h             0.527652  0.124548   MYB-dTAG-VHL_48h

# %%
# add time condition to df
time_cond = [x.split("_")[-1] for x in r.keys()]
d['time'] = time_cond

# add treatment to df
treatment = ["DMSO" if "DMSO" in x else "VHL" for x in r.keys()]
d["treatment"] = treatment

# %% [markdown]
# ERCC scaling factors
# * VHL vs DMSO should be different
# * protein level in VHL < DMSO: more ERCC transcripts in VHL than DMSO (less RNA transcripts)
# * scaling factors: VHL > DMSO - ERCC counts/scaling factors in VHL should be higher

# %%
version = project.replace("_", " ").split(" ")[-1]
print(version)
createDir(res_dir+"/plots/")

# barplot of DMSO vs VHL for each condition
sns.barplot(x="Experiments", y="ERCC pseudo-counts", data=d, ci=None, )
plt.errorbar(x=range(0,len(d)), y=d['ERCC pseudo-counts'],
             yerr=d['var'], fmt='none', ecolor="black")
plt.xticks(rotation=60, ha='right')
plt.title(project.replace("_", " ").split(" v")[0])

plt.savefig(res_dir+"plots/"+project+"_scaling_fact_with_conf.pdf", bbox_inches="tight")
plt.show()
print("Saved to "+res_dir+"plots/"+project+"_scaling_fact_with_conf.pdf")
# Out:
# v1
# Creating output directory: ../results/slamseq_MYB_degraded_timecourse_v1//plots/
# Saved to ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_scaling_fact_with_conf.pdf

# %%
def grouped_barplot(project, df, cat, subcat, val , err, save_file = None):
    'plot and save barchart grouped by time & colored by treatment'
    u = df[cat].unique()
    x = np.arange(len(u))
    subx = df[subcat].unique()
    offsets = (np.arange(len(subx))-np.arange(len(subx)).mean())/(len(subx)+1.)
    width= np.diff(offsets).mean()
    for i,gr in enumerate(subx):
        dfg = df[df[subcat] == gr]
        plt.bar(x+offsets[i], dfg[val].values, width=width, 
                label="{}".format(gr), yerr=dfg[err].values)
    plt.xlabel(cat)
    plt.ylabel(val)
    plt.xticks(x, u)
    plt.title(project.replace("_", " ").split(" v")[0])
    plt.legend(title=subcat, loc="center left", bbox_to_anchor=(1.0, 0.5))
    
    if save_file is not None:
        plt.savefig(save_file, bbox_inches="tight")
        print("Saving to "+save_file)
        
    plt.show()

# %%
grouped_barplot(project, d, "time", "treatment", "ERCC pseudo-counts", "var", 
                save_file = res_dir+"plots/"+project+"_scaling_fact_with_conf_grouped.pdf")
# Out:
# Saving to ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_scaling_fact_with_conf_grouped.pdf

# %% [markdown]
# __save average ERCC scaling factors__

# %%
d
# Out:
#                    ERCC pseudo-counts       var        Experiments time  \
# MYB-dTAG-DMSO_1h             0.325573  0.075519   MYB-dTAG-DMSO_1h   1h
# MYB-dTAG-VHL_1h              0.288937  0.059352    MYB-dTAG-VHL_1h   1h
# MYB-dTAG-DMSO_2h             0.264546  0.043404   MYB-dTAG-DMSO_2h   2h
# MYB-dTAG-VHL_2h              0.267797  0.025024    MYB-dTAG-VHL_2h   2h
# MYB-dTAG-DMSO_4h             0.267105  0.038352   MYB-dTAG-DMSO_4h   4h
# MYB-dTAG-VHL_4h              0.257653  0.016197    MYB-dTAG-VHL_4h   4h
# MYB-dTAG-DMSO_8h             0.229240  0.023660   MYB-dTAG-DMSO_8h   8h
# MYB-dTAG-VHL_8h              0.241336  0.010505    MYB-dTAG-VHL_8h   8h
# MYB-dTAG-DMSO_12h            0.248811  0.052244  MYB-dTAG-DMSO_12h  12h
# MYB-dTAG-VHL_12h             0.253726  0.044261   MYB-dTAG-VHL_12h  12h
# MYB-dTAG-DMSO_24h            0.156618  0.015973  MYB-dTAG-DMSO_24h  24h
# MYB-dTAG-VHL_24h             0.196129  0.020195   MYB-dTAG-VHL_24h  24h
# MYB-dTAG-DMSO_48h            0.295914  0.034832  MYB-dTAG-DMSO_48h  48h
# MYB-dTAG-VHL_48h             0.527652  0.124548   MYB-dTAG-VHL_48h  48h
#
#                   treatment
# MYB-dTAG-DMSO_1h       DMSO
# MYB-dTAG-VHL_1h         VHL
# MYB-dTAG-DMSO_2h       DMSO
# MYB-dTAG-VHL_2h         VHL
# MYB-dTAG-DMSO_4h       DMSO
# MYB-dTAG-VHL_4h         VHL
# MYB-dTAG-DMSO_8h       DMSO
# MYB-dTAG-VHL_8h         VHL
# MYB-dTAG-DMSO_12h      DMSO
# MYB-dTAG-VHL_12h        VHL
# MYB-dTAG-DMSO_24h      DMSO
# MYB-dTAG-VHL_24h        VHL
# MYB-dTAG-DMSO_48h      DMSO
# MYB-dTAG-VHL_48h        VHL

# %%
# save avg ERCC pseudocounts
res_dir = "../results/slamseq_"+project+"/"
d.to_csv(res_dir+project+"_scaling_factors_avg.csv", header=True, index=True)

# %% [markdown]
# ## Saving the data in our bucket

# %%
print(project)
# Out:
# MYB_degraded_timecourse_v1

# %%
! gsutil -m cp ../../data/slamseq_$project/fastqs/* gs://amlproject/RNA/slamseq/$project/fastqs/ 
! gsutil -m cp ../../data/slamseq_$project/res/map/* gs://amlproject/RNA/slamseq/$project/res/map/ 
! gsutil -m cp ../../data/slamseq_$project/res/filter/* gs://amlproject/RNA/slamseq/$project/res/filter/ 
! gsutil -m cp ../../data/slamseq_$project/res/snp/* gs://amlproject/RNA/slamseq/$project/res/snp/ 
! gsutil -m cp ../../data/slamseq_$project/res/count/* gs://amlproject/RNA/slamseq/$project/res/count/
# Out:
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr387-MV411-RUNX1-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr388-MV411-RUNX1-dTAG-DMSO_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr389-MV411-RUNX1-dTAG-DMSO_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr390-MV411-RUNX1-dTAG-DMSO_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr391-MV411-RUNX1-dTAG-VHL_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr392-MV411-RUNX1-dTAG-VHL_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr393-MV411-RUNX1-dTAG-VHL_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr394-MV411-RUNX1-dTAG-VHL_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr395-MV411-RUNX2-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr396-MV411-RUNX2-dTAG-DMSO_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr397-MV411-RUNX2-dTAG-DMSO_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr398-MV411-RUNX2-dTAG-DMSO_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr399-MV411-RUNX2-dTAG-VHL_1h-r1_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr400-MV411-RUNX2-dTAG-VHL_1h-r2_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr401-MV411-RUNX2-dTAG-VHL_1h-r3_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr402-MV411-RUNX2-dTAG-VHL_1h-r4_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr403-MV411-SPI1-dTAG-DMSO_1h-r1_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr404-MV411-SPI1-dTAG-DMSO_1h-r2_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr405-MV411-SPI1-dTAG-DMSO_1h-r3_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001_unpaired_1.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001_val_1.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R1_001_val_1.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001.fastq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001.fastq.gz_trimming_report.txt [Content-Type=text/plain]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001_unpaired_2.fq.gz [Content-Type=application/octet-stream]...
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001_val_2.fq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr406-MV411-SPI1-dTAG-DMSO_1h-r4_R2_001_val_2.fq.gz
# Copying file://../../data/slamseq_4_degrons_v1/fastqs/mr407-MV411-SPI1-dTAG-DMSO_1h-r5_R1_001.fastq.gz [Content-Type=application/octet-stream]...
# Resuming upload for file://../../data/slamseq_4_degrons_v1/fastqs/mr407-MV411-SPI1-dTAG-DMSO_1h-r5_R1_001.fastq.gz
# \ [121/280 files][168.2 GiB/508.3 GiB]  33% Done  38.9 MiB/s ETA 02:29:03

# %% [markdown]
# # SLAM-seq
# All SLAM-seq assays were performed at 60-70% confluency for adherent cells or
# 60% of the maximum cell density counted on a hemocytometer for suspension cells. 5-7h
# prior to each assay, growth medium was aspirated and replaced. Unless stated otherwise,
# cells were pre-treated with indicated small molecule inhibitors or 100µM IAA for 30 min
# to pre-establish full target inhibition or degradation. Newly synthesized RNA was labeled
# for indicated time spans (45 min or 60 min) at a final concentration of 100µM 4-
# thiouridine (4sU, Carbosynth). Adherent cells were harvested by direct snap-freezing of
# plates on dry ice. Suspension cells were spun down and immediately snap-frozen. RNA
# extraction was performed using the RNeasy Plus Mini Kit (Qiagen).
#
# Total RNA was subjected to alkylation by iodoacetamide (Sigma, 10mM) for 15 min and RNA was repurified by ethanol precipitation. 500ng alkylated RNA were used as input for generating
# 3’-end mRNA sequencing libraries using a commercially available kit (QuantSeq 3′
# mRNA-Seq Library Prep Kit FWD for Illumina and PCR Add-on Kit for Illumina,
# Lexogen). Deep sequencing was performed using HiSeq1500 and HiSeq2500 platforms
# (Illumina).

# %% [markdown]
# ## Make count files

# %%
project = project
res_folder = "res"
location = "../../data/slamseq_"+project+"/"+res_folder+"/"+"count/"
print(location)
# Out:
# ../../data/slamseq_MYB_degraded_timecourse_v1/res/count/

# %%
# remove genes that have very low counts
mincount_toremove=5

# remove genes that have a variance of 0 across all samples (these we really want to remove)
# genes that have values of 0,1,2 everywhere
minvar_toremove=0

# %% [markdown]
# <li>readcounts: total counts of every transscript (output of slamdunk algorithm
# <li>tccounts: t to c converted RNA transcripts

# %%
# %%time

# all genes (not just protein coding)
readcounts, tccounts = rna.readFromSlamdunk(loc=location, 
                                            minvar_toremove=minvar_toremove, 
                                            mincount_toremove=mincount_toremove,
                                            verbose=False)
# Out:
# found 70 files:dict_keys(['mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount', 'mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount', 'mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount', 'mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount', 'mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount', 'mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount', 'mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount', 'mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount', 'mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount', 'mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount', 'mr432-MV411-MYB-dTAG-DMSO_2h-r1_tcount', 'mr433-MV411-MYB-dTAG-DMSO_2h-r2_tcount', 'mr434-MV411-MYB-dTAG-DMSO_2h-r3_tcount', 'mr435-MV411-MYB-dTAG-DMSO_2h-r4_tcount', 'mr436-MV411-MYB-dTAG-DMSO_2h-r5_tcount', 'mr437-MV411-MYB-dTAG-VHL_2h-r1_tcount', 'mr438-MV411-MYB-dTAG-VHL_2h-r2_tcount', 'mr439-MV411-MYB-dTAG-VHL_2h-r3_tcount', 'mr440-MV411-MYB-dTAG-VHL_2h-r4_tcount', 'mr441-MV411-MYB-dTAG-VHL_2h-r5_tcount', 'mr442-MV411-MYB-dTAG-DMSO_4h-r1_tcount', 'mr443-MV411-MYB-dTAG-DMSO_4h-r2_tcount', 'mr444-MV411-MYB-dTAG-DMSO_4h-r3_tcount', 'mr445-MV411-MYB-dTAG-DMSO_4h-r4_tcount', 'mr446-MV411-MYB-dTAG-DMSO_4h-r5_tcount', 'mr447-MV411-MYB-dTAG-VHL_4h-r1_tcount', 'mr448-MV411-MYB-dTAG-VHL_4h-r2_tcount', 'mr449-MV411-MYB-dTAG-VHL_4h-r3_tcount', 'mr450-MV411-MYB-dTAG-VHL_4h-r4_tcount', 'mr451-MV411-MYB-dTAG-VHL_4h-r5_tcount', 'mr452-MV411-MYB-dTAG-DMSO_8h-r1_tcount', 'mr453-MV411-MYB-dTAG-DMSO_8h-r2_tcount', 'mr454-MV411-MYB-dTAG-DMSO_8h-r3_tcount', 'mr455-MV411-MYB-dTAG-DMSO_8h-r4_tcount', 'mr456-MV411-MYB-dTAG-DMSO_8h-r5_tcount', 'mr457-MV411-MYB-dTAG-VHL_8h-r1_tcount', 'mr458-MV411-MYB-dTAG-VHL_8h-r2_tcount', 'mr459-MV411-MYB-dTAG-VHL_8h-r3_tcount', 'mr460-MV411-MYB-dTAG-VHL_8h-r4_tcount', 'mr461-MV411-MYB-dTAG-VHL_8h-r5_tcount', 'mr462-MV411-MYB-dTAG-DMSO_12h-r1_tcount', 'mr463-MV411-MYB-dTAG-DMSO_12h-r2_tcount', 'mr464-MV411-MYB-dTAG-DMSO_12h-r3_tcount', 'mr465-MV411-MYB-dTAG-DMSO_12h-r4_tcount', 'mr466-MV411-MYB-dTAG-DMSO_12h-r5_tcount', 'mr467-MV411-MYB-dTAG-VHL_12h-r1_tcount', 'mr468-MV411-MYB-dTAG-VHL_12h-r2_tcount', 'mr469-MV411-MYB-dTAG-VHL_12h-r3_tcount', 'mr470-MV411-MYB-dTAG-VHL_12h-r4_tcount', 'mr471-MV411-MYB-dTAG-VHL_12h-r5_tcount', 'mr472-MV411-MYB-dTAG-DMSO_24h-r1_tcount', 'mr473-MV411-MYB-dTAG-DMSO_24h-r2_tcount', 'mr474-MV411-MYB-dTAG-DMSO_24h-r3_tcount', 'mr475-MV411-MYB-dTAG-DMSO_24h-r4_tcount', 'mr476-MV411-MYB-dTAG-DMSO_24h-r5_tcount', 'mr477-MV411-MYB-dTAG-VHL_24h-r1_tcount', 'mr478-MV411-MYB-dTAG-VHL_24h-r2_tcount', 'mr479-MV411-MYB-dTAG-VHL_24h-r3_tcount', 'mr480-MV411-MYB-dTAG-VHL_24h-r4_tcount', 'mr481-MV411-MYB-dTAG-VHL_24h-r5_tcount', 'mr482-MV411-MYB-dTAG-DMSO_48h-r1_tcount', 'mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount', 'mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount', 'mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount', 'mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount', 'mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount', 'mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount', 'mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount', 'mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount', 'mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount'])
# mr422-MV411-MYB-dTAG-DMSO_1h-r1
# mr423-MV411-MYB-dTAG-DMSO_1h-r2
# mr424-MV411-MYB-dTAG-DMSO_1h-r3
# mr425-MV411-MYB-dTAG-DMSO_1h-r4
# mr426-MV411-MYB-dTAG-DMSO_1h-r5
# mr427-MV411-MYB-dTAG-VHL_1h-r1
# mr428-MV411-MYB-dTAG-VHL_1h-r2
# mr429-MV411-MYB-dTAG-VHL_1h-r3
# mr430-MV411-MYB-dTAG-VHL_1h-r4
# mr431-MV411-MYB-dTAG-VHL_1h-r5
# mr432-MV411-MYB-dTAG-DMSO_2h-r1
# mr433-MV411-MYB-dTAG-DMSO_2h-r2
# mr434-MV411-MYB-dTAG-DMSO_2h-r3
# mr435-MV411-MYB-dTAG-DMSO_2h-r4
# mr436-MV411-MYB-dTAG-DMSO_2h-r5
# mr437-MV411-MYB-dTAG-VHL_2h-r1
# mr438-MV411-MYB-dTAG-VHL_2h-r2
# mr439-MV411-MYB-dTAG-VHL_2h-r3
# mr440-MV411-MYB-dTAG-VHL_2h-r4
# mr441-MV411-MYB-dTAG-VHL_2h-r5
# mr442-MV411-MYB-dTAG-DMSO_4h-r1
# mr443-MV411-MYB-dTAG-DMSO_4h-r2
# mr444-MV411-MYB-dTAG-DMSO_4h-r3
# mr445-MV411-MYB-dTAG-DMSO_4h-r4
# mr446-MV411-MYB-dTAG-DMSO_4h-r5
# mr447-MV411-MYB-dTAG-VHL_4h-r1
# mr448-MV411-MYB-dTAG-VHL_4h-r2
# mr449-MV411-MYB-dTAG-VHL_4h-r3
# mr450-MV411-MYB-dTAG-VHL_4h-r4
# mr451-MV411-MYB-dTAG-VHL_4h-r5
# mr452-MV411-MYB-dTAG-DMSO_8h-r1
# mr453-MV411-MYB-dTAG-DMSO_8h-r2
# mr454-MV411-MYB-dTAG-DMSO_8h-r3
# mr455-MV411-MYB-dTAG-DMSO_8h-r4
# mr456-MV411-MYB-dTAG-DMSO_8h-r5
# mr457-MV411-MYB-dTAG-VHL_8h-r1
# mr458-MV411-MYB-dTAG-VHL_8h-r2
# mr459-MV411-MYB-dTAG-VHL_8h-r3
# mr460-MV411-MYB-dTAG-VHL_8h-r4
# mr461-MV411-MYB-dTAG-VHL_8h-r5
# mr462-MV411-MYB-dTAG-DMSO_12h-r1
# mr463-MV411-MYB-dTAG-DMSO_12h-r2
# mr464-MV411-MYB-dTAG-DMSO_12h-r3
# mr465-MV411-MYB-dTAG-DMSO_12h-r4
# mr466-MV411-MYB-dTAG-DMSO_12h-r5
# mr467-MV411-MYB-dTAG-VHL_12h-r1
# mr468-MV411-MYB-dTAG-VHL_12h-r2
# mr469-MV411-MYB-dTAG-VHL_12h-r3
# mr470-MV411-MYB-dTAG-VHL_12h-r4
# mr471-MV411-MYB-dTAG-VHL_12h-r5
# mr472-MV411-MYB-dTAG-DMSO_24h-r1
# mr473-MV411-MYB-dTAG-DMSO_24h-r2
# mr474-MV411-MYB-dTAG-DMSO_24h-r3
# mr475-MV411-MYB-dTAG-DMSO_24h-r4
# mr476-MV411-MYB-dTAG-DMSO_24h-r5
# mr477-MV411-MYB-dTAG-VHL_24h-r1
# mr478-MV411-MYB-dTAG-VHL_24h-r2
# mr479-MV411-MYB-dTAG-VHL_24h-r3
# mr480-MV411-MYB-dTAG-VHL_24h-r4
# mr481-MV411-MYB-dTAG-VHL_24h-r5
# mr482-MV411-MYB-dTAG-DMSO_48h-r1
# mr483-MV411-MYB-dTAG-DMSO_48h-r2
# mr484-MV411-MYB-dTAG-DMSO_48h-r3
# mr485-MV411-MYB-dTAG-DMSO_48h-r4
# mr486-MV411-MYB-dTAG-DMSO_48h-r5
# mr487-MV411-MYB-dTAG-VHL_48h-r1
# mr488-MV411-MYB-dTAG-VHL_48h-r2
# mr489-MV411-MYB-dTAG-VHL_48h-r3
# mr490-MV411-MYB-dTAG-VHL_48h-r4
# mr491-MV411-MYB-dTAG-VHL_48h-r5
# downloading gene names from biomart
# 1750 count not be parsed... we don't have all genes already
# downloading gene names from biomart
# 1750 count not be parsed... we don't have all genes already
# CPU times: user 6min 21s, sys: 7 s, total: 6min 28s
# Wall time: 7min 5s

# %% [markdown]
# Check for duplicate gene rows

# %%
def dedup_df_genes(df):
    ''' sum rows with the same gene index and remove duplicate '''
    if df.shape[0] != len(df.index.drop_duplicates()):
        print("Duplicate gene rows!")
        print("{} rows | {} unique genes".format(df.shape[0], len(df.index.drop_duplicates())))
        print("Summing of duplicate gene rows.")
        
    # sum duplicate rows, same row order
    duplicate_genes = df.index[df.index.duplicated()].tolist()
    df = df.groupby(df.index).sum().loc[df.index.drop_duplicates()]
    if df.shape[0] != len(df.index.drop_duplicates()):
        raise ValueError(
            "Cannot collapse duplicate gene rows."
        )
    
    return df, duplicate_genes

# %%
readcounts, duplicate_genes = dedup_df_genes(readcounts)
tccounts, duplicate_genes = dedup_df_genes(tccounts)

if readcounts.shape != tccounts.shape:
    raise ValueError("readcounts and tccounts not the same dimensions: {} | {}".format(readcounts.shape, tccounts.shape))
# Out:
# Duplicate gene rows!
# 18347 rows | 18305 unique genes
# Summing of duplicate gene rows.
# Duplicate gene rows!
# 18347 rows | 18305 unique genes
# Summing of duplicate gene rows.

# %% [markdown]
# ### make density plot

# %%
res_dir = "../results/slamseq_{}/".format(project)
print(res_dir)
createDir(res_dir)
# Out:
# ../results/slamseq_MYB_degraded_timecourse_v1/

# %%
col = tccounts.columns.tolist() # sort cols
col.sort()
tccounts = tccounts[col]

# %%
col = readcounts.columns.tolist() # sort cols
col.sort()
readcounts = readcounts[col]

# %%
print(readcounts.shape)
readcounts.iloc[:2]
# Out:
# (18305, 70)
#        mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# A1BG                                        2
# A2MP1                                       6
#
#        mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# A1BG                                        1
# A2MP1                                       1
#
#        mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# A1BG                                        2
# A2MP1                                       3
#
#        mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# A1BG                                        0
# A2MP1                                       6
#
#        mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# A1BG                                        0
# A2MP1                                       4
#
#        mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# A1BG                                       3
# A2MP1                                      0
#
#        mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# A1BG                                       3
# A2MP1                                      1
#
#        mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# A1BG                                       2
# A2MP1                                      6
#
#        mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# A1BG                                       0
# A2MP1                                     11
#
#        mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# A1BG                                       2  ...
# A2MP1                                      2  ...
#
#        mr482-MV411-MYB-dTAG-DMSO_48h-r1_tcount  \
# A1BG                                         0
# A2MP1                                        0
#
#        mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# A1BG                                         1
# A2MP1                                        0
#
#        mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# A1BG                                         1
# A2MP1                                        2
#
#        mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# A1BG                                         0
# A2MP1                                        3
#
#        mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# A1BG                                         3
# A2MP1                                        0
#
#        mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# A1BG                                        1
# A2MP1                                       3
#
#        mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# A1BG                                        4
# A2MP1                                       1
#
#        mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# A1BG                                        4
# A2MP1                                       2
#
#        mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# A1BG                                        1
# A2MP1                                       1
#
#        mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount
# A1BG                                        3
# A2MP1                                       4
#
# [2 rows x 70 columns]

# %% [markdown]
# read counts that are t $\rightarrow$ c converted (actively transcribed)
# * most at 0 = most are not transcribed
# * a lot at 1 or everything at 0 is weird

# %%
# what is the average of highly transcribed genes
# tccounts/readcounts where sum of readcounts in all samples > 30 
a = tccounts[readcounts.sum(1)>30] / readcounts[readcounts.sum(1)>30]
a = a.fillna(0)
a = a.max(1).tolist() # max val per gene
a.sort()
print(len(a))
sns.kdeplot(a)
plt.xlabel("max tccounts / max readcounts per gene")
plt.title(project.replace("_", " ").split(" v")[0])

plt.savefig(res_dir+'plots/'+project+'_tccounts_readcounts_density.pdf', dpi=300, bbox_inches="tight")
plt.show()
# Out:
# 18041

# %%
np.median(a)
# Out:
# 0.1724137931034483

# %%
# Save counts to csv
counts_file_prefix = project+'_'+str(minvar_toremove)+'_'+str(mincount_toremove)

readcounts.to_csv(res_dir+counts_file_prefix+"_readcounts.csv",index=True, index_label="GENE")
print("Saved readcounts to: {}".format(res_dir+counts_file_prefix+"_readcounts.csv"))

tccounts.to_csv(res_dir+counts_file_prefix+"_tccounts.csv",index=True, index_label="GENE")
print("Saved tccounts to: {}".format(res_dir+counts_file_prefix+"_tccounts.csv"))
# Out:
# Saved readcounts to: ../results/slamseq_MYB_degraded_timecourse_v1/MYB_degraded_timecourse_v1_0_5_readcounts.csv
# Saved tccounts to: ../results/slamseq_MYB_degraded_timecourse_v1/MYB_degraded_timecourse_v1_0_5_tccounts.csv

# %% [markdown]
# ### make more df (mean, median, etc.)

# %%
readcounts.iloc[:1]
# Out:
#       mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# A1BG                                       2
#
#       mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# A1BG                                       1
#
#       mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# A1BG                                       2
#
#       mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# A1BG                                       0
#
#       mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# A1BG                                       0
#
#       mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# A1BG                                      3
#
#       mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# A1BG                                      3
#
#       mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# A1BG                                      2
#
#       mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# A1BG                                      0
#
#       mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# A1BG                                      2  ...
#
#       mr482-MV411-MYB-dTAG-DMSO_48h-r1_tcount  \
# A1BG                                        0
#
#       mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# A1BG                                        1
#
#       mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# A1BG                                        1
#
#       mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# A1BG                                        0
#
#       mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# A1BG                                        3
#
#       mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# A1BG                                       1
#
#       mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# A1BG                                       4
#
#       mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# A1BG                                       4
#
#       mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# A1BG                                       1
#
#       mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount
# A1BG                                       3
#
# [1 rows x 70 columns]

# %%
print("Genes with highest read counts per sample.")
for column in readcounts:
    print(column.split("MV411-")[1].split("_")[0] +": "+ str(readcounts[column].idxmax()))
# Out:
# Genes with highest read counts per sample.
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: MALAT1
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-DMSO: MALAT1
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-DMSO: RPL13AP5
# MYB-dTAG-VHL: MALAT1
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: MALAT1
# MYB-dTAG-VHL: RPL13AP5
# MYB-dTAG-VHL: RPL13AP5

# %%
readcounts.idxmax().value_counts()
# Out:
# RPL13AP5    66
# MALAT1       4
# dtype: int64

# %%
print(set([i.split('-')[-2] for i in tccounts.columns]))
print(tccounts.columns[0].split('-', 1))
print(tccounts.columns[0].split('-', 1)[-1].rpartition("-")[0])
set([i.split('-', 1)[-1].rpartition("-")[0] for i in tccounts.columns])
# Out:
# {'VHL_1h', 'DMSO_2h', 'VHL_8h', 'DMSO_12h', 'VHL_24h', 'VHL_12h', 'VHL_48h', 'DMSO_24h', 'DMSO_1h', 'VHL_2h', 'DMSO_48h', 'DMSO_8h', 'VHL_4h', 'DMSO_4h'}
# ['mr422', 'MV411-MYB-dTAG-DMSO_1h-r1_tcount']
# MV411-MYB-dTAG-DMSO_1h
# {'MV411-MYB-dTAG-DMSO_12h',
#  'MV411-MYB-dTAG-DMSO_1h',
#  'MV411-MYB-dTAG-DMSO_24h',
#  'MV411-MYB-dTAG-DMSO_2h',
#  'MV411-MYB-dTAG-DMSO_48h',
#  'MV411-MYB-dTAG-DMSO_4h',
#  'MV411-MYB-dTAG-DMSO_8h',
#  'MV411-MYB-dTAG-VHL_12h',
#  'MV411-MYB-dTAG-VHL_1h',
#  'MV411-MYB-dTAG-VHL_24h',
#  'MV411-MYB-dTAG-VHL_2h',
#  'MV411-MYB-dTAG-VHL_48h',
#  'MV411-MYB-dTAG-VHL_4h',
#  'MV411-MYB-dTAG-VHL_8h'}

# %%
# get mean counts per condition
mtccounts = pd.DataFrame()
mreadcounts = pd.DataFrame()
# conditions maintaing column order
for i in list(dict.fromkeys([i.split('-', 1)[-1].rpartition("-")[0] for i in tccounts.columns])):
    print(i)
    mtccounts[i] = tccounts[[v for v in tccounts.columns if i in v]].mean(1)
    mreadcounts[i] = readcounts[[v for v in readcounts.columns if i in v]].mean(1)

# save mean counts files
mtccounts.to_csv(res_dir+counts_file_prefix+"_mean_tccounts.csv", index=True, index_label="GENE")
mreadcounts.to_csv(res_dir+counts_file_prefix+"_mean_readcounts.csv", index=True, index_label="GENE")
# Out:
# MV411-MYB-dTAG-DMSO_1h
# MV411-MYB-dTAG-VHL_1h
# MV411-MYB-dTAG-DMSO_2h
# MV411-MYB-dTAG-VHL_2h
# MV411-MYB-dTAG-DMSO_4h
# MV411-MYB-dTAG-VHL_4h
# MV411-MYB-dTAG-DMSO_8h
# MV411-MYB-dTAG-VHL_8h
# MV411-MYB-dTAG-DMSO_12h
# MV411-MYB-dTAG-VHL_12h
# MV411-MYB-dTAG-DMSO_24h
# MV411-MYB-dTAG-VHL_24h
# MV411-MYB-dTAG-DMSO_48h
# MV411-MYB-dTAG-VHL_48h

# %%
# get median counts per condition
mtccounts = pd.DataFrame()
mreadcounts = pd.DataFrame()
# conditions maintaing column order
for i in list(dict.fromkeys([i.split('-', 1)[-1].rpartition("-")[0] for i in tccounts.columns])):
    print(i)
    mtccounts[i] = tccounts[[v for v in tccounts.columns if i in v]].median(1)
    mreadcounts[i] = readcounts[[v for v in readcounts.columns if i in v]].median(1)

# save median counts files
mtccounts.to_csv(res_dir+counts_file_prefix+"_median_tccounts.csv", index=True, index_label="GENE")
mreadcounts.to_csv(res_dir+counts_file_prefix+"_median_readcounts.csv", index=True, index_label="GENE")
# Out:
# MV411-MYB-dTAG-DMSO_1h
# MV411-MYB-dTAG-VHL_1h
# MV411-MYB-dTAG-DMSO_2h
# MV411-MYB-dTAG-VHL_2h
# MV411-MYB-dTAG-DMSO_4h
# MV411-MYB-dTAG-VHL_4h
# MV411-MYB-dTAG-DMSO_8h
# MV411-MYB-dTAG-VHL_8h
# MV411-MYB-dTAG-DMSO_12h
# MV411-MYB-dTAG-VHL_12h
# MV411-MYB-dTAG-DMSO_24h
# MV411-MYB-dTAG-VHL_24h
# MV411-MYB-dTAG-DMSO_48h
# MV411-MYB-dTAG-VHL_48h

# %%
(tccounts/readcounts).fillna(0).iloc[:2]
# Out:
#        mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# A1BG                                     0.0
# A2MP1                                    0.0
#
#        mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# A1BG                                     0.0
# A2MP1                                    0.0
#
#        mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# A1BG                                     0.0
# A2MP1                                    0.0
#
#        mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# A1BG                                     0.0
# A2MP1                                    0.0
#
#        mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# A1BG                                     0.0  ...
# A2MP1                                    0.0  ...
#
#        mr482-MV411-MYB-dTAG-DMSO_48h-r1_tcount  \
# A1BG                                       0.0
# A2MP1                                      0.0
#
#        mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# A1BG                                       0.0
# A2MP1                                      0.0
#
#        mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# A1BG                                       0.0
# A2MP1                                      0.0
#
#        mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# A1BG                                       0.0
# A2MP1                                      0.0
#
#        mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# A1BG                                       0.0
# A2MP1                                      0.0
#
#        mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# A1BG                                      0.0
# A2MP1                                     0.0
#
#        mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount
# A1BG                                      0.0
# A2MP1                                     0.0
#
# [2 rows x 70 columns]

# %%
# Save tccounts/readcounts file
(tccounts/readcounts).fillna(0).to_csv(res_dir+counts_file_prefix+"_tccounts_per_readcounts.csv")
print("Saved tccounts/readcounts to: {}".format(res_dir+counts_file_prefix+"_tccounts_per_readcounts.csv"))
# Out:
# Saved tccounts/readcounts to: ../results/slamseq_MYB_degraded_timecourse_v1/MYB_degraded_timecourse_v1_0_5_tccounts_per_readcounts.csv

# %% [markdown]
# ## Look at similarity accross replicates
#
# we have some outliers, else it seems to make some sense and on average, to be extremelly similar!

# %%
createDir("../results/slamseq_"+project+"/plots/")

# %%
[i.split('_tc', 1)[0].split("-", 4)[-1] for i in tccounts.columns[:5]]
# Out:
# ['DMSO_1h-r1', 'DMSO_1h-r2', 'DMSO_1h-r3', 'DMSO_1h-r4', 'DMSO_1h-r5']

# %%
[i.rpartition("_")[0] for i in tccounts.columns.tolist()] # name without _tccount
#tccounts.columns[0].split('-', 1)[-1].rpartition("-")[0]
[i.split("-")[-2] for i in tccounts.columns] # conditions
# Out:
# ['DMSO_1h',
#  'DMSO_1h',
#  'DMSO_1h',
#  'DMSO_1h',
#  'DMSO_1h',
#  'VHL_1h',
#  'VHL_1h',
#  'VHL_1h',
#  'VHL_1h',
#  'VHL_1h',
#  'DMSO_2h',
#  'DMSO_2h',
#  'DMSO_2h',
#  'DMSO_2h',
#  'DMSO_2h',
#  'VHL_2h',
#  'VHL_2h',
#  'VHL_2h',
#  'VHL_2h',
#  'VHL_2h',
#  'DMSO_4h',
#  'DMSO_4h',
#  'DMSO_4h',
#  'DMSO_4h',
#  'DMSO_4h',
#  'VHL_4h',
#  'VHL_4h',
#  'VHL_4h',
#  'VHL_4h',
#  'VHL_4h',
#  'DMSO_8h',
#  'DMSO_8h',
#  'DMSO_8h',
#  'DMSO_8h',
#  'DMSO_8h',
#  'VHL_8h',
#  'VHL_8h',
#  'VHL_8h',
#  'VHL_8h',
#  'VHL_8h',
#  'DMSO_12h',
#  'DMSO_12h',
#  'DMSO_12h',
#  'DMSO_12h',
#  'DMSO_12h',
#  'VHL_12h',
#  'VHL_12h',
#  'VHL_12h',
#  'VHL_12h',
#  'VHL_12h',
#  'DMSO_24h',
#  'DMSO_24h',
#  'DMSO_24h',
#  'DMSO_24h',
#  'DMSO_24h',
#  'VHL_24h',
#  'VHL_24h',
#  'VHL_24h',
#  'VHL_24h',
#  'VHL_24h',
#  'DMSO_48h',
#  'DMSO_48h',
#  'DMSO_48h',
#  'DMSO_48h',
#  'DMSO_48h',
#  'VHL_48h',
#  'VHL_48h',
#  'VHL_48h',
#  'VHL_48h',
#  'VHL_48h']

# %% [markdown]
# ### save plots to pdf

# %%
tccounts.iloc[:,:20].columns.tolist()
# Out:
# ['mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount',
#  'mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount',
#  'mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount',
#  'mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount',
#  'mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount',
#  'mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount',
#  'mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount',
#  'mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount',
#  'mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount',
#  'mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount',
#  'mr432-MV411-MYB-dTAG-DMSO_2h-r1_tcount',
#  'mr433-MV411-MYB-dTAG-DMSO_2h-r2_tcount',
#  'mr434-MV411-MYB-dTAG-DMSO_2h-r3_tcount',
#  'mr435-MV411-MYB-dTAG-DMSO_2h-r4_tcount',
#  'mr436-MV411-MYB-dTAG-DMSO_2h-r5_tcount',
#  'mr437-MV411-MYB-dTAG-VHL_2h-r1_tcount',
#  'mr438-MV411-MYB-dTAG-VHL_2h-r2_tcount',
#  'mr439-MV411-MYB-dTAG-VHL_2h-r3_tcount',
#  'mr440-MV411-MYB-dTAG-VHL_2h-r4_tcount',
#  'mr441-MV411-MYB-dTAG-VHL_2h-r5_tcount']

# %%
# %matplotlib inline
import matplotlib.font_manager

font_settings = {
    "family" : "sans-serif",
    #"sans-serif" : "Arial",
    "size" : 10
}
plt.rc("font", **font_settings)

# tccounts
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(tccounts.corr(), #tccounts.iloc[:,30:50].corr(), 
            # condition w/o rep label
            xticklabels=[i.split('_tc', 1)[0].split("-", 4)[-1] for i in tccounts.columns],
            yticklabels=[i.split('_tc', 1)[0].split("-", 4)[-1] for i in tccounts.columns],
            # condition w/ rep label
            #xticklabels=[i.split('-', 1)[-1].rpartition("_")[0] for i in tccounts.columns],
            #yticklabels=[i.split('-', 1)[-1].rpartition("_")[0] for i in tccounts.columns],
            ax=ax, cmap="rocket")#, vmin=0.9, vmax=1)
plt.title(project.replace("_", " ").split(" v")[0]+"\n"+"Replicate similarity: TC counts")
plt.tight_layout()

#plt.savefig(res_dir+'plots/'+project+'_similarity_replicates_sorted_tccounts.pdf', dpi=300)

print("Replicate similarity plot saved to: {}".format(res_dir+'plots/'+project+
                                                      '_similarity_replicates_sorted_tccounts.pdf'))
# Out:
# Replicate similarity plot saved to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_similarity_replicates_sorted_tccounts.pdf

# %%
# %matplotlib inline

# readcounts
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(readcounts.corr(), 
            # condition w/ replicate
            xticklabels=[i.split('_tc', 1)[0].split("-", 4)[-1] for i in readcounts.columns],
            yticklabels=[i.split('_tc', 1)[0].split("-", 4)[-1] for i in readcounts.columns],
            ax=ax)#, cmap=cmp_cylin), vmin=0.985, vmax=1)
plt.title(project.replace("_", " ").split(" v")[0]+"\n"+"Replicate similarity: read counts")
plt.tight_layout()

plt.savefig(res_dir+'plots/'+project+'_similarity_replicates_sorted_readcounts.pdf', dpi=300)

print("Replicate similarity plot saved to: {}".format(res_dir+'plots/'+project+
                                                      '_similarity_replicates_sorted_readcounts.pdf'))
# Out:
# Replicate similarity plot saved to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_similarity_replicates_sorted_readcounts.pdf

# %% [markdown]
# # DESEQ Analysis

# %%
res_dir = "../results/slamseq_{}/".format(project)
print(res_dir)
# Out:
# ../results/slamseq_MYB_degraded_timecourse_v1/

# %%
readcounts.iloc[:3]
# Out:
#        mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# A1BG                                        2
# A2MP1                                       6
# NAT1                                      285
#
#        mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# A1BG                                        1
# A2MP1                                       1
# NAT1                                      177
#
#        mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# A1BG                                        2
# A2MP1                                       3
# NAT1                                      181
#
#        mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# A1BG                                        0
# A2MP1                                       6
# NAT1                                      258
#
#        mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# A1BG                                        0
# A2MP1                                       4
# NAT1                                       69
#
#        mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# A1BG                                       3
# A2MP1                                      0
# NAT1                                     206
#
#        mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# A1BG                                       3
# A2MP1                                      1
# NAT1                                     159
#
#        mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# A1BG                                       2
# A2MP1                                      6
# NAT1                                     212
#
#        mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# A1BG                                       0
# A2MP1                                     11
# NAT1                                     325
#
#        mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# A1BG                                       2  ...
# A2MP1                                      2  ...
# NAT1                                     276  ...
#
#        mr482-MV411-MYB-dTAG-DMSO_48h-r1_tcount  \
# A1BG                                         0
# A2MP1                                        0
# NAT1                                       184
#
#        mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# A1BG                                         1
# A2MP1                                        0
# NAT1                                       165
#
#        mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# A1BG                                         1
# A2MP1                                        2
# NAT1                                       198
#
#        mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# A1BG                                         0
# A2MP1                                        3
# NAT1                                       305
#
#        mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# A1BG                                         3
# A2MP1                                        0
# NAT1                                       201
#
#        mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# A1BG                                        1
# A2MP1                                       3
# NAT1                                       70
#
#        mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# A1BG                                        4
# A2MP1                                       1
# NAT1                                      145
#
#        mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# A1BG                                        4
# A2MP1                                       2
# NAT1                                      167
#
#        mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# A1BG                                        1
# A2MP1                                       1
# NAT1                                      115
#
#        mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount
# A1BG                                        3
# A2MP1                                       4
# NAT1                                      163
#
# [3 rows x 70 columns]

# %%
readcounts["genes"] = readcounts.index # make genes col
readcounts = readcounts.reset_index(drop=True)

tccounts["genes"] = tccounts.index
tccounts = tccounts.reset_index(drop=True)

# %%
readcounts.iloc[:1]
# Out:
#    mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# 0                                       2
#
#    mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# 0                                       1
#
#    mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# 0                                       2
#
#    mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# 0                                       0
#
#    mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# 0                                       0
#
#    mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# 0                                      3
#
#    mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# 0                                      3
#
#    mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# 0                                      2
#
#    mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# 0                                      0
#
#    mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# 0                                      2  ...
#
#    mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# 0                                        1
#
#    mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# 0                                        1
#
#    mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# 0                                        0
#
#    mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# 0                                        3
#
#    mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# 0                                       1
#
#    mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# 0                                       4
#
#    mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# 0                                       4
#
#    mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# 0                                       1
#
#    mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount  genes
# 0                                       3   A1BG
#
# [1 rows x 71 columns]

# %%
tccounts.iloc[:1]
# Out:
#    mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  \
# 0                                       0
#
#    mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  \
# 0                                       0
#
#    mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  \
# 0                                       0
#
#    mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  \
# 0                                       0
#
#    mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  \
# 0                                       0
#
#    mr427-MV411-MYB-dTAG-VHL_1h-r1_tcount  \
# 0                                      0
#
#    mr428-MV411-MYB-dTAG-VHL_1h-r2_tcount  \
# 0                                      0
#
#    mr429-MV411-MYB-dTAG-VHL_1h-r3_tcount  \
# 0                                      0
#
#    mr430-MV411-MYB-dTAG-VHL_1h-r4_tcount  \
# 0                                      0
#
#    mr431-MV411-MYB-dTAG-VHL_1h-r5_tcount  ...  \
# 0                                      0  ...
#
#    mr483-MV411-MYB-dTAG-DMSO_48h-r2_tcount  \
# 0                                        0
#
#    mr484-MV411-MYB-dTAG-DMSO_48h-r3_tcount  \
# 0                                        0
#
#    mr485-MV411-MYB-dTAG-DMSO_48h-r4_tcount  \
# 0                                        0
#
#    mr486-MV411-MYB-dTAG-DMSO_48h-r5_tcount  \
# 0                                        0
#
#    mr487-MV411-MYB-dTAG-VHL_48h-r1_tcount  \
# 0                                       0
#
#    mr488-MV411-MYB-dTAG-VHL_48h-r2_tcount  \
# 0                                       0
#
#    mr489-MV411-MYB-dTAG-VHL_48h-r3_tcount  \
# 0                                       0
#
#    mr490-MV411-MYB-dTAG-VHL_48h-r4_tcount  \
# 0                                       0
#
#    mr491-MV411-MYB-dTAG-VHL_48h-r5_tcount  genes
# 0                                       0   A1BG
#
# [1 rows x 71 columns]

# %% [markdown]
# __Exclude replicates__
# * 1hr DMSO rep 1
# * 12hr VHL rep 5
# * 48hr DMSO rep 1
# * 48hr VHL rep 1

# %% [markdown]
# __ERCC normalization__
# * 1hr - no
# * 2hr - no
# * 4hr - no
# * 8hr - no
# * 12hr - no
# * 24hr - yes
# * 48hr - yes

# %%
drop_samples = ["DMSO_1h-r1", "VHL_12h-r5", "DMSO_48h-r1", "VHL_48h-r1"]
ERCC_norm_times = ["24h", "48h"]

# %%
# col info
cols = tccounts.columns[:-1]
experiments = [x.split("-", 1)[1].rsplit("-", 1)[0] for x in cols]
conds = [x.split("-")[-2] for x in cols]
time = [x.split("_")[-1] for x in conds]
treatment = [x.split("_")[0] for x in conds]
rep = [x.split("_")[-2].split("-")[-1] for x in cols]
drop = [True if any(sample in x for sample in drop_samples) else False for x in cols]
ERCC_norm = [True if x in ERCC_norm_times else False for x in time]

# experimental design
exp_design = pd.DataFrame(list(zip(cols, experiments, conds, time, treatment, rep, drop, ERCC_norm)), 
                          columns=["col", "experiment", "cond", "time", "treatment", "rep", "drop", "ERCC_norm"])

# %%
exp_design.head()
# Out:
#                                       col              experiment     cond  \
# 0  mr422-MV411-MYB-dTAG-DMSO_1h-r1_tcount  MV411-MYB-dTAG-DMSO_1h  DMSO_1h
# 1  mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount  MV411-MYB-dTAG-DMSO_1h  DMSO_1h
# 2  mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount  MV411-MYB-dTAG-DMSO_1h  DMSO_1h
# 3  mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount  MV411-MYB-dTAG-DMSO_1h  DMSO_1h
# 4  mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount  MV411-MYB-dTAG-DMSO_1h  DMSO_1h
#
#   time treatment rep   drop  ERCC_norm
# 0   1h      DMSO  r1   True      False
# 1   1h      DMSO  r2  False      False
# 2   1h      DMSO  r3  False      False
# 3   1h      DMSO  r4  False      False
# 4   1h      DMSO  r5  False      False

# %%
# save experimental design / metaData
exp_design.to_csv(res_dir+project+"_metaData.csv", index=False)
print("Save exp design/meta data to: "+res_dir+project+"_metaData.csv")
# Out:
# Save exp design/meta data to: ../results/slamseq_MYB_degraded_timecourse_v1/MYB_degraded_timecourse_v1_metaData.csv

# %% [markdown]
# ## MYB 1hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 1h
gene = "MYB"
version = "v1"
var_name = "time"
var = "1h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1))
# Out:
# array([  1.56508458,   4.09062349, 155.67622743, ..., 496.35376772,
#        240.11576582,   3.60020574])

# %%
tccountsGene.columns[[False]+design["DMSO"].tolist()]
# Out:
# Index(['mr423-MV411-MYB-dTAG-DMSO_1h-r2_tcount',
#        'mr424-MV411-MYB-dTAG-DMSO_1h-r3_tcount',
#        'mr425-MV411-MYB-dTAG-DMSO_1h-r4_tcount',
#        'mr426-MV411-MYB-dTAG-DMSO_1h-r5_tcount'],
#       dtype='object')

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
res
# Out:
# 0
# ERCC_mr423-MV411-MYB-dTAG-DMSO_1h-r2_filtered.bam    0.411434
# ERCC_mr424-MV411-MYB-dTAG-DMSO_1h-r3_filtered.bam    0.242111
# ERCC_mr425-MV411-MYB-dTAG-DMSO_1h-r4_filtered.bam    0.289384
# ERCC_mr426-MV411-MYB-dTAG-DMSO_1h-r5_filtered.bam    0.264057
# ERCC_mr427-MV411-MYB-dTAG-VHL_1h-r1_filtered.bam     0.385407
# ERCC_mr428-MV411-MYB-dTAG-VHL_1h-r2_filtered.bam     0.306924
# ERCC_mr429-MV411-MYB-dTAG-VHL_1h-r3_filtered.bam     0.297752
# ERCC_mr430-MV411-MYB-dTAG-VHL_1h-r4_filtered.bam     0.214893
# ERCC_mr431-MV411-MYB-dTAG-VHL_1h-r5_filtered.bam     0.239709
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
(res[[i for i in res.index if '-VHL' in i]].values/
 res[[i for i in res.index if '-DMSO' in i]].values.mean())
# Out:
# array([1.27725403, 1.01715654, 0.98676199, 0.71216499, 0.79440664])

# %%
res[[i for i in res.index if '-VHL' in i]].values
# Out:
# array([0.38540703, 0.3069235 , 0.29775205, 0.21489334, 0.23970948])

# %%
res[[i for i in res.index if '-DMSO' in i]].values.mean()
# Out:
# 0.30174657361999535

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.93 s, sys: 1.97 s, total: 10.9 s
# Wall time: 6.79 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.36 s, sys: 1.91 s, total: 10.3 s
# Wall time: 6.1 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_1h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_1h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.26 s, sys: 1.77 s, total: 10 s
# Wall time: 6.3 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9.12 s, sys: 2.13 s, total: 11.2 s
# Wall time: 6.67 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_1h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_1h_0_5_deseq_readcounts.csv

# %% [markdown]
# ## MYB 2hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 2h
gene = "MYB"
version = "v1"
var_name = "time"
var = "2h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 10
# 0
# ERCC_mr432-MV411-MYB-dTAG-DMSO_2h-r1_filtered.bam    0.227173
# ERCC_mr433-MV411-MYB-dTAG-DMSO_2h-r2_filtered.bam    0.218944
# ERCC_mr434-MV411-MYB-dTAG-DMSO_2h-r3_filtered.bam    0.339323
# ERCC_mr435-MV411-MYB-dTAG-DMSO_2h-r4_filtered.bam    0.281253
# ERCC_mr436-MV411-MYB-dTAG-DMSO_2h-r5_filtered.bam    0.256038
# ERCC_mr437-MV411-MYB-dTAG-VHL_2h-r1_filtered.bam     0.279720
# ERCC_mr438-MV411-MYB-dTAG-VHL_2h-r2_filtered.bam     0.285925
# ERCC_mr439-MV411-MYB-dTAG-VHL_2h-r3_filtered.bam     0.265613
# ERCC_mr440-MV411-MYB-dTAG-VHL_2h-r4_filtered.bam     0.287533
# ERCC_mr441-MV411-MYB-dTAG-VHL_2h-r5_filtered.bam     0.220194
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.67 s, sys: 1.7 s, total: 9.38 s
# Wall time: 5.75 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9.12 s, sys: 2.06 s, total: 11.2 s
# Wall time: 6.72 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_2h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_2h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.59 s, sys: 1.65 s, total: 9.24 s
# Wall time: 5.7 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9 s, sys: 2.02 s, total: 11 s
# Wall time: 6.77 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_2h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_2h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  45.190251        0.273015  0.313194 -0.871711  0.383366  0.735587   NAT1
# 3  44.977775       -0.624456  0.290171  2.152025  0.031395  0.188833   AAMP
# 4  69.579384        0.505409  0.166225 -3.040510  0.002362  0.027596  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
resGene_read.head()
# Out:
#       baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0     1.186268        0.721365  1.435567 -0.502495  0.615319       NaN   A1BG
# 1     2.746355        0.950378  0.888944 -1.069110  0.285020       NaN  A2MP1
# 2   310.018994        0.059052  0.171175 -0.344980  0.730109  0.966961   NAT1
# 3  1110.545906       -0.185126  0.189223  0.978350  0.327901  0.834637   AAMP
# 4   634.134786        0.104827  0.096690 -1.084156  0.278296  0.799028  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ## MYB 4hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 4h
gene = "MYB"
version = "v1"
var_name = "time"
var = "4h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 10
# 0
# ERCC_mr442-MV411-MYB-dTAG-DMSO_4h-r1_filtered.bam    0.232728
# ERCC_mr443-MV411-MYB-dTAG-DMSO_4h-r2_filtered.bam    0.328421
# ERCC_mr444-MV411-MYB-dTAG-DMSO_4h-r3_filtered.bam    0.220414
# ERCC_mr445-MV411-MYB-dTAG-DMSO_4h-r4_filtered.bam    0.281330
# ERCC_mr446-MV411-MYB-dTAG-DMSO_4h-r5_filtered.bam    0.272633
# ERCC_mr447-MV411-MYB-dTAG-VHL_4h-r1_filtered.bam     0.265445
# ERCC_mr448-MV411-MYB-dTAG-VHL_4h-r2_filtered.bam     0.264261
# ERCC_mr449-MV411-MYB-dTAG-VHL_4h-r3_filtered.bam     0.235749
# ERCC_mr450-MV411-MYB-dTAG-VHL_4h-r4_filtered.bam     0.242705
# ERCC_mr451-MV411-MYB-dTAG-VHL_4h-r5_filtered.bam     0.280104
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.75 s, sys: 1.7 s, total: 9.45 s
# Wall time: 5.82 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.42 s, sys: 2.04 s, total: 10.5 s
# Wall time: 6.32 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_4h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_4h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  26.414527        0.690513  0.351334 -1.965404  0.049367  0.162056   NAT1
# 3  21.215665       -0.632553  0.325720  1.942013  0.052135  0.168089   AAMP
# 4  31.465591        0.300500  0.255269 -1.177190  0.239120  0.448081  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    0.121765       -0.540574  3.158718  0.171137  0.864116       NaN   A1BG
# 1    0.366055        0.626279  2.337053 -0.267978  0.788716       NaN  A2MP1
# 2  291.711338        0.781437  0.183985 -4.247277  0.000022  0.000350   NAT1
# 3  746.516641       -0.327172  0.178182  1.836166  0.066333  0.188107   AAMP
# 4  501.317477        0.217266  0.111862 -1.942265  0.052105  0.159177  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.44 s, sys: 1.77 s, total: 9.21 s
# Wall time: 5.67 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.2 s, sys: 2.06 s, total: 10.3 s
# Wall time: 6.21 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_4h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_4h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  25.821671        0.639648  0.350121 -1.826935  0.067710  0.203726   NAT1
# 3  20.899280       -0.683553  0.322731  2.118027  0.034173  0.127981   AAMP
# 4  30.849996        0.252953  0.254973 -0.992078  0.321159  0.541330  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
resGene_read.head()
# Out:
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    0.121765       -0.595423  3.158718  0.188501  0.850484       NaN   A1BG
# 1    0.353852        0.552956  2.360917 -0.234212  0.814820       NaN  A2MP1
# 2  283.610998        0.718031  0.173124 -4.147488  0.000034  0.000430   NAT1
# 3  734.640773       -0.379684  0.179910  2.110406  0.034823  0.113494   AAMP
# 4  490.817851        0.162250  0.096971 -1.673173  0.094293  0.228096  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ## MYB 8hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 8h
gene = "MYB"
version = "v1"
var_name = "time"
var = "8h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 10
# 0
# ERCC_mr452-MV411-MYB-dTAG-DMSO_8h-r1_filtered.bam    0.258144
# ERCC_mr453-MV411-MYB-dTAG-DMSO_8h-r2_filtered.bam    0.234804
# ERCC_mr454-MV411-MYB-dTAG-DMSO_8h-r3_filtered.bam    0.208459
# ERCC_mr455-MV411-MYB-dTAG-DMSO_8h-r4_filtered.bam    0.248922
# ERCC_mr456-MV411-MYB-dTAG-DMSO_8h-r5_filtered.bam    0.195871
# ERCC_mr457-MV411-MYB-dTAG-VHL_8h-r1_filtered.bam     0.242670
# ERCC_mr458-MV411-MYB-dTAG-VHL_8h-r2_filtered.bam     0.240105
# ERCC_mr459-MV411-MYB-dTAG-VHL_8h-r3_filtered.bam     0.229044
# ERCC_mr460-MV411-MYB-dTAG-VHL_8h-r4_filtered.bam     0.234720
# ERCC_mr461-MV411-MYB-dTAG-VHL_8h-r5_filtered.bam     0.260140
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.09 s, sys: 1.81 s, total: 9.9 s
# Wall time: 6.15 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.17 s, sys: 1.85 s, total: 10 s
# Wall time: 6.03 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_8h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_8h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  28.522395       -0.240170  0.236283  1.016451  0.309415  0.576681   NAT1
# 3  24.540796        0.023796  0.246608 -0.096492  0.923130  0.973011   AAMP
# 4  36.429059       -0.330999  0.217694  1.520481  0.128390  0.339165  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    0.451699        1.183427  1.771724 -0.667952  0.504164       NaN   A1BG
# 1    0.631889       -2.186740  1.627883  1.343303  0.179174       NaN  A2MP1
# 2  201.906879       -0.336007  0.163372  2.056702  0.039715  0.108268   NAT1
# 3  693.698384       -0.386621  0.139597  2.769545  0.005613  0.022008   AAMP
# 4  510.823587        0.111244  0.075850 -1.466625  0.142478  0.288559  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.66 s, sys: 1.72 s, total: 9.38 s
# Wall time: 5.68 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9.07 s, sys: 1.99 s, total: 11.1 s
# Wall time: 6.75 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_8h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_8h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  29.123509       -0.171072  0.230137  0.743347  0.457271  0.716301   NAT1
# 3  25.163440        0.093770  0.241316 -0.388579  0.697588  0.870393   AAMP
# 4  37.305176       -0.257605  0.216248  1.191250  0.233555  0.500210  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
resGene_read.head()
# Out:
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    0.471633        1.263503  1.737631 -0.727141  0.467139       NaN   A1BG
# 1    0.637056       -2.113872  1.615785  1.308263  0.190784       NaN  A2MP1
# 2  206.117421       -0.268210  0.156450  1.714347  0.086465  0.199871   NAT1
# 3  708.759792       -0.315782  0.136812  2.308137  0.020991  0.064981   AAMP
# 4  524.769153        0.185493  0.075339 -2.462121  0.013812  0.046418  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ## MYB 12hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 12h
gene = "MYB"
version = "v1"
var_name = "time"
var = "12h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 9
# 0
# ERCC_mr462-MV411-MYB-dTAG-DMSO_12h-r1_filtered.bam    0.218186
# ERCC_mr463-MV411-MYB-dTAG-DMSO_12h-r2_filtered.bam    0.342477
# ERCC_mr464-MV411-MYB-dTAG-DMSO_12h-r3_filtered.bam    0.214905
# ERCC_mr465-MV411-MYB-dTAG-DMSO_12h-r4_filtered.bam    0.268611
# ERCC_mr466-MV411-MYB-dTAG-DMSO_12h-r5_filtered.bam    0.199878
# ERCC_mr467-MV411-MYB-dTAG-VHL_12h-r1_filtered.bam     0.250832
# ERCC_mr468-MV411-MYB-dTAG-VHL_12h-r2_filtered.bam     0.234284
# ERCC_mr469-MV411-MYB-dTAG-VHL_12h-r3_filtered.bam     0.335219
# ERCC_mr470-MV411-MYB-dTAG-VHL_12h-r4_filtered.bam     0.246705
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.09 s, sys: 1.81 s, total: 9.9 s
# Wall time: 6.09 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.19 s, sys: 1.9 s, total: 10.1 s
# Wall time: 6.02 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_12h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_12h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  17.309238        0.091628  0.343473 -0.266769  0.789647  0.922138   NAT1
# 3  19.186966       -1.312183  0.368728  3.558677  0.000373  0.006721   AAMP
# 4  23.696832       -0.207149  0.314842  0.657947  0.510572  0.765489  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    0.814472        0.625308  1.788192 -0.349688  0.726573       NaN   A1BG
# 1    1.311510       -2.458786  1.560671  1.575468  0.115148       NaN  A2MP1
# 2  189.345664       -0.179266  0.197250  0.908825  0.363443  0.603296   NAT1
# 3  656.623476       -0.795272  0.188314  4.223128  0.000024  0.000352   AAMP
# 4  502.352911       -0.232702  0.173364  1.342276  0.179507  0.397784  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 7.6 s, sys: 1.79 s, total: 9.4 s
# Wall time: 5.68 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.39 s, sys: 2.2 s, total: 10.6 s
# Wall time: 6.2 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_12h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_12h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  17.840460        0.170673  0.326487 -0.522754  0.601145  0.804602   NAT1
# 3  19.447619       -1.236768  0.353986  3.493828  0.000476  0.006852   AAMP
# 4  24.304242       -0.126294  0.300160  0.420756  0.673933  0.845716  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat        pvalue      padj  \
# 0    0.812766        0.645336  1.696823 -0.380320  7.037077e-01       NaN
# 1    1.305862       -2.403041  1.498628  1.603494  1.088256e-01       NaN
# 2  193.145236       -0.108350  0.162437  0.667027  5.047551e-01  0.699079
# 3  664.455425       -0.739525  0.138600  5.335671  9.519176e-08  0.000002
# 4  512.848038       -0.158971  0.141926  1.120099  2.626718e-01  0.469512
#
#    genes gene_id
# 0   A1BG    A1BG
# 1  A2MP1   A2MP1
# 2   NAT1    NAT1
# 3   AAMP    AAMP
# 4  AARS1   AARS1

# %% [markdown]
# ## MYB 24hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 24h
gene = "MYB"
version = "v1"
var_name = "time"
var = "24h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 10
# 0
# ERCC_mr472-MV411-MYB-dTAG-DMSO_24h-r1_filtered.bam    0.172618
# ERCC_mr473-MV411-MYB-dTAG-DMSO_24h-r2_filtered.bam    0.158383
# ERCC_mr474-MV411-MYB-dTAG-DMSO_24h-r3_filtered.bam    0.132477
# ERCC_mr475-MV411-MYB-dTAG-DMSO_24h-r4_filtered.bam    0.145428
# ERCC_mr476-MV411-MYB-dTAG-DMSO_24h-r5_filtered.bam    0.174183
# ERCC_mr477-MV411-MYB-dTAG-VHL_24h-r1_filtered.bam     0.216323
# ERCC_mr478-MV411-MYB-dTAG-VHL_24h-r2_filtered.bam     0.189736
# ERCC_mr479-MV411-MYB-dTAG-VHL_24h-r3_filtered.bam     0.216881
# ERCC_mr480-MV411-MYB-dTAG-VHL_24h-r4_filtered.bam     0.162076
# ERCC_mr481-MV411-MYB-dTAG-VHL_24h-r5_filtered.bam     0.195627
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.85 s, sys: 2.37 s, total: 11.2 s
# Wall time: 6.31 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9.36 s, sys: 2.61 s, total: 12 s
# Wall time: 6.67 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_24h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_24h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.077189       -0.261389  3.160747  0.082698  0.934091       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  35.494990        0.088693  0.263100 -0.337106  0.736037  0.847250   NAT1
# 3  28.971679       -0.756021  0.255515  2.958818  0.003088  0.013639   AAMP
# 4  48.174603       -0.815713  0.208873  3.905300  0.000094  0.000684  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat        pvalue          padj  \
# 0    1.825646        0.568979  0.994951 -0.571866  5.674125e-01  6.870952e-01
# 1    0.858275        2.295337  1.438440 -1.595712  1.105530e-01           NaN
# 2  208.551907       -0.571365  0.178402  3.202687  1.361517e-03  4.428881e-03
# 3  685.174540       -0.608742  0.139817  4.353840  1.337734e-05  7.573418e-05
# 4  614.018930       -0.607739  0.109715  5.539267  3.037404e-08  3.238794e-07
#
#    genes gene_id
# 0   A1BG    A1BG
# 1  A2MP1   A2MP1
# 2   NAT1    NAT1
# 3   AAMP    AAMP
# 4  AARS1   AARS1

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.11 s, sys: 2.16 s, total: 10.3 s
# Wall time: 5.89 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 9.92 s, sys: 2.55 s, total: 12.5 s
# Wall time: 6.96 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_24h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_24h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.093512        0.055134  3.160747 -0.017443  0.986083       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  39.511016        0.380466  0.234886 -1.619791  0.105277  0.245976   NAT1
# 3  31.338972       -0.460167  0.226250  2.033889  0.041963  0.124256   AAMP
# 4  52.273568       -0.513803  0.186210  2.759262  0.005793  0.026089  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    2.165543        0.917645  0.917392 -1.000275  0.317177  0.484732   A1BG
# 1    1.075531        2.636549  1.289652 -2.044388  0.040915       NaN  A2MP1
# 2  228.497530       -0.264125  0.164748  1.603209  0.108888  0.217985   NAT1
# 3  749.424060       -0.300492  0.111429  2.696701  0.007003  0.023195   AAMP
# 4  672.920642       -0.294871  0.071068  4.149122  0.000033  0.000213  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# ## MYB 48hr

# %% [markdown]
# ### make design matrix

# %%
# MYB dTAG 48h
gene = "MYB"
version = "v1"
var_name = "time"
var = "48h"
drop_rep = exp_design.loc[(exp_design[var_name] == var) & (exp_design["drop"] == True), "col"]

# %%
# tccounts
tccountsGene = tccounts[tccounts.columns[:-1]]

# readcounts
readcountsGene = readcounts[readcounts.columns[:-1]]

# %%
# get just var data
# remove dropped reps
var_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["drop"] == False)
            else 0 for idx in range(exp_design.shape[0])]

DMSO_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "DMSO") and
             (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

VHL_cols = [1 if (exp_design.iloc[idx][var_name] == var) and (exp_design.iloc[idx]["treatment"] == "VHL") and 
            (exp_design.iloc[idx]["drop"] == False) else 0 for idx in range(exp_design.shape[0])]

# %%
# RUNX1 dTAG (all columns)
design = pd.DataFrame(index= [i.replace("-",".") for i in tccountsGene.columns], 
                      columns=["DMSO","VHL"], 
                      data=np.array([DMSO_cols, VHL_cols], dtype=bool).T)

# %%
# genes as first column
tccountsGene = tccounts[['genes']+list(tccountsGene.columns)]
readcountsGene = readcounts[['genes']+list(readcountsGene.columns)]

# %% [markdown]
# ### ERCC samplewise scaled

# %%
scaling="ERCCsamplewise"

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate & modify size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %%
# read in ERCC pseudocounts
res = pd.read_csv(res_dir+"/"+project+"_scaling_factors.csv", index_col=0, header=None, squeeze=True)

# select var values
res = res[np.array(var_cols, dtype=bool)]
print(len(res))
res
# Out:
# 8
# 0
# ERCC_mr483-MV411-MYB-dTAG-DMSO_48h-r2_filtered.bam    0.286577
# ERCC_mr484-MV411-MYB-dTAG-DMSO_48h-r3_filtered.bam    0.293983
# ERCC_mr485-MV411-MYB-dTAG-DMSO_48h-r4_filtered.bam    0.255793
# ERCC_mr486-MV411-MYB-dTAG-DMSO_48h-r5_filtered.bam    0.282587
# ERCC_mr488-MV411-MYB-dTAG-VHL_48h-r2_filtered.bam     0.351553
# ERCC_mr489-MV411-MYB-dTAG-VHL_48h-r3_filtered.bam     0.581743
# ERCC_mr490-MV411-MYB-dTAG-VHL_48h-r4_filtered.bam     0.540469
# ERCC_mr491-MV411-MYB-dTAG-VHL_48h-r5_filtered.bam     0.445321
# Name: 1, dtype: float64

# %% [markdown]
# __modify size factors__
# <br>VHL size factor * adjusted VHL res (VHL res per sample / average DMSO res)

# %%
# tccounts
sizeFact = deseqGene_tc.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_tc.setSizeFactors(sizeFact)

# %%
# readcounts
sizeFact = deseqGene_read.getSizeFactors()
sizeFact[sum(DMSO_cols):] = sizeFact[sum(DMSO_cols):] * (res[[i for i in res.index if '-VHL' in i]].values/
                                                         res[[i for i in res.index if '-DMSO' in i]].values.mean())
deseqGene_read.setSizeFactors(sizeFact)

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 6.12 s, sys: 868 ms, total: 6.99 s
# Wall time: 5.13 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.24 s, sys: 1.66 s, total: 9.9 s
# Wall time: 6.29 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not tccounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not tccounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_48h_ERCCsamplewise_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_48h_ERCCsamplewise_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat        pvalue          padj  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000e+00           NaN
# 1   0.000000       -0.000000       NaN       NaN  0.000000e+00           NaN
# 2  24.545198       -0.407504  0.336880  1.209642  2.264163e-01  3.397572e-01
# 3  24.228007       -1.357039  0.397788  3.411467  6.461432e-04  3.008671e-03
# 4  56.902746       -1.857605  0.269588  6.890522  5.558785e-12  2.521362e-10
#
#    genes gene_id
# 0   A1BG    A1BG
# 1  A2MP1   A2MP1
# 2   NAT1    NAT1
# 3   AAMP    AAMP
# 4  AARS1   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat        pvalue          padj  \
# 0    1.601994        0.801035  1.258271 -0.636616  5.243752e-01  6.347330e-01
# 1    1.117891        0.363654  1.467424 -0.247818  8.042752e-01  8.647796e-01
# 2  143.184246       -0.981573  0.247223  3.970405  7.175056e-05  2.758278e-04
# 3  549.901762       -0.873362  0.241513  3.616206  2.989522e-04  9.816512e-04
# 4  603.150650       -1.518533  0.202747  7.489790  6.898366e-14  1.875220e-12
#
#    genes gene_id
# 0   A1BG    A1BG
# 1  A2MP1   A2MP1
# 2   NAT1    NAT1
# 3   AAMP    AAMP
# 4  AARS1   AARS1

# %% [markdown]
# ### Unscaled

# %%
scaling = None

# %% [markdown]
# #### make DESeq object

# %%
# tccounts DESeq gene object
# just var data
deseqGene_tc = pyDESeq2.pyDESeq2(count_matrix=tccountsGene[tccountsGene.columns[np.array([1]+var_cols, bool)]], 
                                 design_matrix=design[np.array(var_cols, bool)],
                                 design_formula="~DMSO - VHL",
                                 gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %%
# readcounts DESeq gene object
# just var data
deseqGene_read = pyDESeq2.pyDESeq2(count_matrix=readcountsGene[readcountsGene.columns[np.array([1]+var_cols, bool)]], 
                                   design_matrix=design[np.array(var_cols, bool)],
                                   design_formula="~DMSO - VHL",
                                   gene_column="genes")
# Out:
# you need to have R installed with the DESeq2 library installed
# 3.4.5

# %% [markdown]
# #### estimate size factors

# %%
# tccounts
deseqGene_tc.run_estimate_size_factors(geoMeans = np.exp(np.mean(np.log(
    readcounts[tccountsGene.columns[[False]+design["DMSO"].tolist()]].values+1), 1)))

# readcounts
deseqGene_read.run_estimate_size_factors()

# %% [markdown]
# #### run it

# %%
# %%time

# tccounts
deseqGene_tc.run_deseq()
deseqGene_tc.get_deseq_result()

resGene_tc = deseqGene_tc.deseq_result
resGene_tc.pvalue = np.nan_to_num(np.array(resGene_tc.pvalue), 1)
resGene_tc.log2FoldChange = np.nan_to_num(np.array(resGene_tc.log2FoldChange), 0)
resGene_tc.log2FoldChange = -resGene_tc.log2FoldChange
resGene_tc["gene_id"] = resGene_tc.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 6.96 s, sys: 1 s, total: 7.97 s
# Wall time: 5.81 s

# %%
# %%time

#readcounts
deseqGene_read.run_deseq()
deseqGene_read.get_deseq_result()

resGene_read = deseqGene_read.deseq_result
resGene_read.pvalue = np.nan_to_num(np.array(resGene_read.pvalue), 1)
resGene_read.log2FoldChange = np.nan_to_num(np.array(resGene_read.log2FoldChange), 0)
resGene_read.log2FoldChange = -resGene_read.log2FoldChange
resGene_read["gene_id"] = resGene_read.genes
# Out:
# R[write to console]: using pre-existing size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
# CPU times: user 8.37 s, sys: 1.94 s, total: 10.3 s
# Wall time: 5.95 s

# %% [markdown]
# #### save DESeq results

# %%
# check all genes are in output
if not readcounts.shape[0] == resGene_tc.shape[0]:
    raise ValueError("Results do not have the same number of genes as counts.")

if not readcounts["genes"].isin(resGene_tc["genes"]).all():
    raise ValueError("Results do not have the same genes as counts.")

# %%
# tccounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_tccounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_tc.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_48h_0_5_deseq_tccounts.csv

# %%
# readcounts
#res_dir = "slamseq_{}".format(project)

deseq_res_file = "{}_{}_deseq_readcounts.csv".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
resGene_read.to_csv("{}/{}".format(res_dir, deseq_res_file), index=False)

print("Saved DESeq results to: {}".format(deseq_res_file))
# Out:
# Saved DESeq results to: MYB_degraded_timecourse_v1_MYB_48h_0_5_deseq_readcounts.csv

# %%
print(resGene_tc.shape)
resGene_tc.head()
# Out:
# (18305, 8)
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.000000       -0.000000       NaN       NaN  0.000000       NaN   A1BG
# 1   0.000000       -0.000000       NaN       NaN  0.000000       NaN  A2MP1
# 2  31.858555        0.339874  0.298272 -1.139476  0.254505  0.467440   NAT1
# 3  29.033709       -0.604376  0.377976  1.598981  0.109825  0.266266   AAMP
# 4  66.075502       -1.083337  0.256242  4.227784  0.000024  0.000277  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %%
print(resGene_read.shape)
resGene_read.head()
# Out:
# (18305, 8)
#      baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0    2.240673        1.524158  1.170742 -1.301873  0.192960  0.334765   A1BG
# 1    1.565287        1.107710  1.364342 -0.811901  0.416849  0.575441  A2MP1
# 2  175.818206       -0.235674  0.205305  1.147920  0.251002  0.404705   NAT1
# 3  677.565048       -0.144131  0.183220  0.786660  0.431481  0.588881   AAMP
# 4  712.040620       -0.755144  0.178529  4.229819  0.000023  0.000160  AARS1
#
#   gene_id
# 0    A1BG
# 1   A2MP1
# 2    NAT1
# 3    AAMP
# 4   AARS1

# %% [markdown]
# # PLOTS

# %% [markdown]
# ## whisker's plots

# %% [markdown]
# ### Get CRCs

# %%
crc = pd.read_csv('../data/CRCs.txt',header=None)[0].values.tolist()
print(len(crc))
print(crc)
# Out:
# 31
# ['CEBPA', 'E2F3', 'FLI1', 'FOSL2', 'GFI1', 'HEX', 'IRF8', 'LYL1', 'MEF2C', 'MEF2D', 'MEIS1', 'MYB', 'PLAGL2', 'RUNX1', 'RUNX2', 'RXRA', 'SP1', 'SPI1', 'SREBF1', 'STAT5B', 'TFAP4', 'ZEB2', 'ZFPM1', 'ZNF281', 'LMO2', 'ZMYND8', 'GATA2', 'MAX', 'MYC', 'ETV6', 'HOXA9']

# %% [markdown]
# ### MYB 1h (unscaled)

# %%
# %matplotlib inline

# %%
# MYB dTAG 1h
gene = "MYB"
version = "v1"
var_name = "time"
var = "1h"
scaling=None

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_1h_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
#resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue          padj
# 0.00     0.000000       -6.885410  0.081930 -16.026083  0.000000  4.169242e-87
# 0.45     3.297442       -0.000000  0.377294  -0.214276  0.312183  8.143409e-01
# 0.50     5.453019        0.000000  0.432355  -0.092227  0.381684  8.435402e-01
# 0.75    33.586157        0.275681  1.141081   0.581614  0.722900  9.395009e-01
# 1.00  4834.938853        3.775585  3.352475  20.244847  0.999503  9.995027e-01

# %%
#resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00       0.000000       -3.983753  0.076678 -13.142706  0.000000
# 0.45      69.326787       -0.008962  0.191052  -0.277148  0.336871
# 0.50     111.514525        0.032029  0.208633  -0.123315  0.392057
# 0.75     650.883340        0.236780  0.635873   0.729347  0.686658
# 1.00  192666.451207        4.663691  3.352475  12.848621  0.999966
#
#               padj
# 0.00  2.559162e-35
# 0.45  6.211564e-01
# 0.50  6.518995e-01
# 0.75  8.387542e-01
# 1.00  9.999658e-01

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   4.297009        0.752786  0.450361 -1.671517  0.094620  0.521209   NAT1
# 3   4.927907       -0.223276  0.276458  0.807631  0.419303  0.842671   AAMP
# 4   5.109371        0.108817  0.288949 -0.376597  0.706473  0.939624  AARS1
# 10  6.134381       -0.329921  0.195381  1.688604  0.091295  0.516477  ABCF1
# 11  6.518499       -0.296996  0.187487  1.584088  0.113174  0.560093   ABL1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 10   ABCF1  other
# 11    ABL1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_1h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_1h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 2h (unscaled)

# %%
# %matplotlib inline

# %%
# MYB dTAG 2h
gene = "MYB"
version = "v1"
var_name = "time"
var = "2h"
scaling = None

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_2h_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue          padj
# 0.00     0.000000       -7.839439  0.056167 -19.909083  0.000000  1.127083e-92
# 0.45     5.299296       -0.000000  0.290908  -0.224087  0.256408  6.747991e-01
# 0.50     8.781921        0.000000  0.329911  -0.095603  0.331980  7.188177e-01
# 0.75    56.026930        0.279917  0.905071   0.686466  0.691653  8.869381e-01
# 1.00  8275.895513        4.618558  3.160747  20.869330  0.999712  9.997123e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00       0.000000       -3.237344  0.041529 -20.756989  0.000000
# 0.45      75.410636       -0.002800  0.182535  -0.261008  0.400753
# 0.50     119.690443        0.025952  0.202048  -0.127808  0.453781
# 0.75     722.613135        0.258950  0.606672   0.618913  0.724977
# 1.00  229179.596093        4.912589  3.160747  20.541718  0.999818
#
#               padj
# 0.00  1.510003e-91
# 0.45  8.786791e-01
# 0.50  9.002336e-01
# 0.75  9.647281e-01
# 1.00  9.998177e-01

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   5.529516        0.273015  0.313194 -0.871711  0.383366  0.735587   NAT1
# 3   5.522865       -0.624456  0.290171  2.152025  0.031395  0.188833   AAMP
# 4   6.141175        0.505409  0.166225 -3.040510  0.002362  0.027596  AARS1
# 10  6.557188       -0.349387  0.239186  1.460732  0.144089  0.472211  ABCF1
# 11  6.732463       -0.097869  0.169552  0.577221  0.563790  0.844917   ABL1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 10   ABCF1  other
# 11    ABL1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_2h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_2h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 4h (unscaled)

# %%
# %matplotlib inline

# %%
# MYB dTAG 4h
gene = "MYB"
version = "v1"
var_name = "time"
var = "4h"
scaling=None

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_4h_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00     0.000000       -6.948540  0.073944 -14.563087  0.000000
# 0.45     3.022219       -0.000000  0.371652  -0.163562  0.130603
# 0.50     4.914857        0.000000  0.425978  -0.000549  0.208024
# 0.75    29.926014        0.332335  1.142716   0.896255  0.643059
# 1.00  3982.391427        4.635158  3.160747  22.603521  0.999962
#
#                padj
# 0.00  4.209658e-109
# 0.45   3.456167e-01
# 0.50   4.258013e-01
# 0.75   7.514567e-01
# 1.00   9.996459e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00       0.000000       -4.574308  0.065563 -22.456107  0.000000
# 0.45      58.294527       -0.020091  0.178955  -0.303537  0.196753
# 0.50      91.689555        0.024864  0.200440  -0.112962  0.261255
# 0.75     573.100456        0.376745  0.647419   1.005999  0.624327
# 1.00  177875.429281        4.948241  3.160747  26.842265  0.999941
#
#                padj
# 0.00  1.518883e-154
# 0.45   2.776457e-01
# 0.50   3.419048e-01
# 0.75   7.011808e-01
# 1.00   9.998303e-01

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   4.745327        0.639648  0.350121 -1.826935  0.067710  0.203726   NAT1
# 3   4.452812       -0.683553  0.322731  2.118027  0.034173  0.127981   AAMP
# 4   4.993221        0.252953  0.254973 -0.992078  0.321159  0.541330  AARS1
# 5   3.648908        0.266582  0.373440 -0.713854  0.475317  0.681857   ABAT
# 10  5.446691       -0.870906  0.242488  3.591542  0.000329  0.004021  ABCF1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 5     ABAT  other
# 10   ABCF1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_4h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_4h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 8h (unscaled)

# %%
# %matplotlib inline

# %%
# MYB dTAG 8h
gene = "MYB"
version = "v1"
var_name = "time"
var = "8h"
scaling=None

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_8h_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00     0.000000       -9.072170  0.052768 -29.123296  0.000000
# 0.45     3.560394       -0.000000  0.310552  -0.058651  0.158568
# 0.50     5.882089        0.000000  0.355885   0.115601  0.234419
# 0.75    35.558121        0.185380  1.008240   1.021185  0.660866
# 1.00  4511.019186        4.780008  3.160747  22.240809  0.999901
#
#                padj
# 0.00  2.201063e-182
# 0.45   4.732954e-01
# 0.50   5.466467e-01
# 0.75   8.261279e-01
# 1.00   9.999014e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00       0.000000       -6.296404  0.035502 -35.614750  0.000000
# 0.45      56.202038       -0.056124  0.146093  -0.149075  0.151578
# 0.50      88.885436       -0.004453  0.163416   0.064525  0.211801
# 0.75     516.761658        0.288861  0.573788   1.264412  0.599344
# 1.00  157352.746485        5.502280  3.160747  26.893456  0.999986
#
#                padj
# 0.00  1.290958e-273
# 0.45   2.235145e-01
# 0.50   3.024848e-01
# 0.75   6.909240e-01
# 1.00   9.999865e-01

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   4.912818       -0.171072  0.230137  0.743347  0.457271  0.716301   NAT1
# 3   4.709480        0.093770  0.241316 -0.388579  0.697588  0.870393   AAMP
# 4   5.259467       -0.257605  0.216248  1.191250  0.233555  0.500210  AARS1
# 5   3.532139        0.278657  0.381462 -0.730497  0.465087  0.722329   ABAT
# 10  6.004455       -0.404354  0.162984  2.480938  0.013104  0.071685  ABCF1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 5     ABAT  other
# 10   ABCF1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_8h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_8h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 12h (unscaled)

# %%
# %matplotlib inline

# %%
# MYB dTAG 12h
gene = "MYB"
version = "v1"
var_name = "time"
var = "12h"
scaling=None

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_12h_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00     0.000000       -8.711061  0.085891 -22.616491  0.000000
# 0.45     2.460794       -0.000000  0.418866  -0.033091  0.174787
# 0.50     4.023927        0.000000  0.475528   0.041018  0.246864
# 0.75    23.378027        0.243132  1.202699   0.859942  0.669571
# 1.00  3707.740219        6.742002  3.352471  11.897725  0.999732
#
#                padj
# 0.00  3.017403e-109
# 0.45   4.671572e-01
# 0.50   5.312608e-01
# 0.75   8.083665e-01
# 1.00   9.994479e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue      padj
# 0.00       0.000000       -5.906845  0.063576 -38.237953  0.000000  0.000000
# 0.45      50.292179       -0.065613  0.199408  -0.129995  0.209482  0.304185
# 0.50      81.091291       -0.008972  0.225112   0.043310  0.274848  0.383754
# 0.75     467.508578        0.335288  0.761775   1.100514  0.639360  0.736713
# 1.00  146137.359163        6.301837  3.352471  39.540943  0.999832  0.999832

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   4.235762        0.170673  0.326487 -0.522754  0.601145  0.804602   NAT1
# 3   4.353861       -1.236768  0.353986  3.493828  0.000476  0.006852   AAMP
# 4   4.661307       -0.126294  0.300160  0.420756  0.673933  0.845716  AARS1
# 10  5.351592       -0.176688  0.254105  0.695335  0.486846  0.731552  ABCF1
# 11  5.174917       -0.192052  0.267580  0.717737  0.472919  0.721032   ABL1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 10   ABCF1  other
# 11    ABL1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_12h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_12h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 24h (ERCC normalized)

# %%
# %matplotlib inline

# %%
# MYB dTAG 24h
gene = "MYB"
version = "v1"
var_name = "time"
var = "24h"
scaling="ERCCsamplewise"

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_24h_ERCCsamplewise_0_5_deseq'

# %%
# read in DESeq outputs
resGene_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00     0.000000       -9.343938  0.086949 -23.915035  0.000000
# 0.45     4.823387       -0.261398  0.304962   0.494721  0.065690
# 0.50     7.664118       -0.222022  0.348457   0.722086  0.121572
# 0.75    43.608181        0.000000  0.981763   2.077949  0.571215
# 1.00  4766.412014        6.890170  3.160747  25.118831  0.999838
#
#                padj
# 0.00  3.912144e-135
# 0.45   2.096015e-01
# 0.50   2.791842e-01
# 0.75   6.657460e-01
# 1.00   9.998376e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue      padj
# 0.00       0.000000       -9.240682  0.090315 -39.580354  0.000000  0.000000
# 0.45      72.005610       -0.359986  0.175323   0.813044  0.037654  0.050400
# 0.50     112.273714       -0.301474  0.188749   1.121752  0.075181  0.093633
# 0.75     591.562385        0.100709  0.587676   3.053708  0.483377  0.532263
# 1.00  181458.903625        8.555197  3.160747  37.435845  0.999986  0.999986

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene_tc[resGene_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 2   5.189627        0.088693  0.263100 -0.337106  0.736037  0.847250   NAT1
# 3   4.905528       -0.756021  0.255515  2.958818  0.003088  0.013639   AAMP
# 4   5.619841       -0.815713  0.208873  3.905300  0.000094  0.000684  AARS1
# 5   4.098257        1.364809  0.362217 -3.767933  0.000165  0.001119   ABAT
# 10  6.086314       -0.613824  0.175941  3.488811  0.000485  0.002880  ABCF1
#
#    gene_id   type
# 2     NAT1  other
# 3     AAMP  other
# 4    AARS1  other
# 5     ABAT  other
# 10   ABCF1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_24h_ERCCsamplewise_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_1h_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_24h_ERCCsamplewise_0_5_whiskers_baseMean.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_1h_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ### MYB 48h (ERCC normalized)

# %%
# MYB dTAG 48h
gene = "MYB"
version = "v1"
var_name = "time"
var = "48h"
scaling="ERCCsamplewise"

# %%
deseq_res_file_prefix = "{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))
deseq_res_file_prefix
# Out:
# 'MYB_degraded_timecourse_v1_MYB_48h_ERCCsamplewise_0_5_deseq'

# %%
# read in DESeq outputs
resGene48_tc = pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), 
                           header=[0], index_col=None, squeeze=True)
resGene48_read = pd.read_csv("{}/{}_readcounts.csv".format(res_dir, deseq_res_file_prefix), 
                             header=[0], index_col=None, squeeze=True)

# %%
resGene48_tc.quantile([0,0.45,0.5,0.75,1])
# Out:
#          baseMean  log2FoldChange     lfcSE       stat    pvalue          padj
# 0.00     0.000000       -9.177067  0.169092 -16.227412  0.000000  1.044586e-65
# 0.45     4.156353       -0.660514  0.413642   1.043450  0.019955  8.836985e-02
# 0.50     6.820628       -0.527618  0.463342   1.279505  0.047673  1.306414e-01
# 0.75    38.311320        0.000000  1.172454   2.724074  0.459947  4.867137e-01
# 1.00  4312.111329        7.572320  3.533812  17.662418  0.999993  9.999934e-01

# %%
resGene_read.quantile([0,0.45,0.5,0.75,1])
# Out:
#            baseMean  log2FoldChange     lfcSE       stat    pvalue  \
# 0.00       0.000000      -13.122387  0.115783 -36.254878  0.000000
# 0.45      76.472395       -0.030543  0.224812  -0.383092  0.092286
# 0.50     117.277725        0.050040  0.243941  -0.141889  0.141922
# 0.75     621.434118        0.630694  0.677276   1.380892  0.524107
# 1.00  220675.124521        9.466558  3.533812  30.970142  0.999917
#
#                padj
# 0.00  1.400734e-283
# 0.45   1.456294e-01
# 0.50   2.129234e-01
# 0.75   6.192351e-01
# 1.00   9.999174e-01

# %%
# DESeq results
# baseMean: normalized counts of all samples, normalizing for seqencing depth
res = resGene48_tc[resGene48_tc.baseMean>10]
res = res.assign(baseMean = np.log2(1+res["baseMean"]))
res["type"] = ['crc' if i else "other" for i in  res.genes.isin(crc)]
res.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat        pvalue          padj  \
# 2   4.674980       -0.407504  0.336880  1.209642  2.264163e-01  3.397572e-01
# 3   4.656954       -1.357039  0.397788  3.411467  6.461432e-04  3.008671e-03
# 4   5.855560       -1.857605  0.269588  6.890522  5.558785e-12  2.521362e-10
# 5   3.962011        0.309172  0.440505 -0.701859  4.827674e-01  5.989987e-01
# 10  5.957719       -0.801783  0.271106  2.957454  3.101907e-03  1.106119e-02
#
#     genes gene_id   type
# 2    NAT1    NAT1  other
# 3    AAMP    AAMP  other
# 4   AARS1   AARS1  other
# 5    ABAT    ABAT  other
# 10  ABCF1   ABCF1  other

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_logfch.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax = sns.boxplot(data=res,x="type",y="log2FoldChange").set_title("{} at {} foldChange".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_48h_ERCCsamplewise_0_5_whiskers_logfch.pdf

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_whiskers_baseMean.pdf".format(
    project, "_".join(filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)])))

ax =sns.boxplot(data=res,x="type",y="baseMean").set_title("{} at {} baseMean".format(gene, var))
ax.figure.savefig(fig_file, bbox_inches="tight")
print("Saved box and whisker plot to: {}".format(fig_file))
# Out:
# Saved box and whisker plot to: ../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_48h_ERCCsamplewise_0_5_whiskers_baseMean.pdf

# %% [markdown]
# ## Scatter plot comparison

# %% [markdown]
# tccounts: log2fc

# %% [markdown]
# ### MYB 1h vs 2h

# %%
# MYB dTAG 1h vs 2h
gene = "MYB"
version = "v1"
var_name = "time"
comp_vars = ["1h", "2h"]
scaling=None

# %%
deseq_res_file_prefixes = ["{}_{}_deseq".format(project, "_".join(
    filter(None, [gene, var, scaling, str(minvar_toremove), str(mincount_toremove)]))) for var in comp_vars]
deseq_res_file_prefixes
# Out:
# ['MYB_degraded_timecourse_v1_MYB_1h_0_5_deseq',
#  'MYB_degraded_timecourse_v1_MYB_2h_0_5_deseq']

# %%
# read in DESeq tccounts outputs
res_comp = [pd.read_csv("{}/{}_tccounts.csv".format(res_dir, deseq_res_file_prefix), header=[0], index_col=None, squeeze=True)
            for deseq_res_file_prefix in deseq_res_file_prefixes]

# %%
mix = pd.DataFrame()
mix["gene_id"] = res_comp[0]["gene_id"]

# %%
comp_labels = ["{} {}".format(gene, comp) for comp in comp_vars]

# %%
# combine deseq log2fc outputs
for idx, comp_label in enumerate(comp_labels):
    mix[comp_label] = res_comp[idx]["log2FoldChange"]

# %%
print(mix.shape)
mix.head()
# Out:
# (18305, 3)
#   gene_id    MYB 1h    MYB 2h
# 0    A1BG -0.000000 -0.000000
# 1   A2MP1 -0.000000 -0.000000
# 2    NAT1  0.752786  0.273015
# 3    AAMP -0.223276 -0.624456
# 4   AARS1  0.108817  0.505409

# %%
fig_file = "../results/slamseq_{0}/plots/{0}_{1}_scatter_logfch.pdf".format(
    project, "_".join(filter(None, [gene, comp_vars[0], comp_vars[1], scaling, 
                                    str(minvar_toremove), str(mincount_toremove)])))
fig_file
# Out:
# '../results/slamseq_MYB_degraded_timecourse_v1/plots/MYB_degraded_timecourse_v1_MYB_1h_2h_0_5_scatter_logfch.pdf'

# %%
plot_dir = "../results/slamseq_{0}/plots/".format(project)
plot_dir
# Out:
# '../results/slamseq_MYB_degraded_timecourse_v1/plots/'

# %%
genepyPlot.scatter(data=mix[comp_labels].values[:12000],
                   labels=mix['gene_id'].values.tolist()[:12000], 
                   showlabels=False, 
                   radi= 0.06, alpha=0.3,
                   colors = [0 if i in crc else 1 for i in mix['gene_id'].values.tolist()[:12000]],
                   xname=comp_labels[0], yname=comp_labels[1],
                   folder=plot_dir,
                   title="{} {} vs {} differences in logFoldChange".format(gene, comp_vars[0], comp_vars[1]))
# Out:
#   <div class="bk-root" id="e8659a04-96cb-4176-82b8-b58750acb98e" data-root-id="1374"></div>
# /home/monika/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /home/monika/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4049/4259909554.py in <module>
# ----> 1 genepyPlot.scatter(data=mix[comp_labels].values[:12000],
#       2                    labels=mix['gene_id'].values.tolist()[:12000],
#       3                    showlabels=False,
#       4                    radi= 0.06, alpha=0.3,
#       5                    colors = [0 if i in crc else 1 for i in mix['gene_id'].values.tolist()[:12000]],
#
# ~/genepy/genepy/utils/plot.py in scatter(data, labels, title, showlabels, folder, colors, xname, yname, importance, radi, alpha, colprovided, **kwargs)
#     104   if folder:
#     105     save(p, folder + title.replace(' ', "_") + "_scatter.html")
# --> 106     export_svg(p, filename=folder + title.replace(' ', "_") + "_scatter.svg")
#     107   return p
#     108
#
# ~/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/export.py in export_svg(obj, filename, width, height, webdriver, timeout)
#     141
#     142     '''
# --> 143     svgs = get_svg(obj, width=width, height=height, driver=webdriver, timeout=timeout)
#     144     return _write_collection(svgs, filename, "svg")
#     145
#
# ~/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/export.py in get_svg(obj, driver, timeout, resources, width, height)
#     241             file.write(html)
#     242
# --> 243         web_driver = driver if driver is not None else webdriver_control.get()
#     244         web_driver.get("file:///" + tmp.path)
#     245         wait_until_render_complete(web_driver, timeout)
#
# ~/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/webdriver.py in get(self)
#     147         if not self.reuse or self.current is None:
#     148             self.reset()
# --> 149             self.current = self.create()
#     150         return self.current
#     151
#
# ~/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/webdriver.py in create(self, kind)
#     151
#     152     def create(self, kind: Optional[DriverKind] = None) -> WebDriver:
# --> 153         driver = self._create(kind)
#     154         self._drivers.add(driver)
#     155         return driver
#
# ~/anaconda3/envs/slamseq/lib/python3.8/site-packages/bokeh/io/webdriver.py in _create(self, kind)
#     169                 return driver
#     170
# --> 171             raise RuntimeError("Neither firefox and geckodriver nor a variant of chromium browser and " \
#     172                                "chromedriver are available on system PATH. You can install the former " \
#     173                                "with 'conda install -c conda-forge firefox geckodriver'.")
#
# RuntimeError: Neither firefox and geckodriver nor a variant of chromium browser and chromedriver are available on system PATH. You can install the former with 'conda install -c conda-forge firefox geckodriver'.

# %% [markdown]
# ## Regular volcanos

# %%
from genepy.utils import helper as h
from genepy.utils import plot as genepyPlot
from genepy.rna import pyDESeq2
import genepy.rna as rna

# %% [markdown]
# #### IRF2BP2 3h

# %%
res_file = "../results/"+project+"/"+project+'_'+scaling+"_"+str(minvar_toremove)+'_'+str(mincount_toremove)+'_IRF2BP2_3h_deseq.csv'
resIRF2BP2_3h.to_csv(res_file)

print("Saved DESeq results to: {}".format(res_file))
# Out:
# Saved DESeq results to: ../results/IRF2BP2_degraded_YKL_v1/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5_IRF2BP2_3h_deseq.csv

# %%
resIRF2BP2_3h.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   5.019967       -0.556462  0.738811  0.753185  0.451339       NaN   NAT1
# 1  14.549214        0.315619  0.385422 -0.818892  0.412848  0.644171   AAMP
# 2  16.044563       -0.109872  0.395827  0.277577  0.781337  0.885655  AARS1
# 3   1.695828       -0.946852  1.260507  0.751167  0.452552       NaN   ABAT
# 4   6.332239       -0.439957  0.569045  0.773150  0.439434       NaN  ABCA1
#
#   gene_id
# 0    NAT1
# 1    AAMP
# 2   AARS1
# 3    ABAT
# 4   ABCA1

# %%
volcano_folder = "../results/{0}/plots/{0}_{1}_{2}_{3}".format(project, scaling, minvar_toremove, mincount_toremove)
print(volcano_folder)

genepyPlot.volcano(resIRF2BP2_3h, tohighlight=crc, searchbox=True, 
                   title='MV411 IRF2BP2 dTAG at 3h', 
                   folder=volcano_folder)
# Out:
# ../results/IRF2BP2_degraded_YKL_v1/plots/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5
# Attempting to save figure to ../results/IRF2BP2_degraded_YKL_v1/plots/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5_MV411_IRF2BP2_dTAG_at_3h_volcano.html
#   <div class="bk-root" id="bd546aa5-ff6a-44bc-9caf-179cd1954a6b" data-root-id="6969"></div>
# Column(id='6969', ...)

# %% [markdown]
# #### IRF2BP2 6h

# %%
res_file = "../results/"+project+"/"+project+'_'+scaling+"_"+str(minvar_toremove)+'_'+str(mincount_toremove)+'_IRF2BP2_6h_deseq.csv'
resIRF2BP2_6h.to_csv(res_file)

print("Saved DESeq results to: {}".format(res_file))
# Out:
# Saved DESeq results to: ../results/IRF2BP2_degraded_YKL_v1/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5_IRF2BP2_6h_deseq.csv

# %%
resIRF2BP2_6h.head()
# Out:
#     baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  genes  \
# 0   0.679474        1.835873  1.882485 -0.975239  0.329442  0.997053   NAT1
# 1   6.895730        0.117255  0.620358 -0.189013  0.850083  0.997053   AAMP
# 2  10.859066       -0.073534  0.523147  0.140560  0.888217  0.997053  AARS1
# 3   0.633716       -1.138852  2.091871  0.544418  0.586154  0.997053   ABAT
# 4   1.383080       -1.167510  1.382278  0.844627  0.398319  0.997053  ABCA1
#
#   gene_id
# 0    NAT1
# 1    AAMP
# 2   AARS1
# 3    ABAT
# 4   ABCA1

# %%
volcano_folder = "../results/{0}/plots/{0}_{1}_{2}_{3}".format(project, scaling, minvar_toremove, mincount_toremove)
#volcano_folder = '../results/'+project+'/plots/'+project+'_'+scaling+"_"+str(minvar_toremove)+'_'+str(mincount_toremove)
print(volcano_folder)

genepyPlot.volcano(resIRF2BP2_6h, tohighlight=crc, searchbox=True, 
                   title='MV411 IRF2BP2 dTAG at 6h', 
                   folder=volcano_folder)
# Out:
# ../results/IRF2BP2_degraded_YKL_v1/plots/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5
# Attempting to save figure to ../results/IRF2BP2_degraded_YKL_v1/plots/IRF2BP2_degraded_YKL_v1_ERCCsamplewise_0_5_MV411_IRF2BP2_dTAG_at_6h_volcano.html
#   <div class="bk-root" id="af7ef307-ece0-4445-95d7-62a54e82451a" data-root-id="6539"></div>
# Column(id='6539', ...)
